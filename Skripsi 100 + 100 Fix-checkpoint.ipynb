# %%
import pandas as pd 
import numpy as np
import string 
import re 
from nltk.tokenize import word_tokenize 
from nltk.probability import FreqDist
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

# %%
df = pd.read_excel('data_skripsiku.xlsx')

# %%
df
# Out:
#                     Time Sentiment  \
# 0    2023-02-11 15:32:42  Negative
# 1    2023-02-11 13:55:16  Positive
# 2    2023-02-11 06:55:16  Negative
# 3    2023-02-11 06:39:53  Positive
# 4    2023-02-11 03:29:26  Positive
# ...                  ...       ...
# 1582 2022-10-17 05:59:16  Positive
# 1583 2022-10-17 03:28:27  Negative
# 1584 2022-10-17 02:48:35  Positive
# 1585 2022-10-16 12:57:02  Negative
# 1586 2022-10-16 12:17:51  Positive
#
#                                                 Content  score  \
# 0                       Roboguru harus beli paket… why?      3
# 1                 Sangat membantu jaya terus ruang guru      5
# 2     Video nya ga bisa diputar, padahal udah diundu...      4
# 3                             Keren banget deh pokoknya      5
# 4                                                 bagus      5
# ...                                                 ...    ...
# 1582  Aplikasi nya bagus banget apa lagi belajar nya...      5
# 1583            Buruk sekali tidak ada mapel ushul fiqh      1
# 1584                   Bagussssssssssssss S s s s sss S      5
# 1585  Eror terus video nya ,nyesel gue Makai ruang guru      1
# 1586  Puasss bangatt bisa langsung paham,semoga ruan...      5
#
#      reviewCreatedVersion
# 0                  6.39.0
# 1                  6.52.0
# 2                  6.52.0
# 3                  6.52.0
# 4                  6.52.0
# ...                   ...
# 1582               6.45.1
# 1583               6.45.0
# 1584               6.45.0
# 1585                  NaN
# 1586               6.45.0
#
# [1587 rows x 5 columns]

# %%
df_skripsi = df.drop(['score','reviewCreatedVersion','Time'],axis = 1)

# %%
komennegatif= df_skripsi[df_skripsi['Sentiment'] == "Negative"]
komenpositif= df_skripsi[df_skripsi['Sentiment'] == "Positive"]

# %%
komennegatif100 = komennegatif.head(100)
komenpositif100 = komenpositif.head(100)

# %%
df_komen100 = komennegatif100.merge(komenpositif100 , how='outer')
df_komen100
# Out:
#     Sentiment                                            Content
# 0    Negative                    Roboguru harus beli paket… why?
# 1    Negative  Video nya ga bisa diputar, padahal udah diundu...
# 2    Negative  Aku punya keluhan terhadap link web atau xdari...
# 3    Negative  halo ka, kalo buat PC letak drill soal nya ada...
# 4    Negative                                    Maksa langganan
# ..        ...                                                ...
# 195  Positive  Aplikasi ini sangat membantu dalam hal belajar...
# 196  Positive  Aplikasi nya lengkap, bagus deh pokoknya kalau...
# 197  Positive                  Bagus bisa belajar sambil rebahan
# 198  Positive                              Sangat bagus dan seru
# 199  Positive                               pokoknya is the best
#
# [200 rows x 2 columns]

# %%
df_komen100.Sentiment.value_counts()
# Out:
# Negative    100
# Positive    100
# Name: Sentiment, dtype: int64

# %%
df_skripsi = df_komen100

# %%
df_skripsi.columns = ['label','text_real']

# %%
df_skripsi['text'] = df_skripsi.text_real

# %%
df_skripsi
# Out:
#         label                                          text_real  \
# 0    Negative                    Roboguru harus beli paket… why?
# 1    Negative  Video nya ga bisa diputar, padahal udah diundu...
# 2    Negative  Aku punya keluhan terhadap link web atau xdari...
# 3    Negative  halo ka, kalo buat PC letak drill soal nya ada...
# 4    Negative                                    Maksa langganan
# ..        ...                                                ...
# 195  Positive  Aplikasi ini sangat membantu dalam hal belajar...
# 196  Positive  Aplikasi nya lengkap, bagus deh pokoknya kalau...
# 197  Positive                  Bagus bisa belajar sambil rebahan
# 198  Positive                              Sangat bagus dan seru
# 199  Positive                               pokoknya is the best
#
#                                                   text
# 0                      Roboguru harus beli paket… why?
# 1    Video nya ga bisa diputar, padahal udah diundu...
# 2    Aku punya keluhan terhadap link web atau xdari...
# 3    halo ka, kalo buat PC letak drill soal nya ada...
# 4                                      Maksa langganan
# ..                                                 ...
# 195  Aplikasi ini sangat membantu dalam hal belajar...
# 196  Aplikasi nya lengkap, bagus deh pokoknya kalau...
# 197                  Bagus bisa belajar sambil rebahan
# 198                              Sangat bagus dan seru
# 199                               pokoknya is the best
#
# [200 rows x 3 columns]

# %%
df_skripsi['text'] = df_skripsi['text'].str.lower()
print('Case Folding Result : \n')
print(df_skripsi['text'].head(5))
print('\n\n\n')
# Out:
# Case Folding Result :
#
# 0                      roboguru harus beli paket… why?
# 1    video nya ga bisa diputar, padahal udah diundu...
# 2    aku punya keluhan terhadap link web atau xdari...
# 3    halo ka, kalo buat pc letak drill soal nya ada...
# 4                                      maksa langganan
# Name: text, dtype: object

# %%
def remove_text_special(text):
    # hapus tab, new line, ans back slice
    text = text.replace('\\t'," ").replace('\\n'," ").replace('\\u'," ").replace('\\',"")
    # hapus non ASCII (emot, bahasa china dll)
    text = text.encode('ascii', 'replace').decode('ascii')
    # hapus mention, link, hashtag
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)"," ", text).split())
    # remove URL 
    return text.replace("http://", " ").replace("https://", " ")
df_skripsi['text'] = df_skripsi.text.astype('str')                
df_skripsi['text'] = df_skripsi['text'].apply(remove_text_special)

# %%
#remove kata yang sengaja dipanjangkan
# seperti bisaaaaaaa -> bisa
def spell(word):
    if re.search(r'([a-zA-Z])\1{2,}', word):
        rword = re.sub(r'([a-zA-Z])\1{2,}','\\1', word)
        return rword
    else:
        return word
df_skripsi['text'] = df_skripsi['text'].apply(spell)

# %%
def remove_punctuation(text):
    return text.translate(str.maketrans("","",string.punctuation))

df_skripsi['text'] = df_skripsi['text'].apply(remove_punctuation)

df_skripsi
# Out:
#         label                                          text_real  \
# 0    Negative                    Roboguru harus beli paket… why?
# 1    Negative  Video nya ga bisa diputar, padahal udah diundu...
# 2    Negative  Aku punya keluhan terhadap link web atau xdari...
# 3    Negative  halo ka, kalo buat PC letak drill soal nya ada...
# 4    Negative                                    Maksa langganan
# ..        ...                                                ...
# 195  Positive  Aplikasi ini sangat membantu dalam hal belajar...
# 196  Positive  Aplikasi nya lengkap, bagus deh pokoknya kalau...
# 197  Positive                  Bagus bisa belajar sambil rebahan
# 198  Positive                              Sangat bagus dan seru
# 199  Positive                               pokoknya is the best
#
#                                                   text
# 0                        roboguru harus beli paket why
# 1      video nya ga bisa diputar padahal udah diunduh
# 2    aku punya keluhan terhadap link web atau xdari...
# 3    halo ka kalo buat pc letak drill soal nya ada ...
# 4                                      maksa langganan
# ..                                                 ...
# 195  aplikasi ini sangat membantu dalam hal belajar...
# 196  aplikasi nya lengkap bagus deh pokoknya kalau ...
# 197                  bagus bisa belajar sambil rebahan
# 198                              sangat bagus dan seru
# 199                               pokoknya is the best
#
# [200 rows x 3 columns]

# %%
#remove whitespace leading & trailing
def remove_whitespace_LT(text):
    return text.strip()

df_skripsi['text'] = df_skripsi['text'].apply(remove_whitespace_LT)

df_skripsi
# Out:
#         label                                          text_real  \
# 0    Negative                    Roboguru harus beli paket… why?
# 1    Negative  Video nya ga bisa diputar, padahal udah diundu...
# 2    Negative  Aku punya keluhan terhadap link web atau xdari...
# 3    Negative  halo ka, kalo buat PC letak drill soal nya ada...
# 4    Negative                                    Maksa langganan
# ..        ...                                                ...
# 195  Positive  Aplikasi ini sangat membantu dalam hal belajar...
# 196  Positive  Aplikasi nya lengkap, bagus deh pokoknya kalau...
# 197  Positive                  Bagus bisa belajar sambil rebahan
# 198  Positive                              Sangat bagus dan seru
# 199  Positive                               pokoknya is the best
#
#                                                   text
# 0                        roboguru harus beli paket why
# 1       video nya ga bisa diputar padahal udah diunduh
# 2    aku punya keluhan terhadap link web atau xdari...
# 3    halo ka kalo buat pc letak drill soal nya ada ...
# 4                                      maksa langganan
# ..                                                 ...
# 195  aplikasi ini sangat membantu dalam hal belajar...
# 196  aplikasi nya lengkap bagus deh pokoknya kalau ...
# 197                  bagus bisa belajar sambil rebahan
# 198                              sangat bagus dan seru
# 199                               pokoknya is the best
#
# [200 rows x 3 columns]

# %%
def remove_whitespace_multiple(text):
    return re.sub('\s+',' ',text)

df_skripsi['text'] = df_skripsi['text'].apply(remove_whitespace_multiple)

def remove_singl_char(text):
    return re.sub(r"\b[a-zA-Z]\b", "", text)

df_skripsi['text'] = df_skripsi['text'].apply(remove_singl_char)

df_skripsi
# Out:
#         label                                          text_real  \
# 0    Negative                    Roboguru harus beli paket… why?
# 1    Negative  Video nya ga bisa diputar, padahal udah diundu...
# 2    Negative  Aku punya keluhan terhadap link web atau xdari...
# 3    Negative  halo ka, kalo buat PC letak drill soal nya ada...
# 4    Negative                                    Maksa langganan
# ..        ...                                                ...
# 195  Positive  Aplikasi ini sangat membantu dalam hal belajar...
# 196  Positive  Aplikasi nya lengkap, bagus deh pokoknya kalau...
# 197  Positive                  Bagus bisa belajar sambil rebahan
# 198  Positive                              Sangat bagus dan seru
# 199  Positive                               pokoknya is the best
#
#                                                   text
# 0                        roboguru harus beli paket why
# 1       video nya ga bisa diputar padahal udah diunduh
# 2    aku punya keluhan terhadap link web atau xdari...
# 3    halo ka kalo buat pc letak drill soal nya ada ...
# 4                                      maksa langganan
# ..                                                 ...
# 195  aplikasi ini sangat membantu dalam hal belajar...
# 196  aplikasi nya lengkap bagus deh pokoknya kalau ...
# 197                  bagus bisa belajar sambil rebahan
# 198                              sangat bagus dan seru
# 199                               pokoknya is the best
#
# [200 rows x 3 columns]

# %%
df_skripsi = df_skripsi.drop_duplicates()
df_skripsi = df_skripsi[['label','text_real','text']]
df_skripsi['text'] = df_skripsi['text'].str.lower()

def word_tokenize_wrapper(text):
    return word_tokenize(text)

df_skripsi['text_tokens'] = df_skripsi['text'].apply(word_tokenize_wrapper)

# %%
df_skripsi
# Out:
#         label                                          text_real  \
# 0    Negative                    Roboguru harus beli paket… why?
# 1    Negative  Video nya ga bisa diputar, padahal udah diundu...
# 2    Negative  Aku punya keluhan terhadap link web atau xdari...
# 3    Negative  halo ka, kalo buat PC letak drill soal nya ada...
# 4    Negative                                    Maksa langganan
# ..        ...                                                ...
# 195  Positive  Aplikasi ini sangat membantu dalam hal belajar...
# 196  Positive  Aplikasi nya lengkap, bagus deh pokoknya kalau...
# 197  Positive                  Bagus bisa belajar sambil rebahan
# 198  Positive                              Sangat bagus dan seru
# 199  Positive                               pokoknya is the best
#
#                                                   text  \
# 0                        roboguru harus beli paket why
# 1       video nya ga bisa diputar padahal udah diunduh
# 2    aku punya keluhan terhadap link web atau xdari...
# 3    halo ka kalo buat pc letak drill soal nya ada ...
# 4                                      maksa langganan
# ..                                                 ...
# 195  aplikasi ini sangat membantu dalam hal belajar...
# 196  aplikasi nya lengkap bagus deh pokoknya kalau ...
# 197                  bagus bisa belajar sambil rebahan
# 198                              sangat bagus dan seru
# 199                               pokoknya is the best
#
#                                            text_tokens
# 0                  [roboguru, harus, beli, paket, why]
# 1    [video, nya, ga, bisa, diputar, padahal, udah,...
# 2    [aku, punya, keluhan, terhadap, link, web, ata...
# 3    [halo, ka, kalo, buat, pc, letak, drill, soal,...
# 4                                   [maksa, langganan]
# ..                                                 ...
# 195  [aplikasi, ini, sangat, membantu, dalam, hal, ...
# 196  [aplikasi, nya, lengkap, bagus, deh, pokoknya,...
# 197            [bagus, bisa, belajar, sambil, rebahan]
# 198                         [sangat, bagus, dan, seru]
# 199                          [pokoknya, is, the, best]
#
# [192 rows x 4 columns]

# %%
list_stopwords = stopwords.words('indonesian')
list_stopwords.extend(["yg", "dg", "rt", "dgn", "ny", "d", 'klo', 
                       'kalo', 'amp', 'biar', 'bikin', 'bilang', 
                       'gak', 'ga', 'krn', 'nya', 'nih', 'sih', 
                       'si', 'tau', 'tdk', 'tuh', 'utk', 'ya', 
                       'jd', 'jgn', 'sdh', 'aja', 'n', 't', 
                       'nyg', 'hehe', 'pen', 'u', 'nan', 'loh', 'rt',
                       '&amp', 'yah'])

txt_stopword = pd.read_csv("stopwords.txt", names= ["stopwords"], header = None)
list_stopwords.extend(txt_stopword["stopwords"][0].split(' '))
list_stopwords = set(list_stopwords)
def stopwords_removal(words):
    return [word for word in words if word not in list_stopwords]
df_skripsi['Stopwords'] = df_skripsi['text_tokens'].apply(stopwords_removal)

# %%
list_stopwords
# Out:
# {'',
#  'seenaknya',
#  'pun',
#  'setibanya',
#  'm',
#  'na',
#  'apabilah',
#  'tahun',
#  'tour',
#  'gimana',
#  'hal',
#  'tertentu',
#  'hih',
#  'kamilah',
#  'haahaaa',
#  'hadeh',
#  'reply',
#  'ooo',
#  'misal',
#  'noh',
#  'walau',
#  'lah',
#  'cukuplah',
#  'menginginkan',
#  'don',
#  'ada',
#  'janganlah',
#  'tuu',
#  'practice',
#  'hadech',
#  'yar',
#  'look',
#  'kena',
#  'sesampai',
#  'jugaa',
#  'ingin',
#  'asal',
#  'drpd',
#  'agree',
#  'kpd',
#  'mg',
#  'ngoahahahahahaaa',
#  'bgini',
#  'imb',
#  'manalagi',
#  'spya',
#  'si',
#  'nuh',
#  'di',
#  'selamanya',
#  'trus',
#  'cuma',
#  'memastikan',
#  'hadeeeeehhh',
#  'pentingnya',
#  'klu',
#  'nge',
#  'blom',
#  'ajj',
#  'toeeettt',
#  'haruslah',
#  'koe',
#  'yv',
#  'dipunyai',
#  'tsbt',
#  'jan',
#  'mula',
#  'makin',
#  'deee',
#  'sebutnya',
#  'loooh',
#  'keduanya',
#  'asyiiiiik',
#  'te',
#  'nder',
#  'wis',
#  'menanyakan',
#  'berkenaan',
#  'mengira',
#  'mai',
#  'tho',
#  'peri',
#  'sem',
#  'ping',
#  'ld',
#  'apalagi',
#  'ken',
#  'diakhiri',
#  'meskipun',
#  'acan',
#  'su',
#  'sekadar',
#  'lak',
#  'diberikannya',
#  'silakan',
#  'buat',
#  'sini',
#  'pre',
#  'cc',
#  'mulailah',
#  'bwa',
#  'jin',
#  't',
#  'bk',
#  'mempertanyakan',
#  'sayalah',
#  'maksud',
#  'bah',
#  'inilah',
#  'donk',
#  'apatah',
#  'mengapa',
#  'semasa',
#  'mengatakannya',
#  'will',
#  'peeeeetttt',
#  'march',
#  'wooiii',
#  'neg',
#  'terl',
#  'adoh',
#  'dpt',
#  'jadilah',
#  'wahaye',
#  'besar',
#  'seolah',
#  'naik',
#  'disebutkannya',
#  'terdapat',
#  'follow',
#  'diperkirakan',
#  'masalah',
#  'amat',
#  'sangat',
#  'se',
#  'ibarat',
#  'sama-sama',
#  'tuk',
#  'yokk',
#  'ahaaaaa',
#  'nguyu',
#  'apaapa',
#  'gem',
#  'karepmu',
#  'why',
#  'khususnya',
#  'asu',
#  'diingatkan',
#  'mi',
#  'preesss',
#  'going',
#  'ba',
#  'omg',
#  'u',
#  'turut',
#  'dikatakan',
#  'tiba-tiba',
#  'tunjuk',
#  'disinilah',
#  'diperlihatkan',
#  'terdahulu',
#  'diperbuat',
#  'antara',
#  'biyar',
#  'ai',
#  'jdi',
#  'masing-masing',
#  'kitalah',
#  'aernye',
#  'did',
#  'diingat',
#  'iki',
#  'ahh',
#  'tdak',
#  'bnyk',
#  'dgn',
#  'gak',
#  'suggest',
#  'woooy',
#  'terasa',
#  'astaghfrullah',
#  'sepantasnyalah',
#  'sdh',
#  'ngk',
#  'sal',
#  'tsb',
#  'jee',
#  'sendiri',
#  'terlihat',
#  'mw',
#  'hampir',
#  'siep',
#  'padanya',
#  'woii',
#  'theatre',
#  'fyi',
#  'antaranya',
#  'mau',
#  'astaga',
#  'orang',
#  'ta',
#  'kom',
#  'diperlukan',
#  'eiy',
#  'melainkan',
#  'dipergunakan',
#  'lho',
#  'uittt',
#  'keinginan',
#  'beg',
#  'dua',
#  'ww',
#  'yaelah',
#  'mungkin',
#  'jleb',
#  'th',
#  'neng',
#  'sesuatu',
#  'disini',
#  'selalu',
#  'memba',
#  'wonderfull',
#  'sec',
#  'tandasnya',
#  'macam',
#  'nang',
#  'update',
#  'from',
#  'jumlahnya',
#  'apabila',
#  'tetapi',
#  'hallo',
#  'per',
#  'ka',
#  'vs',
#  'apas',
#  'krn',
#  'ahhhh',
#  'ksi',
#  'org',
#  'kala',
#  'kak',
#  'sebagainya',
#  'bwt',
#  'ts',
#  'dibuatnya',
#  'lain',
#  'setidaknya',
#  'yan',
#  'bisa',
#  'kepada',
#  'belum',
#  'pertanyakan',
#  'berawal',
#  'bagaimanapun',
#  'skrg',
#  'aplagi',
#  'wooiiii',
#  'mon',
#  'sebaliknya',
#  'disebutkan',
#  'kurang',
#  'iya',
#  'memang',
#  'nie',
#  'gt',
#  'on',
#  'tegas',
#  'bermacam',
#  'bas',
#  'gass',
#  'saat',
#  'tidakkah',
#  'qckog',
#  'astaghfirullah',
#  'sebenarnya',
#  'keluar',
#  'kini',
#  'sich',
#  'wh',
#  'ehh',
#  'assuuu',
#  'mengakhiri',
#  'sebagai',
#  'diar',
#  'cokkk',
#  'berupa',
#  'where',
#  'udah',
#  'keterlaluan',
#  'sudahkah',
#  'road',
#  'menyatakan',
#  'sejenak',
#  'ucapnya',
#  'kagak',
#  'dimungkinkan',
#  'pernah',
#  'secukupnya',
#  'sekalipun',
#  'pis',
#  'dialah',
#  'ataukah',
#  'dikarenakan',
#  'berturut-turut',
#  'terjadinya',
#  'peesai',
#  'segera',
#  'ret',
#  'minta',
#  'lahh',
#  'memerlukan',
#  'j',
#  'ibaratnya',
#  'stand',
#  'sekali-kali',
#  'akh',
#  'bawah',
#  'berapalah',
#  'gin',
#  'leb',
#  'dahhh',
#  'sbg',
#  'teh',
#  'sebuah',
#  'begini',
#  'aduhh',
#  'are',
#  'kenapa',
#  'ndase',
#  'gar',
#  'sebaik',
#  'mengucapkannya',
#  'tri',
#  'tentulah',
#  'hilihhh',
#  'aseekkk',
#  'sang',
#  'jdkn',
#  'tiap',
#  'sh',
#  'am',
#  'mengibaratkan',
#  'jgn',
#  'asek',
#  'ingat-ingat',
#  'tar',
#  'asseeekkkk',
#  'mbh',
#  'tiga',
#  'hk',
#  'ros',
#  'cukup',
#  'laah',
#  'gw',
#  'blo',
#  'beib',
#  'dar',
#  'kem',
#  'seseorang',
#  'tr',
#  'memberi',
#  'laelah',
#  'co',
#  'sampaikan',
#  'good',
#  'untuk',
#  'terbanyak',
#  'braderrr',
#  'dimulai',
#  'oo',
#  'r',
#  'rasa',
#  'ol',
#  'dituturkan',
#  'empat',
#  'wal',
#  'aj',
#  'tela',
#  'selama-lamanya',
#  'bikin',
#  'memperba',
#  'memberikan',
#  'dilihat',
#  'sih',
#  'lohhhh',
#  'thd',
#  'sesegera',
#  'dapat',
#  'sendirian',
#  'ntuh',
#  'kpn',
#  'enak',
#  'menjawab',
#  'heeeeellloooo',
#  'seorang',
#  'usah',
#  'elah',
#  'mend',
#  'apa',
#  'sinilah',
#  'ucap',
#  'nyg',
#  'adapun',
#  'jg',
#  'cie',
#  'gig',
#  'hiikksss',
#  'yaaa',
#  'kadar',
#  'sana',
#  'biup',
#  'siap',
#  'ah',
#  'asa',
#  'ten',
#  'pantas',
#  'lahhh',
#  'asyiapp',
#  'rit',
#  'ser',
#  'misalkan',
#  'cukupkah',
#  'death',
#  'dll',
#  'aka',
#  'tampaknya',
#  'me',
#  'anca',
#  'diperlukannya',
#  'inginkan',
#  'aseekk',
#  'bant',
#  'mengatakan',
#  'menanya',
#  'aga',
#  'alu',
#  'jangn',
#  'dust',
#  'asyik',
#  'ho',
#  'merekalah',
#  'gih',
#  'asiiik',
#  'lwt',
#  'semisal',
#  'sedemikian',
#  'toet',
#  'ee',
#  'akulah',
#  'duh',
#  'sebanyak',
#  'gn',
#  'sementara',
#  'tapi',
#  'khan',
#  'kita',
#  'lagian',
#  'halo',
#  'ia',
#  'seingat',
#  'jngn',
#  'dimaksudnya',
#  'bagainamakah',
#  'bermula',
#  'dr',
#  'woyyyyyy',
#  'itukah',
#  'sesaat',
#  'ayyy',
#  'un',
#  'tragedy',
#  'menyangkut',
#  'ci',
#  'melalui',
#  'hehehe',
#  'terdiri',
#  'wuiiih',
#  'katakanlah',
#  'diinginkan',
#  'akse',
#  'diantaranya',
#  'yg',
#  'sesudah',
#  'sada',
#  'keri',
#  'neh',
#  'tuju',
#  'lc',
#  'ggu',
#  'wa',
#  'broo',
#  'jiah',
#  'mahl',
#  'semacam',
#  'dengan',
#  'eihh',
#  'sekitarnya',
#  'yaah',
#  'kamulah',
#  'menambahkan',
#  'dikira',
#  'jelasnya',
#  'ajaah',
#  'beer',
#  'sebisanya',
#  'mksh',
#  'ji',
#  'menuju',
#  'men',
#  'saya',
#  'mas',
#  'seolah-olah',
#  'tegasnya',
#  'mes',
#  'jika',
#  'emng',
#  'wadoooohhh',
#  'akhir',
#  'aph',
#  'backstreet',
#  'ind',
#  'bahwasannya',
#  'dink',
#  'menunjuk',
#  'sedang',
#  'yng',
#  'astagaaaahhh',
#  'g',
#  'boys',
#  'tambah',
#  'sblm',
#  'aiiihhh',
#  'kemungkinan',
#  'selaku',
#  'pak',
#  'pukul',
#  'sedangkan',
#  'hadeuh',
#  'setinggi',
#  'teringat-ingat',
#  'pasti',
#  'mana',
#  'blenggg',
#  'diungkapkan',
#  'nanti',
#  'sosi',
#  'thread',
#  'satu',
#  'seluruh',
#  'semampunya',
#  'ini',
#  'tok',
#  'bermacam-macam',
#  'kedua',
#  'kemudian',
#  'zzzzzz',
#  'bulan',
#  'aaah',
#  'twe',
#  'bertanya',
#  'cam',
#  'sejak',
#  'mampu',
#  'ra',
#  'he',
#  'aja',
#  'berakhirnya',
#  'al',
#  'karenanya',
#  'vi',
#  'tuh',
#  'tuturnya',
#  'mampukah',
#  'bersama-sama',
#  'mel',
#  'ju',
#  'bahahaha',
#  'gedhe',
#  'atr',
#  'c',
#  'jawab',
#  'mempergunakan',
#  'dibuat',
#  'jagan',
#  'katakan',
#  'yee',
#  'haduh',
#  'no',
#  'pen',
#  'kelamaan',
#  'panjang',
#  'hai',
#  'sak',
#  'pem',
#  'wow',
#  'kamu',
#  'aah',
#  'menanti',
#  'diibaratkannya',
#  'spt',
#  'bermaksud',
#  'abc',
#  'loh',
#  'ajib',
#  'semuanya',
#  'please',
#  'mempersoalkan',
#  'selain',
#  'yakali',
#  'alhamdulillah',
#  'dn',
#  'coz',
#  'menyebutkan',
#  'kua',
#  'tutur',
#  'mwnyedihkan',
#  'asn',
#  'kelima',
#  'apalgi',
#  'ti',
#  'ssst',
#  'lewat',
#  'yaa',
#  'ditunjuknya',
#  'juga',
#  'ahool',
#  'berarti',
#  'the',
#  'waahh',
#  'hny',
#  'akhirx',
#  'kelihatan',
#  'dimaksudkan',
#  'deng',
#  'kl',
#  'adanya',
#  'langsung',
#  'pt',
#  'menjelaskan',
#  'cuihhhh',
#  'beginilah',
#  'waktunya',
#  'nya',
#  'ealah',
#  'ih',
#  'baaeerrree',
#  'berbagai',
#  'aig',
#  'merupakan',
#  'ter',
#  'wuuuu',
#  'world',
#  'kapan',
#  'malah',
#  'uhuii',
#  'menyampaikan',
#  'tandas',
#  'berturut',
#  'meski',
#  'aeeee',
#  'fa',
#  'piye',
#  'terakhir',
#  'waduuuhhhh',
#  'ahelah',
#  'bs',
#  'ntup',
#  'berlangsung',
#  'harus',
#  'anta',
#  'lanjut',
#  'sory',
#  'agak',
#  'huh',
#  'saatnya',
#  'care',
#  'may',
#  'aplg',
#  'umum',
#  'mengingat',
#  'penting',
#  'b',
#  'ntap',
#  'tanyakan',
#  'koit',
#  'mm',
#  'belakang',
#  'dimisalkan',
#  'jangan',
#  'ditanya',
#  'mp',
#  'melihatnya',
#  'mengibaratkannya',
#  'asiiikkk',
#  'hari',
#  'paling',
#  'gug',
#  'berikut',
#  'kam',
#  'cik',
#  'tepat',
#  'jengn',
#  'menyeluruh',
#  'tt',
#  'coy',
#  'akhirnya',
#  'ki',
#  'kor',
#  'sek',
#  'dg',
#  'andalah',
#  'i',
#  'dilakukan',
#  'wkwkw',
#  'woooyyyyy',
#  'diminta',
#  'po',
#  'mendatangi',
#  'benarlah',
#  'berikutnya',
#  'dipertanyakan',
#  'aud',
#  'persoalan',
#  'kwak',
#  'o',
#  'ss',
#  'bain',
#  'bung',
#  'kesampaian',
#  'syi',
#  'sebesar',
#  'mohon',
#  'hmmm',
#  '&amp',
#  'atas',
#  'gitulah',
#  'waaahh',
#  'semasih',
#  'dlu',
#  'np',
#  'seusai',
#  'hadeehhh',
#  'ot',
#  'amp',
#  'ntu',
#  'bolehkah',
#  'aseeekkk',
#  'umumnya',
#  'dalam',
#  'diberi',
#  'cuy',
#  'salam',
#  'alah',
#  'rupa',
#  'hadap',
#  'yes',
#  'pada',
#  'sekaligus',
#  'what',
#  'terlalu',
#  'dil',
#  'sedikit',
#  'sekurang-kurangnya',
#  'usai',
#  'dimaksudkannya',
#  'wkwkwk',
#  'tadi',
#  'menggunakan',
#  'hend',
#  'jadinya',
#  'ben',
#  'de',
#  'utk',
#  'perlu',
#  'q',
#  'kinilah',
#  'to',
#  'wooyy',
#  'nk',
#  'berkali-kali',
#  'pek',
#  'tempat',
#  'menandaskan',
#  'aduch',
#  'apabl',
#  'siapa',
#  'ntr',
#  'arti',
#  'yoiii',
#  'berlebihan',
#  'mengingatkan',
#  'menyer',
#  'sul',
#  'joosss',
#  'sebagian',
#  'kalian',
#  'sekurangnya',
#  'awalnya',
#  'sambil',
#  'aaaakkkhhhhhh',
#  'bukanlah',
#  'diucapkan',
#  'rasanya',
#  'ditunjukkannya',
#  'setiap',
#  'mah',
#  'eeh',
#  'bgt',
#  'beri',
#  'za',
#  'berakhir',
#  'kira-kira',
#  'mantaaapp',
#  'uhmmm',
#  'pp',
#  'wi',
#  'yups',
#  'lo',
#  'dwatkn',
#  'ieu',
#  'twit',
#  'pasi',
#  'bila',
#  'peke',
#  'diibaratkan',
#  'masa',
#  'min',
#  'bersama',
#  'piyek',
#  'tur',
#  'uppppsss',
#  'apasih',
#  'er',
#  'baru',
#  'bai',
#  'berlainan',
#  'bagi',
#  'juaraaa',
#  'mb',
#  'kerna',
#  'pertanyaan',
#  'duhh',
#  'mem',
#  'keseluruhannya',
#  'tuit',
#  'sehingga',
#  'setiba',
#  'ajjaaa',
#  'bat',
#  'tir',
#  'fya',
#  'menaiki',
#  'mba',
#  'ay',
#  'ditandaskan',
#  'berujar',
#  'gaess',
#  'lum',
#  'dipastikan',
#  'd',
#  'setengah',
#  'kasus',
#  'gpp',
#  'hhh',
#  'terutama',
#  'kayak',
#  'keseluruhan',
#  'bageb',
#  'inginkah',
#  'itu',
#  'bisn',
#  'semula',
#  'yupsss',
#  'wid',
#  'sendirinya',
#  'sekarang',
#  'lagi',
#  'dng',
#  'berikan',
#  'disebut',
#  'e',
#  'kapankah',
#  'prop',
#  'ea',
#  'apakh',
#  'akubingin',
#  'benarkah',
#  'always',
#  'cuih',
#  'ashes',
#  'bagaimanakah',
#  'woy',
#  'sekiranya',
#  'dila',
#  'byk',
#  'ailapyupul',
#  'tadinya',
#  'bena',
#  'yeee',
#  'sekadarnya',
#  'siapapun',
#  'kali',
#  'mistakes',
#  'sewaktu',
#  'josss',
#  'bagaikan',
#  'sebelumnya',
#  'yakin',
#  'alangkah',
#  'db',
#  'walaupun',
#  'is',
#  'ting',
#  'it',
#  'yuk',
#  'akan',
#  'kannnn',
#  'udahan',
#  'deh',
#  'in',
#  'yup',
#  'dilalui',
#  'dikatakannya',
#  'menurut',
#  'kudu',
#  'ing',
#  'l',
#  'du',
#  'dia',
#  'seng',
#  'ya',
#  'olehnya',
#  'rata',
#  'atau',
#  'his',
#  'bapak',
#  'astagaaaaa',
#  'oleh',
#  'soalnya',
#  'bahahak',
#  'eng',
#  'ntar',
#  'var',
#  'wkwaww',
#  'pohonnnn',
#  'n',
#  'kok',
#  'bagai',
#  'fl',
#  'wouy',
#  'kes',
#  'sib',
#  'tampak',
#  'sebegitu',
#  'tinggi',
#  'menanyai',
#  'luar',
#  'yakni',
#  'jah',
#  'or',
#  'asik',
#  'betul',
#  'kuk',
#  'nii',
#  'disampaikan',
#  'kwkwk',
#  'ditanyakan',
#  'enggaknya',
#  'y',
#  'jauh',
#  'sssst',
#  'ketika',
#  'serupa',
#  'lainnya',
#  'ujar',
#  'sebaiknya',
#  'jawaban',
#  'sama',
#  'tetap',
#  'diperbuatnya',
#  'wih',
#  'oiya',
#  'ditunjuki',
#  'kapanpun',
#  'nyata',
#  'pin',
#  'inikah',
#  'tik',
#  'you',
#  'ujarnya',
#  'dong',
#  'v',
#  'sekaranglah',
#  'dijawab',
#  'yukk',
#  'masing',
#  'akutuh',
#  'tuip',
#  'tw',
#  ...}

# %%
df_skripsi
# Out:
#         label                                          text_real  \
# 0    Negative                    Roboguru harus beli paket… why?
# 1    Negative  Video nya ga bisa diputar, padahal udah diundu...
# 2    Negative  Aku punya keluhan terhadap link web atau xdari...
# 3    Negative  halo ka, kalo buat PC letak drill soal nya ada...
# 4    Negative                                    Maksa langganan
# ..        ...                                                ...
# 195  Positive  Aplikasi ini sangat membantu dalam hal belajar...
# 196  Positive  Aplikasi nya lengkap, bagus deh pokoknya kalau...
# 197  Positive                  Bagus bisa belajar sambil rebahan
# 198  Positive                              Sangat bagus dan seru
# 199  Positive                               pokoknya is the best
#
#                                                   text  \
# 0                        roboguru harus beli paket why
# 1       video nya ga bisa diputar padahal udah diunduh
# 2    aku punya keluhan terhadap link web atau xdari...
# 3    halo ka kalo buat pc letak drill soal nya ada ...
# 4                                      maksa langganan
# ..                                                 ...
# 195  aplikasi ini sangat membantu dalam hal belajar...
# 196  aplikasi nya lengkap bagus deh pokoknya kalau ...
# 197                  bagus bisa belajar sambil rebahan
# 198                              sangat bagus dan seru
# 199                               pokoknya is the best
#
#                                            text_tokens  \
# 0                  [roboguru, harus, beli, paket, why]
# 1    [video, nya, ga, bisa, diputar, padahal, udah,...
# 2    [aku, punya, keluhan, terhadap, link, web, ata...
# 3    [halo, ka, kalo, buat, pc, letak, drill, soal,...
# 4                                   [maksa, langganan]
# ..                                                 ...
# 195  [aplikasi, ini, sangat, membantu, dalam, hal, ...
# 196  [aplikasi, nya, lengkap, bagus, deh, pokoknya,...
# 197            [bagus, bisa, belajar, sambil, rebahan]
# 198                         [sangat, bagus, dan, seru]
# 199                          [pokoknya, is, the, best]
#
#                                              Stopwords
# 0                              [roboguru, beli, paket]
# 1                            [video, diputar, diunduh]
# 2    [keluhan, link, web, xdari, notifikasi, ruangg...
# 3                                   [pc, letak, drill]
# 4                                   [maksa, langganan]
# ..                                                 ...
# 195  [aplikasi, membantu, belajarsaya, siswa, kelas...
# 196  [aplikasi, lengkap, bagus, pokoknya, dipakai, ...
# 197                          [bagus, belajar, rebahan]
# 198                                      [bagus, seru]
# 199                                   [pokoknya, best]
#
# [192 rows x 5 columns]

# %%
def freqDist_wrapper(text):
    return FreqDist(text)

df_skripsi['text_tokens_fdist'] = df_skripsi['text_tokens'].apply(freqDist_wrapper)

print('Frequency Tokens : \n') 
print(df_skripsi['text_tokens_fdist'].head().apply(lambda x : x.most_common()))
# Out:
# Frequency Tokens :
#
# 0    [(roboguru, 1), (harus, 1), (beli, 1), (paket,...
# 1    [(video, 1), (nya, 1), (ga, 1), (bisa, 1), (di...
# 2    [(di, 4), (yang, 3), (aku, 2), (ruangguru, 2),...
# 3    [(halo, 1), (ka, 1), (kalo, 1), (buat, 1), (pc...
# 4                         [(maksa, 1), (langganan, 1)]
# Name: text_tokens_fdist, dtype: object

# %%
from nltk.corpus import stopwords

# %%
list_stopwords = stopwords.words('indonesian')

# %%
list_stopwords
# Out:
# ['ada',
#  'adalah',
#  'adanya',
#  'adapun',
#  'agak',
#  'agaknya',
#  'agar',
#  'akan',
#  'akankah',
#  'akhir',
#  'akhiri',
#  'akhirnya',
#  'aku',
#  'akulah',
#  'amat',
#  'amatlah',
#  'anda',
#  'andalah',
#  'antar',
#  'antara',
#  'antaranya',
#  'apa',
#  'apaan',
#  'apabila',
#  'apakah',
#  'apalagi',
#  'apatah',
#  'artinya',
#  'asal',
#  'asalkan',
#  'atas',
#  'atau',
#  'ataukah',
#  'ataupun',
#  'awal',
#  'awalnya',
#  'bagai',
#  'bagaikan',
#  'bagaimana',
#  'bagaimanakah',
#  'bagaimanapun',
#  'bagi',
#  'bagian',
#  'bahkan',
#  'bahwa',
#  'bahwasanya',
#  'baik',
#  'bakal',
#  'bakalan',
#  'balik',
#  'banyak',
#  'bapak',
#  'baru',
#  'bawah',
#  'beberapa',
#  'begini',
#  'beginian',
#  'beginikah',
#  'beginilah',
#  'begitu',
#  'begitukah',
#  'begitulah',
#  'begitupun',
#  'bekerja',
#  'belakang',
#  'belakangan',
#  'belum',
#  'belumlah',
#  'benar',
#  'benarkah',
#  'benarlah',
#  'berada',
#  'berakhir',
#  'berakhirlah',
#  'berakhirnya',
#  'berapa',
#  'berapakah',
#  'berapalah',
#  'berapapun',
#  'berarti',
#  'berawal',
#  'berbagai',
#  'berdatangan',
#  'beri',
#  'berikan',
#  'berikut',
#  'berikutnya',
#  'berjumlah',
#  'berkali-kali',
#  'berkata',
#  'berkehendak',
#  'berkeinginan',
#  'berkenaan',
#  'berlainan',
#  'berlalu',
#  'berlangsung',
#  'berlebihan',
#  'bermacam',
#  'bermacam-macam',
#  'bermaksud',
#  'bermula',
#  'bersama',
#  'bersama-sama',
#  'bersiap',
#  'bersiap-siap',
#  'bertanya',
#  'bertanya-tanya',
#  'berturut',
#  'berturut-turut',
#  'bertutur',
#  'berujar',
#  'berupa',
#  'besar',
#  'betul',
#  'betulkah',
#  'biasa',
#  'biasanya',
#  'bila',
#  'bilakah',
#  'bisa',
#  'bisakah',
#  'boleh',
#  'bolehkah',
#  'bolehlah',
#  'buat',
#  'bukan',
#  'bukankah',
#  'bukanlah',
#  'bukannya',
#  'bulan',
#  'bung',
#  'cara',
#  'caranya',
#  'cukup',
#  'cukupkah',
#  'cukuplah',
#  'cuma',
#  'dahulu',
#  'dalam',
#  'dan',
#  'dapat',
#  'dari',
#  'daripada',
#  'datang',
#  'dekat',
#  'demi',
#  'demikian',
#  'demikianlah',
#  'dengan',
#  'depan',
#  'di',
#  'dia',
#  'diakhiri',
#  'diakhirinya',
#  'dialah',
#  'diantara',
#  'diantaranya',
#  'diberi',
#  'diberikan',
#  'diberikannya',
#  'dibuat',
#  'dibuatnya',
#  'didapat',
#  'didatangkan',
#  'digunakan',
#  'diibaratkan',
#  'diibaratkannya',
#  'diingat',
#  'diingatkan',
#  'diinginkan',
#  'dijawab',
#  'dijelaskan',
#  'dijelaskannya',
#  'dikarenakan',
#  'dikatakan',
#  'dikatakannya',
#  'dikerjakan',
#  'diketahui',
#  'diketahuinya',
#  'dikira',
#  'dilakukan',
#  'dilalui',
#  'dilihat',
#  'dimaksud',
#  'dimaksudkan',
#  'dimaksudkannya',
#  'dimaksudnya',
#  'diminta',
#  'dimintai',
#  'dimisalkan',
#  'dimulai',
#  'dimulailah',
#  'dimulainya',
#  'dimungkinkan',
#  'dini',
#  'dipastikan',
#  'diperbuat',
#  'diperbuatnya',
#  'dipergunakan',
#  'diperkirakan',
#  'diperlihatkan',
#  'diperlukan',
#  'diperlukannya',
#  'dipersoalkan',
#  'dipertanyakan',
#  'dipunyai',
#  'diri',
#  'dirinya',
#  'disampaikan',
#  'disebut',
#  'disebutkan',
#  'disebutkannya',
#  'disini',
#  'disinilah',
#  'ditambahkan',
#  'ditandaskan',
#  'ditanya',
#  'ditanyai',
#  'ditanyakan',
#  'ditegaskan',
#  'ditujukan',
#  'ditunjuk',
#  'ditunjuki',
#  'ditunjukkan',
#  'ditunjukkannya',
#  'ditunjuknya',
#  'dituturkan',
#  'dituturkannya',
#  'diucapkan',
#  'diucapkannya',
#  'diungkapkan',
#  'dong',
#  'dua',
#  'dulu',
#  'empat',
#  'enggak',
#  'enggaknya',
#  'entah',
#  'entahlah',
#  'guna',
#  'gunakan',
#  'hal',
#  'hampir',
#  'hanya',
#  'hanyalah',
#  'hari',
#  'harus',
#  'haruslah',
#  'harusnya',
#  'hendak',
#  'hendaklah',
#  'hendaknya',
#  'hingga',
#  'ia',
#  'ialah',
#  'ibarat',
#  'ibaratkan',
#  'ibaratnya',
#  'ibu',
#  'ikut',
#  'ingat',
#  'ingat-ingat',
#  'ingin',
#  'inginkah',
#  'inginkan',
#  'ini',
#  'inikah',
#  'inilah',
#  'itu',
#  'itukah',
#  'itulah',
#  'jadi',
#  'jadilah',
#  'jadinya',
#  'jangan',
#  'jangankan',
#  'janganlah',
#  'jauh',
#  'jawab',
#  'jawaban',
#  'jawabnya',
#  'jelas',
#  'jelaskan',
#  'jelaslah',
#  'jelasnya',
#  'jika',
#  'jikalau',
#  'juga',
#  'jumlah',
#  'jumlahnya',
#  'justru',
#  'kala',
#  'kalau',
#  'kalaulah',
#  'kalaupun',
#  'kalian',
#  'kami',
#  'kamilah',
#  'kamu',
#  'kamulah',
#  'kan',
#  'kapan',
#  'kapankah',
#  'kapanpun',
#  'karena',
#  'karenanya',
#  'kasus',
#  'kata',
#  'katakan',
#  'katakanlah',
#  'katanya',
#  'ke',
#  'keadaan',
#  'kebetulan',
#  'kecil',
#  'kedua',
#  'keduanya',
#  'keinginan',
#  'kelamaan',
#  'kelihatan',
#  'kelihatannya',
#  'kelima',
#  'keluar',
#  'kembali',
#  'kemudian',
#  'kemungkinan',
#  'kemungkinannya',
#  'kenapa',
#  'kepada',
#  'kepadanya',
#  'kesampaian',
#  'keseluruhan',
#  'keseluruhannya',
#  'keterlaluan',
#  'ketika',
#  'khususnya',
#  'kini',
#  'kinilah',
#  'kira',
#  'kira-kira',
#  'kiranya',
#  'kita',
#  'kitalah',
#  'kok',
#  'kurang',
#  'lagi',
#  'lagian',
#  'lah',
#  'lain',
#  'lainnya',
#  'lalu',
#  'lama',
#  'lamanya',
#  'lanjut',
#  'lanjutnya',
#  'lebih',
#  'lewat',
#  'lima',
#  'luar',
#  'macam',
#  'maka',
#  'makanya',
#  'makin',
#  'malah',
#  'malahan',
#  'mampu',
#  'mampukah',
#  'mana',
#  'manakala',
#  'manalagi',
#  'masa',
#  'masalah',
#  'masalahnya',
#  'masih',
#  'masihkah',
#  'masing',
#  'masing-masing',
#  'mau',
#  'maupun',
#  'melainkan',
#  'melakukan',
#  'melalui',
#  'melihat',
#  'melihatnya',
#  'memang',
#  'memastikan',
#  'memberi',
#  'memberikan',
#  'membuat',
#  'memerlukan',
#  'memihak',
#  'meminta',
#  'memintakan',
#  'memisalkan',
#  'memperbuat',
#  'mempergunakan',
#  'memperkirakan',
#  'memperlihatkan',
#  'mempersiapkan',
#  'mempersoalkan',
#  'mempertanyakan',
#  'mempunyai',
#  'memulai',
#  'memungkinkan',
#  'menaiki',
#  'menambahkan',
#  'menandaskan',
#  'menanti',
#  'menanti-nanti',
#  'menantikan',
#  'menanya',
#  'menanyai',
#  'menanyakan',
#  'mendapat',
#  'mendapatkan',
#  'mendatang',
#  'mendatangi',
#  'mendatangkan',
#  'menegaskan',
#  'mengakhiri',
#  'mengapa',
#  'mengatakan',
#  'mengatakannya',
#  'mengenai',
#  'mengerjakan',
#  'mengetahui',
#  'menggunakan',
#  'menghendaki',
#  'mengibaratkan',
#  'mengibaratkannya',
#  'mengingat',
#  'mengingatkan',
#  'menginginkan',
#  'mengira',
#  'mengucapkan',
#  'mengucapkannya',
#  'mengungkapkan',
#  'menjadi',
#  'menjawab',
#  'menjelaskan',
#  'menuju',
#  'menunjuk',
#  'menunjuki',
#  'menunjukkan',
#  'menunjuknya',
#  'menurut',
#  'menuturkan',
#  'menyampaikan',
#  'menyangkut',
#  'menyatakan',
#  'menyebutkan',
#  'menyeluruh',
#  'menyiapkan',
#  'merasa',
#  'mereka',
#  'merekalah',
#  'merupakan',
#  'meski',
#  'meskipun',
#  'meyakini',
#  'meyakinkan',
#  'minta',
#  'mirip',
#  'misal',
#  'misalkan',
#  'misalnya',
#  'mula',
#  'mulai',
#  'mulailah',
#  'mulanya',
#  'mungkin',
#  'mungkinkah',
#  'nah',
#  'naik',
#  'namun',
#  'nanti',
#  'nantinya',
#  'nyaris',
#  'nyatanya',
#  'oleh',
#  'olehnya',
#  'pada',
#  'padahal',
#  'padanya',
#  'pak',
#  'paling',
#  'panjang',
#  'pantas',
#  'para',
#  'pasti',
#  'pastilah',
#  'penting',
#  'pentingnya',
#  'per',
#  'percuma',
#  'perlu',
#  'perlukah',
#  'perlunya',
#  'pernah',
#  'persoalan',
#  'pertama',
#  'pertama-tama',
#  'pertanyaan',
#  'pertanyakan',
#  'pihak',
#  'pihaknya',
#  'pukul',
#  'pula',
#  'pun',
#  'punya',
#  'rasa',
#  'rasanya',
#  'rata',
#  'rupanya',
#  'saat',
#  'saatnya',
#  'saja',
#  'sajalah',
#  'saling',
#  'sama',
#  'sama-sama',
#  'sambil',
#  'sampai',
#  'sampai-sampai',
#  'sampaikan',
#  'sana',
#  'sangat',
#  'sangatlah',
#  'satu',
#  'saya',
#  'sayalah',
#  'se',
#  'sebab',
#  'sebabnya',
#  'sebagai',
#  'sebagaimana',
#  'sebagainya',
#  'sebagian',
#  'sebaik',
#  'sebaik-baiknya',
#  'sebaiknya',
#  'sebaliknya',
#  'sebanyak',
#  'sebegini',
#  'sebegitu',
#  'sebelum',
#  'sebelumnya',
#  'sebenarnya',
#  'seberapa',
#  'sebesar',
#  'sebetulnya',
#  'sebisanya',
#  'sebuah',
#  'sebut',
#  'sebutlah',
#  'sebutnya',
#  'secara',
#  'secukupnya',
#  'sedang',
#  'sedangkan',
#  'sedemikian',
#  'sedikit',
#  'sedikitnya',
#  'seenaknya',
#  'segala',
#  'segalanya',
#  'segera',
#  'seharusnya',
#  'sehingga',
#  'seingat',
#  'sejak',
#  'sejauh',
#  'sejenak',
#  'sejumlah',
#  'sekadar',
#  'sekadarnya',
#  'sekali',
#  'sekali-kali',
#  'sekalian',
#  'sekaligus',
#  'sekalipun',
#  'sekarang',
#  'sekarang',
#  'sekecil',
#  'seketika',
#  'sekiranya',
#  'sekitar',
#  'sekitarnya',
#  'sekurang-kurangnya',
#  'sekurangnya',
#  'sela',
#  'selain',
#  'selaku',
#  'selalu',
#  'selama',
#  'selama-lamanya',
#  'selamanya',
#  'selanjutnya',
#  'seluruh',
#  'seluruhnya',
#  'semacam',
#  'semakin',
#  'semampu',
#  'semampunya',
#  'semasa',
#  'semasih',
#  'semata',
#  'semata-mata',
#  'semaunya',
#  'sementara',
#  'semisal',
#  'semisalnya',
#  'sempat',
#  'semua',
#  'semuanya',
#  'semula',
#  'sendiri',
#  'sendirian',
#  'sendirinya',
#  'seolah',
#  'seolah-olah',
#  'seorang',
#  'sepanjang',
#  'sepantasnya',
#  'sepantasnyalah',
#  'seperlunya',
#  'seperti',
#  'sepertinya',
#  'sepihak',
#  'sering',
#  'seringnya',
#  'serta',
#  'serupa',
#  'sesaat',
#  'sesama',
#  'sesampai',
#  'sesegera',
#  'sesekali',
#  'seseorang',
#  'sesuatu',
#  'sesuatunya',
#  'sesudah',
#  'sesudahnya',
#  'setelah',
#  'setempat',
#  'setengah',
#  'seterusnya',
#  'setiap',
#  'setiba',
#  'setibanya',
#  'setidak-tidaknya',
#  'setidaknya',
#  'setinggi',
#  'seusai',
#  'sewaktu',
#  'siap',
#  'siapa',
#  'siapakah',
#  'siapapun',
#  'sini',
#  'sinilah',
#  'soal',
#  'soalnya',
#  'suatu',
#  'sudah',
#  'sudahkah',
#  'sudahlah',
#  'supaya',
#  'tadi',
#  'tadinya',
#  'tahu',
#  'tahun',
#  'tak',
#  'tambah',
#  'tambahnya',
#  'tampak',
#  'tampaknya',
#  'tandas',
#  'tandasnya',
#  'tanpa',
#  'tanya',
#  'tanyakan',
#  'tanyanya',
#  'tapi',
#  'tegas',
#  'tegasnya',
#  'telah',
#  'tempat',
#  'tengah',
#  'tentang',
#  'tentu',
#  'tentulah',
#  'tentunya',
#  'tepat',
#  'terakhir',
#  'terasa',
#  'terbanyak',
#  'terdahulu',
#  'terdapat',
#  'terdiri',
#  'terhadap',
#  'terhadapnya',
#  'teringat',
#  'teringat-ingat',
#  'terjadi',
#  'terjadilah',
#  'terjadinya',
#  'terkira',
#  'terlalu',
#  'terlebih',
#  'terlihat',
#  'termasuk',
#  'ternyata',
#  'tersampaikan',
#  'tersebut',
#  'tersebutlah',
#  'tertentu',
#  'tertuju',
#  'terus',
#  'terutama',
#  'tetap',
#  'tetapi',
#  'tiap',
#  'tiba',
#  'tiba-tiba',
#  'tidak',
#  'tidakkah',
#  'tidaklah',
#  'tiga',
#  'tinggi',
#  'toh',
#  'tunjuk',
#  'turut',
#  'tutur',
#  'tuturnya',
#  'ucap',
#  'ucapnya',
#  'ujar',
#  'ujarnya',
#  'umum',
#  'umumnya',
#  'ungkap',
#  'ungkapnya',
#  'untuk',
#  'usah',
#  'usai',
#  'waduh',
#  'wah',
#  'wahai',
#  'waktu',
#  'waktunya',
#  'walau',
#  'walaupun',
#  'wong',
#  'yaitu',
#  'yakin',
#  'yakni',
#  'yang']

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier

clf =  RandomForestClassifier(random_state=0, max_features ='sqrt',max_depth = 100)
knn = KNeighborsClassifier(n_neighbors=7)
nb = GaussianNB()
dt = DecisionTreeClassifier(max_features ='sqrt',max_depth = 100)
svm = SVC(degree=3)
# clf.fit(X, y)

# %%
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

normalizad_word = pd.read_csv("colloquial-indonesian-lexicon.csv")

normalizad_word_dict = {}

for index, row in normalizad_word.iterrows():
    if row[0] not in normalizad_word_dict:
        normalizad_word_dict[row[0]] = row[1] 

def normalized_term(document):
    return [normalizad_word_dict[term] if term in normalizad_word_dict else term for term in document]

df_skripsi['text_normalized'] = df_skripsi['Stopwords'].apply(normalized_term)


# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in df_skripsi['text_normalized']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")


# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]

df_skripsi['text_tokens_stemmed'] = df_skripsi['text_normalized'].swifter.apply(get_stemmed_term)
# Out:
# 674
# ------------------------
# roboguru : roboguru
# beli : beli
# paket : paket
# video : video
# diputar : putar
# diunduh : unduh
# keluhan : keluh
# link : link
# web : web
# xdari : xdari
# notifikasi : notifikasi
# ruangguru : ruangguru
# buka : buka
# semuakesel : semuakesel
# banget : banget
# mencoba : coba
# pindah : pindah
# lokasi : lokasi
# siyalnya : siyalnya
# full : full
# loading : loading
# errorpleaselah : errorpleaselah
# tolong : tolong
# jaga : jaga
# kenyamanan : nyaman
# aplikasi : aplikasi
# jugasebenernya : jugasebenernya
# tinggal : tinggal
# jaringannya : jaring
# ngebut : ngebut
# nyaman : nyaman
# pakai : pakai
# pc : pc
# letak : letak
# drill : drill
# maksa : maksa
# langganan : langgan
# jawabannya : jawab
# salah : salah
# kasih : kasih
# ar : ar
# ulangan : ulang
# 92 : 92
# buruk : buruk
# sudah : sudah
# bagus : bagus
# kadang : kadang
# quiznya : quiznya
# error : error
# benar : benar
# dapat : dapat
# xp : xp
# pelajaran : ajar
# bintang : bintang
# 4 : 4
# seru : seru
# dafa : dafa
# lulu : lulu
# ruang : ruang
# guru : guru
# menyenangkan : senang
# kecewa : kecewa
# jawabanpenjelasan : jawabanpenjelasan
# komputerleptop : komputerleptop
# websitecrome : websitecrome
# diaksesdan : diaksesdan
# berlangganan : langgan
# dibukaitu : dibukaitu
# saran : saran
# kesan : kesan
# sayasaya : sayasaya
# harap : harap
# kedepannya : depan
# penggunaan : guna
# website : website
# terbuka : buka
# terimakasih : terimakasih
# lumayan : lumayan
# tuli : tuli
# upgrade : upgrade
# subtitle : subtitle
# indonesia : indonesia
# terima kasih : terima kasih
# sumpah : sumpah
# keluh : keluh
# kesah : kesah
# doang : doang
# suport : suport
# android : android
# suruh : suruh
# hh : hh
# selesai : selesai
# sekian : sekian
# videonya : video
# tulisanya : tulisanya
# gagal : gagal
# memuat : muat
# coba : coba
# 3 : 3
# nyobs : nyobs
# mode : mode
# online : online
# offline : offline
# tulisannya : tulis
# kayak : kayak
# belajar : ajar
# susah : susah
# hasil : hasil
# screenshot : screenshot
# mtk : mtk
# wajib : wajib
# minat : minat
# dipisahkan : pisah
# mudah : mudah
# overall : overall
# eemm : eemm
# tanya : tanya
# tutor : tutor
# koinnya : koin
# mahal : mahal
# 1 : 1
# 15 : 15
# krg : krg
# pas : pas
# putus2 : putus2
# jaringan : jaring
# lancar : lancar
# maaf : maaf
# kondisikan : kondisi
# konsultannya : konsultan
# menghubungi : hubung
# chat : chat
# telfon : telfon
# risih : risih
# berminat : minat
# konfirmasi : konfirmasi
# konsultanbeli : konsultanbeli
# marketplace : marketplace
# terima : terima
# hapus : hapus
# karena : karena
# english : english
# tagihan : tagih
# burik : burik
# sok : sok
# pembahasan : bahas
# banayak : banayak
# netral : netral
# aplikasinya : aplikasi
# fitur : fitur
# fiturnya : fiturnya
# lengkap : lengkap
# sayangnya : sayang
# materi : materi
# diakses : akses
# gbng : gbng
# instal : instal
# smkwakwakwak : smkwakwakwak
# jelek : jelek
# bayar : bayar
# 2 : 2
# komplen : komplen
# berminggu2 : berminggu2
# penyelesaian : selesai
# dianggap : anggap
# bukti : bukti
# disertakan : serta
# download : download
# dibukaerror : dibukaerror
# sihkalau : sihkalau
# dibenahi : benah
# muat : muat
# ulang : ulang
# trussvidio : trussvidio
# putar : putar
# knpaa : knpaa
# padhal : padhal
# menonton : tonton
# menyesal : sesal
# baca : baca
# suka : suka
# lola : lola
# lobby : lobby
# tetap : tetap
# menekan : tekan
# avatar : avatar
# berubah : ubah
# persis : persis
# teman : teman
# avayar : avayar
# lan : lan
# diubah : ubah
# bari : bari
# level : level
# 82 : 82
# rg : rg
# buriek : buriek
# jujur : jujur
# banguss : banguss
# keganggu : ganggu
# spam : spam
# message : message
# ganti : ganti
# membeli : beli
# kemarin : kemarin
# kesalahan : salah
# sistem : sistem
# terus : terus
# wifi : wifi
# tiket : tiket
# setelah : telah
# takutnya : takut
# 7 : 7
# butuh : butuh
# semoga : moga
# secepatnya : cepat
# duit : duit
# kenapa : kenapa
# enggak : enggak
# mapel : mapel
# bhsa : bhsa
# daerah : daerah
# pertanianseni : pertanianseni
# budaya : budaya
# pakarya : pakarya
# informatika : informatika
# sekolah : sekolah
# lupa : lupa
# nilai : nilai
# gurunya : guru
# ingat : ingat
# mengasih : asih
# ku : ku
# pencet : pencet
# kirim : kirim
# muncul : muncul
# tulisan : tulis
# begini : begini
# invalid : invalid
# response : response
# was : was
# received : received
# upstream : upstream
# server : server
# solusi : solusi
# apk : apk
# menunggu : tunggu
# antrian : antri
# aman : aman
# berkisar : kisar
# 50 : 50
# keatas : atas
# cepat : cepat
# 10 : 10
# diperbaiki : baik
# tertipu : tipu
# plus : plus
# bernama : nama
# dinna : dinna
# sesuai : sesuai
# difoto : foto
# tindaklanjuti : tindaklanjuti
# semenjak : semenjak
# lihat : lihat
# gaenak : gaenak
# hp : hp
# bagusdi : bagusdi
# laptop : laptop
# ditonton : tonton
# penyimpanan : simpan
# dibandingkan : banding
# mengajarnya : ajar
# selengkapnya : lengkap
# nomer : nomer
# penawaran : tawar
# teror : teror
# pinjol : pinjol
# awalawal : awalawal
# namanya : nama
# koin : koin
# harga : harga
# belinya : beli
# sesi : sesi
# nanyain : nanyain
# sesinya : sesi
# ngabisin : ngabisin
# harganya : harga
# peraturannya : atur
# turun : turun
# aneh : aneh
# dipakai : pakai
# terusan : terus
# google : google
# batesnya : batesnya
# giliran : gilir
# bates : bates
# anak : anak
# lounching : lounching
# perpanjangan : panjang
# serasa : serasa
# dikoyak : koyak
# oyakpdhl : oyakpdhl
# semester : semester
# smstr : smstr
# pelanggan : langgan
# diperhatikan : perhati
# yakinlah : yakin
# cocok : cocok
# dipahami : paham
# peningkatan : tingkat
# adapto : adapto
# kuis : kuis
# tibatiba : tibatiba
# buram : buram
# bergarisgaris : bergarisgaris
# niat : niat
# uang : uang
# tampilantingkatkn : tampilantingkatkn
# gratis : gratis
# bug : bug
# musik : musik
# ganggu : ganggu
# koneksi : koneksi
# force : force
# close : close
# heran : heran
# poco : poco
# pro : pro
# chipsetnya : chipsetnya
# snapdragon : snapdragon
# 800 : 800
# malas : malas
# perbaiki : baik
# pembelajaran : ajar
# hewan : hewan
# sakit : sakit
# balikin : balikin
# nyicil : nyicil
# pengin : pengin
# tapi : tapi
# lagi : lagi
# hemat : hemat
# dkembaiin : dkembaiin
# pasti : pasti
# affah : affah
# iya : iya
# butut : butut
# minimal : minimal
# difix : difix
# rilis : rilis
# poling : poling
# lantai : lantai
# masih : masih
# ngawur : ngawur
# this : this
# application : application
# very : very
# live : live
# lag : lag
# enggak usah : enggak usah
# parah : parah
# sulit : sulit
# reting : reting
# paksa : paksa
# akses : akses
# luas : luas
# berfungsi : fungsi
# mengecewakan : kecewa
# pengguna : guna
# ruanggru : ruanggru
# dihilangkan : hilang
# pelekspiperlekspi : pelekspiperlekspi
# pepiku : pepiku
# awaskslsutidak : awaskslsutidak
# lengakappetoperepiku : lengakappetoperepiku
# sayang : sayang
# juara : juara
# kelas : kelas
# berusaha : usaha
# semaksimal : maksimal
# dering : dering
# menyebut : sebut
# nama : nama
# pemangil : pemangil
# vidionya : vidionya
# mulu : mulu
# daily : daily
# challenge : challenge
# indak : indak
# dibuka : buka
# customer : customer
# servicenya : servicenya
# tutup : tutup
# install : install
# sms : sms
# kode : kode
# otp : otp
# ngelag : ngelag
# scroll : scroll
# diam : diam
# sinyal : sinyal
# konten : konten
# promosi : promosi
# dipikirkan : pikir
# dichat : dichat
# orang tua : orang tua
# pemaksaan : paksa
# liga : liga
# quality : quality
# terganggu : ganggu
# cuman : cuman
# ngelagnya : ngelagnya
# anjing : anjing
# login : login
# ngerjain : ngerjain
# donlot : donlot
# 80 : 80
# apli : apli
# penjelasannya : jelas
# pahami : paham
# lemot : lot
# padahal : padahal
# stabil : stabil
# mood : mood
# pembelajarannyaa : pembelajarannyaa
# polling : polling
# teaching : teaching
# disalahkan : salah
# latsolnya : latsolnya
# hasilnya : hasil
# berulang : ulang
# mempelajari : ajar
# bahasa : bahasa
# asing : asing
# semudah : mudah
# ucapkanmemerlukan : ucapkanmemerlukan
# ketekunan : tekun
# rajin : rajin
# mempraktikan : praktik
# pemakaian : pakai
# pelajari : ajar
# takut : takut
# salahsalah : salahsalah
# kok : kok
# kagak : kagak
# ml : ml
# memakai : pakai
# vale : vale
# brain : brain
# academy : academy
# ekspektasi : ekspektasi
# menjamin : jamin
# kualitas : kualitas
# emosi : emosi
# sukacuman : sukacuman
# membantu : bantu
# meningkat : tingkat
# paham : paham
# telepon : telepon
# kendala : kendala
# memutar : putar
# adaptonya : adaptonya
# berjalan : jalan
# sampai : sampai
# stuck : stuck
# situ : situ
# tolonglah : tolong
# jengkel : jengkel
# pelajarannya : ajar
# dikit : dikit
# hilang : hilang
# jaya : jaya
# keren : keren
# pokoknya : pokok
# aplikasihnya : aplikasihnya
# berguna : guna
# olimpiade : olimpiade
# ambon : ambon
# rating : rating
# 5 : 5
# terimaiasih : terimaiasih
# pembuat : buat
# mantap : mantap
# membosankan : bosan
# terbaik : baik
# dunia : dunia
# pickup : pickup
# miliki : milik
# operasi : operasi
# militer : militer
# politik : politik
# menderita : derita
# hati : hati
# je : je
# champions : champions
# uefa : uefa
# musim : musim
# panas : panas
# orang-orang : orang
# beriman : iman
# beramal : amal
# soleh : soleh
# solehah : solehah
# mejing : mejing
# gapyear : gapyear
# memahami : paham
# utbk : utbk
# bantuan : bantu
# apa : apa
# hyo : hyo
# bimbel : bimbel
# best : best
# because : because
# spesifikasinya : spesifikasi
# memuaskan : muas
# really : really
# with : with
# understand : understand
# about : about
# each : each
# lesson : lesson
# enthusiastic : enthusiastic
# exploring : exploring
# every : every
# knowledge : knowledge
# day : day
# hope : hope
# support : support
# future : future
# even : even
# better : better
# interesting : interesting
# everyone : everyone
# interested : interested
# thank : thank
# much : much
# developers : developers
# mempermudah : mudah
# pekerjaan : kerja
# modul : modul
# dimasukkan : masuk
# didalam : dalam
# soalsoal : soalsoal
# menunjang : tunjang
# kinerja : kerja
# guruguru : guruguru
# latihan : latih
# anakpun : anak
# dalamnya : dalam
# dimana : mana
# memgerti : memgerti
# skor : skor
# worksheetnya : worksheetnya
# dibutuhkan : butuh
# mengoreksi : koreksi
# persiapannya : siap
# skip : skip
# second : second
# device : device
# pclaptop : pclaptop
# tambahan : tambah
# pintar : pintar
# anaknya : anak
# menambah : tambah
# wawasan : wawas
# ruanggurudari : ruanggurudari
# pahamjuga : pahamjuga
# sulitjuga : sulitjuga
# dafadan : dafadan
# luluyang : luluyang
# usia : usia
# prasekolah : prasekolah
# butuhkan : butuh
# love : love
# materinya : materi
# ngejar : ngejar
# ranking : ranking
# baguus : baguus
# mudahh : mudahh
# pelayanan : layan
# laporkan : lapor
# direspon : direspon
# kakaknyapembelajarannya : kakaknyapembelajarannya
# jiwa : jiwa
# ngejelasin : ngejelasin
# detail : detail
# gara : gara
# baguuss : baguuss
# lengkapbelajar : lengkapbelajar
# bosan : bosan
# bermanfaat : manfaat
# top : top
# tampah : tampah
# 54 : 54
# pliss : pliss
# gut : gut
# gua : gua
# dibagian : bagi
# matematika : matematika
# penjelasan : jelas
# matemetikakalo : matemetikakalo
# dijelasin : dijelasin
# permisi : permisi
# daftar : daftar
# menarik : tarik
# bantu : bantu
# rangking : rangking
# ilmu : ilmu
# plajari : plajari
# semangat : semangat
# masbro : masbro
# belajarnya : ajar
# membaca : baca
# bolehh : bolehh
# sehari : hari
# mengerti : erti
# smk : smk
# kah : kah
# rekomendasi : rekomendasi
# sd : sd
# bermanfaatdan : bermanfaatdan
# sekolahan : sekolah
# anak-anak : anak
# ranting5 : ranting5
# dqri : dqri
# anakanak : anakanak
# giat : giat
# aku : aku
# apknya : apknya
# menghitung : hitung
# menggukur : menggukur
# sudut : sudut
# trimakasih : trimakasih
# phytagoras : phytagoras
# untung : untung
# gampang : gampang
# dimengerti : erti
# pemahaman : paham
# baangget : baangget
# aplikadi : aplikadi
# vidio : vidio
# tabisa : tabisa
# qjsudoeojoffikroeorrirutjyyri : qjsudoeojoffikroeorrirutjyyri
# fruuttugutir : fruuttugutir
# trik : trik
# ir : ir
# tiri : tiri
# taman : taman
# routoytyui : routoytyui
# yirritkhohohjonou : yirritkhohohjonou
# hridurugituuouih : hridurugituuouih
# today : today
# trigonometri : trigonometri
# all : all
# huigititiriirurut : huigititiriirurut
# tuturu4u4uru : tuturu4u4uru
# ruhfhhdjujdjduduudfuuftryrehudfuufuufjggjugjgjg : ruhfhhdjujdjduduudfuuftryrehudfuufuufjggjugjgjg
# jgguutuguyru : jgguutuguyru
# gadis : gadis
# gr : gr
# daging : daging
# ayam : ayam
# try : try
# i6 : i6
# berbagayrghtiihhjyigki : berbagayrghtiihhjyigki
# tempatku : tempat
# itiutktuykktu : itiutktuykktu
# uduu : uduu
# belajarsaya : belajarsaya
# siswa : siswa
# terbantu : bantu
# soalsoalnya : soalsoalnya
# pembahasannya : bahas
# rebahan : rebah
# {'roboguru': 'roboguru', 'beli': 'beli', 'paket': 'paket', 'video': 'video', 'diputar': 'putar', 'diunduh': 'unduh', 'keluhan': 'keluh', 'link': 'link', 'web': 'web', 'xdari': 'xdari', 'notifikasi': 'notifikasi', 'ruangguru': 'ruangguru', 'buka': 'buka', 'semuakesel': 'semuakesel', 'banget': 'banget', 'mencoba': 'coba', 'pindah': 'pindah', 'lokasi': 'lokasi', 'siyalnya': 'siyalnya', 'full': 'full', 'loading': 'loading', 'errorpleaselah': 'errorpleaselah', 'tolong': 'tolong', 'jaga': 'jaga', 'kenyamanan': 'nyaman', 'aplikasi': 'aplikasi', 'jugasebenernya': 'jugasebenernya', 'tinggal': 'tinggal', 'jaringannya': 'jaring', 'ngebut': 'ngebut', 'nyaman': 'nyaman', 'pakai': 'pakai', 'pc': 'pc', 'letak': 'letak', 'drill': 'drill', 'maksa': 'maksa', 'langganan': 'langgan', 'jawabannya': 'jawab', 'salah': 'salah', 'kasih': 'kasih', 'ar': 'ar', 'ulangan': 'ulang', '92': '92', 'buruk': 'buruk', 'sudah': 'sudah', 'bagus': 'bagus', 'kadang': 'kadang', 'quiznya': 'quiznya', 'error': 'error', 'benar': 'benar', 'dapat': 'dapat', 'xp': 'xp', 'pelajaran': 'ajar', 'bintang': 'bintang', '4': '4', 'seru': 'seru', 'dafa': 'dafa', 'lulu': 'lulu', 'ruang': 'ruang', 'guru': 'guru', 'menyenangkan': 'senang', 'kecewa': 'kecewa', 'jawabanpenjelasan': 'jawabanpenjelasan', 'komputerleptop': 'komputerleptop', 'websitecrome': 'websitecrome', 'diaksesdan': 'diaksesdan', 'berlangganan': 'langgan', 'dibukaitu': 'dibukaitu', 'saran': 'saran', 'kesan': 'kesan', 'sayasaya': 'sayasaya', 'harap': 'harap', 'kedepannya': 'depan', 'penggunaan': 'guna', 'website': 'website', 'terbuka': 'buka', 'terimakasih': 'terimakasih', 'lumayan': 'lumayan', 'tuli': 'tuli', 'upgrade': 'upgrade', 'subtitle': 'subtitle', 'indonesia': 'indonesia', 'terima kasih': 'terima kasih', 'sumpah': 'sumpah', 'keluh': 'keluh', 'kesah': 'kesah', 'doang': 'doang', 'suport': 'suport', 'android': 'android', 'suruh': 'suruh', 'hh': 'hh', 'selesai': 'selesai', 'sekian': 'sekian', 'videonya': 'video', 'tulisanya': 'tulisanya', 'gagal': 'gagal', 'memuat': 'muat', 'coba': 'coba', '3': '3', 'nyobs': 'nyobs', 'mode': 'mode', 'online': 'online', 'offline': 'offline', 'tulisannya': 'tulis', 'kayak': 'kayak', 'belajar': 'ajar', 'susah': 'susah', 'hasil': 'hasil', 'screenshot': 'screenshot', 'mtk': 'mtk', 'wajib': 'wajib', 'minat': 'minat', 'dipisahkan': 'pisah', 'mudah': 'mudah', 'overall': 'overall', 'eemm': 'eemm', 'tanya': 'tanya', 'tutor': 'tutor', 'koinnya': 'koin', 'mahal': 'mahal', '1': '1', '15': '15', 'krg': 'krg', 'pas': 'pas', 'putus2': 'putus2', 'jaringan': 'jaring', 'lancar': 'lancar', 'maaf': 'maaf', 'kondisikan': 'kondisi', 'konsultannya': 'konsultan', 'menghubungi': 'hubung', 'chat': 'chat', 'telfon': 'telfon', 'risih': 'risih', 'berminat': 'minat', 'konfirmasi': 'konfirmasi', 'konsultanbeli': 'konsultanbeli', 'marketplace': 'marketplace', 'terima': 'terima', 'hapus': 'hapus', 'karena': 'karena', 'english': 'english', 'tagihan': 'tagih', 'burik': 'burik', 'sok': 'sok', 'pembahasan': 'bahas', 'banayak': 'banayak', 'netral': 'netral', 'aplikasinya': 'aplikasi', 'fitur': 'fitur', 'fiturnya': 'fiturnya', 'lengkap': 'lengkap', 'sayangnya': 'sayang', 'materi': 'materi', 'diakses': 'akses', 'gbng': 'gbng', 'instal': 'instal', 'smkwakwakwak': 'smkwakwakwak', 'jelek': 'jelek', 'bayar': 'bayar', '2': '2', 'komplen': 'komplen', 'berminggu2': 'berminggu2', 'penyelesaian': 'selesai', 'dianggap': 'anggap', 'bukti': 'bukti', 'disertakan': 'serta', 'download': 'download', 'dibukaerror': 'dibukaerror', 'sihkalau': 'sihkalau', 'dibenahi': 'benah', 'muat': 'muat', 'ulang': 'ulang', 'trussvidio': 'trussvidio', 'putar': 'putar', 'knpaa': 'knpaa', 'padhal': 'padhal', 'menonton': 'tonton', 'menyesal': 'sesal', 'baca': 'baca', 'suka': 'suka', 'lola': 'lola', 'lobby': 'lobby', 'tetap': 'tetap', 'menekan': 'tekan', 'avatar': 'avatar', 'berubah': 'ubah', 'persis': 'persis', 'teman': 'teman', 'avayar': 'avayar', 'lan': 'lan', 'diubah': 'ubah', 'bari': 'bari', 'level': 'level', '82': '82', 'rg': 'rg', 'buriek': 'buriek', 'ju ...
# ------------------------
# Pandas Apply:   0%|          | 0/192 [00:00<?, ?it/s]

# %%
df_skripsi
# Out:
#         label                                          text_real  \
# 0    Negative                    Roboguru harus beli paket… why?
# 1    Negative  Video nya ga bisa diputar, padahal udah diundu...
# 2    Negative  Aku punya keluhan terhadap link web atau xdari...
# 3    Negative  halo ka, kalo buat PC letak drill soal nya ada...
# 4    Negative                                    Maksa langganan
# ..        ...                                                ...
# 195  Positive  Aplikasi ini sangat membantu dalam hal belajar...
# 196  Positive  Aplikasi nya lengkap, bagus deh pokoknya kalau...
# 197  Positive                  Bagus bisa belajar sambil rebahan
# 198  Positive                              Sangat bagus dan seru
# 199  Positive                               pokoknya is the best
#
#                                                   text  \
# 0                        roboguru harus beli paket why
# 1       video nya ga bisa diputar padahal udah diunduh
# 2    aku punya keluhan terhadap link web atau xdari...
# 3    halo ka kalo buat pc letak drill soal nya ada ...
# 4                                      maksa langganan
# ..                                                 ...
# 195  aplikasi ini sangat membantu dalam hal belajar...
# 196  aplikasi nya lengkap bagus deh pokoknya kalau ...
# 197                  bagus bisa belajar sambil rebahan
# 198                              sangat bagus dan seru
# 199                               pokoknya is the best
#
#                                            text_tokens  \
# 0                  [roboguru, harus, beli, paket, why]
# 1    [video, nya, ga, bisa, diputar, padahal, udah,...
# 2    [aku, punya, keluhan, terhadap, link, web, ata...
# 3    [halo, ka, kalo, buat, pc, letak, drill, soal,...
# 4                                   [maksa, langganan]
# ..                                                 ...
# 195  [aplikasi, ini, sangat, membantu, dalam, hal, ...
# 196  [aplikasi, nya, lengkap, bagus, deh, pokoknya,...
# 197            [bagus, bisa, belajar, sambil, rebahan]
# 198                         [sangat, bagus, dan, seru]
# 199                          [pokoknya, is, the, best]
#
#                                              Stopwords  \
# 0                              [roboguru, beli, paket]
# 1                            [video, diputar, diunduh]
# 2    [keluhan, link, web, xdari, notifikasi, ruangg...
# 3                                   [pc, letak, drill]
# 4                                   [maksa, langganan]
# ..                                                 ...
# 195  [aplikasi, membantu, belajarsaya, siswa, kelas...
# 196  [aplikasi, lengkap, bagus, pokoknya, dipakai, ...
# 197                          [bagus, belajar, rebahan]
# 198                                      [bagus, seru]
# 199                                   [pokoknya, best]
#
#                                      text_tokens_fdist  \
# 0    {'roboguru': 1, 'harus': 1, 'beli': 1, 'paket'...
# 1    {'video': 1, 'nya': 1, 'ga': 1, 'bisa': 1, 'di...
# 2    {'aku': 2, 'punya': 1, 'keluhan': 1, 'terhadap...
# 3    {'halo': 1, 'ka': 1, 'kalo': 1, 'buat': 1, 'pc...
# 4                         {'maksa': 1, 'langganan': 1}
# ..                                                 ...
# 195  {'aplikasi': 3, 'ini': 2, 'sangat': 2, 'memban...
# 196  {'aplikasi': 1, 'nya': 2, 'lengkap': 1, 'bagus...
# 197  {'bagus': 1, 'bisa': 1, 'belajar': 1, 'sambil'...
# 198     {'sangat': 1, 'bagus': 1, 'dan': 1, 'seru': 1}
# 199      {'pokoknya': 1, 'is': 1, 'the': 1, 'best': 1}
#
#                                        text_normalized  \
# 0                              [roboguru, beli, paket]
# 1                            [video, diputar, diunduh]
# 2    [keluhan, link, web, xdari, notifikasi, ruangg...
# 3                                   [pc, letak, drill]
# 4                                   [maksa, langganan]
# ..                                                 ...
# 195  [aplikasi, membantu, belajarsaya, siswa, kelas...
# 196  [aplikasi, lengkap, bagus, pokoknya, dipakai, ...
# 197                          [bagus, belajar, rebahan]
# 198                                      [bagus, seru]
# 199                                   [pokoknya, best]
#
#                                    text_tokens_stemmed
# 0                              [roboguru, beli, paket]
# 1                                [video, putar, unduh]
# 2    [keluh, link, web, xdari, notifikasi, ruanggur...
# 3                                   [pc, letak, drill]
# 4                                     [maksa, langgan]
# ..                                                 ...
# 195  [aplikasi, bantu, belajarsaya, siswa, kelas, 7...
# 196  [aplikasi, lengkap, bagus, pokok, pakai, ajar,...
# 197                               [bagus, ajar, rebah]
# 198                                      [bagus, seru]
# 199                                      [pokok, best]
#
# [192 rows x 8 columns]

# %%
def merge_again(text):
    return ' '.join(text)

# %%
df_skripsi['done_text'] = df_skripsi['text_tokens_stemmed'].apply(merge_again)
df_skripsi
# Out:
#         label                                          text_real  \
# 0    Negative                    Roboguru harus beli paket… why?
# 1    Negative  Video nya ga bisa diputar, padahal udah diundu...
# 2    Negative  Aku punya keluhan terhadap link web atau xdari...
# 3    Negative  halo ka, kalo buat PC letak drill soal nya ada...
# 4    Negative                                    Maksa langganan
# ..        ...                                                ...
# 195  Positive  Aplikasi ini sangat membantu dalam hal belajar...
# 196  Positive  Aplikasi nya lengkap, bagus deh pokoknya kalau...
# 197  Positive                  Bagus bisa belajar sambil rebahan
# 198  Positive                              Sangat bagus dan seru
# 199  Positive                               pokoknya is the best
#
#                                                   text  \
# 0                        roboguru harus beli paket why
# 1       video nya ga bisa diputar padahal udah diunduh
# 2    aku punya keluhan terhadap link web atau xdari...
# 3    halo ka kalo buat pc letak drill soal nya ada ...
# 4                                      maksa langganan
# ..                                                 ...
# 195  aplikasi ini sangat membantu dalam hal belajar...
# 196  aplikasi nya lengkap bagus deh pokoknya kalau ...
# 197                  bagus bisa belajar sambil rebahan
# 198                              sangat bagus dan seru
# 199                               pokoknya is the best
#
#                                            text_tokens  \
# 0                  [roboguru, harus, beli, paket, why]
# 1    [video, nya, ga, bisa, diputar, padahal, udah,...
# 2    [aku, punya, keluhan, terhadap, link, web, ata...
# 3    [halo, ka, kalo, buat, pc, letak, drill, soal,...
# 4                                   [maksa, langganan]
# ..                                                 ...
# 195  [aplikasi, ini, sangat, membantu, dalam, hal, ...
# 196  [aplikasi, nya, lengkap, bagus, deh, pokoknya,...
# 197            [bagus, bisa, belajar, sambil, rebahan]
# 198                         [sangat, bagus, dan, seru]
# 199                          [pokoknya, is, the, best]
#
#                                              Stopwords  \
# 0                              [roboguru, beli, paket]
# 1                            [video, diputar, diunduh]
# 2    [keluhan, link, web, xdari, notifikasi, ruangg...
# 3                                   [pc, letak, drill]
# 4                                   [maksa, langganan]
# ..                                                 ...
# 195  [aplikasi, membantu, belajarsaya, siswa, kelas...
# 196  [aplikasi, lengkap, bagus, pokoknya, dipakai, ...
# 197                          [bagus, belajar, rebahan]
# 198                                      [bagus, seru]
# 199                                   [pokoknya, best]
#
#                                      text_tokens_fdist  \
# 0    {'roboguru': 1, 'harus': 1, 'beli': 1, 'paket'...
# 1    {'video': 1, 'nya': 1, 'ga': 1, 'bisa': 1, 'di...
# 2    {'aku': 2, 'punya': 1, 'keluhan': 1, 'terhadap...
# 3    {'halo': 1, 'ka': 1, 'kalo': 1, 'buat': 1, 'pc...
# 4                         {'maksa': 1, 'langganan': 1}
# ..                                                 ...
# 195  {'aplikasi': 3, 'ini': 2, 'sangat': 2, 'memban...
# 196  {'aplikasi': 1, 'nya': 2, 'lengkap': 1, 'bagus...
# 197  {'bagus': 1, 'bisa': 1, 'belajar': 1, 'sambil'...
# 198     {'sangat': 1, 'bagus': 1, 'dan': 1, 'seru': 1}
# 199      {'pokoknya': 1, 'is': 1, 'the': 1, 'best': 1}
#
#                                        text_normalized  \
# 0                              [roboguru, beli, paket]
# 1                            [video, diputar, diunduh]
# 2    [keluhan, link, web, xdari, notifikasi, ruangg...
# 3                                   [pc, letak, drill]
# 4                                   [maksa, langganan]
# ..                                                 ...
# 195  [aplikasi, membantu, belajarsaya, siswa, kelas...
# 196  [aplikasi, lengkap, bagus, pokoknya, dipakai, ...
# 197                          [bagus, belajar, rebahan]
# 198                                      [bagus, seru]
# 199                                   [pokoknya, best]
#
#                                    text_tokens_stemmed  \
# 0                              [roboguru, beli, paket]
# 1                                [video, putar, unduh]
# 2    [keluh, link, web, xdari, notifikasi, ruanggur...
# 3                                   [pc, letak, drill]
# 4                                     [maksa, langgan]
# ..                                                 ...
# 195  [aplikasi, bantu, belajarsaya, siswa, kelas, 7...
# 196  [aplikasi, lengkap, bagus, pokok, pakai, ajar,...
# 197                               [bagus, ajar, rebah]
# 198                                      [bagus, seru]
# 199                                      [pokok, best]
#
#                                              done_text
# 0                                  roboguru beli paket
# 1                                    video putar unduh
# 2    keluh link web xdari notifikasi ruangguru buka...
# 3                                       pc letak drill
# 4                                        maksa langgan
# ..                                                 ...
# 195  aplikasi bantu belajarsaya siswa kelas 7 bantu...
# 196  aplikasi lengkap bagus pokok pakai ajar bahas ...
# 197                                   bagus ajar rebah
# 198                                         bagus seru
# 199                                         pokok best
#
# [192 rows x 9 columns]

# %%
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# %%
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer

# %%
tfid = TfidfVectorizer(
    min_df = 3,
    max_df = 0.10,
    ngram_range = (1,2)
)

# %%
count_vect = CountVectorizer(
    min_df = 3,
    max_df = 0.10,
    ngram_range = (1,2)
)

# %%
tfid_result = tfid.fit_transform(df_skripsi["done_text"]).toarray()
tfid_df = pd.DataFrame(tfid_result, columns = tfid.get_feature_names())
tfid_df.columns = ["word_" + str(x) for x in tfid_df.columns]
tfid_df.index = df_skripsi.index
# new_data = pd.concat([, tfid_df], axis=1)

# %%
tfid_df.columns
# Out:
# Index(['word_10', 'word_anak', 'word_apk', 'word_aplikasi ajar',
#        'word_aplikasi bagus', 'word_aplikasi bantu', 'word_bagus banget',
#        'word_bahas', 'word_baik', 'word_banget ajar', 'word_banget aplikasi',
#        'word_bantu', 'word_bantu ajar', 'word_bayar', 'word_beli', 'word_best',
#        'word_bintang', 'word_buka', 'word_butuh', 'word_cepat', 'word_coba',
#        'word_download', 'word_download video', 'word_error', 'word_erti',
#        'word_fitur', 'word_ganggu', 'word_guna', 'word_hasil', 'word_hp',
#        'word_jaring', 'word_jaring bagus', 'word_jelas', 'word_jelek',
#        'word_kasih', 'word_kasih ruang', 'word_kayak', 'word_kecewa',
#        'word_kelas', 'word_kenapa', 'word_keren', 'word_ku', 'word_langgan',
#        'word_lengkap', 'word_lihat', 'word_loading', 'word_lumayan',
#        'word_maaf', 'word_mahal', 'word_mantap', 'word_mapel', 'word_materi',
#        'word_materi ajar', 'word_muat', 'word_mudah', 'word_mudah paham',
#        'word_nama', 'word_nilai', 'word_offline', 'word_online', 'word_paham',
#        'word_pakai', 'word_paket', 'word_pas', 'word_pintar', 'word_pokok',
#        'word_putar', 'word_roboguru', 'word_ruang guru', 'word_ruangguru',
#        'word_salah', 'word_sayang', 'word_selesai', 'word_semangat',
#        'word_seru', 'word_sesal', 'word_sesuai', 'word_sistem', 'word_sudah',
#        'word_suka', 'word_suruh', 'word_tanya', 'word_terima',
#        'word_terima kasih', 'word_terimakasih', 'word_terus', 'word_tingkat',
#        'word_tolong', 'word_tolong baik', 'word_tonton', 'word_tulis',
#        'word_ulang', 'word_video', 'word_web', 'word_wifi'],
#       dtype='object')

# %%
cvzr_result = count_vect.fit_transform(df_skripsi["done_text"]).toarray()
cvzr_df = pd.DataFrame(cvzr_result, columns = count_vect.get_feature_names())
cvzr_df.columns = ["word_" + str(x) for x in cvzr_df.columns]
cvzr_df.index = df_skripsi.index
# new_data = pd.concat([, tfid_df], axis=1)

# %%
kolomcv = cvzr_df.columns
kolomcv
# Out:
# Index(['word_10', 'word_anak', 'word_apk', 'word_aplikasi ajar',
#        'word_aplikasi bagus', 'word_aplikasi bantu', 'word_bagus banget',
#        'word_bahas', 'word_baik', 'word_banget ajar', 'word_banget aplikasi',
#        'word_bantu', 'word_bantu ajar', 'word_bayar', 'word_beli', 'word_best',
#        'word_bintang', 'word_buka', 'word_butuh', 'word_cepat', 'word_coba',
#        'word_download', 'word_download video', 'word_error', 'word_erti',
#        'word_fitur', 'word_ganggu', 'word_guna', 'word_hasil', 'word_hp',
#        'word_jaring', 'word_jaring bagus', 'word_jelas', 'word_jelek',
#        'word_kasih', 'word_kasih ruang', 'word_kayak', 'word_kecewa',
#        'word_kelas', 'word_kenapa', 'word_keren', 'word_ku', 'word_langgan',
#        'word_lengkap', 'word_lihat', 'word_loading', 'word_lumayan',
#        'word_maaf', 'word_mahal', 'word_mantap', 'word_mapel', 'word_materi',
#        'word_materi ajar', 'word_muat', 'word_mudah', 'word_mudah paham',
#        'word_nama', 'word_nilai', 'word_offline', 'word_online', 'word_paham',
#        'word_pakai', 'word_paket', 'word_pas', 'word_pintar', 'word_pokok',
#        'word_putar', 'word_roboguru', 'word_ruang guru', 'word_ruangguru',
#        'word_salah', 'word_sayang', 'word_selesai', 'word_semangat',
#        'word_seru', 'word_sesal', 'word_sesuai', 'word_sistem', 'word_sudah',
#        'word_suka', 'word_suruh', 'word_tanya', 'word_terima',
#        'word_terima kasih', 'word_terimakasih', 'word_terus', 'word_tingkat',
#        'word_tolong', 'word_tolong baik', 'word_tonton', 'word_tulis',
#        'word_ulang', 'word_video', 'word_web', 'word_wifi'],
#       dtype='object')

# %%
y = df_skripsi.label

# %%
X = cvzr_df.to_numpy()
y = df_skripsi.label
y_pred = cross_val_predict(clf, X, y, cv=5)
conf_mat = confusion_matrix(y_pred, y)

# %%
print(conf_mat)
print(classification_report(y, y_pred, digits = 4))
# Out:
# [[66 11]
#  [34 81]]
#               precision    recall  f1-score   support
#
#     Negative     0.8571    0.6600    0.7458       100
#     Positive     0.7043    0.8804    0.7826        92
#
#     accuracy                         0.7656       192
#    macro avg     0.7807    0.7702    0.7642       192
# weighted avg     0.7839    0.7656    0.7634       192

# %%
print('Naive Bayes')
X = cvzr_df.to_numpy()
y = df_skripsi.label
y_pred = cross_val_predict(nb, X, y, cv=10)
conf_mat = confusion_matrix(y_pred, y)
print(conf_mat)
print(classification_report(y, y_pred, digits = 4))
# Out:
# Naive Bayes
# [[63  6]
#  [37 86]]
#               precision    recall  f1-score   support
#
#     Negative     0.9130    0.6300    0.7456       100
#     Positive     0.6992    0.9348    0.8000        92
#
#     accuracy                         0.7760       192
#    macro avg     0.8061    0.7824    0.7728       192
# weighted avg     0.8106    0.7760    0.7716       192

# %%
print('Naive Bayes')
X = tfid_df.to_numpy()
y = df_skripsi.label
y_pred = cross_val_predict(nb, X, y, cv=10)
conf_mat = confusion_matrix(y_pred, y)
print(conf_mat)
print(classification_report(y, y_pred, digits = 4))
# Out:
# Naive Bayes
# [[65  6]
#  [35 86]]
#               precision    recall  f1-score   support
#
#     Negative     0.9155    0.6500    0.7602       100
#     Positive     0.7107    0.9348    0.8075        92
#
#     accuracy                         0.7865       192
#    macro avg     0.8131    0.7924    0.7839       192
# weighted avg     0.8174    0.7865    0.7829       192

# %%
print('KNN')
X = cvzr_df.to_numpy()
y = df_skripsi.label
y_pred = cross_val_predict(knn, X, y, cv=10)
conf_mat = confusion_matrix(y_pred, y)
print(conf_mat)
print(classification_report(y, y_pred, digits = 4))
# Out:
# KNN
# [[38 10]
#  [62 82]]
#               precision    recall  f1-score   support
#
#     Negative     0.7917    0.3800    0.5135       100
#     Positive     0.5694    0.8913    0.6949        92
#
#     accuracy                         0.6250       192
#    macro avg     0.6806    0.6357    0.6042       192
# weighted avg     0.6852    0.6250    0.6004       192

# %%
print('KNN')
X = tfid_df.to_numpy()
y = df_skripsi.label
y_pred = cross_val_predict(knn, X, y, cv=10)
conf_mat = confusion_matrix(y_pred, y)
print(conf_mat)
print(classification_report(y, y_pred, digits = 4))
# Out:
# KNN
# [[99 76]
#  [ 1 16]]
#               precision    recall  f1-score   support
#
#     Negative     0.5657    0.9900    0.7200       100
#     Positive     0.9412    0.1739    0.2936        92
#
#     accuracy                         0.5990       192
#    macro avg     0.7534    0.5820    0.5068       192
# weighted avg     0.7456    0.5990    0.5157       192

# %%
print('SVM')
X = cvzr_df.to_numpy()
y = df_skripsi.label
y_pred = cross_val_predict(svm, X, y, cv=10)
conf_mat = confusion_matrix(y_pred, y)
print(conf_mat)
print(classification_report(y, y_pred, digits = 4))
# Out:
# SVM
# [[58 18]
#  [42 74]]
#               precision    recall  f1-score   support
#
#     Negative     0.7632    0.5800    0.6591       100
#     Positive     0.6379    0.8043    0.7115        92
#
#     accuracy                         0.6875       192
#    macro avg     0.7005    0.6922    0.6853       192
# weighted avg     0.7032    0.6875    0.6842       192

# %%
print('SVM')
X = cvzr_df.to_numpy()
y = df_skripsi.label
y_pred = cross_val_predict(svm, X, y, cv=10)
conf_mat = confusion_matrix(y_pred, y)
print(conf_mat)
print(classification_report(y, y_pred, digits = 4))
# Out:
# SVM
# [[74 17]
#  [26 75]]
#               precision    recall  f1-score   support
#
#     Negative     0.8132    0.7400    0.7749       100
#     Positive     0.7426    0.8152    0.7772        92
#
#     accuracy                         0.7760       192
#    macro avg     0.7779    0.7776    0.7760       192
# weighted avg     0.7794    0.7760    0.7760       192

# %%
print('Random Forest')
X = cvzr_df.to_numpy()
y = df_skripsi.label
y_pred = cross_val_predict(clf, X, y, cv=10)
conf_mat = confusion_matrix(y_pred, y)
print(conf_mat)
print(classification_report(y, y_pred, digits = 4))
# Out:
# Random Forest
# [[68 14]
#  [32 78]]
#               precision    recall  f1-score   support
#
#     Negative     0.8293    0.6800    0.7473       100
#     Positive     0.7091    0.8478    0.7723        92
#
#     accuracy                         0.7604       192
#    macro avg     0.7692    0.7639    0.7598       192
# weighted avg     0.7717    0.7604    0.7592       192

# %%
print('Random Forest')
X = tfid_df.to_numpy()
y = df_skripsi.label
y_pred = cross_val_predict(clf, X, y, cv=10)
conf_mat = confusion_matrix(y_pred, y)
print(conf_mat)
print(classification_report(y, y_pred, digits = 4))
# Out:
# Random Forest
# [[64 11]
#  [36 81]]
#               precision    recall  f1-score   support
#
#     Negative     0.8533    0.6400    0.7314       100
#     Positive     0.6923    0.8804    0.7751        92
#
#     accuracy                         0.7552       192
#    macro avg     0.7728    0.7602    0.7533       192
# weighted avg     0.7762    0.7552    0.7524       192

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

# %%
SemuaText = "".join(df_skripsi['done_text'])

def create_wordcloud(text, filename): 
    stopwords = set(STOPWORDS)

    wc = WordCloud(background_color="white",
                   max_words=200,
                   stopwords=stopwords)

    wc.generate(text)
    wc.to_file(filename+".png")
    plt.figure()
    plt.imshow(wc, interpolation="bilinear")
    plt.axis("off")
    plt.show()

# %%
SemuaText
# Out:
# 'roboguru beli paketvideo putar unduhkeluh link web xdari notifikasi ruangguru buka semuakesel banget coba pindah lokasi siyalnya full loading errorpleaselah tolong banget jaga nyaman aplikasi jugasebenernya tinggal jaring ngebut nyaman pakai ruanggurupc letak drillmaksa langganjawab salahkasih ar salah ulang 92 buruksudah bagus kadang quiznya error benar dapat xpaplikasi bagus banget ajar kasih bintang 4 seru banget video dafa lulu seru bangetaplikasi ruang guru senang kecewa jawabanpenjelasan komputerleptop websitecrome diaksesdan langgan langgan dibukaitu saran kesan sayasaya harap depan guna ruang guru website buka bagus terimakasihlumayan tuli tolong upgrade subtitle indonesia tuli terima kasihbangetsumpah keluh kesah doang ruang guru suport android suruh pindah web hh selesai benar ruang guru sekian terimakasihtolong video tulisanya gagal muat video coba 3 nyobs coba buka video mode online offline tulis kayak ajar susahtolong hasil screenshot mtk wajib minat pisah mudah terimakasihoverall bagus eemm tanya tutor koin mahal 1 15 krg pas tutorvideo putus2 jaring lancar langganmaaf tolong kondisi konsultan 1 hubung chat telfon risih minat langgan konfirmasi salah konsultanbeli paket marketplace terima kasihhapus karena ajar english tagihburiksokbahas banayaknetralaplikasi bagus fitur fiturnya lengkap sayang materi ajar lengkap error aksesgbnginstal smkwakwakwakjelek banget aplikasi bayar 2 komplen berminggu2 selesai anggap beli paket ajar bukti sertadownload video banget jaring bagusaplikasi bagus langgan video dibukaerror sihkalau tolong benahsuruh muat ulang trussvidio putar knpaa padhal sudah langganjelek langgan tonton download sesalruang baca suka lolalobby tetap pas tekan avatar ubah persis teman lobby avayar lan ubah bari level 82 rgburiekjujur banguss banget ganggu spam messageganti paket langgan salah beli kemarin coba ganti web salah sistem terus pakai wifi tiket ganti paket 2 telah tiket paket ganti takut 7 ganti butuh ajar moga ganti paket cepat terimakasihmaaf bintang suka langgan duit bayarkenapa enggak mapel bhsa daerah pertanianseni budaya pakarya informatika mapel sekolahkemarin tutor lupa kasih nilai guru ingat kasih nilai guru pas selesai asih bintang pas ku pencet kirim muncul tulis begini invalid response was received upstream server tolong kasih solusiapk pas download video offline tulis tunggu antri download 1 pakai wifi jaring aman pakai download apk kisar 50 atas video cepat download video 10 tolong baiktipu fitur roboguru plus guru nama dinna sesuai foto tolong tindaklanjutisemenjak lihat bayar gaenakfitur hp sudah bagusdi laptop jelek banget sistem download video tonton offline laptop banget simpan laptop banding hpmateri ajar bagus lengkap lengkap bayarnomer kirim tawar kayak teror pinjolawalawal langgan fitur nama roboguru plus pakai koin harga beli lumayan beli sesi 1 koin nanyain terus fitur roboguru plus sesi 1 sesi ngabisin koin harga lumayan kecewa atur ubah begini harga koin turunaneh pas langgan roboguru pakai terus google pas langgan batesnya google gilir roboguru rg pakai batesruangguru bagus anak langgan lounching maaf panjang serasa koyak oyakpdhl langgan 1 2 semester smstr 2 tolong langgan perhati yakin cocok tetap panjangmateri mudah paham tingkat fitur adapto kuis video tibatiba buram bergarisgarislanggan video niat ajar bayar uangsuka tampilantingkatknkenapa gratisaplikasi bagus kadang bug musik pas ganggu bangetapkkoneksi suka error suka force close heran hp poco 3 pro chipsetnya snapdragon 800ruang gurumalas langgan mahal banget 1lumayan ajar baik putar video ajar loading hewan ajar sakitbalikin fitur nyicil pengin beli tapi lagi hemat uang dkembaiin pasti langganaffah iya jelekbututminimal difix apk rilis poling lantai masih ngawurthis application very live suka lagenggak usah langgan sesal parahsuka ruangguru sulit bandingreting suruh paksaburikakses video ajar susah loading jaring bagus ruang simpan luaslanggan fitur fungsi loading tolong baikfitur download bahas kecewa guna r ...

# %%
create_wordcloud(SemuaText,"Semua Sentimen")

# %%
komenpositif= df_skripsi[df_skripsi['label'] == "Positive"]

# %%
Positive = "".join(komenpositif['done_text'])

def create_wordcloud(text, filename): 
    stopwords = set(STOPWORDS)

    wc = WordCloud(background_color="white",
                   max_words=200,
                   stopwords=stopwords)

    wc.generate(text)
    wc.to_file(filename+".png")
    plt.figure()
    plt.imshow(wc, interpolation="bilinear")
    plt.axis("off")
    plt.show()

# %%
create_wordcloud(Positive,"Semua Positive")

# %%
komennegatif= df_skripsi[df_skripsi['label'] == "Negative"]

# %%
Negative = "".join(komennegatif['done_text'])

def create_wordcloud(text, filename): 
    stopwords = set(STOPWORDS)

    wc = WordCloud(background_color="white",
                   max_words=200,
                   stopwords=stopwords)

    wc.generate(text)
    wc.to_file(filename+".png")
    plt.figure()
    plt.imshow(wc, interpolation="bilinear")
    plt.axis("off")
    plt.show()

# %%
create_wordcloud(Negative,"Semua Negative")
