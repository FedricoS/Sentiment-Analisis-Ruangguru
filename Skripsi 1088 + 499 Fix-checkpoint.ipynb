# %%
import pandas as pd 
import numpy as np
import string 
import re 
from nltk.tokenize import word_tokenize 
from nltk.probability import FreqDist
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

# %%
df = pd.read_excel('data_skripsiku.xlsx')

# %%
df
# Out:
#                     Time Sentiment  \
# 0    2023-02-11 15:32:42  Negative
# 1    2023-02-11 13:55:16  Positive
# 2    2023-02-11 06:55:16  Negative
# 3    2022-10-16 12:57:02  Negative
# 4    2023-02-11 06:39:53  Positive
# ...                  ...       ...
# 1582 2022-10-17 06:24:26  Positive
# 1583 2022-10-17 05:59:16  Positive
# 1584 2022-10-17 03:28:27  Negative
# 1585 2022-10-17 02:48:35  Positive
# 1586 2022-10-16 12:17:51  Positive
#
#                                                 Content  score  \
# 0                       Roboguru harus beli paket… why?      3
# 1                 Sangat membantu jaya terus ruang guru      5
# 2     Video nya ga bisa diputar, padahal udah diundu...      4
# 3     Eror terus video nya ,nyesel gue Makai ruang guru      1
# 4                             Keren banget deh pokoknya      5
# ...                                                 ...    ...
# 1582  Bagus banget aplikasinya, bisa membantu saya d...      5
# 1583  Aplikasi nya bagus banget apa lagi belajar nya...      5
# 1584            Buruk sekali tidak ada mapel ushul fiqh      1
# 1585                   Bagussssssssssssss S s s s sss S      5
# 1586  Puasss bangatt bisa langsung paham, semoga rua...      5
#
#      reviewCreatedVersion
# 0                  6.39.0
# 1                  6.52.0
# 2                  6.52.0
# 3                     NaN
# 4                  6.52.0
# ...                   ...
# 1582                  NaN
# 1583               6.45.1
# 1584               6.45.0
# 1585               6.45.0
# 1586               6.45.0
#
# [1587 rows x 5 columns]

# %%
df_skripsi = df.drop(['score','reviewCreatedVersion','Time'],axis = 1)

# %%
df_skripsi
# Out:
#      Sentiment                                            Content
# 0     Negative                    Roboguru harus beli paket… why?
# 1     Positive              Sangat membantu jaya terus ruang guru
# 2     Negative  Video nya ga bisa diputar, padahal udah diundu...
# 3     Negative  Eror terus video nya ,nyesel gue Makai ruang guru
# 4     Positive                          Keren banget deh pokoknya
# ...        ...                                                ...
# 1582  Positive  Bagus banget aplikasinya, bisa membantu saya d...
# 1583  Positive  Aplikasi nya bagus banget apa lagi belajar nya...
# 1584  Negative            Buruk sekali tidak ada mapel ushul fiqh
# 1585  Positive                   Bagussssssssssssss S s s s sss S
# 1586  Positive  Puasss bangatt bisa langsung paham, semoga rua...
#
# [1587 rows x 2 columns]

# %% [markdown]
# # Mendeteksi Positif & Negatif

# %%
df_skripsi.Sentiment.value_counts()
# Out:
# Positive    1088
# Negative     499
# Name: Sentiment, dtype: int64

# %% [markdown]
# # Menampilkan Bagian Kolom pada Data

# %%
df_skripsi.columns = ['label','text_real']

# %%
df_skripsi['text'] = df_skripsi.text_real

# %% [markdown]
# # Menampilkan DataFrame

# %%
df_skripsi
# Out:
#          label                                          text_real  \
# 0     Negative                    Roboguru harus beli paket… why?
# 1     Positive              Sangat membantu jaya terus ruang guru
# 2     Negative  Video nya ga bisa diputar, padahal udah diundu...
# 3     Negative  Eror terus video nya ,nyesel gue Makai ruang guru
# 4     Positive                          Keren banget deh pokoknya
# ...        ...                                                ...
# 1582  Positive  Bagus banget aplikasinya, bisa membantu saya d...
# 1583  Positive  Aplikasi nya bagus banget apa lagi belajar nya...
# 1584  Negative            Buruk sekali tidak ada mapel ushul fiqh
# 1585  Positive                   Bagussssssssssssss S s s s sss S
# 1586  Positive  Puasss bangatt bisa langsung paham, semoga rua...
#
#                                                    text
# 0                       Roboguru harus beli paket… why?
# 1                 Sangat membantu jaya terus ruang guru
# 2     Video nya ga bisa diputar, padahal udah diundu...
# 3     Eror terus video nya ,nyesel gue Makai ruang guru
# 4                             Keren banget deh pokoknya
# ...                                                 ...
# 1582  Bagus banget aplikasinya, bisa membantu saya d...
# 1583  Aplikasi nya bagus banget apa lagi belajar nya...
# 1584            Buruk sekali tidak ada mapel ushul fiqh
# 1585                   Bagussssssssssssss S s s s sss S
# 1586  Puasss bangatt bisa langsung paham, semoga rua...
#
# [1587 rows x 3 columns]

# %% [markdown]
# # Mengubah Huruf Menjadi Kecil

# %%
df_skripsi['text'] = df_skripsi['text'].str.lower()
print('Case Folding Result : \n')
print(df_skripsi['text'].head(5))
print('\n\n\n')
# Out:
# Case Folding Result :
#
# 0                      roboguru harus beli paket… why?
# 1                sangat membantu jaya terus ruang guru
# 2    video nya ga bisa diputar, padahal udah diundu...
# 3    eror terus video nya ,nyesel gue makai ruang guru
# 4                            keren banget deh pokoknya
# Name: text, dtype: object

# %% [markdown]
# # Menghapus Special Karakter dan Url

# %%
def remove_text_special(text):
    # hapus tab, new line, ans back slice
    text = text.replace('\\t'," ").replace('\\n'," ").replace('\\u'," ").replace('\\',"")
    # hapus non ASCII (emot, bahasa china dll)
    text = text.encode('ascii', 'replace').decode('ascii')
    # hapus mention, link, hashtag
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)"," ", text).split())
    # remove URL 
    return text.replace("http://", " ").replace("https://", " ")
df_skripsi['text'] = df_skripsi.text.astype('str')                
df_skripsi['text'] = df_skripsi['text'].apply(remove_text_special)

# %% [markdown]
# # Menghapus Elongasi

# %%
#remove kata yang sengaja dipanjangkan
# seperti bisaaaaaaa -> bisa
def spell(word):
    if re.search(r'([a-zA-Z])\1{2,}', word):
        rword = re.sub(r'([a-zA-Z])\1{2,}','\\1', word)
        return rword
    else:
        return word
df_skripsi['text'] = df_skripsi['text'].apply(spell)

# %% [markdown]
# # Menghapus Tanda Baca

# %%
def remove_punctuation(text):
    return text.translate(str.maketrans("","",string.punctuation))

df_skripsi['text'] = df_skripsi['text'].apply(remove_punctuation)

df_skripsi
# Out:
#          label                                          text_real  \
# 0     Negative                    Roboguru harus beli paket… why?
# 1     Positive              Sangat membantu jaya terus ruang guru
# 2     Negative  Video nya ga bisa diputar, padahal udah diundu...
# 3     Negative  Eror terus video nya ,nyesel gue Makai ruang guru
# 4     Positive                          Keren banget deh pokoknya
# ...        ...                                                ...
# 1582  Positive  Bagus banget aplikasinya, bisa membantu saya d...
# 1583  Positive  Aplikasi nya bagus banget apa lagi belajar nya...
# 1584  Negative            Buruk sekali tidak ada mapel ushul fiqh
# 1585  Positive                   Bagussssssssssssss S s s s sss S
# 1586  Positive  Puasss bangatt bisa langsung paham, semoga rua...
#
#                                                    text
# 0                         roboguru harus beli paket why
# 1                 sangat membantu jaya terus ruang guru
# 2       video nya ga bisa diputar padahal udah diunduh
# 3      eror terus video nya nyesel gue makai ruang guru
# 4                             keren banget deh pokoknya
# ...                                                 ...
# 1582  bagus banget aplikasinya bisa membantu saya da...
# 1583  aplikasi nya bagus banget apa lagi belajar nya...
# 1584            buruk sekali tidak ada mapel ushul fiqh
# 1585                                  bagus s s s s s s
# 1586  puas bangatt bisa langsung paham semoga ruang ...
#
# [1587 rows x 3 columns]

# %% [markdown]
# # Menghapus Enter Tab

# %%
#remove whitespace leading & trailing
def remove_whitespace_LT(text):
    return text.strip()

df_skripsi['text'] = df_skripsi['text'].apply(remove_whitespace_LT)

df_skripsi
# Out:
#          label                                          text_real  \
# 0     Negative                    Roboguru harus beli paket… why?
# 1     Positive              Sangat membantu jaya terus ruang guru
# 2     Negative  Video nya ga bisa diputar, padahal udah diundu...
# 3     Negative  Eror terus video nya ,nyesel gue Makai ruang guru
# 4     Positive                          Keren banget deh pokoknya
# ...        ...                                                ...
# 1582  Positive  Bagus banget aplikasinya, bisa membantu saya d...
# 1583  Positive  Aplikasi nya bagus banget apa lagi belajar nya...
# 1584  Negative            Buruk sekali tidak ada mapel ushul fiqh
# 1585  Positive                   Bagussssssssssssss S s s s sss S
# 1586  Positive  Puasss bangatt bisa langsung paham, semoga rua...
#
#                                                    text
# 0                         roboguru harus beli paket why
# 1                 sangat membantu jaya terus ruang guru
# 2        video nya ga bisa diputar padahal udah diunduh
# 3      eror terus video nya nyesel gue makai ruang guru
# 4                             keren banget deh pokoknya
# ...                                                 ...
# 1582  bagus banget aplikasinya bisa membantu saya da...
# 1583  aplikasi nya bagus banget apa lagi belajar nya...
# 1584            buruk sekali tidak ada mapel ushul fiqh
# 1585                                  bagus s s s s s s
# 1586  puas bangatt bisa langsung paham semoga ruang ...
#
# [1587 rows x 3 columns]

# %% [markdown]
# # Menghapus Spasi yang Terlalu Banyak

# %%
def remove_whitespace_multiple(text):
    return re.sub('\s+',' ',text)

df_skripsi['text'] = df_skripsi['text'].apply(remove_whitespace_multiple)

def remove_singl_char(text):
    return re.sub(r"\b[a-zA-Z]\b", "", text)

df_skripsi['text'] = df_skripsi['text'].apply(remove_singl_char)

df_skripsi
# Out:
#          label                                          text_real  \
# 0     Negative                    Roboguru harus beli paket… why?
# 1     Positive              Sangat membantu jaya terus ruang guru
# 2     Negative  Video nya ga bisa diputar, padahal udah diundu...
# 3     Negative  Eror terus video nya ,nyesel gue Makai ruang guru
# 4     Positive                          Keren banget deh pokoknya
# ...        ...                                                ...
# 1582  Positive  Bagus banget aplikasinya, bisa membantu saya d...
# 1583  Positive  Aplikasi nya bagus banget apa lagi belajar nya...
# 1584  Negative            Buruk sekali tidak ada mapel ushul fiqh
# 1585  Positive                   Bagussssssssssssss S s s s sss S
# 1586  Positive  Puasss bangatt bisa langsung paham, semoga rua...
#
#                                                    text
# 0                         roboguru harus beli paket why
# 1                 sangat membantu jaya terus ruang guru
# 2        video nya ga bisa diputar padahal udah diunduh
# 3      eror terus video nya nyesel gue makai ruang guru
# 4                             keren banget deh pokoknya
# ...                                                 ...
# 1582  bagus banget aplikasinya bisa membantu saya da...
# 1583  aplikasi nya bagus banget apa lagi belajar nya...
# 1584            buruk sekali tidak ada mapel ushul fiqh
# 1585                                        bagus
# 1586  puas bangatt bisa langsung paham semoga ruang ...
#
# [1587 rows x 3 columns]

# %% [markdown]
# # Membuat Kolom text_token Berisi Kumpulan Kata-kata yang dipisah dengan Koma

# %%
df_skripsi = df_skripsi.drop_duplicates()
df_skripsi = df_skripsi[['label','text_real','text']]
df_skripsi['text'] = df_skripsi['text'].str.lower()

def word_tokenize_wrapper(text):
    return word_tokenize(text)

df_skripsi['text_tokens'] = df_skripsi['text'].apply(word_tokenize_wrapper)

# %%
df_skripsi
# Out:
#          label                                          text_real  \
# 0     Negative                    Roboguru harus beli paket… why?
# 1     Positive              Sangat membantu jaya terus ruang guru
# 2     Negative  Video nya ga bisa diputar, padahal udah diundu...
# 3     Negative  Eror terus video nya ,nyesel gue Makai ruang guru
# 4     Positive                          Keren banget deh pokoknya
# ...        ...                                                ...
# 1582  Positive  Bagus banget aplikasinya, bisa membantu saya d...
# 1583  Positive  Aplikasi nya bagus banget apa lagi belajar nya...
# 1584  Negative            Buruk sekali tidak ada mapel ushul fiqh
# 1585  Positive                   Bagussssssssssssss S s s s sss S
# 1586  Positive  Puasss bangatt bisa langsung paham, semoga rua...
#
#                                                    text  \
# 0                         roboguru harus beli paket why
# 1                 sangat membantu jaya terus ruang guru
# 2        video nya ga bisa diputar padahal udah diunduh
# 3      eror terus video nya nyesel gue makai ruang guru
# 4                             keren banget deh pokoknya
# ...                                                 ...
# 1582  bagus banget aplikasinya bisa membantu saya da...
# 1583  aplikasi nya bagus banget apa lagi belajar nya...
# 1584            buruk sekali tidak ada mapel ushul fiqh
# 1585                                        bagus
# 1586  puas bangatt bisa langsung paham semoga ruang ...
#
#                                             text_tokens
# 0                   [roboguru, harus, beli, paket, why]
# 1          [sangat, membantu, jaya, terus, ruang, guru]
# 2     [video, nya, ga, bisa, diputar, padahal, udah,...
# 3     [eror, terus, video, nya, nyesel, gue, makai, ...
# 4                        [keren, banget, deh, pokoknya]
# ...                                                 ...
# 1582  [bagus, banget, aplikasinya, bisa, membantu, s...
# 1583  [aplikasi, nya, bagus, banget, apa, lagi, bela...
# 1584    [buruk, sekali, tidak, ada, mapel, ushul, fiqh]
# 1585                                            [bagus]
# 1586  [puas, bangatt, bisa, langsung, paham, semoga,...
#
# [1451 rows x 4 columns]

# %% [markdown]
# # Menghapus Stopwords

# %%
list_stopwords = stopwords.words('indonesian')
list_stopwords.extend(["yg", "dg", "rt", "dgn", "ny", "d", 'klo', 
                       'kalo', 'amp', 'biar', 'bikin', 'bilang', 
                       'gak', 'ga', 'krn', 'nya', 'nih', 'sih', 
                       'si', 'tau', 'tdk', 'tuh', 'utk', 'ya', 
                       'jd', 'jgn', 'sdh', 'aja', 'n', 't', 
                       'nyg', 'hehe', 'pen', 'u', 'nan', 'loh', 'rt',
                       '&amp', 'yah'])

txt_stopword = pd.read_csv("stopwords.txt", names= ["stopwords"], header = None)
list_stopwords.extend(txt_stopword["stopwords"][0].split(' '))
list_stopwords = set(list_stopwords)
def stopwords_removal(words):
    return [word for word in words if word not in list_stopwords]
df_skripsi['Stopwords'] = df_skripsi['text_tokens'].apply(stopwords_removal)

# %%
list_stopwords
# Out:
# {'',
#  'bwa',
#  'bulan',
#  'again',
#  'bas',
#  'berbagai',
#  'ts',
#  'aku',
#  'setempat',
#  'waduhhh',
#  'sbg',
#  'semampu',
#  'km',
#  'ckakak',
#  'hadeh',
#  'mo',
#  'blom',
#  'selama',
#  'asuuu',
#  'stand',
#  'soalnya',
#  'buat',
#  'umum',
#  'aaaakkkhhhhhh',
#  'dimaksud',
#  'bersama',
#  'teh',
#  'tahun',
#  'always',
#  'pohonnnn',
#  'ng',
#  'dalam',
#  'woyyyyyy',
#  'apkah',
#  'eiy',
#  'wkwaww',
#  'baru',
#  'demikianlah',
#  'menanti',
#  'makanya',
#  'woyyy',
#  'setidak-tidaknya',
#  'ingat',
#  'mul',
#  'hny',
#  'h',
#  'kagak',
#  'yang',
#  'ditanya',
#  'makin',
#  'tahu',
#  'bagaimana',
#  'waaahh',
#  'udahlah',
#  'disebut',
#  'cuma',
#  'akankah',
#  'uhuii',
#  'ing',
#  'siiiiiiiih',
#  'dll',
#  'ibaratnya',
#  'tiap',
#  'betulkah',
#  'mempertanyakan',
#  'sekaranglah',
#  'ooo',
#  'syyo',
#  'dech',
#  'third',
#  'apa',
#  'setinggi',
#  'si',
#  'artinya',
#  'diketahui',
#  'kenapa',
#  'soal',
#  'the',
#  'tang',
#  'apaaaaa',
#  'toet',
#  'dipersoalkan',
#  'sebaik-baiknya',
#  'bkal',
#  'sayrap',
#  'waahh',
#  'amp',
#  'alah',
#  'jengn',
#  'ditunjukkan',
#  'akse',
#  'gig',
#  'penc',
#  'apalagi',
#  'dimulai',
#  'kah',
#  'diantaranya',
#  'moga',
#  'heeeeellloooo',
#  'fir',
#  'jgn',
#  'liyat',
#  'nuh',
#  'akh',
#  'akubingin',
#  'mksh',
#  'say',
#  'astagpirullohalazmin',
#  'semampunya',
#  'coy',
#  'benarkah',
#  'diri',
#  'diberikannya',
#  'elah',
#  'wen',
#  'ketika',
#  'arti',
#  'mampukah',
#  'gitulah',
#  'yaa',
#  'klw',
#  'yah',
#  'beg',
#  'daripada',
#  'kapan',
#  'follow',
#  'gom',
#  'ker',
#  'menurut',
#  'jawaban',
#  'sedemikian',
#  'dibuat',
#  'blenggg',
#  'selaku',
#  'jadinya',
#  'ucapnya',
#  'ndy',
#  'josss',
#  'aajh',
#  'menyeluruh',
#  'ditujukan',
#  'jagan',
#  'hari',
#  'jl',
#  'heleh',
#  'kal',
#  'perlunya',
#  'ayoo',
#  'ja',
#  'biasanya',
#  'udah',
#  'tepat',
#  'p',
#  'rrrrrr',
#  'cie',
#  'sering',
#  'joosss',
#  'atas',
#  'toeeettt',
#  'antara',
#  'terlalu',
#  'hal',
#  'ky',
#  'akulah',
#  'prop',
#  'tik',
#  'yukk',
#  'kapanpun',
#  'bla',
#  'ahhh',
#  'semata',
#  'baiklah',
#  'yup',
#  'tragedy',
#  'sosi',
#  'sama-sama',
#  'eih',
#  'agak',
#  'gaess',
#  'diperlihatkan',
#  'backstreet',
#  'ibu',
#  'ternyata',
#  'diminta',
#  'mendapat',
#  'berkeinginan',
#  'wj',
#  'dapat',
#  'gass',
#  'reply',
#  'ol',
#  'sbgai',
#  'keri',
#  'diakhiri',
#  'going',
#  'siapa',
#  'diungkapkan',
#  'woooy',
#  'memihak',
#  'dtg',
#  'kelihatannya',
#  'ee',
#  'deng',
#  'al',
#  'ne',
#  'itukah',
#  'bers',
#  'jangan',
#  'sekitar',
#  'mb',
#  'dikerjakan',
#  'am',
#  'terbanyak',
#  'er',
#  'sich',
#  'tur',
#  'untuk',
#  'sj',
#  'memberi',
#  'segalanya',
#  'begi',
#  'tah',
#  'tanya',
#  'segera',
#  'koit',
#  'kerja',
#  'y',
#  'kemudian',
#  'orang',
#  'cokkk',
#  'akutuh',
#  'ajaa',
#  'so',
#  'mengibaratkannya',
#  'anta',
#  'awokawokawok',
#  'haahaaa',
#  'terkira',
#  'dab',
#  'oh',
#  'belakangan',
#  'keseluruhannya',
#  'menginginkan',
#  'uhuyyy',
#  'meminta',
#  'poi',
#  'lwt',
#  'pd',
#  'terdapat',
#  'sama',
#  'ncuup',
#  'ken',
#  'kita',
#  'ade',
#  'apakh',
#  'dikatakan',
#  'diibaratkan',
#  'bur',
#  'di',
#  'diberikan',
#  'disini',
#  'yokk',
#  'yan',
#  'tadi',
#  'macam',
#  's',
#  'se',
#  'semisal',
#  'eeeh',
#  'eeh',
#  'krn',
#  'ot',
#  'jah',
#  'melihatnya',
#  'sekitarnya',
#  'pt',
#  'gsk',
#  'pastilah',
#  'seberapa',
#  'semua',
#  'mere',
#  'dipastikan',
#  'nympek',
#  'rang',
#  'mata',
#  'pula',
#  'juaraaa',
#  'lc',
#  'ajjaaa',
#  'pe',
#  'if',
#  'seluruh',
#  'lur',
#  'jleb',
#  'sec',
#  'berturut',
#  'hehehe',
#  'dwatkn',
#  'that',
#  'jumlah',
#  'aiiihhh',
#  'awal',
#  'siip',
#  'mengatakan',
#  'persoalan',
#  'mempergunakan',
#  'ma',
#  'tentu',
#  'meskipun',
#  'melakukan',
#  'wk',
#  'meyakinkan',
#  'saa',
#  'ra',
#  'tentunya',
#  'kami',
#  'sejauh',
#  'wahhh',
#  'semaunya',
#  'menuju',
#  'su',
#  'ht',
#  'diibaratkannya',
#  'sepantasnyalah',
#  'mlm',
#  'adapun',
#  'berlebihan',
#  'tampaknya',
#  'kembali',
#  'seolah-olah',
#  'pertama-tama',
#  'sejak',
#  'menjawab',
#  'mba',
#  'donk',
#  'wadoooohhh',
#  'dituturkannya',
#  'berkehendak',
#  'utk',
#  'tuu',
#  'berakhirlah',
#  'ypk',
#  'aga',
#  'woooyyyyy',
#  'asiiikkk',
#  'luar',
#  'bagaikan',
#  'woyyyyy',
#  'o',
#  'death',
#  'bs',
#  'mirip',
#  'jomp',
#  'jee',
#  'couldn',
#  'klop',
#  'ser',
#  'pp',
#  'tt',
#  'sud',
#  'diakhirinya',
#  'loooh',
#  'assuuu',
#  'keleus',
#  'selama-lamanya',
#  'gak',
#  'katakanlah',
#  'kasus',
#  'dgn',
#  'tuju',
#  'menyer',
#  'men',
#  'ca',
#  'ajasi',
#  'broo',
#  'klu',
#  'hadeeehhh',
#  'helo',
#  'kua',
#  'jelas',
#  'dibia',
#  'iyaa',
#  'ditunjuki',
#  'sajalah',
#  'dlm',
#  'bahahaha',
#  'beginilah',
#  'alhamdulillah',
#  'twe',
#  'udahan',
#  'nantinya',
#  'menandaskan',
#  'imb',
#  'gaesss',
#  'ieu',
#  'oei',
#  'bkn',
#  'bnyk',
#  'ten',
#  'sebagaimana',
#  'lum',
#  'a',
#  'berkenaan',
#  'tuip',
#  'lewat',
#  'ms',
#  'asu',
#  'care',
#  'sekaligus',
#  'diar',
#  'sangat',
#  'diingat',
#  'depan',
#  'ditandaskan',
#  'tong',
#  'sesegera',
#  'sekarang',
#  'berakhir',
#  'apakah',
#  'sekurang-kurangnya',
#  'smple',
#  'neg',
#  'bakal',
#  'meski',
#  'sebagian',
#  'terakhir',
#  'karenanya',
#  'twit',
#  'manalagi',
#  'md',
#  'ahelah',
#  'menanyai',
#  'gih',
#  'hend',
#  'j',
#  'aww',
#  'akan',
#  'semula',
#  'kemungkinannya',
#  'iya',
#  'kelima',
#  'enak',
#  'bukankah',
#  'paling',
#  'dulu',
#  'dekat',
#  'ajaah',
#  'jo',
#  'jangn',
#  'asek',
#  'x',
#  'harusnya',
#  'haaa',
#  'cuy',
#  'ting',
#  'dimulailah',
#  'kwak',
#  'db',
#  'kelamaan',
#  'con',
#  'huhuhu',
#  'preesss',
#  'memberikan',
#  'sam',
#  'uppppsss',
#  'agar',
#  'salam',
#  'beer',
#  'cuih',
#  'diucapkannya',
#  'jadi',
#  'r',
#  'pertanyaan',
#  'dengan',
#  'seorang',
#  'sek',
#  'ji',
#  'fya',
#  'da',
#  'ditanyai',
#  'tersampaikan',
#  'ungkapnya',
#  'pen',
#  'apalgi',
#  'semata-mata',
#  'tanyanya',
#  'nie',
#  'digunakan',
#  'mulailah',
#  'sedikit',
#  'astaghfrullah',
#  'ditunjuk',
#  'trus',
#  'punya',
#  'terhadapnya',
#  'gimana',
#  'spya',
#  'turut',
#  'apaaaannnn',
#  'no',
#  'huaaahaaaaa',
#  'kok',
#  'ama',
#  'ialah',
#  'piyek',
#  'dahhh',
#  'ki',
#  'menjadi',
#  'cukupkah',
#  'bena',
#  'terus',
#  'tambah',
#  'dg',
#  'misal',
#  'at',
#  'diketahuinya',
#  'sekiranya',
#  'bila',
#  'nguyu',
#  'termasuk',
#  'usai',
#  'tiga',
#  'aa',
#  'sebuah',
#  'sebutnya',
#  'dar',
#  'tuk',
#  'kedua',
#  'huh',
#  'lohhhh',
#  'met',
#  'boys',
#  'sihhh',
#  'lebih',
#  'tir',
#  'aseekk',
#  'sebagainya',
#  'naik',
#  'sudah',
#  'bg',
#  'are',
#  'moh',
#  'berturut-turut',
#  'menuturkan',
#  'sebaik',
#  'tambahnya',
#  'walaupun',
#  'ba',
#  'man',
#  'malah',
#  'piye',
#  'in',
#  'seh',
#  'haduh',
#  'bermacam',
#  'ha',
#  'sibuj',
#  'baik',
#  'sedangkan',
#  'aplagi',
#  'neeh',
#  'aplg',
#  'owalah',
#  'seluruhnya',
#  'bersiap',
#  'lat',
#  'mendatangkan',
#  'come',
#  'yaitu',
#  'aud',
#  'dahulu',
#  'ttg',
#  'ujar',
#  'dipunyai',
#  'memperkirakan',
#  'his',
#  'sampai',
#  'caranya',
#  'sejenak',
#  'tinggi',
#  'sendirian',
#  'yakali',
#  'yee',
#  'don',
#  'awwww',
#  'kepada',
#  'gn',
#  'ay',
#  'per',
#  'menunjuknya',
#  'mampu',
#  'mrk',
#  'samlekum',
#  'karepmu',
#  'jelaslah',
#  'nah',
#  'bat',
#  'ngoahahahahahaaa',
#  'k',
#  'tanyakan',
#  'harus',
#  'wal',
#  'emng',
#  'acan',
#  'apabedanya',
#  'jumlahnya',
#  'tutur',
#  'th',
#  'ataupun',
#  'tentang',
#  'hk',
#  'apas',
#  'jdi',
#  'jat',
#  'sudahkah',
#  'ni',
#  'woii',
#  'kini',
#  'mbok',
#  'tsb',
#  'e',
#  'astagaaaaa',
#  'or',
#  'ny',
#  'uittt',
#  'ge',
#  'waduh',
#  'jikalau',
#  'lamanya',
#  'dini',
#  'bgt',
#  'memang',
#  'melihat',
#  'setiba',
#  'an',
#  'wi',
#  'byk',
#  'anca',
#  'dlu',
#  'bain',
#  'abc',
#  'yng',
#  'berapakah',
#  'ros',
#  'rb',
#  'ju',
#  'where',
#  'tuh',
#  'ehhhh',
#  'disinilah',
#  'cik',
#  'nya',
#  'wuiih',
#  'deh',
#  'fa',
#  'meyakini',
#  'aka',
#  'tadinya',
#  'aang',
#  'peel',
#  'yu',
#  'ndezz',
#  'biasa',
#  'dimintai',
#  'ngak',
#  'ucap',
#  'tho',
#  'sekalian',
#  'ujarnya',
#  'awokaowkaowk',
#  'ailapyupul',
#  'aduhh',
#  'saatnya',
#  'kali',
#  'jg',
#  'sejumlah',
#  'benarlah',
#  'sin',
#  'atuh',
#  'road',
#  'menegaskan',
#  'sepertinya',
#  'menyangkut',
#  'serupa',
#  'hehe',
#  'ada',
#  'adoh',
#  'inilah',
#  'sebagai',
#  'ayyy',
#  'meng',
#  'dimaksudnya',
#  'pentingnya',
#  'hadap',
#  'dil',
#  'seseorang',
#  'menyebutkan',
#  'apaa',
#  'berlangsung',
#  'biyar',
#  'asn',
#  'diperkirakan',
#  'ntap',
#  'berjumlah',
#  'dipertanyakan',
#  'neh',
#  'terb',
#  'ckckck',
#  'bukan',
#  'ikut',
#  'joss',
#  'ping',
#  'omg',
#  'oleh',
#  'aduch',
#  'cuk',
#  'kepadanya',
#  'ti',
#  'peesai',
#  'tandasnya',
#  'seperlunya',
#  'begini',
#  'asalkan',
#  'bant',
#  'berkali-kali',
#  'neng',
#  'bekerja',
#  'dirinya',
#  'na',
#  'bung',
#  'mr',
#  'ups',
#  'mantaaapp',
#  'astaga',
#  'sib',
#  'nanti',
#  'yaaa',
#  'nis',
#  'merupakan',
#  'piee',
#  'f',
#  'biarpun',
#  'diperlukan',
#  'kamilah',
#  'mw',
#  'wuuuu',
#  'v',
#  'ehe',
#  'seharusnya',
#  'aph',
#  'kemungkinan',
#  'walau',
#  'kes',
#  'mwnyedihkan',
#  'sig',
#  'inikah',
#  'antar',
#  'seringnya',
#  'menghendaki',
#  'mengatakannya',
#  'dilakukan',
#  'var',
#  'pea',
#  'diberi',
#  'tak',
#  'hallo',
#  'sekurangnya',
#  'te',
#  'berujar',
#  'pem',
#  'berawal',
#  'kpn',
#  'wooiiii',
#  'jln',
#  'by',
#  'lanjut',
#  'yg',
#  'sesama',
#  'wis',
#  'asee',
#  'euy',
#  'ta',
#  'sampai-sampai',
#  'awalnya',
#  'bertanya',
#  'para',
#  'itulah',
#  'siap',
#  'ilah',
#  'oi',
#  'angg',
#  'kam',
#  'yes',
#  'dp',
#  'menggunakan',
#  'dng',
#  'menunjukkan',
#  'lg',
#  'ea',
#  'sebegitu',
#  'tan',
#  'kiranya',
#  'ojo',
#  'yo',
#  'sebisanya',
#  'mon',
#  'bara',
#  'ntar',
#  'laahh',
#  'olehnya',
#  'cukup',
#  'mempersoalkan',
#  'm',
#  'asyiapp',
#  'gitu',
#  'apalg',
#  'masing',
#  'ajaaah',
#  'ih',
#  'jngn',
#  'mistakes',
#  'n',
#  'dink',
#  'of',
#  'mendatangi',
#  'sook',
#  'lha',
#  'wahaye',
#  'beberapa',
#  'tegasnya',
#  'selalu',
#  'dimungkinkan',
#  'dilalui',
#  'beginikah',
#  'mengerjakan',
#  'ntah',
#  'dimaksudkan',
#  'gt',
#  'tidakkah',
#  'ntr',
#  'kadar',
#  'betul',
#  'bap',
#  'zzzzzz',
#  'braderrr',
#  'bgini',
#  'maaaaad',
#  'terlebih',
#  'fl',
#  'share',
#  'pertanyakan',
#  'bersiap-siap',
#  'ab',
#  'ksh',
#  'manakala',
#  'wa',
#  'secara',
#  'balik',
#  'bermacam-macam',
#  'lama',
#  'lho',
#  'cam',
#  'can',
#  'penting',
#  'lagian',
#  'bagiamana',
#  'practice',
#  'msh',
#  'bahwasanya',
#  'nk',
#  'menunjuk',
#  'teringat',
#  'ai',
#  'terjadi',
#  'ben',
#  'hello',
#  'uea',
#  'ntu',
#  'hendak',
#  'terdahulu',
#  'nyok',
#  'membuat',
#  'toh',
#  'waktunya',
#  'gun',
#  'terutama',
#  'wih',
#  'zzz',
#  'entahlah',
#  'jugaa',
#  'sssst',
#  'hadeehhh',
#  'dua',
#  'begitu',
#  'sebesar',
#  'wyg',
#  'theatre',
#  'may',
#  'datang',
#  'ah',
#  'malahan',
#  'jelaskan',
#  'bagaimanapun',
#  'nyata',
#  'yuk',
#  'sebenarnya',
#  'ahhhhh',
#  'aahhh',
#  'ahhay',
#  'beh',
#  'peri',
#  'yeee',
#  'dituturkan',
#  'guna',
#  'akhirx',
#  'ajj',
#  'mp',
#  'ci',
#  'lalu',
#  'bagai',
#  'seperti',
#  'apabila',
#  'mas',
#  'djangan',
#  'baaeerrree',
#  't',
#  'tau',
#  'pis',
#  'kinilah',
#  'ahhahshahahsha',
#  'tiba',
#  'didatangkan',
#  'dimisalkan',
#  'rupa',
#  'wihhhhh',
#  'kalian',
#  'sdh',
#  'po',
#  'ibarat',
#  'pada',
#  'sekrg',
#  'dialah',
#  'apain',
#  'setibanya',
#  'dst',
#  'diperbuatnya',
#  'antaranya',
#  'selain',
#  'masa',
#  'ngo',
#  'mm',
#  'mem',
#  'wala',
#  'jauh',
#  'berakhirnya',
#  'sesampai',
#  'sudahlah',
#  'syi',
#  'sendiri',
#  'mengetahui',
#  'pihak',
#  'kudu',
#  'horeee',
#  'bah',
#  'berikan',
#  'bukanlah',
#  'qckog',
#  'good',
#  'berupa',
#  'mpod',
#  'peeeeetttt',
#  'pic',
#  'dehh',
#  'menyatakan',
#  'tidak',
#  'ka',
#  'le',
#  'fii',
#  'juga',
#  'bahwa',
#  'hayo',
#  'sih',
#  'mengungkapkan',
#  'sebutlah',
#  'nek',
#  'ga',
#  'tegas',
#  'tsbt',
#  'waktu',
#  'biar',
#  'sy',
#  'lo',
#  'lahhh',
#  'hai',
#  'merasa',
#  'kem',
#  'terasa',
#  'koe',
#  'nyang',
#  'tempat',
#  ...}

# %%
df_skripsi
# Out:
#          label                                          text_real  \
# 0     Negative                    Roboguru harus beli paket… why?
# 1     Positive              Sangat membantu jaya terus ruang guru
# 2     Negative  Video nya ga bisa diputar, padahal udah diundu...
# 3     Negative  Eror terus video nya ,nyesel gue Makai ruang guru
# 4     Positive                          Keren banget deh pokoknya
# ...        ...                                                ...
# 1582  Positive  Bagus banget aplikasinya, bisa membantu saya d...
# 1583  Positive  Aplikasi nya bagus banget apa lagi belajar nya...
# 1584  Negative            Buruk sekali tidak ada mapel ushul fiqh
# 1585  Positive                   Bagussssssssssssss S s s s sss S
# 1586  Positive  Puasss bangatt bisa langsung paham, semoga rua...
#
#                                                    text  \
# 0                         roboguru harus beli paket why
# 1                 sangat membantu jaya terus ruang guru
# 2        video nya ga bisa diputar padahal udah diunduh
# 3      eror terus video nya nyesel gue makai ruang guru
# 4                             keren banget deh pokoknya
# ...                                                 ...
# 1582  bagus banget aplikasinya bisa membantu saya da...
# 1583  aplikasi nya bagus banget apa lagi belajar nya...
# 1584            buruk sekali tidak ada mapel ushul fiqh
# 1585                                        bagus
# 1586  puas bangatt bisa langsung paham semoga ruang ...
#
#                                             text_tokens  \
# 0                   [roboguru, harus, beli, paket, why]
# 1          [sangat, membantu, jaya, terus, ruang, guru]
# 2     [video, nya, ga, bisa, diputar, padahal, udah,...
# 3     [eror, terus, video, nya, nyesel, gue, makai, ...
# 4                        [keren, banget, deh, pokoknya]
# ...                                                 ...
# 1582  [bagus, banget, aplikasinya, bisa, membantu, s...
# 1583  [aplikasi, nya, bagus, banget, apa, lagi, bela...
# 1584    [buruk, sekali, tidak, ada, mapel, ushul, fiqh]
# 1585                                            [bagus]
# 1586  [puas, bangatt, bisa, langsung, paham, semoga,...
#
#                                               Stopwords
# 0                               [roboguru, beli, paket]
# 1                         [membantu, jaya, ruang, guru]
# 2                             [video, diputar, diunduh]
# 3        [eror, video, nyesel, gue, makai, ruang, guru]
# 4                             [keren, banget, pokoknya]
# ...                                                 ...
# 1582    [bagus, banget, aplikasinya, membantu, belajar]
# 1583  [aplikasi, bagus, banget, belajar, aulia, bint...
# 1584                        [buruk, mapel, ushul, fiqh]
# 1585                                            [bagus]
# 1586  [puas, bangatt, paham, semoga, ruang, guru, su...
#
# [1451 rows x 5 columns]

# %% [markdown]
# # Distribusi Frekuensi NLTK

# %%
def freqDist_wrapper(text):
    return FreqDist(text)

df_skripsi['text_tokens_fdist'] = df_skripsi['text_tokens'].apply(freqDist_wrapper)

print('Frequency Tokens : \n') 
print(df_skripsi['text_tokens_fdist'].head().apply(lambda x : x.most_common()))
# Out:
# Frequency Tokens :
#
# 0    [(roboguru, 1), (harus, 1), (beli, 1), (paket,...
# 1    [(sangat, 1), (membantu, 1), (jaya, 1), (terus...
# 2    [(video, 1), (nya, 1), (ga, 1), (bisa, 1), (di...
# 3    [(eror, 1), (terus, 1), (video, 1), (nya, 1), ...
# 4    [(keren, 1), (banget, 1), (deh, 1), (pokoknya,...
# Name: text_tokens_fdist, dtype: object

# %% [markdown]
# # Filtering (Penghapusan Stopwords) / Normalisasi

# %%
from nltk.corpus import stopwords

# %%
list_stopwords = stopwords.words('indonesian')

# %%
list_stopwords
# Out:
# ['ada',
#  'adalah',
#  'adanya',
#  'adapun',
#  'agak',
#  'agaknya',
#  'agar',
#  'akan',
#  'akankah',
#  'akhir',
#  'akhiri',
#  'akhirnya',
#  'aku',
#  'akulah',
#  'amat',
#  'amatlah',
#  'anda',
#  'andalah',
#  'antar',
#  'antara',
#  'antaranya',
#  'apa',
#  'apaan',
#  'apabila',
#  'apakah',
#  'apalagi',
#  'apatah',
#  'artinya',
#  'asal',
#  'asalkan',
#  'atas',
#  'atau',
#  'ataukah',
#  'ataupun',
#  'awal',
#  'awalnya',
#  'bagai',
#  'bagaikan',
#  'bagaimana',
#  'bagaimanakah',
#  'bagaimanapun',
#  'bagi',
#  'bagian',
#  'bahkan',
#  'bahwa',
#  'bahwasanya',
#  'baik',
#  'bakal',
#  'bakalan',
#  'balik',
#  'banyak',
#  'bapak',
#  'baru',
#  'bawah',
#  'beberapa',
#  'begini',
#  'beginian',
#  'beginikah',
#  'beginilah',
#  'begitu',
#  'begitukah',
#  'begitulah',
#  'begitupun',
#  'bekerja',
#  'belakang',
#  'belakangan',
#  'belum',
#  'belumlah',
#  'benar',
#  'benarkah',
#  'benarlah',
#  'berada',
#  'berakhir',
#  'berakhirlah',
#  'berakhirnya',
#  'berapa',
#  'berapakah',
#  'berapalah',
#  'berapapun',
#  'berarti',
#  'berawal',
#  'berbagai',
#  'berdatangan',
#  'beri',
#  'berikan',
#  'berikut',
#  'berikutnya',
#  'berjumlah',
#  'berkali-kali',
#  'berkata',
#  'berkehendak',
#  'berkeinginan',
#  'berkenaan',
#  'berlainan',
#  'berlalu',
#  'berlangsung',
#  'berlebihan',
#  'bermacam',
#  'bermacam-macam',
#  'bermaksud',
#  'bermula',
#  'bersama',
#  'bersama-sama',
#  'bersiap',
#  'bersiap-siap',
#  'bertanya',
#  'bertanya-tanya',
#  'berturut',
#  'berturut-turut',
#  'bertutur',
#  'berujar',
#  'berupa',
#  'besar',
#  'betul',
#  'betulkah',
#  'biasa',
#  'biasanya',
#  'bila',
#  'bilakah',
#  'bisa',
#  'bisakah',
#  'boleh',
#  'bolehkah',
#  'bolehlah',
#  'buat',
#  'bukan',
#  'bukankah',
#  'bukanlah',
#  'bukannya',
#  'bulan',
#  'bung',
#  'cara',
#  'caranya',
#  'cukup',
#  'cukupkah',
#  'cukuplah',
#  'cuma',
#  'dahulu',
#  'dalam',
#  'dan',
#  'dapat',
#  'dari',
#  'daripada',
#  'datang',
#  'dekat',
#  'demi',
#  'demikian',
#  'demikianlah',
#  'dengan',
#  'depan',
#  'di',
#  'dia',
#  'diakhiri',
#  'diakhirinya',
#  'dialah',
#  'diantara',
#  'diantaranya',
#  'diberi',
#  'diberikan',
#  'diberikannya',
#  'dibuat',
#  'dibuatnya',
#  'didapat',
#  'didatangkan',
#  'digunakan',
#  'diibaratkan',
#  'diibaratkannya',
#  'diingat',
#  'diingatkan',
#  'diinginkan',
#  'dijawab',
#  'dijelaskan',
#  'dijelaskannya',
#  'dikarenakan',
#  'dikatakan',
#  'dikatakannya',
#  'dikerjakan',
#  'diketahui',
#  'diketahuinya',
#  'dikira',
#  'dilakukan',
#  'dilalui',
#  'dilihat',
#  'dimaksud',
#  'dimaksudkan',
#  'dimaksudkannya',
#  'dimaksudnya',
#  'diminta',
#  'dimintai',
#  'dimisalkan',
#  'dimulai',
#  'dimulailah',
#  'dimulainya',
#  'dimungkinkan',
#  'dini',
#  'dipastikan',
#  'diperbuat',
#  'diperbuatnya',
#  'dipergunakan',
#  'diperkirakan',
#  'diperlihatkan',
#  'diperlukan',
#  'diperlukannya',
#  'dipersoalkan',
#  'dipertanyakan',
#  'dipunyai',
#  'diri',
#  'dirinya',
#  'disampaikan',
#  'disebut',
#  'disebutkan',
#  'disebutkannya',
#  'disini',
#  'disinilah',
#  'ditambahkan',
#  'ditandaskan',
#  'ditanya',
#  'ditanyai',
#  'ditanyakan',
#  'ditegaskan',
#  'ditujukan',
#  'ditunjuk',
#  'ditunjuki',
#  'ditunjukkan',
#  'ditunjukkannya',
#  'ditunjuknya',
#  'dituturkan',
#  'dituturkannya',
#  'diucapkan',
#  'diucapkannya',
#  'diungkapkan',
#  'dong',
#  'dua',
#  'dulu',
#  'empat',
#  'enggak',
#  'enggaknya',
#  'entah',
#  'entahlah',
#  'guna',
#  'gunakan',
#  'hal',
#  'hampir',
#  'hanya',
#  'hanyalah',
#  'hari',
#  'harus',
#  'haruslah',
#  'harusnya',
#  'hendak',
#  'hendaklah',
#  'hendaknya',
#  'hingga',
#  'ia',
#  'ialah',
#  'ibarat',
#  'ibaratkan',
#  'ibaratnya',
#  'ibu',
#  'ikut',
#  'ingat',
#  'ingat-ingat',
#  'ingin',
#  'inginkah',
#  'inginkan',
#  'ini',
#  'inikah',
#  'inilah',
#  'itu',
#  'itukah',
#  'itulah',
#  'jadi',
#  'jadilah',
#  'jadinya',
#  'jangan',
#  'jangankan',
#  'janganlah',
#  'jauh',
#  'jawab',
#  'jawaban',
#  'jawabnya',
#  'jelas',
#  'jelaskan',
#  'jelaslah',
#  'jelasnya',
#  'jika',
#  'jikalau',
#  'juga',
#  'jumlah',
#  'jumlahnya',
#  'justru',
#  'kala',
#  'kalau',
#  'kalaulah',
#  'kalaupun',
#  'kalian',
#  'kami',
#  'kamilah',
#  'kamu',
#  'kamulah',
#  'kan',
#  'kapan',
#  'kapankah',
#  'kapanpun',
#  'karena',
#  'karenanya',
#  'kasus',
#  'kata',
#  'katakan',
#  'katakanlah',
#  'katanya',
#  'ke',
#  'keadaan',
#  'kebetulan',
#  'kecil',
#  'kedua',
#  'keduanya',
#  'keinginan',
#  'kelamaan',
#  'kelihatan',
#  'kelihatannya',
#  'kelima',
#  'keluar',
#  'kembali',
#  'kemudian',
#  'kemungkinan',
#  'kemungkinannya',
#  'kenapa',
#  'kepada',
#  'kepadanya',
#  'kesampaian',
#  'keseluruhan',
#  'keseluruhannya',
#  'keterlaluan',
#  'ketika',
#  'khususnya',
#  'kini',
#  'kinilah',
#  'kira',
#  'kira-kira',
#  'kiranya',
#  'kita',
#  'kitalah',
#  'kok',
#  'kurang',
#  'lagi',
#  'lagian',
#  'lah',
#  'lain',
#  'lainnya',
#  'lalu',
#  'lama',
#  'lamanya',
#  'lanjut',
#  'lanjutnya',
#  'lebih',
#  'lewat',
#  'lima',
#  'luar',
#  'macam',
#  'maka',
#  'makanya',
#  'makin',
#  'malah',
#  'malahan',
#  'mampu',
#  'mampukah',
#  'mana',
#  'manakala',
#  'manalagi',
#  'masa',
#  'masalah',
#  'masalahnya',
#  'masih',
#  'masihkah',
#  'masing',
#  'masing-masing',
#  'mau',
#  'maupun',
#  'melainkan',
#  'melakukan',
#  'melalui',
#  'melihat',
#  'melihatnya',
#  'memang',
#  'memastikan',
#  'memberi',
#  'memberikan',
#  'membuat',
#  'memerlukan',
#  'memihak',
#  'meminta',
#  'memintakan',
#  'memisalkan',
#  'memperbuat',
#  'mempergunakan',
#  'memperkirakan',
#  'memperlihatkan',
#  'mempersiapkan',
#  'mempersoalkan',
#  'mempertanyakan',
#  'mempunyai',
#  'memulai',
#  'memungkinkan',
#  'menaiki',
#  'menambahkan',
#  'menandaskan',
#  'menanti',
#  'menanti-nanti',
#  'menantikan',
#  'menanya',
#  'menanyai',
#  'menanyakan',
#  'mendapat',
#  'mendapatkan',
#  'mendatang',
#  'mendatangi',
#  'mendatangkan',
#  'menegaskan',
#  'mengakhiri',
#  'mengapa',
#  'mengatakan',
#  'mengatakannya',
#  'mengenai',
#  'mengerjakan',
#  'mengetahui',
#  'menggunakan',
#  'menghendaki',
#  'mengibaratkan',
#  'mengibaratkannya',
#  'mengingat',
#  'mengingatkan',
#  'menginginkan',
#  'mengira',
#  'mengucapkan',
#  'mengucapkannya',
#  'mengungkapkan',
#  'menjadi',
#  'menjawab',
#  'menjelaskan',
#  'menuju',
#  'menunjuk',
#  'menunjuki',
#  'menunjukkan',
#  'menunjuknya',
#  'menurut',
#  'menuturkan',
#  'menyampaikan',
#  'menyangkut',
#  'menyatakan',
#  'menyebutkan',
#  'menyeluruh',
#  'menyiapkan',
#  'merasa',
#  'mereka',
#  'merekalah',
#  'merupakan',
#  'meski',
#  'meskipun',
#  'meyakini',
#  'meyakinkan',
#  'minta',
#  'mirip',
#  'misal',
#  'misalkan',
#  'misalnya',
#  'mula',
#  'mulai',
#  'mulailah',
#  'mulanya',
#  'mungkin',
#  'mungkinkah',
#  'nah',
#  'naik',
#  'namun',
#  'nanti',
#  'nantinya',
#  'nyaris',
#  'nyatanya',
#  'oleh',
#  'olehnya',
#  'pada',
#  'padahal',
#  'padanya',
#  'pak',
#  'paling',
#  'panjang',
#  'pantas',
#  'para',
#  'pasti',
#  'pastilah',
#  'penting',
#  'pentingnya',
#  'per',
#  'percuma',
#  'perlu',
#  'perlukah',
#  'perlunya',
#  'pernah',
#  'persoalan',
#  'pertama',
#  'pertama-tama',
#  'pertanyaan',
#  'pertanyakan',
#  'pihak',
#  'pihaknya',
#  'pukul',
#  'pula',
#  'pun',
#  'punya',
#  'rasa',
#  'rasanya',
#  'rata',
#  'rupanya',
#  'saat',
#  'saatnya',
#  'saja',
#  'sajalah',
#  'saling',
#  'sama',
#  'sama-sama',
#  'sambil',
#  'sampai',
#  'sampai-sampai',
#  'sampaikan',
#  'sana',
#  'sangat',
#  'sangatlah',
#  'satu',
#  'saya',
#  'sayalah',
#  'se',
#  'sebab',
#  'sebabnya',
#  'sebagai',
#  'sebagaimana',
#  'sebagainya',
#  'sebagian',
#  'sebaik',
#  'sebaik-baiknya',
#  'sebaiknya',
#  'sebaliknya',
#  'sebanyak',
#  'sebegini',
#  'sebegitu',
#  'sebelum',
#  'sebelumnya',
#  'sebenarnya',
#  'seberapa',
#  'sebesar',
#  'sebetulnya',
#  'sebisanya',
#  'sebuah',
#  'sebut',
#  'sebutlah',
#  'sebutnya',
#  'secara',
#  'secukupnya',
#  'sedang',
#  'sedangkan',
#  'sedemikian',
#  'sedikit',
#  'sedikitnya',
#  'seenaknya',
#  'segala',
#  'segalanya',
#  'segera',
#  'seharusnya',
#  'sehingga',
#  'seingat',
#  'sejak',
#  'sejauh',
#  'sejenak',
#  'sejumlah',
#  'sekadar',
#  'sekadarnya',
#  'sekali',
#  'sekali-kali',
#  'sekalian',
#  'sekaligus',
#  'sekalipun',
#  'sekarang',
#  'sekarang',
#  'sekecil',
#  'seketika',
#  'sekiranya',
#  'sekitar',
#  'sekitarnya',
#  'sekurang-kurangnya',
#  'sekurangnya',
#  'sela',
#  'selain',
#  'selaku',
#  'selalu',
#  'selama',
#  'selama-lamanya',
#  'selamanya',
#  'selanjutnya',
#  'seluruh',
#  'seluruhnya',
#  'semacam',
#  'semakin',
#  'semampu',
#  'semampunya',
#  'semasa',
#  'semasih',
#  'semata',
#  'semata-mata',
#  'semaunya',
#  'sementara',
#  'semisal',
#  'semisalnya',
#  'sempat',
#  'semua',
#  'semuanya',
#  'semula',
#  'sendiri',
#  'sendirian',
#  'sendirinya',
#  'seolah',
#  'seolah-olah',
#  'seorang',
#  'sepanjang',
#  'sepantasnya',
#  'sepantasnyalah',
#  'seperlunya',
#  'seperti',
#  'sepertinya',
#  'sepihak',
#  'sering',
#  'seringnya',
#  'serta',
#  'serupa',
#  'sesaat',
#  'sesama',
#  'sesampai',
#  'sesegera',
#  'sesekali',
#  'seseorang',
#  'sesuatu',
#  'sesuatunya',
#  'sesudah',
#  'sesudahnya',
#  'setelah',
#  'setempat',
#  'setengah',
#  'seterusnya',
#  'setiap',
#  'setiba',
#  'setibanya',
#  'setidak-tidaknya',
#  'setidaknya',
#  'setinggi',
#  'seusai',
#  'sewaktu',
#  'siap',
#  'siapa',
#  'siapakah',
#  'siapapun',
#  'sini',
#  'sinilah',
#  'soal',
#  'soalnya',
#  'suatu',
#  'sudah',
#  'sudahkah',
#  'sudahlah',
#  'supaya',
#  'tadi',
#  'tadinya',
#  'tahu',
#  'tahun',
#  'tak',
#  'tambah',
#  'tambahnya',
#  'tampak',
#  'tampaknya',
#  'tandas',
#  'tandasnya',
#  'tanpa',
#  'tanya',
#  'tanyakan',
#  'tanyanya',
#  'tapi',
#  'tegas',
#  'tegasnya',
#  'telah',
#  'tempat',
#  'tengah',
#  'tentang',
#  'tentu',
#  'tentulah',
#  'tentunya',
#  'tepat',
#  'terakhir',
#  'terasa',
#  'terbanyak',
#  'terdahulu',
#  'terdapat',
#  'terdiri',
#  'terhadap',
#  'terhadapnya',
#  'teringat',
#  'teringat-ingat',
#  'terjadi',
#  'terjadilah',
#  'terjadinya',
#  'terkira',
#  'terlalu',
#  'terlebih',
#  'terlihat',
#  'termasuk',
#  'ternyata',
#  'tersampaikan',
#  'tersebut',
#  'tersebutlah',
#  'tertentu',
#  'tertuju',
#  'terus',
#  'terutama',
#  'tetap',
#  'tetapi',
#  'tiap',
#  'tiba',
#  'tiba-tiba',
#  'tidak',
#  'tidakkah',
#  'tidaklah',
#  'tiga',
#  'tinggi',
#  'toh',
#  'tunjuk',
#  'turut',
#  'tutur',
#  'tuturnya',
#  'ucap',
#  'ucapnya',
#  'ujar',
#  'ujarnya',
#  'umum',
#  'umumnya',
#  'ungkap',
#  'ungkapnya',
#  'untuk',
#  'usah',
#  'usai',
#  'waduh',
#  'wah',
#  'wahai',
#  'waktu',
#  'waktunya',
#  'walau',
#  'walaupun',
#  'wong',
#  'yaitu',
#  'yakin',
#  'yakni',
#  'yang']

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier

clf =  RandomForestClassifier(random_state=0, max_features ='sqrt',max_depth = 100)
knn = KNeighborsClassifier(n_neighbors=7)
nb = GaussianNB()
dt = DecisionTreeClassifier(max_features ='sqrt',max_depth = 100)
svm = SVC(degree=3)
# clf.fit(X, y)

# %%
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

normalizad_word = pd.read_csv("colloquial-indonesian-lexicon.csv")

normalizad_word_dict = {}

for index, row in normalizad_word.iterrows():
    if row[0] not in normalizad_word_dict:
        normalizad_word_dict[row[0]] = row[1] 

def normalized_term(document):
    return [normalizad_word_dict[term] if term in normalizad_word_dict else term for term in document]

df_skripsi['text_normalized'] = df_skripsi['Stopwords'].apply(normalized_term)


# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in df_skripsi['text_normalized']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")


# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]

df_skripsi['text_tokens_stemmed'] = df_skripsi['text_normalized'].swifter.apply(get_stemmed_term)
# Out:
# 2550
# ------------------------
# roboguru : roboguru
# beli : beli
# paket : paket
# membantu : bantu
# jaya : jaya
# ruang : ruang
# guru : guru
# video : video
# diputar : putar
# diunduh : unduh
# eror : eror
# menyesal : sesal
# gue : gue
# makai : maka
# keren : keren
# banget : banget
# pokoknya : pokok
# bagus : bagus
# aplikasihnya : aplikasihnya
# berguna : guna
# olimpiade : olimpiade
# ambon : ambon
# kasih : kasih
# rating : rating
# 5 : 5
# bintang : bintang
# terimaiasih : terimaiasih
# aplikasi : aplikasi
# terimakasih : terimakasih
# pembuat : buat
# mantap : mantap
# keluhan : keluh
# link : link
# web : web
# xdari : xdari
# notifikasi : notifikasi
# ruangguru : ruangguru
# buka : buka
# semuakesel : semuakesel
# mencoba : coba
# pindah : pindah
# lokasi : lokasi
# siyalnya : siyalnya
# full : full
# loading : loading
# errorpleaselah : errorpleaselah
# tolong : tolong
# jaga : jaga
# kenyamanan : nyaman
# jugasebenernya : jugasebenernya
# tinggal : tinggal
# jaringannya : jaring
# ngebut : ngebut
# nyaman : nyaman
# pakai : pakai
# pc : pc
# letak : letak
# drill : drill
# maksa : maksa
# langganan : langgan
# membosankan : bosan
# menyenangkan : senang
# suka : suka
# mempelajari : ajar
# pelajaran : ajar
# terbaik : baik
# dunia : dunia
# pickup : pickup
# sayang : sayang
# miliki : milik
# peningkatan : tingkat
# sistem : sistem
# operasi : operasi
# militer : militer
# politik : politik
# berusaha : usaha
# menderita : derita
# sakit : sakit
# hati : hati
# je : je
# liga : liga
# champions : champions
# uefa : uefa
# musim : musim
# panas : panas
# orang-orang : orang
# beriman : iman
# beramal : amal
# soleh : soleh
# solehah : solehah
# jawabannya : jawab
# salah : salah
# ar : ar
# ulangan : ulang
# 92 : 92
# buruk : buruk
# belajar : ajar
# mejing : mejing
# sudah : sudah
# kadang : kadang
# quiznya : quiznya
# error : error
# benar : benar
# dapat : dapat
# xp : xp
# gapyear : gapyear
# semoga : moga
# memahami : paham
# utbk : utbk
# bantuan : bantu
# apa : apa
# hyo : hyo
# bimbel : bimbel
# online : online
# best : best
# because : because
# fitur : fitur
# spesifikasinya : spesifikasi
# lengkap : lengkap
# memuaskan : muas
# really : really
# with : with
# this : this
# understand : understand
# about : about
# each : each
# lesson : lesson
# enthusiastic : enthusiastic
# exploring : exploring
# every : every
# knowledge : knowledge
# day : day
# hope : hope
# support : support
# future : future
# even : even
# better : better
# interesting : interesting
# everyone : everyone
# interested : interested
# application : application
# thank : thank
# very : very
# much : much
# developers : developers
# seru : seru
# mempermudah : mudah
# pekerjaan : kerja
# modul : modul
# dimasukkan : masuk
# didalam : dalam
# soalsoal : soalsoal
# menunjang : tunjang
# kinerja : kerja
# guruguru : guruguru
# latihan : latih
# anakpun : anak
# dalamnya : dalam
# hasil : hasil
# dimana : mana
# anak : anak
# memgerti : memgerti
# skor : skor
# worksheetnya : worksheetnya
# dibutuhkan : butuh
# mengoreksi : koreksi
# persiapannya : siap
# kelas : kelas
# 4 : 4
# dafa : dafa
# lulu : lulu
# kecewa : kecewa
# jawabanpenjelasan : jawabanpenjelasan
# komputerleptop : komputerleptop
# websitecrome : websitecrome
# diaksesdan : diaksesdan
# berlangganan : langgan
# dibukaitu : dibukaitu
# saran : saran
# kesan : kesan
# sayasaya : sayasaya
# harap : harap
# kedepannya : depan
# penggunaan : guna
# website : website
# terbuka : buka
# skip : skip
# 10 : 10
# second : second
# device : device
# pclaptop : pclaptop
# tambahan : tambah
# pintar : pintar
# anaknya : anak
# pembahasan : bahas
# menambah : tambah
# wawasan : wawas
# ruanggurudari : ruanggurudari
# paham : paham
# sampai : sampai
# pahamjuga : pahamjuga
# sulitjuga : sulitjuga
# dafadan : dafadan
# luluyang : luluyang
# menonton : tonton
# terima : terima
# aplikasinya : aplikasi
# usia : usia
# prasekolah : prasekolah
# lumayan : lumayan
# tuli : tuli
# upgrade : upgrade
# subtitle : subtitle
# indonesia : indonesia
# terima kasih : terima kasih
# ku : ku
# butuhkan : butuh
# love : love
# materinya : materi
# cocok : cocok
# ngejar : ngejar
# ranking : ranking
# baguus : baguus
# sumpah : sumpah
# keluh : keluh
# kesah : kesah
# doang : doang
# suport : suport
# android : android
# suruh : suruh
# hh : hh
# selesai : selesai
# sekian : sekian
# mudahh : mudahh
# pelayanan : layan
# laporkan : lapor
# direspon : direspon
# kakaknyapembelajarannya : kakaknyapembelajarannya
# mudah : mudah
# dipahami : paham
# videonya : video
# tulisanya : tulisanya
# gagal : gagal
# memuat : muat
# coba : coba
# 3 : 3
# nyobs : nyobs
# mode : mode
# offline : offline
# tulisannya : tulis
# kayak : kayak
# susah : susah
# jiwa : jiwa
# ngejelasin : ngejelasin
# detail : detail
# screenshot : screenshot
# mtk : mtk
# wajib : wajib
# minat : minat
# dipisahkan : pisah
# overall : overall
# eemm : eemm
# tanya : tanya
# tutor : tutor
# koinnya : koin
# mahal : mahal
# 1 : 1
# 15 : 15
# krg : krg
# pas : pas
# gara : gara
# putus2 : putus2
# jaringan : jaring
# lancar : lancar
# maaf : maaf
# kondisikan : kondisi
# konsultannya : konsultan
# menghubungi : hubung
# chat : chat
# telfon : telfon
# risih : risih
# berminat : minat
# konfirmasi : konfirmasi
# konsultanbeli : konsultanbeli
# marketplace : marketplace
# baguuss : baguuss
# lengkapbelajar : lengkapbelajar
# bosan : bosan
# bermanfaat : manfaat
# hapus : hapus
# karena : karena
# english : english
# tagihan : tagih
# burik : burik
# sok : sok
# banayak : banayak
# top : top
# netral : netral
# tampah : tampah
# hp : hp
# 54 : 54
# pliss : pliss
# fiturnya : fiturnya
# sayangnya : sayang
# materi : materi
# diakses : akses
# gbng : gbng
# instal : instal
# smkwakwakwak : smkwakwakwak
# jelek : jelek
# bayar : bayar
# 2 : 2
# komplen : komplen
# berminggu2 : berminggu2
# penyelesaian : selesai
# dianggap : anggap
# bukti : bukti
# disertakan : serta
# download : download
# dibukaerror : dibukaerror
# sihkalau : sihkalau
# dibenahi : benah
# gut : gut
# gua : gua
# dibagian : bagi
# mapel : mapel
# matematika : matematika
# penjelasan : jelas
# sulit : sulit
# matemetikakalo : matemetikakalo
# dijelasin : dijelasin
# dikit : dikit
# permisi : permisi
# daftar : daftar
# muat : muat
# ulang : ulang
# trussvidio : trussvidio
# putar : putar
# knpaa : knpaa
# padhal : padhal
# menarik : tarik
# bantu : bantu
# rangking : rangking
# ilmu : ilmu
# plajari : plajari
# baca : baca
# lola : lola
# lobby : lobby
# tetap : tetap
# menekan : tekan
# avatar : avatar
# berubah : ubah
# persis : persis
# teman : teman
# avayar : avayar
# lan : lan
# diubah : ubah
# bari : bari
# level : level
# 82 : 82
# rg : rg
# semangat : semangat
# masbro : masbro
# buriek : buriek
# belajarnya : ajar
# jujur : jujur
# banguss : banguss
# keganggu : ganggu
# spam : spam
# message : message
# membaca : baca
# ganti : ganti
# membeli : beli
# kemarin : kemarin
# kesalahan : salah
# terus : terus
# wifi : wifi
# tiket : tiket
# setelah : telah
# takutnya : takut
# 7 : 7
# butuh : butuh
# secepatnya : cepat
# bolehh : bolehh
# sehari : hari
# duit : duit
# kenapa : kenapa
# enggak : enggak
# bhsa : bhsa
# daerah : daerah
# pertanianseni : pertanianseni
# budaya : budaya
# pakarya : pakarya
# informatika : informatika
# sekolah : sekolah
# lupa : lupa
# nilai : nilai
# gurunya : guru
# ingat : ingat
# mengasih : asih
# pencet : pencet
# kirim : kirim
# muncul : muncul
# tulisan : tulis
# begini : begini
# invalid : invalid
# response : response
# was : was
# received : received
# upstream : upstream
# server : server
# solusi : solusi
# mengerti : erti
# smk : smk
# kah : kah
# rekomendasi : rekomendasi
# ngerjain : ngerjain
# sd : sd
# masih : masih
# bermanfaatdan : bermanfaatdan
# pahami : paham
# sekolahan : sekolah
# apk : apk
# menunggu : tunggu
# antrian : antri
# aman : aman
# berkisar : kisar
# 50 : 50
# keatas : atas
# cepat : cepat
# diperbaiki : baik
# tertipu : tipu
# plus : plus
# bernama : nama
# dinna : dinna
# sesuai : sesuai
# difoto : foto
# tindaklanjuti : tindaklanjuti
# semenjak : semenjak
# lihat : lihat
# gaenak : gaenak
# anak-anak : anak
# bagusdi : bagusdi
# laptop : laptop
# ditonton : tonton
# penyimpanan : simpan
# dibandingkan : banding
# mengajarnya : ajar
# selengkapnya : lengkap
# ranting5 : ranting5
# dqri : dqri
# anakanak : anakanak
# giat : giat
# nomer : nomer
# penawaran : tawar
# teror : teror
# pinjol : pinjol
# aku : aku
# awalawal : awalawal
# namanya : nama
# koin : koin
# harga : harga
# belinya : beli
# sesi : sesi
# nanyain : nanyain
# sesinya : sesi
# ngabisin : ngabisin
# harganya : harga
# peraturannya : atur
# turun : turun
# apknya : apknya
# rajin : rajin
# menghitung : hitung
# menggukur : menggukur
# sudut : sudut
# trimakasih : trimakasih
# meningkat : tingkat
# phytagoras : phytagoras
# untung : untung
# gampang : gampang
# dimengerti : erti
# pemahaman : paham
# baangget : baangget
# aneh : aneh
# dipakai : pakai
# terusan : terus
# google : google
# batesnya : batesnya
# giliran : gilir
# bates : bates
# aplikadi : aplikadi
# vidio : vidio
# tabisa : tabisa
# lounching : lounching
# perpanjangan : panjang
# serasa : serasa
# dikoyak : koyak
# oyakpdhl : oyakpdhl
# semester : semester
# smstr : smstr
# pelanggan : langgan
# diperhatikan : perhati
# yakinlah : yakin
# qjsudoeojoffikroeorrirutjyyri : qjsudoeojoffikroeorrirutjyyri
# fruuttugutir : fruuttugutir
# trik : trik
# ir : ir
# tiri : tiri
# taman : taman
# routoytyui : routoytyui
# yirritkhohohjonou : yirritkhohohjonou
# hridurugituuouih : hridurugituuouih
# today : today
# trigonometri : trigonometri
# all : all
# huigititiriirurut : huigititiriirurut
# tuturu4u4uru : tuturu4u4uru
# ruhfhhdjujdjduduudfuuftryrehudfuufuufjggjugjgjg : ruhfhhdjujdjduduudfuuftryrehudfuufuufjggjugjgjg
# jgguutuguyru : jgguutuguyru
# gadis : gadis
# gratis : gratis
# gr : gr
# daging : daging
# ayam : ayam
# try : try
# i6 : i6
# berbagayrghtiihhjyigki : berbagayrghtiihhjyigki
# tempatku : tempat
# itiutktuykktu : itiutktuykktu
# uduu : uduu
# adapto : adapto
# kuis : kuis
# tibatiba : tibatiba
# buram : buram
# bergarisgaris : bergarisgaris
# niat : niat
# uang : uang
# belajarsaya : belajarsaya
# siswa : siswa
# terbantu : bantu
# soalsoalnya : soalsoalnya
# pembahasannya : bahas
# rebahan : rebah
# tampilantingkatkn : tampilantingkatkn
# intinya : inti
# perfect : perfect
# bug : bug
# musik : musik
# ganggu : ganggu
# xyiqis : xyiqis
# memberika : memberika
# lumayanlah : lumayan
# diajarkan : ajar
# koneksi : koneksi
# force : force
# close : close
# heran : heran
# poco : poco
# pro : pro
# chipsetnya : chipsetnya
# snapdragon : snapdragon
# 800 : 800
# kepala : kepala
# volum : volum
# kubustabung : kubustabung
# pelajarin : pelajarin
# malas : malas
# pemilihan : pilih
# rute : rute
# driver : driver
# sopan : sopan
# seragam : seragam
# perbaiki : baik
# pembelajaran : ajar
# hewan : hewan
# balikin : balikin
# nyicil : nyicil
# pengin : pengin
# tapi : tapi
# lagi : lagi
# hemat : hemat
# dkembaiin : dkembaiin
# pasti : pasti
# memudahkan : mudah
# kakaknya : kakak
# kegunaan : guna
# berkualitas : kualitas
# sembilan : sembilan
# puluh : puluh
# affah : affah
# iya : iya
# andi : andi
# pelajar : ajar
# butut : butut
# sekali : sekali
# unik : unik
# terpercaya : percaya
# menengah : tengah
# ujian : uji
# sangat : sangat
# minimal : minimal
# difix : difix
# rilis : rilis
# poling : poling
# lantai : lantai
# ngawur : ngawur
# live : live
# lag : lag
# enggak usah : enggak usah
# parah : parah
# dev : dev
# knt : knt
# reting : reting
# paksa : paksa
# akses : akses
# luas : luas
# god : god
# berfungsi : fungsi
# reward : reward
# proses : proses
# mengajar : ajar
# mengecewakan : kecewa
# pengguna : guna
# ruanggru : ruanggru
# dihilangkan : hilang
# pelekspiperlekspi : pelekspiperlekspi
# pepiku : pepiku
# awaskslsutidak : awaskslsutidak
# lengakappetoperepiku : lengakappetoperepiku
# itu : itu
# kita : kita
# nya : nya
# pokok : pokok
# buatt : buatt
# berterimakasih : berterimakasih
# rekomend : rekomend
# kalian : kalian
# semuaa : semuaa
# terkenal : kenal
# deh : deh
# naira : naira
# salsabila : salsabila
# pipi : pipi
# vivi : vivi
# dina : dina
# naya : naya
# grbrugeuvskhuve : grbrugeuvskhuve
# jwuhruvlwhvrbhxisvnkechsgrirhrh73vehehehehhsbks : jwuhruvlwhvrbhxisvnkechsgrirhrh73vehehehehhsbks
#  : 
# juara : juara
# semaksimal : maksimal
# dering : dering
# menyebut : sebut
# nama : nama
# pemangil : pemangil
# tua : tua
# anakmaterinya : anakmaterinya
# bagusguru : bagusguru
# pembimbing : bimbing
# baiktelitikompeten : baiktelitikompeten
# bidang : bidang
# masingtrimakasih : masingtrimakasih
# vidionya : vidionya
# mulu : mulu
# daily : daily
# challenge : challenge
# indak : indak
# dibuka : buka
# customer : customer
# servicenya : servicenya
# tutup : tutup
# install : install
# sms : sms
# kode : kode
# otp : otp
# ngelag : ngelag
# scroll : scroll
# diam : diam
# maha : maha
# sinyal : sinyal
# animasi : animasi
# pemakaian : pakai
# dibawakan : bawa
# konten : konten
# promosi : promosi
# dipikirkan : pikir
# dichat : dichat
# orang tua : orang tua
# pemaksaan : paksa
# siswasiswi : siswasiswi
# quality : quality
# terganggu : ganggu
# rumah : rumah
# terjangkau : jangkau
# diluar : luar
# terpenting : penting
# ilmunya : ilmu
# cuman : cuman
# ngelagnya : ngelagnya
# membuka : buka
# anjing : anjing
# login : login
# kelaz : kelaz
# donlot : donlot
# 80 : 80
# apli : apli
# dirasa : rasa
# disekolah : seko
# bahas : bahas
# penjelasannya : jelas
# lemot : lot
# padahal : padahal
# stabil : stabil
# mood : mood
# pembelajarannyaa : pembelajarannyaa
# kakak : kakak
# ika : ika
# memberitahukan : memberitahukan
# bagusan : bagus
# dilengkapi : lengkap
# quiz2 : quiz2
# mengasah : asah
# tingkat : tingkat
# kepahaman : paham
# polling : polling
# teaching : teaching
# disalahkan : salah
# osnksn : osnksn
# bidangnya : bidang
# masingmasing : masingmasing
# beranimasi : animasi
# membahas : bahas
# soal2 : soal2
# osk : osk
# osp : osp
# osn : osn
# diterima : terima
# pls : pls
# bimbingan : bimbing
# minn : minn
# latsolnya : latsolnya
# hasilnya : hasil
# berulang : ulang
# bahasa : bahasa
# asing : asing
# semudah : mudah
# ucapkanmemerlukan : ucapkanmemerlukan
# ketekunan : tekun
# mempraktikan : praktik
# pelajari : ajar
# takut : takut
# salahsalah : salahsalah
# keluarga : keluarga
# kok : kok
# kagak : kagak
# ml : ml
# memakai : pakai
# vale : vale
# brain : brain
# academy : academy
# ekspektasi : ekspektasi
# menjamin : jamin
# kualitas : kualitas
# emosi : emosi
# sukacuman : sukacuman
# nice : nice
# saking : saking
# sadar : sadar
# makan : makan
# telepon : telepon
# senang : senang
# belajarruang : belajarruang
# terbaikterima : terbaikterima
# kendala : kendala
# memutar : putar
# adaptonya : adaptonya
# berjalan : jalan
# stuck : stuck
# situ : situ
# tolonglah : tolong
# jengkel : jengkel
# sngat : sngat
# pelajarannya : ajar
# hilang : hilang
# mati : mati
# hidup : hidup
# game : game
# diteror : teror
# whatsapp : whatsapp
# telpon : telpon
# berkali : kali
# minggu : minggu
# ajaran : ajar
# enggak ada : enggak ada
# lawan : lawan
# bimble : bimble
# semakin : makin
# chuy : chuy
# mengesalkan : kesal
# load : load
# belum : belum
# akun : akun
# log : log
# out : out
# history : history
# tontonan : tonton
# otomatis : otomatis
# hilangtolong : hilangtolong
# habis : habis
# ngedown : ngedown
# sihapaa : sihapaa
# siyal : siyal
# kencengtolong : kencengtolong
# teamnya : teamnya
# kofirmasikannggangu : kofirmasikannggangu
# diganggutolong : diganggutolong
# melamar : lamar
# disuatu : suatu
# perusahan : usah
# alasannya : alas
# tunggu : tunggu
# ulangi : ulang
# pencarian : cari
# klik : klik
# berkalikali : berkalikali
# batal : batal
# tutornya : tutor
# tugas : tugas
# buangbuang : buangbuang
# kesal : kesal
# buffering : buffering
# notif : notif
# kondisi : kondisi
# komentar : komentar
# mengalami : alami
# menghambat : hambat
# nelponganggu : nelponganggu
# ketemu : ketemu
# hebat : hebat
# mengajarkan : ajar
# stop : stop
# cucusaya : cucusaya
# putus : putus
# enjoy : enjoy
# belajarnyaaku : belajarnyaaku
# main : main
# youtube : youtube
# menit : menit
# putusputustolonglahya : putusputustolonglahya
# mixsiu : mixsiu
# byr : byr
# diharapkan : harap
# dikembalikan : kembali
# membeliberlangganan : membeliberlangganan
# dibolehin : dibolehin
# thx : thx
# aplkasi : aplkasi
# pertannyan : pertannyan
# kalkulator : kalkulator
# gratisnya : gratis
# kebutuhan : butuh
# indstri : indstri
# berpendidikan : didik
# thanks : thanks
# meskii : meski
# iklan : iklan
# mengarti : arti
# manyoritas : manyoritas
# kapitalis : kapitalis
# didapatkan : dapat
# puas : puas
# kesini : kesini
# terbatas : batas
# berbayar : bayar
# mengganggu : ganggu
# barbagai : barbagai
# silakan : sila
# temani : teman
# penurunan : turun
# performa : performa
# satunya : satu
# sharing : sharing
# yangmana : yangmana
# diupload : diupload
# terkropterzoom : terkropterzoom
# menyebabkan : sebab
# informasi : informasi
# terbaca : baca
# terkrop : terkrop
# turunkan : turun
# ada : ada
# mulok : mulok
# sistemnya : sistem
# kasihan : kasihan
# kepakai : pakai
# pembelajarannya : ajar
# interaktif : interaktif
# detik : detik
# orang : orang
# bilangnya : bilang
# alhasil : alhasil
# poin : poin
# sedih : sedih
# termotivasi : motivasi
# payah : payah
# makaisnya : maka
# perpanjang : panjang
# kakak2 : kakak2
# informatif : informatif
# trimakaciw : trimakaciw
# beast : beast
# l0 : l0
# inggris : inggris
# ipa : ipa
# tidakk : tidakk
# jelaas : jelaas
# mantab : mantab
# kebimbel : kebimbel
# hubungi : hubung
# karyawan : karyawan
# menggangu : menggangu
# kudapat : dapat
# lupakanseperti : lupakanseperti
# kehidupan : hidup
# dberikan : dberikan
# seksamadari : seksamadari
# terbit : terbit
# matahari : matahari
# terbenamnya : benam
# ddekat : ddekat
# sayawalaupun : sayawalaupun
# manusia : manusia
# sempurna : sempurna
# menyempurnakan : sempurna
# apps : apps
# rgtapi : rgtapi
# baiknya : baik
# malam : malam
# jamnya : jam
# kesorean : sore
# nabrak : nabrak
# jam : jam
# mendownload : mendownload
# simpel : simpel
# dptdi : dptdi
# pemanfaatan : manfaat
# begitu : begitu
# bsar : bsar
# ilustrasinya : ilustrasi
# jika : jika
# mengedepankan : depan
# perbaikan : baik
# mulaiterima : mulaiterima
# kembangkan : kembang
# terkendala : kendala
# streamingnya : streamingnya
# sukses : sukses
# masukan : masuk
# email : email
# mengapus : mengapus
# mengasyik : asyik
# dipahi : pah
# kuisnya : kuis
# gurusinyal : gurusinyal
# oke : oke
# terpaksa : paksa
# enggak jelas : enggak jelas
# kesel : kesel
# guruterimakasih : guruterimakasih
# esmezing : esmezing
# wicis : wicis
# kul : kul
# af : af
# belajarjdi : belajarjdi
# konyol : konyol
# meninggalkan : tinggal
# sebentar : sebentar
# open : open
# ngebosenin : ngebosenin
# berkat : berkat
# apapun : apa
# rangkuman : rangkum
# saja : saja
# lagih : lagih
# les : les
# selamat : selamat
# worth : worth
# dikunci : kunci
# babi : babi
# plis : plis
# ngantuk : ngantuk
# peliharaan : pelihara
# hewanya : hewanya
# lemah : lemah
# lucu : lucu
# dewasa : dewasa
# ketiga : tiga
# menunjukan : tunjuk
# kerajinan : rajin
# teknik : teknik
# servernya : servernya
# growtopia : growtopia
# play : play
# pengetahuan : tahu
# 834403 : 834403
# facebook : facebook
# laznxcarlw : laznxcarlw
# apkx : apkx
# anakku : anak
# kuota : kuota
# premiumnya : premium
# 0 : 0
# seminggu : minggu
# normal : normal
# diperbaik : baik
# lovee : lovee
# sama : sama
# guruu : guruu
# menghadapi : hadap
# snbtutbk : snbtutbk
# sinyalnya : sinyal
# banayakin : banayakin
# vid : vid
# mendidik : didik
# kurikulum : kurikulum
# merdeka : merdeka
# tersedia : sedia
# lengkapi : lengkap
# cari : cari
# nasional : nasional
# bangga : bangga
# biologi : biologi
# kimia : kimia
# fisika : fisika
# praktikumnya : praktikum
# terbayang : bayang
# premium : premium
# menyebarkan : sebar
# nomor : nomor
# auto : auto
# lock : lock
# scren : scren
# terkadang : terkadang
# layar : layar
# amazing : amazing
# rasionalisasi : rasionalisasi
# rapot : rapot
# refresh : refresh
# capek : capek
# memasukkan : masuk
# bagustetapi : bagustetapi
# ringking : ringking
# gara-gara : gara-gara
# sebenarnya : benar
# memang : memang
# bermasalah : masalah
# berpuluh : puluh
# menolak : tolak
# paketnya : paket
# diturunin : diturunin
# ditambahin : ditambahin
# miskin : miskin
# berlanggan : langgan
# memaksa : paksa
# its : its
# learning : learning
# help : help
# understanding : understanding
# school : school
# ngechat : ngechat
# tes : tes
# awesome : awesome
# bagusmembantu : bagusmembantu
# upload : upload
# file : file
# rapor : rapor
# x1 : x1
# gmnaa : gmnaa
# tolol : tolol
# t0d : t0d
# disayang : sayang
# urutnya : urut
# rank : rank
# 23 : 23
# donwload : donwload
# sih : sih
# apalagii : apalagi
# libur : libur
# bisa : bisa
# meluangkan : luang
# kosong : kosong
# bawaannya : bawa
# internet : internet
# amanaman : amanaman
# memaksakan : paksa
# kehendak : hendak
# merating : merating
# menerus : terus
# scrolling : scrolling
# temui : temu
# typo : typo
# penulisan : tulis
# note : note
# signal : signal
# enggak bisa : enggak bisa
# dekat : dekat
# dikasih : kasih
# bagusstetapi : bagusstetapi
# bab : bab
# pkn : pkn
# 8 : 8
# tambahkan : tambah
# program : program
# cha : cha
# ching : ching
# progam : progam
# kedepan : depan
# mangkin : mangkin
# ya : ya
# tranfer : tranfer
# 600rb : 600rb
# 24jam : 24jam
# adminnya : adminnya
# dulu : dulu
# menepati : tepat
# janji : janji
# bertambah : tambah
# bintangnya : bintang
# baikdan : baikdan
# sebel : sebel
# ditungguin : ditungguin
# munculmuncul : munculmuncul
# bangsa : bangsa
# besardan : besardan
# terussudah : terussudah
# kelass : kelass
# benerkeren : benerkeren
# naikk : naikk
# malasan : malas
# gurukeren : gurukeren
# pikir : pikir
# protes : protes
# tanggapan : tanggap
# menyakn : menyakn
# forum : forum
# robo : robo
# bad : bad
# request : request
# ambil : ambil
# rendah : rendah
# lancar2 : lancar2
# keputar : putar
# nyangkut2 : nyangkut2
# pelitt : pelitt
# gratisin : gratisin
# apiikas : apiikas
# menajubkan : menajubkan
# bantuin : bantuin
# lolos : lolos
# kampus : kampus
# penjawabnya : jawab
# menyerukan : seru
# diupdate : diupdate
# loadingnya : loadingnya
# bagusbagus : bagusbagus
# memperbaiki : baik
# snmptnsbmptn : snmptnsbmptn
# serap : serap
# bekal : bekal
# non : non
# master : master
# semuah : semuah
# ulasan : ulas
# owner : owner
# sakli : sakli
# palagi : palagi
# ribet : ribet
# tersembunyi : sembunyi
# diskon : diskon
# murah : murah
# dispam : dispam
# nomornya : nomor
# mengirim : kirim
# promo : promo
# beik : beik
# sajatapi : sajatapi
# baguslahdll : baguslahdll
# 5oh : 5oh
# data : data
# bicara : bicara
# dengar : dengar
# ngelek : ngelek
# geser : geser
# kekana : kana
# kekiri : kir
# peringkat : peringkat
# pulsa : pulsa
# rp25000 : rp25000
# institusi : institusi
# pendidikan : didik
# baikterutama : baikterutama
# elegan : elegan
# bermasalahtolong : bermasalahtolong
# aplikasinnya : aplikasinnya
# dicoba : coba
# berbeda : beda
# beda : beda
# menangis : menang
# huhu : huhu
# benerin : benerin
# opsi : opsi
# seringkali : seringkali
# peluang : peluang
# snbp : snbp
# terblokir : blokir
# ngulang : ngulang
# bolak : bolak
# super : super
# duper : duper
# gurusales : gurusales
# admin : admin
# jelasin : jelasin
# oaksa : oaksa
# kegunaannya : guna
# soak : soak
# menyimpang : simpang
# sesuaisoal : sesuaisoal
# berbobot : bobot
# service : service
# pelayananan : pelayananan
# valas : valas
# merepotkan : repot
# assalamualaikum : assalamualaikum
# wr : wr
# taala : taala
# wb : wb
# khalifahtul : khalifahtul
# rasyid : rasyid
# generasi : generasi
# prinsip : prinsip
# menjunjung : junjung
# perkembangan : kembang
# membaharui : baharu
# inovasi : inovasi
# setia : setia
# not : not
# belajae : belajae
# disuruh : suruh
# apl : apl
# bayak : bayak
# layarnya : layar
# udak : udak
# jenjang : jenjang
# jurusan : jurus
# farmasisemoga : farmasisemoga
# menyediakan : sedia
# farmasi : farmasi
# mission : mission
# scheduling : scheduling
# errornya : errornya
# masmba : masmba
# respon : respon
# diread : diread
# have : have
# great : great
# sekarangjauh : sekarangjauh
# onlineyang : onlineyang
# 30mnt : 30mnt
# batasan : batas
# soalyang : soalyang
# 1soal : 1soal
# koinkaya : koinkaya
# minsemoga : minsemoga
# lagiagar : lagiagar
# contohnya : contoh
# format : format
# memori : memori
# card : card
# gagaltidak : gagaltidak
# serusekali : serusekali
# jokowi : jokowi
# dirumah : rumah
# dicerna : cerna
# gru : gru
# terhubung : hubung
# internetpadahal : internetpadahal
# wifidatanya : wifidatanya
# dehsekarang : dehsekarang
# penuh : penuh
# lancarr : lancarr
# muter : muter
# videone : videone
# padshal : padshal
# enak2 : enak2
# gamood : gamood
# bagusberjalan : bagusberjalan
# dikiranya : kira
# dibikin : bikin
# tahunan : tahun
# aslii : asli
# recomen : recomen
# bismillah : bismillah
# slesai : slesai
# skornya : skor
# ruangbelajar : ruangbelajar
# bao : bao
# axis : axis
# infertilitas : infertilitas
# kebuka : buka
# adik : adik
# selesaidiakhir : selesaidiakhir
# okee : okee
# rangkumannya : rangkum
# nggat : nggat
# sekedar : dar
# usulan : usul
# pembagian : bagi
# persemester : semester
# mencari : cari
# terimakasihh : terimakasihh
# sistematis : sistematis
# jawabanya : jawabanya
# tiada : tiada
# membimbing : bimbing
# amin : amin
# disayangkan : sayang
# dikenal : kenal
# menelpon : telpon
# menawarkan : tawar
# elite : elite
# disitu : situ
# reguler : reguler
# sejujurnya : jujur
# seakan : akan
# menyepelekan : sepele
# privasi : privasi
# kebijakan : bijak
# ifa : ifa
# dikata : kata
# culun : culun
# bodo : bodo
# mantul : mantul
# komen : komen
# sungguh : sungguh
# benyak : benyak
# lang : lang
# ganan : ganan
# biat : biat
# ringkasan : ringkas
# ringkasanya : ringkasanya
# bugstuck : bugstuck
# edit : edit
# kecepatan : cepat
# mbps : mbps
# ketagihan : tagih
# pet : pet
# gold : gold
# goldnya : goldnya
# pakaian : pakai
# 6 : 6
# ranknyajadi : ranknyajadi
# stiker : stiker
# hadiah : hadiah
# harian : hari
# 9 : 9
# robotguru : robotguru
# fix : fix
# ramah : ramah
# salahnya : salah
# marahtidak : marahtidak
# becanda : becanda
# metode : metode
# enteh : enteh
# menyukai : suka
# sukaak : sukaak
# mengapai : kapai
# mengadakan : ada
# pengertiannya : erti
# masnya : mas
# bercanda : canda
# kesemua : semua
# sekolahlu : sekolahlu
# videony : videony
# berlanggananykok : berlanggananykok
# responnya : responnya
# hangus : hangus
# 800k : 800k
# utbkuntuk : utbkuntuk
# responyakarena : responyakarena
# mending : mending
# rindu : rindu
# diruang : ruang
# meningkatkan : tingkat
# segitu : segitu
# berhasil : hasil
# registrasi : registrasi
# tryout : tryout
# nyagimana : nyagimana
# pilihan : pilih
# tekan : tekan
# wah : wah
# boo : boo
# 9084 : 9084
# mematika : mematika
# apiksilnya : apiksilnya
# bu : bu
# sumber : sumber
# tawarin : tawarin
# lembar : lembar
# mencatat : catat
# menggambar : gambar
# hi : hi
# lulus : lulus
# kuliah : kuliah
# menghapus : hapus
# namai : nama
# palsusamaran : palsusamaran
# sigw : sigw
# inikrna : inikrna
# menempel : tempel
# trskaka : trskaka
# berlanggananudh : berlanggananudh
# loginin : loginin
# jugatapi : jugatapi
# terustrs : terustrs
# abangga : abangga
# bersungguh : sungguh
# anjga : anjga
# gwdan : gwdan
# sometimes : sometimes
# think : think
# born : born
# snang : snang
# dngn : dngn
# bohong : bohong
# kokk : kokk
# app : app
# lmao : lmao
# telpon2 : telpon2
# ngeganggu : ngeganggu
# membatu : batu
# pemberian : beri
# singkat : singkat
# trkoordinir : trkoordinir
# mnjengkelkan : mnjengkelkan
# teros : ros
# staf-stafnya : staf
# jawabinmbok : jawabinmbok
# mnghubungi : mnghubungi
# dicek : cek
# blomsudah : blomsudah
# tanggal : tanggal
# 25februari2022 : 25februari2022
# 28maret2022 : 28maret2022
# sebulan : bulan
# benaran : benar
# diiklankan : iklan
# tidakyg : tidakyg
# telanjur : telanjur
# setahun : tahun
# selese : selese
# dimatiin : dimatiin
# snbt : snbt
# episode : episode
# 14 : 14
# cek : cek
# terkerjakan : kerja
# pengajaran : ajar
# andai : andai
# mahasiswa : mahasiswa
# maba : maba
# tahap : tahap
# tpb : tpb
# berpengalaman : alam
# gurupengalaman : gurupengalaman
# 12 : 12
# awokawok : awokawok
# mampua : mampua
# bangkrut : bangkrut
# most : most
# appropriate : appropriate
# gampanh : gampanh
# gambar : gambar
# tipe : tipe
# visual : visual
# tugasnya : tugas
# bisasaya : bisasaya
# gratismenurut : gratismenurut
# gurusemoga : gurusemoga
# betah : betah
# muter2 : muter2
# kencang : kencang
# lemott : lemott
# rugi : rugi
# belajarbikin : belajarbikin
# mengeejakan : eja
# syangnya : syangnya
# tiba-tiba : tiba
# sendiri : sendiri
# enng : enng
# terstruktur : struktur
# daffa : daffa
# lulunya : lulunya
# latihannya : latih
# tv : tv
# invasi : invasi
# lakukan : laku
# brainly : brainly
# awoakwoakwk : awoakwoakwk
# asli : asli
# konsultasi : konsultasi
# lelet : lelet
# uptodate : uptodate
# syadr : syadr
# menjelaskanya : menjelaskanya
# sangngat : sangngat
# kepikiran : pikir
# jlk : jlk
# film : film
# stars : stars
# obsasinal : obsasinal
# mendukung : dukung
# sangatt : sangatt
# mambantu : mambantu
# kurikulumnya : kurikulum
# suaranya : suara
# lirih : lirih
# quizznya : quizznya
# kendalalangganan : kendalalangganan
# 9blnbaru : 9blnbaru
# 1bln : 1bln
# nydan : nydan
# sandinya : sandi
# solusinyamohon : solusinyamohon
# bantuannya : bantu
# bebe : bebe
# rapa : rapa
# plajaran : plajaran
# pjokdanbahasa : pjokdanbahasa
# baiki : baik
# kls : kls
# leg : leg
# terkonsep : konsep
# buatyang : buatyang
# berlangganannya : langgan
# efektif : efektif
# gila : gila
# enggak tau : enggak tau
# mengetik : etik
# apalagitakjub : apalagitakjub
# bgtdi : bgtdi
# pelajarannilai : pelajarannilai
# gede : gede
# trsgatau : trsgatau
# lagitp : lagitp
# manfaat : manfaat
# kerasa : rasa
# cocoa : cocoa
# until : until
# testing : testing
# rumus : rumus
# mls : mls
# menyukainya : suka
# usianya : usia
# dipilih : pilih
# basan : bas
# uas : uas
# pakaisering : pakaisering
# 100 : 100
# harhanya : harhanya
# bank : bank
# diturunkan : turun
# seratus : ratus
# screen : screen
# shot : shot
# wow : wow
# sakali : sakal
# menghibur : hibur
# loh : loh
# bergabung : gabung
# bismillahirrahmanirrahim : bismillahirrahmanirrahim
# bafus : bafus
# aduh : aduh
# ikutan : ikut
# apanya : apa
# kreativitas : kreativitas
# menentu : tentu
# persiapan : siap
# bgtrecomended : bgtrecomended
# malah : malah
# aplknya : aplknya
# playlist : playlist
# geme : geme
# direfresh : direfresh
# anjh : anjh
# nemenin : nemenin
# 11 : 11
# penyampaian : sampai
# dipahamin : dipahamin
# gaiss : gaiss
# modal : modal
# fokus : fokus
# teachernya : teachernya
# developermengenai : developermengenai
# pengerjaan : kerja
# tryouttolong : tryouttolong
# batas : batas
# diulang : ulang
# pengerjaannyadengan : pengerjaannyadengan
# terbiasa : biasa
# tersebutterimakasih : tersebutterimakasih
# dipaksa : paksa
# au : au
# screnshot : screnshot
# menyebalkan : sebal
# anjir : anjir
# rese : rese
# wu : wu
# sampaah : sampaah
# kebanyak : banyak
# macetpadahal : macetpadahal
# laintapi : laintapi
# bagos : bagos
# daat : daat
# begus : begus
# benget : benget
# bentuk : bentuk
# bestt : bestt
# gratisan : gratis
# pitar : pitar
# 2013 : 2013
# bodoh : bodoh
# berkembang : kembang
# kegiatan : giat
# ajib : ajib
# simple : simple
# berterima : terima
# kenaikan : naik
# pay : pay
# version : version
# hahaha : hahaha
# agama : agama
# muslim : muslim
# perintahkan : perintah
# bearti : bearti
# biaya : biaya
# anjas : anjas
# badaz : badaz
# meledak : ledak
# bangettcuma : bangettcuma
# harganyaapadahal : harganyaapadahal
# buatku : buat
# menemukan : temu
# alpikasi : alpikasi
# fdan : fdan
# dipelajari : ajar
# ppkn : ppkn
# pts : pts
# mommy : mommy
# momy : momy
# ajalah : aja
# babay : babay
# pelayanannya : layan
# ajukan : aju
# costumer : costumer
# mengabaikan : abai
# pesan : pesan
# pernyataan : nyata
# ruanggur : ruanggur
# akhir2 : akhir2
# jarang : jarang
# membutuhkan : butuh
# diroboguru : diroboguru
# dsb : dsb
# membayar : bayar
# robogurunya : robogurunya
# kemudahan : mudah
# versi : versi
# dekstop : dekstop
# bugnya : bugnya
# hitam : hitam
# padat : padat
# mahal2 : mahal2
# spiritt : spiritt
# tombol : tombol
# lompat : lompat
# pcdesktop : pcdesktop
# tekantekan : tekantekan
# kakakkakak : kakakkakak
# hadirnya : hadir
# 2023 : 2023
# diruangguru : diruangguru
# team : team
# sport : sport
# sosiologi : sosiologi
# tindakan : tindak
# sosial : sosial
# lakilaki : lakilaki
# ngajarnya : ngajarnya
# menghilangkan : hilang
# tlong : tlong
# nih : nih
# masak : masak
# kerusakan : rusa
# kalau : kalau
# rate : rate
# 5lagi : 5lagi
# disaat : saat
# misi : misi
# konselor : konselor
# temannya : teman
# kekurangan : kurang
# 1suaranya : 1suaranya
# patah : patah
# lima5 : lima5
# diatas : atas
# rata2kkm : rata2kkm
# bonusnya : bonus
# semangatsuka : semangatsuka
# boring : boring
# jelaspadat : jelaspadat
# dijamin : jamin
# langganannya : langgan
# jepang : jepang
# mandarin : mandarin
# ibb : ibb
# apliaksinya : apliaksinya
# rangkumansering : rangkumansering
# bawahscroll : bawahscroll
# turunmohon : turunmohon
# diperbaikiterimakasih : diperbaikiterimakasih
# pendapatku : dapat
# animasinya : animasi
# konsentrasinya : konsentrasi
# otak : otak
# pemula : mula
# 90100 : 90100
# 7089 : 7089
# berkatmu : berkat
# menukar : tukar
# sehat : sehat
# wassalamualaikum : wassalamualaikum
# warahmatullahi : warahmatullahi
# wabarakatuh : wabarakatuh
# lamaa : lamaa
# ditingkatkan : tingkat
# bangetcocok : bangetcocok
# bagusanat : bagusanat
# prestasi : prestasi
# tingginilai : tingginilai
# bioguru : bioguru
# foto : foto
# perbaki : baki
# pjok : pjok
# tikseni : tikseni
# pkwu : pkwu
# jadih : jadih
# rengking : rengking
# benerga : benerga
# etis : etis
# nilaiku : nilai
# semangatku : semangat
# ruangan : ruang
# situs : situs
# webtapi : webtapi
# keenakan : enak
# pembayarannya : bayar
# gpay : gpay
# rekomendasikan : rekomendasi
# arab : arab
# quran : quran
# hadis : hadis
# madrasah : madrasah
# tqu : tqu
# pengalaman : alam
# balasan : balas
# apaansih : apaansih
# ipad : ipad
# kayaknya : kayak
# ngelanjutin : ngelanjutin
# jangka : jangka
# pendek : pendek
# siplah : sip
# aksesnya : akses
# mengulang : ulang
# nambahin : nambahin
# inijadi : inijadi
# bocoran : bocor
# reporterjurnalis : reporterjurnalis
# tvberita : tvberita
# semangit : semangit
# bingung : bingung
# beruntung : untung
# menyelesaikan : selesai
# memahaminya : paham
# dabestt : dabestt
# kebantu : bantu
# gurupas : gurupas
# asalnya : asal
# bags : bags
# nyon : nyon
# gaji : gaji
# seklai : seklai
# serumenyenangkan : serumenyenangkan
# rafli : rafli
# malije : malije
# sdn : sdn
# bukit : bukit
# durian : durian
# sebagus : bagus
# itutp : itutp
# kendalasaya : kendalasaya
# berhenti : henti
# ruanggurulebih : ruanggurulebih
# ygy : ygy
# ubah : ubah
# sambilan : sambil
# belajarmending : belajarmending
# kesimpan : simpan
# tersimpan : simpan
# insyaallah : insyaallah
# mengurangi : kurang
# susahmakasih : susahmakasih
# dihatisemoga : dihatisemoga
# annisa : annisa
# zhaafira : zhaafira
# syahbana : syahbana
# smooth : smooth
# fleksibel : fleksibel
# rada : rada
# kaku : kaku
# mutar : mutar
# fidio : fidio
# tiduran : tidur
# lanskap : lanskap
# penjelasanya : jasa
# berak : berak
# penggunaannya : guna
# soalkalau : soalkalau
# nextsering : nextsering
# home : home
# nyaangeselin : nyaangeselin
# bisen : bisen
# soalpembahasan : soalpembahasan
# pelaharannya : lahar
# ditambah : tambah
# sebelemun : bun
# berisik : berisik
# hdehh : hdehh
# jwbn : jwbn
# bnrny : bnrny
# gjls : gjls
# hhee : hhee
# kuisbehe : kuisbehe
# ntitibatiba : ntitibatiba
# otoh : otoh
# mu : mu
# berlatih : latih
# jahat : jahat
# baguscuma : baguscuma
# yasaya : yasaya
# gitukayak : gitukayak
# dukungan : dukung
# cerita : cerita
# asww : asww
# kadaang : kadaang
# jempol : jempol
# logika : logika
# mermanfaat : mermanfaat
# minini : min
# 89 : 89
# stan : stan
# ketahuan : tahu
# bngke : bngke
# membantuku : bantu
# labih : labih
# murahin : murahin
# langgananya : langgananya
# pollingnya : pollingnya
# menyambung : sambung
# pengennya : ken
# sampah : sampah
# mnatap : mnatap
# rencana : rencana
# bertele : tele
# tele : tele
# over : over
# anjg : anjg
# kacau : kacau
# bego : bego
# fun : fun
# ngegame : ngegame
# developernya : developer
# cache : cache
# bersih : bersih
# ratusan : ratus
# ribu : ribu
# ruangbelajarnya : ruangbelajarnya
# pembelajraan : pembelajraan
# contoh : contoh
# memungkin : mungkin
# dilatih : latih
# memilih : pilih
# dampak : dampak
# uangnya : uang
# mencapai : capai
# cita : cita
# citaku : cita
# 700 : 700
# kebanyakan : banyak
# gaya : gaya
# ngebug : ngebug
# stylenya : stylenya
# dibanding : banding
# apalah : apa
# hukum : hukum
# ugm : ugm
# pintercerdas : pintercerdas
# bergunakadang : bergunakadang
# 90 : 90
# sihpokoknya : sihpokoknya
# impianku : impi
# aamiinayo : aamiinayo
# aktif : aktif
# 2x : 2x
# cs : cs
# via : via
# terbaikn : terbaikn
# tingkatkan : tingkat
# tim : tim
# nelfon : nelfon
# mulupadahal : mulupadahal
# iseng : iseng
# ditelfonin : ditelfonin
# call : call
# 34 : 34
# pusing : pusing
# fahira : fahira
# ngembaliinnya : ngembaliinnya
# ruangbelajarruangbelajar : ruangbelajarruangbelajar
# kritik : kritik
# dipertahankan : tahan
# penyebab : sebab
# pergi : pergi
# bertelelele : tele
# kesempatan : sempat
# menurutku : turut
# provaider : provaider
# kecewe : kecewe
# indongmert : indongmert
# pesanan : pesan
# tolak : tolak
# alasan : alas
# kendalanya : kendala
# perbaik : baik
# 75 : 75
# 85 : 85
# membanyaki : banyak
# ngapai : ngapai
# kepo : kepo
# yauda : yauda
# gadijawab : gadijawab
# bpk : bpk
# verifikasi : verifikasi
# menyusahkan : susah
# cool : cool
# aplnya : aplnya
# nnya : nnya
# muda : muda
# ngeleg : ngeleg
# besok : besok
# peraktis : peraktis
# juga : juga
# puter : puter
# kira-kira : kira
# ngerjakan : ngerjakan
# overal : overal
# ngestuck : ngestuck
# papa : papa
# karyawannya : karyawannya
# phk : phk
# kegedean : gede
# ngiklan : ngiklan
# datang : datang
# kesekolah : seko
# onlineharga : onlineharga
# teman-teman : teman
# manfaatnya : manfaat
# bagussd : bagussd
# percaya : percaya
# daridulu : daridulu
# terdaftar : daftar
# jwujur : jwujur
# asiq : asiq
# tube : tube
# koneksinya : koneksi
# membanty : membanty
# mantaapp : mantaapp
# mutch : mutch
# marahin : marahin
# levelnya : level
# evolusi : evolusi
# awalyah : awalyah
# ruangguruku : ruangguruku
# internetnya : internetnya
# ruanggurunya : ruanggurunya
# privat : privat
# ptspas : ptspas
# harapannya : harap
# membangun : bangun
# cerdas : cerdas
# sdm : sdm
# belejar : belejar
# huwuw : huwuw
# sidanira : sidanira
# tertinggi : tinggi
# menyangka : sangka
# wukwuk : wukwuk
# trust : trust
# issues : issues
# materimateri : materimateri
# ringkas : ringkas
# rumusrumusnya : rumusrumusnya
# ez : ez
# ketimbang : ketimbang
# wowkowk : wowkowk
# mwa : mwa
# bermaanfaat : bermaanfaat
# meledakrip : meledakrip
# 33 : 33
# 2020 : 2020
# stm : stm
# mts : mts
# janjian : janji
# masihh : masihh
# maju : maju
# raport : raport
# ruangg : ruangg
# gurru : gurru
# bestsaya : bestsaya
# fiturvideojadwal : fiturvideojadwal
# logout : logout
# buang : buang
# 1th : 1th
# dikasi : kasi
# kesulitan : sulit
# langgananeh : langgananeh
# sekolahmateri : sekolahmateri
# sembarangan : sembarang
# siapamungkin : siapamungkin
# uh : uh
# kukira : kira
# 64 : 64
# pemblajaranruang : pemblajaranruang
# semua : semua
# plajaranya : plajaranya
# cpat : cpat
# fahami : fahami
# tak : tak
# perguruan : guru
# 500 : 500
# angus : angus
# garagara : garagara
# wooi : wooi
# nerror : nerror
# setaon : setaon
# agen : agen
# balas : balas
# kak : kak
# suer : suer
# baik : baik
# dibalas : balas
# blok : blok
# kejar : kejar
# rentenir : rentenir
# biarkan : biar
# tenang : tenang
# efisien : efisien
# 3vid : 3vid
# memperluas : luas
# arghtt : arghtt
# sepuluh : puluh
# karmilah : karmilah
# balita : balita
# mdhnya : mdhnya
# ktkn : ktkn
# trm : trm
# downlod : downlod
# hihihihihihihihih : hihihihihihihihih
# lama-lama : lama
# ladang : ladang
# bisnis : bisnis
# berujung : ujung
# marketing : marketing
# telpwa : telpwa
# sewajarnya : wajar
# bisnisnya : bisnis
# pendidikannya : didik
# matematikanya : matematika
# brmsalah : brmsalah
# ternyata : nyata
# sananya : sana
# uninstall : uninstall
# berbelit : belit
# belit : belit
# jazakumullah : jazakumullah
# khair : khair
# bayargak : bayargak
# buku : buku
# gamegaada : gamegaada
# buffer : buffer
# desktop : desktop
# lah : lah
# anime : anime
# ditanyain : ditanyain
# ditelpon : telpon
# sekli : sekli
# gamenya : gamenya
# nelp : nelp
# debat : debat
# thecher : thecher
# jelasinnya : jelasinnya
# dpet : dpet
# 69 : 69
# dong : dong
# hanya : hanya
# smart : smart
# schedule : schedule
# menampilkan : tampil
# mingguan : minggu
# kali : kali
# kami : kami
# ruaanguru : ruaanguru
# menyesatkan : sesat
# peran : peran
# pelajaranku : ajar
# dapatnya : dapat
# didownload : didownload
# ph : ph
# media : media
# lacar : lacar
# mendaftar : daftar
# ayo : ayo
# donlowd : donlowd
# cuan : cuan
# serba : serba
# loginnya : loginnya
# cantik : cantik
# apilikasi : apilikasi
# temantemannya : temantemannya
# apliny : apliny
# abang : abang
# kecuali : kecuali
# pikerie : pikerie
# abget : abget
# yaudah : yaudah
# dilingkapi : lingkap
# mengenal : kenal
# kagum : kagum
# perjuangan : juang
# pendiri : diri
# mengelola : kelola
# berjuang : juang
# sekuat2 : sekuat2
# menyumbangkan : sumbang
# tenaga : tenaga
# ide : ide
# menghasilkan : hasil
# kompleks : kompleks
# pembelajaranya : pembelajaranya
# menciptakan : cipta
# sdsaya : sdsaya
# private : private
# diulangi : ulang
# materinyadan : materinyadan
# adasaya : adasaya
# semuakalau : semuakalau
# kebingungan : bingung
# melapor : lapor
# sajaruang : sajaruang
# animasinyagakalah : animasinyagakalah
# tvsambil : tvsambil
# aplilasinya : aplilasinya
# ajarkan : ajar
# berkarakter : karakter
# dahulutpi : dahulutpi
# peliharaanyabelajar : peliharaanyabelajar
# ngescroll : ngescroll
# mitra : mitra
# skalinya : skalinya
# seharian : hari
# cobattp : cobattp
# lapor : lapor
# yamohon : yamohon
# gadapet : gadapet
# hehehehe : hehehehe
# teks : teks
# eksposisi : eksposisi
# maunya : mau
# akunnya : akun
# masukkan : masuk
# ananda : ananda
# suci : suci
# nyerti : nyerti
# disimak : simak
# assalamulaikum : assalamulaikum
# undip : undip
# ptn : ptn
# sesat : sesat
# dale : dale
# kerjakan : kerja
# egi : egi
# mengunakan : mengunakan
# tekun : tekun
# rungguru : rungguru
# pokonyaaku : pokonyaaku
# bimbing : bimbing
# siu : siu
# gam : gam
# presentase : presentase
# serius : serius
# jatuhnya : jatuh
# downloadnya : downloadnya
# naikin : naikin
# ratingnya : ratingnya
# downlot : downlot
# buset : buset
# allah : allah
# jadi : jadi
# makinn : makinn
# slayy : slayy
# anggunly : anggunly
# sekolahku : sekolah
# kerren : kerren
# rumusnya : rumus
# berprestasi : prestasi
# kenal : kenal
# mewakili : wakil
# lomba : lomba
# cermat : cermat
# menang : menang
# baguzz : baguzz
# abiez : abiez
# bubarkan : bubar
# ruanguru : ruanguru
# membantuk : membantuk
# adalah : adalah
# ribuan : ribu
# macet : macet
# tersinkronisasi : sinkronisasi
# windows : windows
# selalu : selalu
# isi : isi
# mengajari : ajar
# anakterimakasih : anakterimakasih
# pangkal : pangkal
# pandai : pandai
# akhirakhir : akhirakhir
# terkunci : kunci
# rumitdan : rumitdan
# sihvidio : sihvidio
# bagusviturnya : bagusviturnya
# muantap : muantap
# manapun : mana
# lama : lama
# nelponpdhl : nelponpdhl
# bersemangat : semangat
# instalnya : instalnya
# student : student
# advisor : advisor
# gbisa : gbisa
# sikap : sikap
# putri : putri
# faiq : faiq
# alfurqan : alfurqan
# maulana : maulana
# yusuf : yusuf
# 3a : 3a
# dimarahi : marah
# job : job
# kata : kata
# masuk : masuk
# canggih : canggih
# skill : skill
# mengcewakan : mengcewakan
# sangan : sangan
# adi : adi
# lebi : lebi
# semagant : semagant
# utuk : utuk
# lengkaplumayan : lengkaplumayan
# keterima : terima
# membalas : balas
# gambarnya : gambar
# terbaru : baru
# official : official
# malam2 : malam2
# sibuk : sibuk
# dek : dek
# chatnya : chatnya
# 2220 : 2220
# wth : wth
# research : research
# larut : larut
# beware : beware
# ruaangguru : ruaangguru
# persubbab : subbab
# ksami : ksami
# rung : rung
# ngisi : ngisi
# pwiss : pwiss
# moment : moment
# 12210000 : 12210000
# memenuhi : penuh
# biasnya : bias
# kucing : kucing
# energi : energi
# haloruangguru : haloruangguru
# keperawatan : awat
# kefarmasiandan : kefarmasiandan
# laboratorium : laboratorium
# medikjadi : medikjadi
# jurusannya : jurus
# yamasa : yamasa
# kesehatan : sehat
# sihmohon : sihmohon
# dikembangkan : kembang
# kecawa : kecawa
# segini : gin
# melulu : melulu
# thankyou : thankyou
# untukpihak : untukpihak
# kenqoa : kenqoa
# jawab : jawab
# terakhirnya : akhir
# smngt : smngt
# belajarr : belajarr
# learn : learn
# year : year
# lira : lira
# em2 : em2
# usah : usah
# perlukan : perlu
# paketan : paket
# freeze : freeze
# pkt : pkt
# sangaat : sangaat
# membantuu : membantuu
# orangtua : orangtua
# mengeluarkan : keluar
# 600000 : 600000
# pelajaranya : pelajaranya
# konrol : konrol
# terpengaruh : pengaruh
# genjutsu : genjutsu
# ruangbk : ruangbk
# mberi : mberi
# ranting : ranting
# woe : woe
# kelewat : lewat
# asw : asw
# amamaj : amamaj
# dibandingin : dibandingin
# qr : qr
# disana : sana
# cepatnya : cepat
# zonk : zonk
# berhatihati : berhatihati
# digunain : digunain
# hai : hai
# diterangkan : terang
# rinci : rinci
# dibahas : bahas
# runtutan : runtut
# 5w1h : 5w1h
# mentor : mentor
# selamaa : selamaa
# drastis : drastis
# pokoknyaa : pokoknyaa
# makasiih : makasiih
# pagi : pagi
# rambut : rambut
# eda : eda
# perhatiannya : perhati
# ucapkan : ucap
# kunjungan : kunjung
# berbelanja : belanja
# aktifitas : aktifitas
# produk : produk
# mobil : mobil
# bekas : bekas
# sahrir : sahrir
# akhirat : akhirat
# tega : tega
# kejadian : jadi
# perbedaan : beda
# kuat : kuat
# alternatif : alternatif
# yey : yey
# dikali : kali
# 196 : 196
# badus : badus
# donlow : donlow
# murid : murid
# membikin : bikin
# beserta : serta
# quiz : quiz
# menikmatinya : nikmat
# kakakabang : kakakabang
# enggak punya : enggak punya
# kakbang : kakbang
# mengakses : akses
# terjedah : terjedah
# langgana : langgana
# jeda : jeda
# hahahah : hahahah
# hinaapk : hinaapk
# sekarang : sekarang
# mengikuti : ikut
# tmb : tmb
# segi : segi
# ekonomi : ekonomi
# klamaan : klamaan
# tanyak : tanyak
# endak : endak
# angel : angel
# inggrisnya : inggris
# aps : aps
# banyakan : banyak
# banggat : banggat
# mind : mind
# map : map
# keburuntunggan : keburuntunggan
# seprofesi : profesi
# seangkatan : angkat
# tahun : tahun
# 1989 : 1989
# indonesiasemoga : indonesiasemoga
# dalm : dalm
# lindungan : lindung
# tuhan : tuhan
# esasaat : esasaat
# pensiun : pensiun
# ditagih : tagih
# rp : rp
# 100000 : 100000
# amar : amar
# kashi : kashi
# bitag : bitag
# bahus : bahus
# ganiat : ganiat
# ajg : ajg
# zenius : zenius
# ruanggura : ruanggura
# masda : masda
# konghadga : konghadga
# kera : kera
# biki : bik
# lukadga : lukadga
# get : get
# contact : contact
# taunya : tau
# dibilang : bilang
# malamnya : malam
# misscall : misscall
# saya : saya
# lgii : lgii
# nglaig : nglaig
# bett : bett
# plisskarna : plisskarna
# 123 : 123
# walaupn : walaupn
# melobagus : melobagus
# apelikasi : apelikasi
# merubah : rubah
# chatny : chatny
# blokir : blokir
# aktivitas : aktivitas
# aplikasianya : aplikasianya
# bagusteruskandan : bagusteruskandan
# skem : skem
# bilang : bilang
# berkerja : kerja
# pengembangan : kembang
# seringsering : seringsering
# keponakan : keponakan
# pilih : pilih
# sukanya : suka
# lahlagi : lahlagi
# jwbnnya : jwbnnya
# dari : dari
# huft : huft
# disesuaikan : sesuai
# yasama : yasama
# menarin : menarin
# beutty : beutty
# 3x : 3x
# transaksi : transaksi
# ditindaklanjuti : ditindaklanjuti
# ywojalh : ywojalh
# nalah : nalah
# skng : skng
# debes : debes
# jualan : jual
# mah : mah
# harus : harus
# lngganan : lngganan
# hha : hha
# tonton : tonton
# maksud : maksud
# bagusnya : bagus
# operator : operator
# ditlp : ditlp
# mengaku : aku
# capslock : capslock
# profesional : profesional
# opeator : opeator
# tqs : tqs
# mudahan : mudah
# bangetmudah : bangetmudah
# durasi : durasi
# 4050 : 4050
# jenuh : jenuh
# logo : logo
# perbaikannya : baik
# 0000 : 0000
# bangun : bangun
# akhrinya : akhrinya
# harry : harry
# diamond : diamond
# tiger : tiger
# lesu : lesu
# bangunnya : bangun
# atur : atur
# 1200 : 1200
# langsung : langsung
# membntu : membntu
# segeralah : segera
# bersamasama : bersamasama
# tergantung : gantung
# pemakai : pakai
# batu : batu
# legendaris : legendaris
# bermenitmenit : bermenitmenit
# epep : epep
# aulia : aulia
# ushul : ushul
# fiqh : fiqh
# bangatt : bangatt
# penerus : terus
# {'roboguru': 'roboguru', 'beli': 'beli', 'paket': 'paket', 'membantu': 'bantu', 'jaya': 'jaya', 'ruang': 'ruang', 'guru': 'guru', 'video': 'video', 'diputar': 'putar', 'diunduh': 'unduh', 'eror': 'eror', 'menyesal': 'sesal', 'gue': 'gue', 'makai': 'maka', 'keren': 'keren', 'banget': 'banget', 'pokoknya': 'pokok', 'bagus': 'bagus', 'aplikasihnya': 'aplikasihnya', 'berguna': 'guna', 'olimpiade': 'olimpiade', 'ambon': 'ambon', 'kasih': 'kasih', 'rating': 'rating', '5': '5', 'bintang': 'bintang', 'terimaiasih': 'terimaiasih', 'aplikasi': 'aplikasi', 'terimakasih': 'terimakasih', 'pembuat': 'buat', 'mantap': 'mantap', 'keluhan': 'keluh', 'link': 'link', 'web': 'web', 'xdari': 'xdari', 'notifikasi': 'notifikasi', 'ruangguru': 'ruangguru', 'buka': 'buka', 'semuakesel': 'semuakesel', 'mencoba': 'coba', 'pindah': 'pindah', 'lokasi': 'lokasi', 'siyalnya': 'siyalnya', 'full': 'full', 'loading': 'loading', 'errorpleaselah': 'errorpleaselah', 'tolong': 'tolong', 'jaga': 'jaga', 'kenyamanan': 'nyaman', 'jugasebenernya': 'jugasebenernya', 'tinggal': 'tinggal', 'jaringannya': 'jaring', 'ngebut': 'ngebut', 'nyaman': 'nyaman', 'pakai': 'pakai', 'pc': 'pc', 'letak': 'letak', 'drill': 'drill', 'maksa': 'maksa', 'langganan': 'langgan', 'membosankan': 'bosan', 'menyenangkan': 'senang', 'suka': 'suka', 'mempelajari': 'ajar', 'pelajaran': 'ajar', 'terbaik': 'baik', 'dunia': 'dunia', 'pickup': 'pickup', 'sayang': 'sayang', 'miliki': 'milik', 'peningkatan': 'tingkat', 'sistem': 'sistem', 'operasi': 'operasi', 'militer': 'militer', 'politik': 'politik', 'berusaha': 'usaha', 'menderita': 'derita', 'sakit': 'sakit', 'hati': 'hati', 'je': 'je', 'liga': 'liga', 'champions': 'champions', 'uefa': 'uefa', 'musim': 'musim', 'panas': 'panas', 'orang-orang': 'orang', 'beriman': 'iman', 'beramal': 'amal', 'soleh': 'soleh', 'solehah': 'solehah', 'jawabannya': 'jawab', 'salah': 'salah', 'ar': 'ar', 'ulangan': 'ulang', '92': '92', 'buruk': 'buruk', 'belajar': 'ajar', 'mejing': 'mejing', 'sudah': 'sudah', 'kadang': 'kadang', 'quiznya': 'quiznya', 'error': 'error', 'benar': 'benar', 'dapat': 'dapat', 'xp': 'xp', 'gapyear': 'gapyear', 'semoga': 'moga', 'memahami': 'paham', 'utbk': 'utbk', 'bantuan': 'bantu', 'apa': 'apa', 'hyo': 'hyo', 'bimbel': 'bimbel', 'online': 'online', 'best': 'best', 'because': 'because', 'fitur': 'fitur', 'spesifikasinya': 'spesifikasi', 'lengkap': 'lengkap', 'memuaskan': 'muas', 'really': 'really', 'with': 'with', 'this': 'this', 'understand': 'understand', 'about': 'about', 'each': 'each', 'lesson': 'lesson', 'enthusiastic': 'enthusiastic', 'exploring': 'exploring', 'every': 'every', 'knowledge': 'knowledge', 'day': 'day', 'hope': 'hope', 'support': 'support', 'future': 'future', 'even': 'even', 'better': 'better', 'interesting': 'interesting', 'everyone': 'everyone', 'interested': 'interested', 'application': 'application', 'thank': 'thank', 'very': 'very', 'much': 'much', 'developers': 'developers', 'seru': 'seru', 'mempermudah': 'mudah', 'pekerjaan': 'kerja', 'modul': 'modul', 'dimasukkan': 'masuk', 'didalam': 'dalam', 'soalsoal': 'soalsoal', 'menunjang': 'tunjang', 'kinerja': 'kerja', 'guruguru': 'guruguru', 'latihan': 'latih', 'anakpun': 'anak', 'dalamnya': 'dalam', 'hasil': 'hasil', 'dimana': 'mana', 'anak': 'anak', 'memgerti': 'memgerti', 'skor': 'skor', 'worksheetnya': 'worksheetnya', 'dibutuhkan': 'butuh', 'mengoreksi': 'koreksi', 'persiapannya': 'siap', 'kelas': 'kelas', '4': '4', 'dafa': 'dafa', 'lulu': 'lulu', 'kecewa': 'kecewa', 'jawabanpenjelasan': 'jawabanpenjelasan', 'komputerleptop': 'komputerleptop', 'websitecrome': 'websitecrome', 'diaksesdan': 'diaksesdan', 'berlangganan': 'langgan', 'dibukaitu': 'dibukaitu', 'saran': 'saran', 'kesan': 'kesan', 'sayasaya': 'sayasaya', 'harap': 'harap', 'kedepannya': 'depan', 'penggunaan': 'guna', 'website': 'website', 'terbuka': 'buka', 'skip': 'skip', '10': '10', 'second': 'second', 'device': 'device', 'pclaptop': 'pclaptop', 'tambahan': 'tambah', 'pintar': 'pintar', 'anaknya': 'anak', 'pe ...
# ------------------------
# Pandas Apply:   0%|          | 0/1451 [00:00<?, ?it/s]

# %%
df_skripsi
