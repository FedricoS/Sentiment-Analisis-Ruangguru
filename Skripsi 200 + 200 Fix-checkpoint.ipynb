# %%
import pandas as pd 
import numpy as np
import string 
import re 
from nltk.tokenize import word_tokenize 
from nltk.probability import FreqDist
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

# %%
df = pd.read_excel('data_skripsiku.xlsx')

# %%
df
# Out:
#                     Time Sentiment  \
# 0    2023-02-11 15:32:42  Negative
# 1    2023-02-11 13:55:16  Positive
# 2    2023-02-11 06:55:16  Negative
# 3    2022-10-16 12:57:02  Negative
# 4    2023-02-11 06:39:53  Positive
# ...                  ...       ...
# 1582 2022-10-17 06:24:26  Positive
# 1583 2022-10-17 05:59:16  Positive
# 1584 2022-10-17 03:28:27  Negative
# 1585 2022-10-17 02:48:35  Positive
# 1586 2022-10-16 12:17:51  Positive
#
#                                                 Content  score  \
# 0                       Roboguru harus beli paket… why?      3
# 1                 Sangat membantu jaya terus ruang guru      5
# 2     Video nya ga bisa diputar, padahal udah diundu...      4
# 3     Eror terus video nya ,nyesel gue Makai ruang guru      1
# 4                             Keren banget deh pokoknya      5
# ...                                                 ...    ...
# 1582  Bagus banget aplikasinya, bisa membantu saya d...      5
# 1583  Aplikasi nya bagus banget apa lagi belajar nya...      5
# 1584            Buruk sekali tidak ada mapel ushul fiqh      1
# 1585                   Bagussssssssssssss S s s s sss S      5
# 1586  Puasss bangatt bisa langsung paham, semoga rua...      5
#
#      reviewCreatedVersion
# 0                  6.39.0
# 1                  6.52.0
# 2                  6.52.0
# 3                     NaN
# 4                  6.52.0
# ...                   ...
# 1582                  NaN
# 1583               6.45.1
# 1584               6.45.0
# 1585               6.45.0
# 1586               6.45.0
#
# [1587 rows x 5 columns]

# %%
df_skripsi = df.drop(['score','reviewCreatedVersion','Time'],axis = 1)

# %%
komennegatif= df_skripsi[df_skripsi['Sentiment'] == "Negative"]
komenpositif= df_skripsi[df_skripsi['Sentiment'] == "Positive"]

# %%
komennegatif100 = komennegatif.head(200)
komenpositif100 = komenpositif.head(200)

# %%
df_komen100 = komennegatif100.merge(komenpositif100 , how='outer')
df_komen100
# Out:
#     Sentiment                                            Content
# 0    Negative                    Roboguru harus beli paket… why?
# 1    Negative  Video nya ga bisa diputar, padahal udah diundu...
# 2    Negative  Eror terus video nya ,nyesel gue Makai ruang guru
# 3    Negative  Aku punya keluhan terhadap link web atau xdari...
# 4    Negative  halo ka, kalo buat PC letak drill soal nya ada...
# ..        ...                                                ...
# 395  Positive  Aku suka banget .aku bisa ketemu orang orang h...
# 396  Positive  Sangat membantu saya mengajarkan tugas dan mem...
# 397  Positive  Ini bagus banget karena bisa bantu cucusaya be...
# 398  Positive       Saya sangat senang sekali bisa di ruang guru
# 399  Positive                                             Mixsiu
#
# [400 rows x 2 columns]

# %% [markdown]
# # Mendeteksi Positive & Negative

# %%
df_komen100.Sentiment.value_counts()
# Out:
# Negative    200
# Positive    200
# Name: Sentiment, dtype: int64

# %%
df_skripsi = df_komen100

# %% [markdown]
# # Menampilkan Bagian Kolom pada Data

# %%
df_skripsi.columns = ['label','text_real']

# %%
df_skripsi['text'] = df_skripsi.text_real

# %% [markdown]
# # Menampilkan DataFrame

# %%
df_skripsi
# Out:
#         label                                          text_real  \
# 0    Negative                    Roboguru harus beli paket… why?
# 1    Negative  Video nya ga bisa diputar, padahal udah diundu...
# 2    Negative  Eror terus video nya ,nyesel gue Makai ruang guru
# 3    Negative  Aku punya keluhan terhadap link web atau xdari...
# 4    Negative  halo ka, kalo buat PC letak drill soal nya ada...
# ..        ...                                                ...
# 395  Positive  Aku suka banget .aku bisa ketemu orang orang h...
# 396  Positive  Sangat membantu saya mengajarkan tugas dan mem...
# 397  Positive  Ini bagus banget karena bisa bantu cucusaya be...
# 398  Positive       Saya sangat senang sekali bisa di ruang guru
# 399  Positive                                             Mixsiu
#
#                                                   text
# 0                      Roboguru harus beli paket… why?
# 1    Video nya ga bisa diputar, padahal udah diundu...
# 2    Eror terus video nya ,nyesel gue Makai ruang guru
# 3    Aku punya keluhan terhadap link web atau xdari...
# 4    halo ka, kalo buat PC letak drill soal nya ada...
# ..                                                 ...
# 395  Aku suka banget .aku bisa ketemu orang orang h...
# 396  Sangat membantu saya mengajarkan tugas dan mem...
# 397  Ini bagus banget karena bisa bantu cucusaya be...
# 398       Saya sangat senang sekali bisa di ruang guru
# 399                                             Mixsiu
#
# [400 rows x 3 columns]

# %% [markdown]
# # Mengubah Huruf menjadi Kecil

# %%
df_skripsi['text'] = df_skripsi['text'].str.lower()
print('Case Folding Result : \n')
print(df_skripsi['text'].head(5))
print('\n\n\n')
# Out:
# Case Folding Result :
#
# 0                      roboguru harus beli paket… why?
# 1    video nya ga bisa diputar, padahal udah diundu...
# 2    eror terus video nya ,nyesel gue makai ruang guru
# 3    aku punya keluhan terhadap link web atau xdari...
# 4    halo ka, kalo buat pc letak drill soal nya ada...
# Name: text, dtype: object

# %% [markdown]
# # Menghapus Special Karakter dan Url

# %%
def remove_text_special(text):
    # hapus tab, new line, ans back slice
    text = text.replace('\\t'," ").replace('\\n'," ").replace('\\u'," ").replace('\\',"")
    # hapus non ASCII (emot, bahasa china dll)
    text = text.encode('ascii', 'replace').decode('ascii')
    # hapus mention, link, hashtag
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)"," ", text).split())
    # remove URL 
    return text.replace("http://", " ").replace("https://", " ")
df_skripsi['text'] = df_skripsi.text.astype('str')                
df_skripsi['text'] = df_skripsi['text'].apply(remove_text_special)

# %% [markdown]
# # Menghapus Elongasi

# %%
#remove kata yang sengaja dipanjangkan
# seperti bisaaaaaaa -> bisa
def spell(word):
    if re.search(r'([a-zA-Z])\1{2,}', word):
        rword = re.sub(r'([a-zA-Z])\1{2,}','\\1', word)
        return rword
    else:
        return word
df_skripsi['text'] = df_skripsi['text'].apply(spell)

# %% [markdown]
# # Menghapus Tanda Baca

# %%
def remove_punctuation(text):
    return text.translate(str.maketrans("","",string.punctuation))

df_skripsi['text'] = df_skripsi['text'].apply(remove_punctuation)

df_skripsi
# Out:
#         label                                          text_real  \
# 0    Negative                    Roboguru harus beli paket… why?
# 1    Negative  Video nya ga bisa diputar, padahal udah diundu...
# 2    Negative  Eror terus video nya ,nyesel gue Makai ruang guru
# 3    Negative  Aku punya keluhan terhadap link web atau xdari...
# 4    Negative  halo ka, kalo buat PC letak drill soal nya ada...
# ..        ...                                                ...
# 395  Positive  Aku suka banget .aku bisa ketemu orang orang h...
# 396  Positive  Sangat membantu saya mengajarkan tugas dan mem...
# 397  Positive  Ini bagus banget karena bisa bantu cucusaya be...
# 398  Positive       Saya sangat senang sekali bisa di ruang guru
# 399  Positive                                             Mixsiu
#
#                                                   text
# 0                        roboguru harus beli paket why
# 1      video nya ga bisa diputar padahal udah diunduh
# 2     eror terus video nya nyesel gue makai ruang guru
# 3    aku punya keluhan terhadap link web atau xdari...
# 4    halo ka kalo buat pc letak drill soal nya ada ...
# ..                                                 ...
# 395  aku suka banget aku bisa ketemu orang orang he...
# 396  sangat membantu saya mengajarkan tugas dan mem...
# 397  ini bagus banget karena bisa bantu cucusaya be...
# 398       saya sangat senang sekali bisa di ruang guru
# 399                                             mixsiu
#
# [400 rows x 3 columns]

# %% [markdown]
# # Menghapus Enter Tab

# %%
#remove whitespace leading & trailing
def remove_whitespace_LT(text):
    return text.strip()

df_skripsi['text'] = df_skripsi['text'].apply(remove_whitespace_LT)

df_skripsi
# Out:
#         label                                          text_real  \
# 0    Negative                    Roboguru harus beli paket… why?
# 1    Negative  Video nya ga bisa diputar, padahal udah diundu...
# 2    Negative  Eror terus video nya ,nyesel gue Makai ruang guru
# 3    Negative  Aku punya keluhan terhadap link web atau xdari...
# 4    Negative  halo ka, kalo buat PC letak drill soal nya ada...
# ..        ...                                                ...
# 395  Positive  Aku suka banget .aku bisa ketemu orang orang h...
# 396  Positive  Sangat membantu saya mengajarkan tugas dan mem...
# 397  Positive  Ini bagus banget karena bisa bantu cucusaya be...
# 398  Positive       Saya sangat senang sekali bisa di ruang guru
# 399  Positive                                             Mixsiu
#
#                                                   text
# 0                        roboguru harus beli paket why
# 1       video nya ga bisa diputar padahal udah diunduh
# 2     eror terus video nya nyesel gue makai ruang guru
# 3    aku punya keluhan terhadap link web atau xdari...
# 4    halo ka kalo buat pc letak drill soal nya ada ...
# ..                                                 ...
# 395  aku suka banget aku bisa ketemu orang orang he...
# 396  sangat membantu saya mengajarkan tugas dan mem...
# 397  ini bagus banget karena bisa bantu cucusaya be...
# 398       saya sangat senang sekali bisa di ruang guru
# 399                                             mixsiu
#
# [400 rows x 3 columns]

# %% [markdown]
# # Menghapus Spasi yang Terlalu Banyak

# %%
def remove_whitespace_multiple(text):
    return re.sub('\s+',' ',text)

df_skripsi['text'] = df_skripsi['text'].apply(remove_whitespace_multiple)

def remove_singl_char(text):
    return re.sub(r"\b[a-zA-Z]\b", "", text)

df_skripsi['text'] = df_skripsi['text'].apply(remove_singl_char)

df_skripsi
# Out:
#         label                                          text_real  \
# 0    Negative                    Roboguru harus beli paket… why?
# 1    Negative  Video nya ga bisa diputar, padahal udah diundu...
# 2    Negative  Eror terus video nya ,nyesel gue Makai ruang guru
# 3    Negative  Aku punya keluhan terhadap link web atau xdari...
# 4    Negative  halo ka, kalo buat PC letak drill soal nya ada...
# ..        ...                                                ...
# 395  Positive  Aku suka banget .aku bisa ketemu orang orang h...
# 396  Positive  Sangat membantu saya mengajarkan tugas dan mem...
# 397  Positive  Ini bagus banget karena bisa bantu cucusaya be...
# 398  Positive       Saya sangat senang sekali bisa di ruang guru
# 399  Positive                                             Mixsiu
#
#                                                   text
# 0                        roboguru harus beli paket why
# 1       video nya ga bisa diputar padahal udah diunduh
# 2     eror terus video nya nyesel gue makai ruang guru
# 3    aku punya keluhan terhadap link web atau xdari...
# 4    halo ka kalo buat pc letak drill soal nya ada ...
# ..                                                 ...
# 395  aku suka banget aku bisa ketemu orang orang he...
# 396  sangat membantu saya mengajarkan tugas dan mem...
# 397  ini bagus banget karena bisa bantu cucusaya be...
# 398       saya sangat senang sekali bisa di ruang guru
# 399                                             mixsiu
#
# [400 rows x 3 columns]

# %% [markdown]
# # Membuat Kolom text_token Berisi Kumpulan Kata-kata yang dipisah dengan Koma

# %%
df_skripsi = df_skripsi.drop_duplicates()
df_skripsi = df_skripsi[['label','text_real','text']]
df_skripsi['text'] = df_skripsi['text'].str.lower()

def word_tokenize_wrapper(text):
    return word_tokenize(text)

df_skripsi['text_tokens'] = df_skripsi['text'].apply(word_tokenize_wrapper)

# %%
df_skripsi
# Out:
#         label                                          text_real  \
# 0    Negative                    Roboguru harus beli paket… why?
# 1    Negative  Video nya ga bisa diputar, padahal udah diundu...
# 2    Negative  Eror terus video nya ,nyesel gue Makai ruang guru
# 3    Negative  Aku punya keluhan terhadap link web atau xdari...
# 4    Negative  halo ka, kalo buat PC letak drill soal nya ada...
# ..        ...                                                ...
# 395  Positive  Aku suka banget .aku bisa ketemu orang orang h...
# 396  Positive  Sangat membantu saya mengajarkan tugas dan mem...
# 397  Positive  Ini bagus banget karena bisa bantu cucusaya be...
# 398  Positive       Saya sangat senang sekali bisa di ruang guru
# 399  Positive                                             Mixsiu
#
#                                                   text  \
# 0                        roboguru harus beli paket why
# 1       video nya ga bisa diputar padahal udah diunduh
# 2     eror terus video nya nyesel gue makai ruang guru
# 3    aku punya keluhan terhadap link web atau xdari...
# 4    halo ka kalo buat pc letak drill soal nya ada ...
# ..                                                 ...
# 395  aku suka banget aku bisa ketemu orang orang he...
# 396  sangat membantu saya mengajarkan tugas dan mem...
# 397  ini bagus banget karena bisa bantu cucusaya be...
# 398       saya sangat senang sekali bisa di ruang guru
# 399                                             mixsiu
#
#                                            text_tokens
# 0                  [roboguru, harus, beli, paket, why]
# 1    [video, nya, ga, bisa, diputar, padahal, udah,...
# 2    [eror, terus, video, nya, nyesel, gue, makai, ...
# 3    [aku, punya, keluhan, terhadap, link, web, ata...
# 4    [halo, ka, kalo, buat, pc, letak, drill, soal,...
# ..                                                 ...
# 395  [aku, suka, banget, aku, bisa, ketemu, orang, ...
# 396  [sangat, membantu, saya, mengajarkan, tugas, d...
# 397  [ini, bagus, banget, karena, bisa, bantu, cucu...
# 398  [saya, sangat, senang, sekali, bisa, di, ruang...
# 399                                           [mixsiu]
#
# [380 rows x 4 columns]

# %% [markdown]
# # Menghapus Stopwords

# %%
list_stopwords = stopwords.words('indonesian')
list_stopwords.extend(["yg", "dg", "rt", "dgn", "ny", "d", 'klo', 
                       'kalo', 'amp', 'biar', 'bikin', 'bilang', 
                       'gak', 'ga', 'krn', 'nya', 'nih', 'sih', 
                       'si', 'tau', 'tdk', 'tuh', 'utk', 'ya', 
                       'jd', 'jgn', 'sdh', 'aja', 'n', 't', 
                       'nyg', 'hehe', 'pen', 'u', 'nan', 'loh', 'rt',
                       '&amp', 'yah'])

txt_stopword = pd.read_csv("stopwords.txt", names= ["stopwords"], header = None)
list_stopwords.extend(txt_stopword["stopwords"][0].split(' '))
list_stopwords = set(list_stopwords)
def stopwords_removal(words):
    return [word for word in words if word not in list_stopwords]
df_skripsi['Stopwords'] = df_skripsi['text_tokens'].apply(stopwords_removal)

# %%
list_stopwords
# Out:
# {'',
#  'sekaranglah',
#  'dalam',
#  'rasanya',
#  'sampaikan',
#  'ajaa',
#  'teringat-ingat',
#  'oiya',
#  're',
#  'mata',
#  'sang',
#  'sebabnya',
#  'disinilah',
#  'piye',
#  'ngoahahahahahaaa',
#  'disebut',
#  'woooooi',
#  'jiaah',
#  'sig',
#  'jadilah',
#  'sy',
#  'follow',
#  'tw',
#  'wyg',
#  'seenaknya',
#  'dink',
#  'semisalnya',
#  'perlukah',
#  'sajalah',
#  'melainkan',
#  'sich',
#  'sekadar',
#  'memperlihatkan',
#  'disini',
#  'bermacam-macam',
#  'bermula',
#  'dahhh',
#  'per',
#  'deh',
#  'tiba',
#  'bisa',
#  'jan',
#  'tetap',
#  'jawabnya',
#  'dll',
#  'beib',
#  'bawah',
#  'jgn',
#  'terhadap',
#  'seng',
#  'dilakukan',
#  'baik',
#  'mana',
#  'betul',
#  'sebanyak',
#  'tahun',
#  'ama',
#  'aph',
#  'bahwasannya',
#  'setiap',
#  'kepadanya',
#  'selalu',
#  'dil',
#  'kalian',
#  'percuma',
#  'siapakah',
#  'sudahkah',
#  'on',
#  'dianya',
#  'baiklah',
#  'jngn',
#  'dimintai',
#  'gem',
#  'keseluruhannya',
#  'haruslah',
#  'daripada',
#  'walaupun',
#  'sejumlah',
#  'dimungkinkan',
#  'sih',
#  'sedikit',
#  'bers',
#  'waduh',
#  'koit',
#  'kpd',
#  'kala',
#  'terakhir',
#  'laah',
#  'menanya',
#  'md',
#  'bertutur',
#  'kr',
#  'seusai',
#  'k',
#  'pea',
#  'sambil',
#  'ailapyupul',
#  'dp',
#  'asyiapp',
#  'nder',
#  'hend',
#  'asee',
#  'dan',
#  'ki',
#  'lg',
#  'hiikksss',
#  'ti',
#  'ntr',
#  'hingga',
#  'aduch',
#  'demi',
#  'pem',
#  'kesampaian',
#  'udahlah',
#  'diibaratkannya',
#  'np',
#  'apaaaannnn',
#  'pi',
#  'apabl',
#  'sesegera',
#  'uppppsss',
#  'terhadapnya',
#  'mengenai',
#  'akhiri',
#  'lain',
#  'soal',
#  'sepertinya',
#  'jelasnya',
#  'jauuh',
#  'baru',
#  'menyeluruh',
#  'serupa',
#  'malah',
#  'peesai',
#  'waaahh',
#  'ihh',
#  'olehnya',
#  'macam',
#  'aseekk',
#  'preesss',
#  'pp',
#  'hadeh',
#  'eo',
#  'don',
#  'dah',
#  'sinilah',
#  'ea',
#  'the',
#  'haaa',
#  'bolehlah',
#  'aernye',
#  'ge',
#  'cam',
#  'mendatang',
#  'dikira',
#  'noh',
#  'hr',
#  'tri',
#  'sempat',
#  'pre',
#  'nyatanya',
#  'setelah',
#  'tuip',
#  'terlalu',
#  'ya',
#  'kamulah',
#  'er',
#  'kelihatannya',
#  'woyyyyyy',
#  'j',
#  'ngak',
#  'diucapkannya',
#  'terb',
#  'apaan',
#  'yu',
#  'sama',
#  'sedang',
#  'begitukah',
#  'aiiihhh',
#  'tandasnya',
#  'apasih',
#  'sbgai',
#  'yaah',
#  'kepa',
#  'ampe',
#  'sekarang',
#  'jah',
#  'mengg',
#  'kelamaan',
#  'angg',
#  'mengapa',
#  'hallo',
#  'gk',
#  'berdatangan',
#  'diungkapkan',
#  'yaitu',
#  'lanjut',
#  'ooohhh',
#  'cuy',
#  'ingin',
#  'gpp',
#  'sepantasnyalah',
#  'menuturkan',
#  'berbagai',
#  'itukah',
#  'sedemikian',
#  'sebaliknya',
#  'ho',
#  'd',
#  'gun',
#  'setengah',
#  'mon',
#  'berkali-kali',
#  'pernah',
#  'tambahnya',
#  'mengakhiri',
#  'sblm',
#  'kudu',
#  'huhuhu',
#  'wal',
#  'tanyakan',
#  'wooiiii',
#  'asyiiiiik',
#  'nantinya',
#  'kapanpun',
#  'bagian',
#  'berakhirnya',
#  'mrk',
#  'empat',
#  'lu',
#  'aaah',
#  'pukul',
#  'dimulai',
#  'jab',
#  'teh',
#  'ind',
#  'deng',
#  'akhirx',
#  'siip',
#  'loe',
#  'ingat-ingat',
#  'ada',
#  'beginikah',
#  'ngo',
#  'ajaah',
#  'man',
#  'tentu',
#  'astaghf',
#  'piyek',
#  'udah',
#  'dehh',
#  'hadech',
#  'dimisalkan',
#  'h',
#  'banyak',
#  'ros',
#  'mula',
#  'yee',
#  'selama',
#  'tour',
#  'gitu',
#  'berarti',
#  'ieu',
#  'menandaskan',
#  'tl',
#  'pe',
#  'tampak',
#  'berlangsung',
#  'ntu',
#  'la',
#  'meskipun',
#  'imb',
#  'rt',
#  'fya',
#  'ta',
#  'saatnya',
#  'sal',
#  'bgaimana',
#  'tadinya',
#  'sekitar',
#  'pun',
#  'bg',
#  'tur',
#  'kual',
#  'berlebihan',
#  'kek',
#  'be',
#  'pula',
#  'n',
#  'kn',
#  'kwk',
#  'sory',
#  'my',
#  'tandas',
#  'hendaklah',
#  'yth',
#  'memulai',
#  'orang',
#  'sebaiknya',
#  'ataupun',
#  'hadeehhh',
#  'mantaaapp',
#  'tragedy',
#  'awokawokawok',
#  'bulan',
#  'pada',
#  'bagaimanapun',
#  'duh',
#  'q',
#  'terlebih',
#  'segala',
#  'sela',
#  'semua',
#  'ditujukan',
#  'aduhh',
#  'sampai',
#  'merupakan',
#  'bersama',
#  'mm',
#  'bukan',
#  'ela',
#  'dgn',
#  'bar',
#  'tentulah',
#  'yupsss',
#  'bagaikan',
#  'dmn',
#  'ja',
#  'cik',
#  'astaghfirullah',
#  'wkwaww',
#  'kebetulan',
#  'kal',
#  'tentunya',
#  'sehingga',
#  'sekali-kali',
#  'kalau',
#  'suatu',
#  'sak',
#  'tinggi',
#  'gangs',
#  'pr',
#  'berikut',
#  'twe',
#  'huh',
#  'aaa',
#  'yups',
#  'mendapatkan',
#  'dilalui',
#  'seperlunya',
#  'jelaskan',
#  'hanya',
#  'is',
#  'penc',
#  'ckakak',
#  'kurang',
#  'diar',
#  'keri',
#  'gar',
#  'pertanyaan',
#  'wis',
#  'alu',
#  'ingat',
#  'sendirian',
#  'dila',
#  'jiah',
#  'guys',
#  'berkehendak',
#  'pasi',
#  'lat',
#  'donk',
#  'to',
#  'khan',
#  'ret',
#  'eeeh',
#  'jangn',
#  'nanti',
#  'wah',
#  'dst',
#  'mendapat',
#  'uhuii',
#  'menjelaskan',
#  'dikerjakan',
#  'ber',
#  'waduhhh',
#  'berlalu',
#  'seluruh',
#  'mun',
#  'bagaimanakah',
#  'ditambahkan',
#  'eeh',
#  'secara',
#  'apabila',
#  'menyiapkan',
#  'kitalah',
#  'disebutkan',
#  'syyo',
#  'demikianlah',
#  'djangan',
#  'sama-sama',
#  'ny',
#  'mi',
#  'sekiranya',
#  'heeeeellloooo',
#  'menurut',
#  'para',
#  'nis',
#  'seorang',
#  'and',
#  'atuh',
#  'jelas',
#  'ol',
#  'spy',
#  'tahu',
#  'inikah',
#  'look',
#  'dini',
#  'wala',
#  'po',
#  'ehhh',
#  'ditunjuki',
#  'ciiee',
#  'berjumlah',
#  'ahhhh',
#  'woyyyyy',
#  'jgan',
#  'bahwasanya',
#  'tuturnya',
#  'nek',
#  'dar',
#  'jagan',
#  'pt',
#  'le',
#  'samlekum',
#  'lohhhh',
#  'sebab',
#  'sebelumnya',
#  'silakan',
#  'blm',
#  'kira',
#  'bla',
#  'ncuup',
#  'aku',
#  'sesaat',
#  'mampu',
#  'ksh',
#  'rupanya',
#  'dipertanyakan',
#  'benar',
#  'pohonnnn',
#  'jat',
#  'ae',
#  'dipergunakan',
#  'padahal',
#  'ww',
#  'x',
#  'berapa',
#  'om',
#  'pol',
#  'apakh',
#  'astagfirullah',
#  'org',
#  'keleus',
#  'tu',
#  'mengibaratkannya',
#  'sebagian',
#  'bapak',
#  'saling',
#  'a',
#  'wooyy',
#  'loooh',
#  'mulanya',
#  'aaaahhhh',
#  'nih',
#  'dijelaskan',
#  'ju',
#  'mere',
#  'ujarnya',
#  'th',
#  'satu',
#  'terjadilah',
#  'ini',
#  'hello',
#  'seluruhnya',
#  'kak',
#  'tt',
#  'agak',
#  'tiba-tiba',
#  'diperlukan',
#  'pret',
#  'nii',
#  'berapapun',
#  'memperkirakan',
#  'mungkinkah',
#  'wouy',
#  'menaiki',
#  'b',
#  'memang',
#  'semata-mata',
#  'mang',
#  'ndy',
#  'abd',
#  'langsung',
#  'masing',
#  'te',
#  'akankah',
#  'dipastikan',
#  'anca',
#  'seketika',
#  'hai',
#  'ting',
#  'menginginkan',
#  'sem',
#  'ntup',
#  'keinginan',
#  'sekrg',
#  'masalah',
#  'aka',
#  'pentingnya',
#  'what',
#  'wkwkw',
#  'jln',
#  'cc',
#  'hk',
#  'tp',
#  'astaga',
#  'dua',
#  'hampir',
#  'r',
#  'mul',
#  'menggunakan',
#  'siiiiiiiih',
#  'dwatkn',
#  'naik',
#  'yeee',
#  'asik',
#  'keadaan',
#  'sudah',
#  'sihhh',
#  'astagaaaahhh',
#  'from',
#  'terjadinya',
#  'apaansi',
#  'ga',
#  'katakanlah',
#  'klop',
#  'coy',
#  'eh',
#  'ben',
#  'diperbuatnya',
#  'sdh',
#  'maww',
#  'lamanya',
#  'masalahnya',
#  'tah',
#  'pd',
#  'kagak',
#  'nya',
#  'melakukan',
#  'sekurangnya',
#  'mistakes',
#  'juga',
#  'drpd',
#  'kenapa',
#  'apabedanya',
#  'bwa',
#  'ibaratkan',
#  'oo',
#  'persoalan',
#  'trus',
#  'yg',
#  'jdi',
#  'seolah',
#  'sam',
#  'jikalau',
#  'begi',
#  'sud',
#  'merasa',
#  'lak',
#  'setidak-tidaknya',
#  'pic',
#  'uittt',
#  'atas',
#  'tempat',
#  'dialah',
#  'tuk',
#  'flood',
#  'mempersiapkan',
#  'woooy',
#  'sbg',
#  'rupa',
#  'as',
#  'dibuat',
#  'gih',
#  'benarlah',
#  'bahahak',
#  'gug',
#  'ksp',
#  'terdapat',
#  'kl',
#  'peeeeetttt',
#  'menyangkut',
#  'apalg',
#  'w',
#  'neeh',
#  'bagainamakah',
#  'sekalipun',
#  'yaelah',
#  'mempergunakan',
#  'sendiri',
#  'lama',
#  'keluar',
#  'balik',
#  'kan',
#  'agar',
#  'perlu',
#  'bun',
#  'mengerjakan',
#  'mer',
#  'meminta',
#  'ilah',
#  'dilihat',
#  'sebagaimana',
#  'jangan',
#  'asalkan',
#  'bs',
#  'jleb',
#  'kecil',
#  'diberikannya',
#  'enggaknya',
#  'hayo',
#  'kem',
#  'sebenarnya',
#  'sebaik',
#  'memperbuat',
#  'sejak',
#  'berada',
#  'dijelaskannya',
#  'kes',
#  'artinya',
#  'dahulu',
#  'diantara',
#  'sana',
#  'seharusnya',
#  'jg',
#  'seingat',
#  'sib',
#  'al',
#  'apalgi',
#  'masihkah',
#  'selaku',
#  'krn',
#  'bukanlah',
#  'beer',
#  'btw',
#  'mba',
#  'bagemana',
#  'asa',
#  'akh',
#  'peel',
#  'tuju',
#  'biasanya',
#  'yah',
#  'masa',
#  'dimaksudnya',
#  'cukupkah',
#  'asn',
#  'bahkan',
#  'are',
#  'apabilah',
#  'gin',
#  'sesekali',
#  'hey',
#  'beh',
#  'untuk',
#  'nahh',
#  'oi',
#  'kerja',
#  'ehh',
#  'nge',
#  'asu',
#  'wih',
#  'tan',
#  'sada',
#  'astagpirullohalazmin',
#  'hendak',
#  'ky',
#  'jauh',
#  'secukupnya',
#  'sesama',
#  'memintakan',
#  'tek',
#  'asuuu',
#  'eaaaa',
#  'ahahahah',
#  'ditanyakan',
#  'depan',
#  'aud',
#  'hmmmmmm',
#  'mempunyai',
#  'do',
#  'by',
#  'didatangkan',
#  'demikian',
#  'slrh',
#  'memerlukan',
#  'hhh',
#  'lohh',
#  'sebesar',
#  'but',
#  'mempersoalkan',
#  'yakali',
#  'adoh',
#  'akulah',
#  'ialah',
#  'fa',
#  'awokaowkaowk',
#  'salam',
#  'ld',
#  'dimaksud',
#  'inilah',
#  'nyang',
#  'toet',
#  'ajib',
#  'mengingatkan',
#  'seberapa',
#  'diperlihatkan',
#  'mpod',
#  'sebelum',
#  'tuu',
#  'bersama-sama',
#  'adapun',
#  'bahahaha',
#  'menunjuki',
#  'kwkwk',
#  'luar',
#  'bai',
#  'bena',
#  'tanya',
#  'semula',
#  'jee',
#  'ht',
#  'bas',
#  'lainnya',
#  'begitulah',
#  'met',
#  'ntuh',
#  'sebaik-baiknya',
#  'biup',
#  'apain',
#  'sebut',
#  'setiba',
#  'terlihat',
#  'ii',
#  'kembali',
#  'kiranya',
#  'kasihh',
#  'cokkk',
#  'yv',
#  'am',
#  'meski',
#  'baaeerrree',
#  'hehe',
#  'turut',
#  'terutama',
#  'iki',
#  'bahwa',
#  'menunjuk',
#  'dimulainya',
#  'mbh',
#  'semampu',
#  'kemudian',
#  'aplagi',
#  'menantikan',
#  'in',
#  'ba',
#  'menyampaikan',
#  'mg',
#  'tela',
#  'ahaaaaa',
#  'practice',
#  'audzubillah',
#  'bermaksud',
#  'haiii',
#  'asek',
#  'berujar',
#  'ikut',
#  'ngk',
#  'sebuah',
#  'cara',
#  'eye',
#  'agaknya',
#  'wid',
#  'dab',
#  'mau',
#  'gmn',
#  'dibia',
#  'sik',
#  'pak',
#  'woooyyyyy',
#  'yukk',
#  'datang',
#  'sekaligus',
#  'apa',
#  'anda',
#  'seterusnya',
#  'tidakkah',
#  'if',
#  'kantri',
#  'kata',
#  'apkah',
#  'tersebutlah',
#  'of',
#  'saa',
#  'ibarat',
#  'waktu',
#  'diketahui',
#  'bo',
#  'ypk',
#  'menegaskan',
#  'bakal',
#  'ng',
#  'ibaratnya',
#  'can',
#  'ahool',
#  'dibuatnya',
#  'perlunya',
#  'skrg',
#  'ehe',
#  'dituturkannya',
#  'u',
#  'ahhh',
#  'eng',
#  'dapat',
#  'men',
#  'berapakah',
#  'ken',
#  'khusus',
#  'ajaaah',
#  'haha',
#  'antar',
#  'padanya',
#  'usai',
#  'they',
#  'mereka',
#  'dust',
#  'ujar',
#  'lebih',
#  'menyer',
#  'lur',
#  'spt',
#  'ndezz',
#  'like',
#  'meh',
#  'tepat',
#  'bukannya',
#  'enak',
#  'sa',
#  'bro',
#  't',
#  'setibanya',
#  'bant',
#  'sj',
#  'semacam',
#  'siapa',
#  'justru',
#  'co',
#  'oh',
#  'keunn',
#  'eiy',
#  'bag',
#  'f',
#  'ay',
#  'lbh',
#  'gedhe',
#  'hadeeuh',
#  'cukup',
#  'p',
#  'menjawab',
#  'kpn',
#  'halah',
#  'lihat',
#  'xs',
#  'mb',
#  'berupa',
#  'where',
#  'keterlaluan',
#  'heleh',
#  'pek',
#  'sangat',
#  'terl',
#  'ajjaaa',
#  'bk',
#  'aseekkk',
#  'diperlukannya',
#  'lai',
#  'liyat',
#  'apakah',
#  'semaunya',
#  'wh',
#  'bwt',
#  'laelah',
#  'kini',
#  'loh',
#  'berkenaan',
#  'ggh',
#  'dikatakan',
#  'pertama-tama',
#  'berikutnya',
#  'sesudahnya',
#  'kira-kira',
#  'tong',
#  'meyakini',
#  'adanya',
#  'sebisanya',
#  'wahaye',
#  'sec',
#  'ahhay',
#  'setidaknya',
#  'ma',
#  'tersebut',
#  'tiga',
#  'broo',
#  'akhirnya',
#  'sekadarnya',
#  'ji',
#  'diinginkan',
#  'atau',
#  'ke',
#  'alangkah',
#  'sedikitnya',
#  'jdkn',
#  'tgjwb',
#  'digunakan',
#  'sebagai',
#  'hendaknya',
#  'membuat',
#  'itu',
#  'me',
#  'tr',
#  'sayalah',
#  'memberikan',
#  'lahh',
#  'gn',
#  'ooo',
#  'ia',
#  'c',
#  'kor',
#  'ajasi',
#  'assuuu',
#  'gimana',
#  'sul',
#  'hih',
#  'misalkan',
#  'boys',
#  'wow',
#  'cuih',
#  'mampukah',
#  'moga',
#  'dirinya',
#  'hehehe',
#  'qckog',
#  'memastikan',
#  'klo',
#  'menyatakan',
#  'biarpun',
#  'memungkinkan',
#  'masing-masing',
#  'sendirinya',
#  'vs',
#  'sar',
#  'jhiee',
#  'siep',
#  'sini',
#  'asiiikkk',
#  'tersampaikan',
#  'gsk',
#  'entahlah',
#  'joss',
#  'kah',
#  'kok',
#  'bur',
#  'memperba',
#  'adalah',
#  'jo',
#  'bilang',
#  'wk',
#  'kepada',
#  'kam',
#  'sebegini',
#  'kalaulah',
#  'mengatakannya',
#  'khususnya',
#  'mengira',
#  'dech',
#  'bi',
#  'dia',
#  'bah',
#  'diingatkan',
#  'ntar',
#  ...}

# %% [markdown]
# # Distribusi Frekuensi NLTK

# %%
def freqDist_wrapper(text):
    return FreqDist(text)

df_skripsi['text_tokens_fdist'] = df_skripsi['text_tokens'].apply(freqDist_wrapper)

print('Frequency Tokens : \n') 
print(df_skripsi['text_tokens_fdist'].head().apply(lambda x : x.most_common()))
# Out:
# Frequency Tokens :
#
# 0    [(roboguru, 1), (harus, 1), (beli, 1), (paket,...
# 1    [(video, 1), (nya, 1), (ga, 1), (bisa, 1), (di...
# 2    [(eror, 1), (terus, 1), (video, 1), (nya, 1), ...
# 3    [(di, 4), (yang, 3), (aku, 2), (ruangguru, 2),...
# 4    [(halo, 1), (ka, 1), (kalo, 1), (buat, 1), (pc...
# Name: text_tokens_fdist, dtype: object

# %% [markdown]
# # Filtering (penghapusan stopwords) / Normalisasi

# %%
from nltk.corpus import stopwords

# %%
list_stopwords = stopwords.words('indonesian')

# %%
list_stopwords
# Out:
# ['ada',
#  'adalah',
#  'adanya',
#  'adapun',
#  'agak',
#  'agaknya',
#  'agar',
#  'akan',
#  'akankah',
#  'akhir',
#  'akhiri',
#  'akhirnya',
#  'aku',
#  'akulah',
#  'amat',
#  'amatlah',
#  'anda',
#  'andalah',
#  'antar',
#  'antara',
#  'antaranya',
#  'apa',
#  'apaan',
#  'apabila',
#  'apakah',
#  'apalagi',
#  'apatah',
#  'artinya',
#  'asal',
#  'asalkan',
#  'atas',
#  'atau',
#  'ataukah',
#  'ataupun',
#  'awal',
#  'awalnya',
#  'bagai',
#  'bagaikan',
#  'bagaimana',
#  'bagaimanakah',
#  'bagaimanapun',
#  'bagi',
#  'bagian',
#  'bahkan',
#  'bahwa',
#  'bahwasanya',
#  'baik',
#  'bakal',
#  'bakalan',
#  'balik',
#  'banyak',
#  'bapak',
#  'baru',
#  'bawah',
#  'beberapa',
#  'begini',
#  'beginian',
#  'beginikah',
#  'beginilah',
#  'begitu',
#  'begitukah',
#  'begitulah',
#  'begitupun',
#  'bekerja',
#  'belakang',
#  'belakangan',
#  'belum',
#  'belumlah',
#  'benar',
#  'benarkah',
#  'benarlah',
#  'berada',
#  'berakhir',
#  'berakhirlah',
#  'berakhirnya',
#  'berapa',
#  'berapakah',
#  'berapalah',
#  'berapapun',
#  'berarti',
#  'berawal',
#  'berbagai',
#  'berdatangan',
#  'beri',
#  'berikan',
#  'berikut',
#  'berikutnya',
#  'berjumlah',
#  'berkali-kali',
#  'berkata',
#  'berkehendak',
#  'berkeinginan',
#  'berkenaan',
#  'berlainan',
#  'berlalu',
#  'berlangsung',
#  'berlebihan',
#  'bermacam',
#  'bermacam-macam',
#  'bermaksud',
#  'bermula',
#  'bersama',
#  'bersama-sama',
#  'bersiap',
#  'bersiap-siap',
#  'bertanya',
#  'bertanya-tanya',
#  'berturut',
#  'berturut-turut',
#  'bertutur',
#  'berujar',
#  'berupa',
#  'besar',
#  'betul',
#  'betulkah',
#  'biasa',
#  'biasanya',
#  'bila',
#  'bilakah',
#  'bisa',
#  'bisakah',
#  'boleh',
#  'bolehkah',
#  'bolehlah',
#  'buat',
#  'bukan',
#  'bukankah',
#  'bukanlah',
#  'bukannya',
#  'bulan',
#  'bung',
#  'cara',
#  'caranya',
#  'cukup',
#  'cukupkah',
#  'cukuplah',
#  'cuma',
#  'dahulu',
#  'dalam',
#  'dan',
#  'dapat',
#  'dari',
#  'daripada',
#  'datang',
#  'dekat',
#  'demi',
#  'demikian',
#  'demikianlah',
#  'dengan',
#  'depan',
#  'di',
#  'dia',
#  'diakhiri',
#  'diakhirinya',
#  'dialah',
#  'diantara',
#  'diantaranya',
#  'diberi',
#  'diberikan',
#  'diberikannya',
#  'dibuat',
#  'dibuatnya',
#  'didapat',
#  'didatangkan',
#  'digunakan',
#  'diibaratkan',
#  'diibaratkannya',
#  'diingat',
#  'diingatkan',
#  'diinginkan',
#  'dijawab',
#  'dijelaskan',
#  'dijelaskannya',
#  'dikarenakan',
#  'dikatakan',
#  'dikatakannya',
#  'dikerjakan',
#  'diketahui',
#  'diketahuinya',
#  'dikira',
#  'dilakukan',
#  'dilalui',
#  'dilihat',
#  'dimaksud',
#  'dimaksudkan',
#  'dimaksudkannya',
#  'dimaksudnya',
#  'diminta',
#  'dimintai',
#  'dimisalkan',
#  'dimulai',
#  'dimulailah',
#  'dimulainya',
#  'dimungkinkan',
#  'dini',
#  'dipastikan',
#  'diperbuat',
#  'diperbuatnya',
#  'dipergunakan',
#  'diperkirakan',
#  'diperlihatkan',
#  'diperlukan',
#  'diperlukannya',
#  'dipersoalkan',
#  'dipertanyakan',
#  'dipunyai',
#  'diri',
#  'dirinya',
#  'disampaikan',
#  'disebut',
#  'disebutkan',
#  'disebutkannya',
#  'disini',
#  'disinilah',
#  'ditambahkan',
#  'ditandaskan',
#  'ditanya',
#  'ditanyai',
#  'ditanyakan',
#  'ditegaskan',
#  'ditujukan',
#  'ditunjuk',
#  'ditunjuki',
#  'ditunjukkan',
#  'ditunjukkannya',
#  'ditunjuknya',
#  'dituturkan',
#  'dituturkannya',
#  'diucapkan',
#  'diucapkannya',
#  'diungkapkan',
#  'dong',
#  'dua',
#  'dulu',
#  'empat',
#  'enggak',
#  'enggaknya',
#  'entah',
#  'entahlah',
#  'guna',
#  'gunakan',
#  'hal',
#  'hampir',
#  'hanya',
#  'hanyalah',
#  'hari',
#  'harus',
#  'haruslah',
#  'harusnya',
#  'hendak',
#  'hendaklah',
#  'hendaknya',
#  'hingga',
#  'ia',
#  'ialah',
#  'ibarat',
#  'ibaratkan',
#  'ibaratnya',
#  'ibu',
#  'ikut',
#  'ingat',
#  'ingat-ingat',
#  'ingin',
#  'inginkah',
#  'inginkan',
#  'ini',
#  'inikah',
#  'inilah',
#  'itu',
#  'itukah',
#  'itulah',
#  'jadi',
#  'jadilah',
#  'jadinya',
#  'jangan',
#  'jangankan',
#  'janganlah',
#  'jauh',
#  'jawab',
#  'jawaban',
#  'jawabnya',
#  'jelas',
#  'jelaskan',
#  'jelaslah',
#  'jelasnya',
#  'jika',
#  'jikalau',
#  'juga',
#  'jumlah',
#  'jumlahnya',
#  'justru',
#  'kala',
#  'kalau',
#  'kalaulah',
#  'kalaupun',
#  'kalian',
#  'kami',
#  'kamilah',
#  'kamu',
#  'kamulah',
#  'kan',
#  'kapan',
#  'kapankah',
#  'kapanpun',
#  'karena',
#  'karenanya',
#  'kasus',
#  'kata',
#  'katakan',
#  'katakanlah',
#  'katanya',
#  'ke',
#  'keadaan',
#  'kebetulan',
#  'kecil',
#  'kedua',
#  'keduanya',
#  'keinginan',
#  'kelamaan',
#  'kelihatan',
#  'kelihatannya',
#  'kelima',
#  'keluar',
#  'kembali',
#  'kemudian',
#  'kemungkinan',
#  'kemungkinannya',
#  'kenapa',
#  'kepada',
#  'kepadanya',
#  'kesampaian',
#  'keseluruhan',
#  'keseluruhannya',
#  'keterlaluan',
#  'ketika',
#  'khususnya',
#  'kini',
#  'kinilah',
#  'kira',
#  'kira-kira',
#  'kiranya',
#  'kita',
#  'kitalah',
#  'kok',
#  'kurang',
#  'lagi',
#  'lagian',
#  'lah',
#  'lain',
#  'lainnya',
#  'lalu',
#  'lama',
#  'lamanya',
#  'lanjut',
#  'lanjutnya',
#  'lebih',
#  'lewat',
#  'lima',
#  'luar',
#  'macam',
#  'maka',
#  'makanya',
#  'makin',
#  'malah',
#  'malahan',
#  'mampu',
#  'mampukah',
#  'mana',
#  'manakala',
#  'manalagi',
#  'masa',
#  'masalah',
#  'masalahnya',
#  'masih',
#  'masihkah',
#  'masing',
#  'masing-masing',
#  'mau',
#  'maupun',
#  'melainkan',
#  'melakukan',
#  'melalui',
#  'melihat',
#  'melihatnya',
#  'memang',
#  'memastikan',
#  'memberi',
#  'memberikan',
#  'membuat',
#  'memerlukan',
#  'memihak',
#  'meminta',
#  'memintakan',
#  'memisalkan',
#  'memperbuat',
#  'mempergunakan',
#  'memperkirakan',
#  'memperlihatkan',
#  'mempersiapkan',
#  'mempersoalkan',
#  'mempertanyakan',
#  'mempunyai',
#  'memulai',
#  'memungkinkan',
#  'menaiki',
#  'menambahkan',
#  'menandaskan',
#  'menanti',
#  'menanti-nanti',
#  'menantikan',
#  'menanya',
#  'menanyai',
#  'menanyakan',
#  'mendapat',
#  'mendapatkan',
#  'mendatang',
#  'mendatangi',
#  'mendatangkan',
#  'menegaskan',
#  'mengakhiri',
#  'mengapa',
#  'mengatakan',
#  'mengatakannya',
#  'mengenai',
#  'mengerjakan',
#  'mengetahui',
#  'menggunakan',
#  'menghendaki',
#  'mengibaratkan',
#  'mengibaratkannya',
#  'mengingat',
#  'mengingatkan',
#  'menginginkan',
#  'mengira',
#  'mengucapkan',
#  'mengucapkannya',
#  'mengungkapkan',
#  'menjadi',
#  'menjawab',
#  'menjelaskan',
#  'menuju',
#  'menunjuk',
#  'menunjuki',
#  'menunjukkan',
#  'menunjuknya',
#  'menurut',
#  'menuturkan',
#  'menyampaikan',
#  'menyangkut',
#  'menyatakan',
#  'menyebutkan',
#  'menyeluruh',
#  'menyiapkan',
#  'merasa',
#  'mereka',
#  'merekalah',
#  'merupakan',
#  'meski',
#  'meskipun',
#  'meyakini',
#  'meyakinkan',
#  'minta',
#  'mirip',
#  'misal',
#  'misalkan',
#  'misalnya',
#  'mula',
#  'mulai',
#  'mulailah',
#  'mulanya',
#  'mungkin',
#  'mungkinkah',
#  'nah',
#  'naik',
#  'namun',
#  'nanti',
#  'nantinya',
#  'nyaris',
#  'nyatanya',
#  'oleh',
#  'olehnya',
#  'pada',
#  'padahal',
#  'padanya',
#  'pak',
#  'paling',
#  'panjang',
#  'pantas',
#  'para',
#  'pasti',
#  'pastilah',
#  'penting',
#  'pentingnya',
#  'per',
#  'percuma',
#  'perlu',
#  'perlukah',
#  'perlunya',
#  'pernah',
#  'persoalan',
#  'pertama',
#  'pertama-tama',
#  'pertanyaan',
#  'pertanyakan',
#  'pihak',
#  'pihaknya',
#  'pukul',
#  'pula',
#  'pun',
#  'punya',
#  'rasa',
#  'rasanya',
#  'rata',
#  'rupanya',
#  'saat',
#  'saatnya',
#  'saja',
#  'sajalah',
#  'saling',
#  'sama',
#  'sama-sama',
#  'sambil',
#  'sampai',
#  'sampai-sampai',
#  'sampaikan',
#  'sana',
#  'sangat',
#  'sangatlah',
#  'satu',
#  'saya',
#  'sayalah',
#  'se',
#  'sebab',
#  'sebabnya',
#  'sebagai',
#  'sebagaimana',
#  'sebagainya',
#  'sebagian',
#  'sebaik',
#  'sebaik-baiknya',
#  'sebaiknya',
#  'sebaliknya',
#  'sebanyak',
#  'sebegini',
#  'sebegitu',
#  'sebelum',
#  'sebelumnya',
#  'sebenarnya',
#  'seberapa',
#  'sebesar',
#  'sebetulnya',
#  'sebisanya',
#  'sebuah',
#  'sebut',
#  'sebutlah',
#  'sebutnya',
#  'secara',
#  'secukupnya',
#  'sedang',
#  'sedangkan',
#  'sedemikian',
#  'sedikit',
#  'sedikitnya',
#  'seenaknya',
#  'segala',
#  'segalanya',
#  'segera',
#  'seharusnya',
#  'sehingga',
#  'seingat',
#  'sejak',
#  'sejauh',
#  'sejenak',
#  'sejumlah',
#  'sekadar',
#  'sekadarnya',
#  'sekali',
#  'sekali-kali',
#  'sekalian',
#  'sekaligus',
#  'sekalipun',
#  'sekarang',
#  'sekarang',
#  'sekecil',
#  'seketika',
#  'sekiranya',
#  'sekitar',
#  'sekitarnya',
#  'sekurang-kurangnya',
#  'sekurangnya',
#  'sela',
#  'selain',
#  'selaku',
#  'selalu',
#  'selama',
#  'selama-lamanya',
#  'selamanya',
#  'selanjutnya',
#  'seluruh',
#  'seluruhnya',
#  'semacam',
#  'semakin',
#  'semampu',
#  'semampunya',
#  'semasa',
#  'semasih',
#  'semata',
#  'semata-mata',
#  'semaunya',
#  'sementara',
#  'semisal',
#  'semisalnya',
#  'sempat',
#  'semua',
#  'semuanya',
#  'semula',
#  'sendiri',
#  'sendirian',
#  'sendirinya',
#  'seolah',
#  'seolah-olah',
#  'seorang',
#  'sepanjang',
#  'sepantasnya',
#  'sepantasnyalah',
#  'seperlunya',
#  'seperti',
#  'sepertinya',
#  'sepihak',
#  'sering',
#  'seringnya',
#  'serta',
#  'serupa',
#  'sesaat',
#  'sesama',
#  'sesampai',
#  'sesegera',
#  'sesekali',
#  'seseorang',
#  'sesuatu',
#  'sesuatunya',
#  'sesudah',
#  'sesudahnya',
#  'setelah',
#  'setempat',
#  'setengah',
#  'seterusnya',
#  'setiap',
#  'setiba',
#  'setibanya',
#  'setidak-tidaknya',
#  'setidaknya',
#  'setinggi',
#  'seusai',
#  'sewaktu',
#  'siap',
#  'siapa',
#  'siapakah',
#  'siapapun',
#  'sini',
#  'sinilah',
#  'soal',
#  'soalnya',
#  'suatu',
#  'sudah',
#  'sudahkah',
#  'sudahlah',
#  'supaya',
#  'tadi',
#  'tadinya',
#  'tahu',
#  'tahun',
#  'tak',
#  'tambah',
#  'tambahnya',
#  'tampak',
#  'tampaknya',
#  'tandas',
#  'tandasnya',
#  'tanpa',
#  'tanya',
#  'tanyakan',
#  'tanyanya',
#  'tapi',
#  'tegas',
#  'tegasnya',
#  'telah',
#  'tempat',
#  'tengah',
#  'tentang',
#  'tentu',
#  'tentulah',
#  'tentunya',
#  'tepat',
#  'terakhir',
#  'terasa',
#  'terbanyak',
#  'terdahulu',
#  'terdapat',
#  'terdiri',
#  'terhadap',
#  'terhadapnya',
#  'teringat',
#  'teringat-ingat',
#  'terjadi',
#  'terjadilah',
#  'terjadinya',
#  'terkira',
#  'terlalu',
#  'terlebih',
#  'terlihat',
#  'termasuk',
#  'ternyata',
#  'tersampaikan',
#  'tersebut',
#  'tersebutlah',
#  'tertentu',
#  'tertuju',
#  'terus',
#  'terutama',
#  'tetap',
#  'tetapi',
#  'tiap',
#  'tiba',
#  'tiba-tiba',
#  'tidak',
#  'tidakkah',
#  'tidaklah',
#  'tiga',
#  'tinggi',
#  'toh',
#  'tunjuk',
#  'turut',
#  'tutur',
#  'tuturnya',
#  'ucap',
#  'ucapnya',
#  'ujar',
#  'ujarnya',
#  'umum',
#  'umumnya',
#  'ungkap',
#  'ungkapnya',
#  'untuk',
#  'usah',
#  'usai',
#  'waduh',
#  'wah',
#  'wahai',
#  'waktu',
#  'waktunya',
#  'walau',
#  'walaupun',
#  'wong',
#  'yaitu',
#  'yakin',
#  'yakni',
#  'yang']

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier

clf =  RandomForestClassifier(random_state=0, max_features ='sqrt',max_depth = 100)
knn = KNeighborsClassifier(n_neighbors=7)
nb = GaussianNB()
dt = DecisionTreeClassifier(max_features ='sqrt',max_depth = 100)
svm = SVC(degree=3)
# clf.fit(X, y)

# %%
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

normalizad_word = pd.read_csv("colloquial-indonesian-lexicon.csv")

normalizad_word_dict = {}

for index, row in normalizad_word.iterrows():
    if row[0] not in normalizad_word_dict:
        normalizad_word_dict[row[0]] = row[1] 

def normalized_term(document):
    return [normalizad_word_dict[term] if term in normalizad_word_dict else term for term in document]

df_skripsi['text_normalized'] = df_skripsi['Stopwords'].apply(normalized_term)


# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in df_skripsi['text_normalized']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")


# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]

df_skripsi['text_tokens_stemmed'] = df_skripsi['text_normalized'].swifter.apply(get_stemmed_term)
# Out:
# 1089
# ------------------------
# roboguru : roboguru
# beli : beli
# paket : paket
# video : video
# diputar : putar
# diunduh : unduh
# eror : eror
# menyesal : sesal
# gue : gue
# makai : maka
# ruang : ruang
# guru : guru
# keluhan : keluh
# link : link
# web : web
# xdari : xdari
# notifikasi : notifikasi
# ruangguru : ruangguru
# buka : buka
# semuakesel : semuakesel
# banget : banget
# mencoba : coba
# pindah : pindah
# lokasi : lokasi
# siyalnya : siyalnya
# full : full
# loading : loading
# errorpleaselah : errorpleaselah
# tolong : tolong
# jaga : jaga
# kenyamanan : nyaman
# aplikasi : aplikasi
# jugasebenernya : jugasebenernya
# tinggal : tinggal
# jaringannya : jaring
# ngebut : ngebut
# nyaman : nyaman
# pakai : pakai
# pc : pc
# letak : letak
# drill : drill
# maksa : maksa
# langganan : langgan
# jawabannya : jawab
# salah : salah
# kasih : kasih
# ar : ar
# ulangan : ulang
# 92 : 92
# buruk : buruk
# sudah : sudah
# bagus : bagus
# kadang : kadang
# quiznya : quiznya
# error : error
# benar : benar
# dapat : dapat
# xp : xp
# pelajaran : ajar
# bintang : bintang
# 4 : 4
# seru : seru
# dafa : dafa
# lulu : lulu
# menyenangkan : senang
# kecewa : kecewa
# jawabanpenjelasan : jawabanpenjelasan
# komputerleptop : komputerleptop
# websitecrome : websitecrome
# diaksesdan : diaksesdan
# berlangganan : langgan
# dibukaitu : dibukaitu
# saran : saran
# kesan : kesan
# sayasaya : sayasaya
# harap : harap
# kedepannya : depan
# penggunaan : guna
# website : website
# terbuka : buka
# terimakasih : terimakasih
# lumayan : lumayan
# tuli : tuli
# upgrade : upgrade
# subtitle : subtitle
# indonesia : indonesia
# terima kasih : terima kasih
# sumpah : sumpah
# keluh : keluh
# kesah : kesah
# doang : doang
# suport : suport
# android : android
# suruh : suruh
# hh : hh
# selesai : selesai
# sekian : sekian
# videonya : video
# tulisanya : tulisanya
# gagal : gagal
# memuat : muat
# coba : coba
# 3 : 3
# nyobs : nyobs
# mode : mode
# online : online
# offline : offline
# tulisannya : tulis
# kayak : kayak
# belajar : ajar
# susah : susah
# hasil : hasil
# screenshot : screenshot
# mtk : mtk
# wajib : wajib
# minat : minat
# dipisahkan : pisah
# mudah : mudah
# overall : overall
# eemm : eemm
# tanya : tanya
# tutor : tutor
# koinnya : koin
# mahal : mahal
# 1 : 1
# 15 : 15
# krg : krg
# pas : pas
# putus2 : putus2
# jaringan : jaring
# lancar : lancar
# maaf : maaf
# kondisikan : kondisi
# konsultannya : konsultan
# menghubungi : hubung
# chat : chat
# telfon : telfon
# risih : risih
# berminat : minat
# konfirmasi : konfirmasi
# konsultanbeli : konsultanbeli
# marketplace : marketplace
# terima : terima
# hapus : hapus
# karena : karena
# english : english
# tagihan : tagih
# burik : burik
# sok : sok
# pembahasan : bahas
# banayak : banayak
# netral : netral
# aplikasinya : aplikasi
# fitur : fitur
# fiturnya : fiturnya
# lengkap : lengkap
# sayangnya : sayang
# materi : materi
# diakses : akses
# gbng : gbng
# instal : instal
# smkwakwakwak : smkwakwakwak
# jelek : jelek
# bayar : bayar
# 2 : 2
# komplen : komplen
# berminggu2 : berminggu2
# penyelesaian : selesai
# dianggap : anggap
# bukti : bukti
# disertakan : serta
# download : download
# dibukaerror : dibukaerror
# sihkalau : sihkalau
# dibenahi : benah
# muat : muat
# ulang : ulang
# trussvidio : trussvidio
# putar : putar
# knpaa : knpaa
# padhal : padhal
# menonton : tonton
# baca : baca
# suka : suka
# lola : lola
# lobby : lobby
# tetap : tetap
# menekan : tekan
# avatar : avatar
# berubah : ubah
# persis : persis
# teman : teman
# avayar : avayar
# lan : lan
# diubah : ubah
# bari : bari
# level : level
# 82 : 82
# rg : rg
# buriek : buriek
# jujur : jujur
# banguss : banguss
# keganggu : ganggu
# spam : spam
# message : message
# ganti : ganti
# membeli : beli
# kemarin : kemarin
# kesalahan : salah
# sistem : sistem
# terus : terus
# wifi : wifi
# tiket : tiket
# setelah : telah
# takutnya : takut
# 7 : 7
# butuh : butuh
# semoga : moga
# secepatnya : cepat
# duit : duit
# kenapa : kenapa
# enggak : enggak
# mapel : mapel
# bhsa : bhsa
# daerah : daerah
# pertanianseni : pertanianseni
# budaya : budaya
# pakarya : pakarya
# informatika : informatika
# sekolah : sekolah
# lupa : lupa
# nilai : nilai
# gurunya : guru
# ingat : ingat
# mengasih : asih
# ku : ku
# pencet : pencet
# kirim : kirim
# muncul : muncul
# tulisan : tulis
# begini : begini
# invalid : invalid
# response : response
# was : was
# received : received
# upstream : upstream
# server : server
# solusi : solusi
# apk : apk
# menunggu : tunggu
# antrian : antri
# aman : aman
# berkisar : kisar
# 50 : 50
# keatas : atas
# cepat : cepat
# 10 : 10
# diperbaiki : baik
# tertipu : tipu
# plus : plus
# bernama : nama
# dinna : dinna
# sesuai : sesuai
# difoto : foto
# tindaklanjuti : tindaklanjuti
# semenjak : semenjak
# lihat : lihat
# gaenak : gaenak
# hp : hp
# bagusdi : bagusdi
# laptop : laptop
# ditonton : tonton
# penyimpanan : simpan
# dibandingkan : banding
# mengajarnya : ajar
# selengkapnya : lengkap
# nomer : nomer
# penawaran : tawar
# teror : teror
# pinjol : pinjol
# awalawal : awalawal
# namanya : nama
# koin : koin
# harga : harga
# belinya : beli
# sesi : sesi
# nanyain : nanyain
# sesinya : sesi
# ngabisin : ngabisin
# harganya : harga
# peraturannya : atur
# turun : turun
# aneh : aneh
# dipakai : pakai
# terusan : terus
# google : google
# batesnya : batesnya
# giliran : gilir
# bates : bates
# anak : anak
# lounching : lounching
# perpanjangan : panjang
# serasa : serasa
# dikoyak : koyak
# oyakpdhl : oyakpdhl
# semester : semester
# smstr : smstr
# pelanggan : langgan
# diperhatikan : perhati
# yakinlah : yakin
# cocok : cocok
# dipahami : paham
# peningkatan : tingkat
# adapto : adapto
# kuis : kuis
# tibatiba : tibatiba
# buram : buram
# bergarisgaris : bergarisgaris
# niat : niat
# uang : uang
# tampilantingkatkn : tampilantingkatkn
# gratis : gratis
# bug : bug
# musik : musik
# ganggu : ganggu
# koneksi : koneksi
# force : force
# close : close
# heran : heran
# poco : poco
# pro : pro
# chipsetnya : chipsetnya
# snapdragon : snapdragon
# 800 : 800
# malas : malas
# perbaiki : baik
# pembelajaran : ajar
# hewan : hewan
# sakit : sakit
# balikin : balikin
# nyicil : nyicil
# pengin : pengin
# tapi : tapi
# lagi : lagi
# hemat : hemat
# dkembaiin : dkembaiin
# pasti : pasti
# affah : affah
# iya : iya
# butut : butut
# minimal : minimal
# difix : difix
# rilis : rilis
# poling : poling
# lantai : lantai
# masih : masih
# ngawur : ngawur
# this : this
# application : application
# very : very
# live : live
# lag : lag
# enggak usah : enggak usah
# parah : parah
# sulit : sulit
# reting : reting
# paksa : paksa
# akses : akses
# luas : luas
# berfungsi : fungsi
# mengecewakan : kecewa
# pengguna : guna
# ruanggru : ruanggru
# dihilangkan : hilang
# pelekspiperlekspi : pelekspiperlekspi
# pepiku : pepiku
# awaskslsutidak : awaskslsutidak
# lengakappetoperepiku : lengakappetoperepiku
# sayang : sayang
# juara : juara
# kelas : kelas
# berusaha : usaha
# semaksimal : maksimal
# dering : dering
# menyebut : sebut
# nama : nama
# pemangil : pemangil
# vidionya : vidionya
# mulu : mulu
# daily : daily
# challenge : challenge
# indak : indak
# dibuka : buka
# customer : customer
# servicenya : servicenya
# tutup : tutup
# install : install
# sms : sms
# kode : kode
# otp : otp
# ngelag : ngelag
# scroll : scroll
# diam : diam
# sinyal : sinyal
# konten : konten
# promosi : promosi
# dipikirkan : pikir
# dichat : dichat
# orang tua : orang tua
# pemaksaan : paksa
# liga : liga
# quality : quality
# terganggu : ganggu
# cuman : cuman
# ngelagnya : ngelagnya
# anjing : anjing
# login : login
# ngerjain : ngerjain
# donlot : donlot
# 80 : 80
# apli : apli
# penjelasannya : jelas
# pahami : paham
# lemot : lot
# padahal : padahal
# stabil : stabil
# mood : mood
# pembelajarannyaa : pembelajarannyaa
# polling : polling
# teaching : teaching
# disalahkan : salah
# latsolnya : latsolnya
# hasilnya : hasil
# berulang : ulang
# mempelajari : ajar
# bahasa : bahasa
# asing : asing
# semudah : mudah
# ucapkanmemerlukan : ucapkanmemerlukan
# ketekunan : tekun
# rajin : rajin
# mempraktikan : praktik
# pemakaian : pakai
# pelajari : ajar
# takut : takut
# salahsalah : salahsalah
# kok : kok
# kagak : kagak
# ml : ml
# memakai : pakai
# vale : vale
# brain : brain
# academy : academy
# ekspektasi : ekspektasi
# menjamin : jamin
# kualitas : kualitas
# emosi : emosi
# sukacuman : sukacuman
# membantu : bantu
# meningkat : tingkat
# paham : paham
# telepon : telepon
# kendala : kendala
# memutar : putar
# adaptonya : adaptonya
# berjalan : jalan
# sampai : sampai
# stuck : stuck
# situ : situ
# tolonglah : tolong
# jengkel : jengkel
# pelajarannya : ajar
# dikit : dikit
# hilang : hilang
# mati : mati
# hidup : hidup
# game : game
# diteror : teror
# whatsapp : whatsapp
# telpon : telpon
# berkali : kali
# minggu : minggu
# ajaran : ajar
# mengesalkan : kesal
# load : load
# belum : belum
# akun : akun
# log : log
# out : out
# history : history
# tontonan : tonton
# otomatis : otomatis
# hilangtolong : hilangtolong
# habis : habis
# ngedown : ngedown
# sihapaa : sihapaa
# siyal : siyal
# gua : gua
# kencengtolong : kencengtolong
# teamnya : teamnya
# kofirmasikannggangu : kofirmasikannggangu
# diganggutolong : diganggutolong
# belajarnya : ajar
# alasannya : alas
# tunggu : tunggu
# ulangi : ulang
# pencarian : cari
# klik : klik
# berkalikali : berkalikali
# batal : batal
# tutornya : tutor
# tugas : tugas
# buangbuang : buangbuang
# kesal : kesal
# buffering : buffering
# notif : notif
# kondisi : kondisi
# komentar : komentar
# mengalami : alami
# menghambat : hambat
# nelponganggu : nelponganggu
# sopan : sopan
# stop : stop
# putus : putus
# enjoy : enjoy
# belajarnyaaku : belajarnyaaku
# main : main
# youtube : youtube
# 5 : 5
# menit : menit
# putusputustolonglahya : putusputustolonglahya
# gampang : gampang
# aplkasi : aplkasi
# pertannyan : pertannyan
# kalkulator : kalkulator
# iklan : iklan
# dimengerti : erti
# mengarti : arti
# manyoritas : manyoritas
# kapitalis : kapitalis
# puas : puas
# kesini : kesini
# terbatas : batas
# berbayar : bayar
# mengganggu : ganggu
# penurunan : turun
# performa : performa
# satunya : satu
# sharing : sharing
# yangmana : yangmana
# diupload : diupload
# terkropterzoom : terkropterzoom
# menyebabkan : sebab
# informasi : informasi
# terbaca : baca
# terkrop : terkrop
# turunkan : turun
# rating : rating
# ada : ada
# mulok : mulok
# sistemnya : sistem
# kasihan : kasihan
# kepakai : pakai
# pembelajarannya : ajar
# interaktif : interaktif
# detik : detik
# orang : orang
# bilangnya : bilang
# alhasil : alhasil
# poin : poin
# sedih : sedih
# termotivasi : motivasi
# payah : payah
# perpanjang : panjang
# kakak2 : kakak2
# tidakk : tidakk
# jelaas : jelaas
# kebimbel : kebimbel
# hubungi : hubung
# karyawan : karyawan
# menggangu : menggangu
# mendownload : mendownload
# terkendala : kendala
# streamingnya : streamingnya
# masukan : masuk
# email : email
# mengapus : mengapus
# gurusinyal : gurusinyal
# oke : oke
# terpaksa : paksa
# enggak jelas : enggak jelas
# kesel : kesel
# konyol : konyol
# meninggalkan : tinggal
# sebentar : sebentar
# open : open
# rangkuman : rangkum
# saja : saja
# lagih : lagih
# les : les
# dikunci : kunci
# babi : babi
# tua : tua
# plis : plis
# vidio : vidio
# servernya : servernya
# growtopia : growtopia
# play : play
# kuota : kuota
# try : try
# premiumnya : premium
# 0 : 0
# seminggu : minggu
# normal : normal
# diperbaik : baik
# sinyalnya : sinyal
# materinya : materi
# banayakin : banayakin
# vid : vid
# kurikulum : kurikulum
# merdeka : merdeka
# tersedia : sedia
# lengkapi : lengkap
# perfect : perfect
# sempurna : sempurna
# premium : premium
# menyebarkan : sebar
# nomor : nomor
# auto : auto
# lock : lock
# scren : scren
# terkadang : terkadang
# layar : layar
# rasionalisasi : rasionalisasi
# rapot : rapot
# refresh : refresh
# capek : capek
# memasukkan : masuk
# bagustetapi : bagustetapi
# sebenarnya : benar
# detail : detail
# memang : memang
# bermasalah : masalah
# berpuluh : puluh
# puluh : puluh
# menolak : tolak
# paketnya : paket
# diturunin : diturunin
# ditambahin : ditambahin
# miskin : miskin
# berlanggan : langgan
# memaksa : paksa
# kebutuhan : butuh
# ngechat : ngechat
# upload : upload
# file : file
# rapor : rapor
# x1 : x1
# gmnaa : gmnaa
# tolol : tolol
# smk : smk
# t0d : t0d
# disayang : sayang
# internet : internet
# amanaman : amanaman
# memaksakan : paksa
# kehendak : hendak
# merating : merating
# menerus : terus
# scrolling : scrolling
# temui : temu
# typo : typo
# penulisan : tulis
# note : note
# signal : signal
# enggak bisa : enggak bisa
# dekat : dekat
# utbk : utbk
# dikasih : kasih
# penjelasan : jelas
# bagusstetapi : bagusstetapi
# bab : bab
# pkn : pkn
# 8 : 8
# tambahkan : tambah
# daftar : daftar
# tranfer : tranfer
# 600rb : 600rb
# 24jam : 24jam
# adminnya : adminnya
# dulu : dulu
# menepati : tepat
# janji : janji
# bertambah : tambah
# bintangnya : bintang
# sebel : sebel
# ditungguin : ditungguin
# jam : jam
# kuisnya : kuis
# munculmuncul : munculmuncul
# pikir : pikir
# protes : protes
# tanggapan : tanggap
# menyakn : menyakn
# forum : forum
# ketemu : ketemu
# robo : robo
# bad : bad
# request : request
# ambil : ambil
# rendah : rendah
# lancar2 : lancar2
# keputar : putar
# nyangkut2 : nyangkut2
# pelitt : pelitt
# gratisin : gratisin
# proses : proses
# penjawabnya : jawab
# diupdate : diupdate
# loadingnya : loadingnya
# bagusbagus : bagusbagus
# memperbaiki : baik
# owner : owner
# palagi : palagi
# semangat : semangat
# ribet : ribet
# tersembunyi : sembunyi
# diskon : diskon
# murah : murah
# dispam : dispam
# nomornya : nomor
# mengirim : kirim
# promo : promo
# beik : beik
# sajatapi : sajatapi
# baguslahdll : baguslahdll
# 5oh : 5oh
# data : data
# bicara : bicara
# ngejelasin : ngejelasin
# dengar : dengar
# ngelek : ngelek
# geser : geser
# kekana : kana
# kekiri : kir
# bermasalahtolong : bermasalahtolong
# dicoba : coba
# berbeda : beda
# beda : beda
# menangis : menang
# huhu : huhu
# benerin : benerin
# apknya : apknya
# opsi : opsi
# seringkali : seringkali
# peluang : peluang
# snbp : snbp
# terblokir : blokir
# ngulang : ngulang
# bolak : bolak
# super : super
# duper : duper
# gurusales : gurusales
# admin : admin
# jelasin : jelasin
# lemah : lemah
# oaksa : oaksa
# kegunaannya : guna
# soak : soak
# menyimpang : simpang
# sesuaisoal : sesuaisoal
# berbobot : bobot
# service : service
# memuaskan : muas
# membosankan : bosan
# pelayananan : pelayananan
# valas : valas
# merepotkan : repot
# belajae : belajae
# disuruh : suruh
# apl : apl
# bayak : bayak
# layarnya : layar
# udak : udak
# jenjang : jenjang
# jurusan : jurus
# farmasisemoga : farmasisemoga
# menyediakan : sedia
# farmasi : farmasi
# latihan : latih
# mission : mission
# scheduling : scheduling
# jaya : jaya
# keren : keren
# pokoknya : pokok
# aplikasihnya : aplikasihnya
# berguna : guna
# olimpiade : olimpiade
# ambon : ambon
# terimaiasih : terimaiasih
# pembuat : buat
# mantap : mantap
# terbaik : baik
# dunia : dunia
# pickup : pickup
# miliki : milik
# operasi : operasi
# militer : militer
# politik : politik
# menderita : derita
# hati : hati
# je : je
# champions : champions
# uefa : uefa
# musim : musim
# panas : panas
# orang-orang : orang
# beriman : iman
# beramal : amal
# soleh : soleh
# solehah : solehah
# mejing : mejing
# gapyear : gapyear
# memahami : paham
# bantuan : bantu
# apa : apa
# hyo : hyo
# bimbel : bimbel
# best : best
# because : because
# spesifikasinya : spesifikasi
# really : really
# with : with
# understand : understand
# about : about
# each : each
# lesson : lesson
# enthusiastic : enthusiastic
# exploring : exploring
# every : every
# knowledge : knowledge
# day : day
# hope : hope
# support : support
# future : future
# even : even
# better : better
# interesting : interesting
# everyone : everyone
# interested : interested
# thank : thank
# much : much
# developers : developers
# mempermudah : mudah
# pekerjaan : kerja
# modul : modul
# dimasukkan : masuk
# didalam : dalam
# soalsoal : soalsoal
# menunjang : tunjang
# kinerja : kerja
# guruguru : guruguru
# anakpun : anak
# dalamnya : dalam
# dimana : mana
# memgerti : memgerti
# skor : skor
# worksheetnya : worksheetnya
# dibutuhkan : butuh
# mengoreksi : koreksi
# persiapannya : siap
# skip : skip
# second : second
# device : device
# pclaptop : pclaptop
# tambahan : tambah
# pintar : pintar
# anaknya : anak
# menambah : tambah
# wawasan : wawas
# ruanggurudari : ruanggurudari
# pahamjuga : pahamjuga
# sulitjuga : sulitjuga
# dafadan : dafadan
# luluyang : luluyang
# usia : usia
# prasekolah : prasekolah
# butuhkan : butuh
# love : love
# ngejar : ngejar
# ranking : ranking
# baguus : baguus
# mudahh : mudahh
# pelayanan : layan
# laporkan : lapor
# direspon : direspon
# kakaknyapembelajarannya : kakaknyapembelajarannya
# jiwa : jiwa
# gara : gara
# baguuss : baguuss
# lengkapbelajar : lengkapbelajar
# bosan : bosan
# bermanfaat : manfaat
# top : top
# tampah : tampah
# 54 : 54
# pliss : pliss
# gut : gut
# dibagian : bagi
# matematika : matematika
# matemetikakalo : matemetikakalo
# dijelasin : dijelasin
# permisi : permisi
# menarik : tarik
# bantu : bantu
# rangking : rangking
# ilmu : ilmu
# plajari : plajari
# masbro : masbro
# membaca : baca
# bolehh : bolehh
# sehari : hari
# mengerti : erti
# kah : kah
# rekomendasi : rekomendasi
# sd : sd
# bermanfaatdan : bermanfaatdan
# sekolahan : sekolah
# anak-anak : anak
# ranting5 : ranting5
# dqri : dqri
# anakanak : anakanak
# giat : giat
# aku : aku
# menghitung : hitung
# menggukur : menggukur
# sudut : sudut
# trimakasih : trimakasih
# phytagoras : phytagoras
# untung : untung
# pemahaman : paham
# baangget : baangget
# aplikadi : aplikadi
# tabisa : tabisa
# qjsudoeojoffikroeorrirutjyyri : qjsudoeojoffikroeorrirutjyyri
# fruuttugutir : fruuttugutir
# trik : trik
# ir : ir
# tiri : tiri
# taman : taman
# routoytyui : routoytyui
# yirritkhohohjonou : yirritkhohohjonou
# hridurugituuouih : hridurugituuouih
# today : today
# trigonometri : trigonometri
# all : all
# huigititiriirurut : huigititiriirurut
# tuturu4u4uru : tuturu4u4uru
# ruhfhhdjujdjduduudfuuftryrehudfuufuufjggjugjgjg : ruhfhhdjujdjduduudfuuftryrehudfuufuufjggjugjgjg
# jgguutuguyru : jgguutuguyru
# gadis : gadis
# gr : gr
# daging : daging
# ayam : ayam
# i6 : i6
# berbagayrghtiihhjyigki : berbagayrghtiihhjyigki
# tempatku : tempat
# itiutktuykktu : itiutktuykktu
# uduu : uduu
# belajarsaya : belajarsaya
# siswa : siswa
# terbantu : bantu
# soalsoalnya : soalsoalnya
# pembahasannya : bahas
# rebahan : rebah
# intinya : inti
# xyiqis : xyiqis
# memberika : memberika
# lumayanlah : lumayan
# diajarkan : ajar
# kepala : kepala
# volum : volum
# kubustabung : kubustabung
# pelajarin : pelajarin
# pemilihan : pilih
# rute : rute
# driver : driver
# seragam : seragam
# memudahkan : mudah
# kakaknya : kakak
# kegunaan : guna
# berkualitas : kualitas
# sembilan : sembilan
# andi : andi
# pelajar : ajar
# sekali : sekali
# unik : unik
# terpercaya : percaya
# menengah : tengah
# ujian : uji
# sangat : sangat
# dev : dev
# knt : knt
# god : god
# reward : reward
# mengajar : ajar
# itu : itu
# kita : kita
# nya : nya
# pokok : pokok
# buatt : buatt
# berterimakasih : berterimakasih
# rekomend : rekomend
# kalian : kalian
# semuaa : semuaa
# terkenal : kenal
# deh : deh
# naira : naira
# salsabila : salsabila
# pipi : pipi
# vivi : vivi
# dina : dina
# naya : naya
# grbrugeuvskhuve : grbrugeuvskhuve
# jwuhruvlwhvrbhxisvnkechsgrirhrh73vehehehehhsbks : jwuhruvlwhvrbhxisvnkechsgrirhrh73vehehehehhsbks
#  : 
# anakmaterinya : anakmaterinya
# bagusguru : bagusguru
# pembimbing : bimbing
# baiktelitikompeten : baiktelitikompeten
# bidang : bidang
# masingtrimakasih : masingtrimakasih
# maha : maha
# animasi : animasi
# dibawakan : bawa
# siswasiswi : siswasiswi
# rumah : rumah
# terjangkau : jangkau
# diluar : luar
# terpenting : penting
# ilmunya : ilmu
# membuka : buka
# kelaz : kelaz
# dirasa : rasa
# disekolah : seko
# bahas : bahas
# kakak : kakak
# ika : ika
# memberitahukan : memberitahukan
# bagusan : bagus
# dilengkapi : lengkap
# quiz2 : quiz2
# mengasah : asah
# tingkat : tingkat
# kepahaman : paham
# osnksn : osnksn
# bidangnya : bidang
# masingmasing : masingmasing
# beranimasi : animasi
# membahas : bahas
# soal2 : soal2
# osk : osk
# osp : osp
# osn : osn
# diterima : terima
# pls : pls
# bimbingan : bimbing
# minn : minn
# keluarga : keluarga
# nice : nice
# saking : saking
# sadar : sadar
# makan : makan
# senang : senang
# belajarruang : belajarruang
# terbaikterima : terbaikterima
# sngat : sngat
# enggak ada : enggak ada
# lawan : lawan
# bimble : bimble
# semakin : makin
# chuy : chuy
# melamar : lamar
# disuatu : suatu
# perusahan : usah
# hebat : hebat
# mengajarkan : ajar
# cucusaya : cucusaya
# mixsiu : mixsiu
# {'roboguru': 'roboguru', 'beli': 'beli', 'paket': 'paket', 'video': 'video', 'diputar': 'putar', 'diunduh': 'unduh', 'eror': 'eror', 'menyesal': 'sesal', 'gue': 'gue', 'makai': 'maka', 'ruang': 'ruang', 'guru': 'guru', 'keluhan': 'keluh', 'link': 'link', 'web': 'web', 'xdari': 'xdari', 'notifikasi': 'notifikasi', 'ruangguru': 'ruangguru', 'buka': 'buka', 'semuakesel': 'semuakesel', 'banget': 'banget', 'mencoba': 'coba', 'pindah': 'pindah', 'lokasi': 'lokasi', 'siyalnya': 'siyalnya', 'full': 'full', 'loading': 'loading', 'errorpleaselah': 'errorpleaselah', 'tolong': 'tolong', 'jaga': 'jaga', 'kenyamanan': 'nyaman', 'aplikasi': 'aplikasi', 'jugasebenernya': 'jugasebenernya', 'tinggal': 'tinggal', 'jaringannya': 'jaring', 'ngebut': 'ngebut', 'nyaman': 'nyaman', 'pakai': 'pakai', 'pc': 'pc', 'letak': 'letak', 'drill': 'drill', 'maksa': 'maksa', 'langganan': 'langgan', 'jawabannya': 'jawab', 'salah': 'salah', 'kasih': 'kasih', 'ar': 'ar', 'ulangan': 'ulang', '92': '92', 'buruk': 'buruk', 'sudah': 'sudah', 'bagus': 'bagus', 'kadang': 'kadang', 'quiznya': 'quiznya', 'error': 'error', 'benar': 'benar', 'dapat': 'dapat', 'xp': 'xp', 'pelajaran': 'ajar', 'bintang': 'bintang', '4': '4', 'seru': 'seru', 'dafa': 'dafa', 'lulu': 'lulu', 'menyenangkan': 'senang', 'kecewa': 'kecewa', 'jawabanpenjelasan': 'jawabanpenjelasan', 'komputerleptop': 'komputerleptop', 'websitecrome': 'websitecrome', 'diaksesdan': 'diaksesdan', 'berlangganan': 'langgan', 'dibukaitu': 'dibukaitu', 'saran': 'saran', 'kesan': 'kesan', 'sayasaya': 'sayasaya', 'harap': 'harap', 'kedepannya': 'depan', 'penggunaan': 'guna', 'website': 'website', 'terbuka': 'buka', 'terimakasih': 'terimakasih', 'lumayan': 'lumayan', 'tuli': 'tuli', 'upgrade': 'upgrade', 'subtitle': 'subtitle', 'indonesia': 'indonesia', 'terima kasih': 'terima kasih', 'sumpah': 'sumpah', 'keluh': 'keluh', 'kesah': 'kesah', 'doang': 'doang', 'suport': 'suport', 'android': 'android', 'suruh': 'suruh', 'hh': 'hh', 'selesai': 'selesai', 'sekian': 'sekian', 'videonya': 'video', 'tulisanya': 'tulisanya', 'gagal': 'gagal', 'memuat': 'muat', 'coba': 'coba', '3': '3', 'nyobs': 'nyobs', 'mode': 'mode', 'online': 'online', 'offline': 'offline', 'tulisannya': 'tulis', 'kayak': 'kayak', 'belajar': 'ajar', 'susah': 'susah', 'hasil': 'hasil', 'screenshot': 'screenshot', 'mtk': 'mtk', 'wajib': 'wajib', 'minat': 'minat', 'dipisahkan': 'pisah', 'mudah': 'mudah', 'overall': 'overall', 'eemm': 'eemm', 'tanya': 'tanya', 'tutor': 'tutor', 'koinnya': 'koin', 'mahal': 'mahal', '1': '1', '15': '15', 'krg': 'krg', 'pas': 'pas', 'putus2': 'putus2', 'jaringan': 'jaring', 'lancar': 'lancar', 'maaf': 'maaf', 'kondisikan': 'kondisi', 'konsultannya': 'konsultan', 'menghubungi': 'hubung', 'chat': 'chat', 'telfon': 'telfon', 'risih': 'risih', 'berminat': 'minat', 'konfirmasi': 'konfirmasi', 'konsultanbeli': 'konsultanbeli', 'marketplace': 'marketplace', 'terima': 'terima', 'hapus': 'hapus', 'karena': 'karena', 'english': 'english', 'tagihan': 'tagih', 'burik': 'burik', 'sok': 'sok', 'pembahasan': 'bahas', 'banayak': 'banayak', 'netral': 'netral', 'aplikasinya': 'aplikasi', 'fitur': 'fitur', 'fiturnya': 'fiturnya', 'lengkap': 'lengkap', 'sayangnya': 'sayang', 'materi': 'materi', 'diakses': 'akses', 'gbng': 'gbng', 'instal': 'instal', 'smkwakwakwak': 'smkwakwakwak', 'jelek': 'jelek', 'bayar': 'bayar', '2': '2', 'komplen': 'komplen', 'berminggu2': 'berminggu2', 'penyelesaian': 'selesai', 'dianggap': 'anggap', 'bukti': 'bukti', 'disertakan': 'serta', 'download': 'download', 'dibukaerror': 'dibukaerror', 'sihkalau': 'sihkalau', 'dibenahi': 'benah', 'muat': 'muat', 'ulang': 'ulang', 'trussvidio': 'trussvidio', 'putar': 'putar', 'knpaa': 'knpaa', 'padhal': 'padhal', 'menonton': 'tonton', 'baca': 'baca', 'suka': 'suka', 'lola': 'lola', 'lobby': 'lobby', 'tetap': 'tetap', 'menekan': 'tekan', 'avatar': 'avatar', 'berubah': 'ubah', 'persis': 'persis', 'teman': 'teman', 'avayar': 'avayar', 'lan': 'lan', 'diubah': 'ubah', 'bari': 'bari', 'level': 'level',  ...
# ------------------------
# Pandas Apply:   0%|          | 0/380 [00:00<?, ?it/s]

# %%
df_skripsi
# Out:
#         label                                          text_real  \
# 0    Negative                    Roboguru harus beli paket… why?
# 1    Negative  Video nya ga bisa diputar, padahal udah diundu...
# 2    Negative  Eror terus video nya ,nyesel gue Makai ruang guru
# 3    Negative  Aku punya keluhan terhadap link web atau xdari...
# 4    Negative  halo ka, kalo buat PC letak drill soal nya ada...
# ..        ...                                                ...
# 395  Positive  Aku suka banget .aku bisa ketemu orang orang h...
# 396  Positive  Sangat membantu saya mengajarkan tugas dan mem...
# 397  Positive  Ini bagus banget karena bisa bantu cucusaya be...
# 398  Positive       Saya sangat senang sekali bisa di ruang guru
# 399  Positive                                             Mixsiu
#
#                                                   text  \
# 0                        roboguru harus beli paket why
# 1       video nya ga bisa diputar padahal udah diunduh
# 2     eror terus video nya nyesel gue makai ruang guru
# 3    aku punya keluhan terhadap link web atau xdari...
# 4    halo ka kalo buat pc letak drill soal nya ada ...
# ..                                                 ...
# 395  aku suka banget aku bisa ketemu orang orang he...
# 396  sangat membantu saya mengajarkan tugas dan mem...
# 397  ini bagus banget karena bisa bantu cucusaya be...
# 398       saya sangat senang sekali bisa di ruang guru
# 399                                             mixsiu
#
#                                            text_tokens  \
# 0                  [roboguru, harus, beli, paket, why]
# 1    [video, nya, ga, bisa, diputar, padahal, udah,...
# 2    [eror, terus, video, nya, nyesel, gue, makai, ...
# 3    [aku, punya, keluhan, terhadap, link, web, ata...
# 4    [halo, ka, kalo, buat, pc, letak, drill, soal,...
# ..                                                 ...
# 395  [aku, suka, banget, aku, bisa, ketemu, orang, ...
# 396  [sangat, membantu, saya, mengajarkan, tugas, d...
# 397  [ini, bagus, banget, karena, bisa, bantu, cucu...
# 398  [saya, sangat, senang, sekali, bisa, di, ruang...
# 399                                           [mixsiu]
#
#                                              Stopwords  \
# 0                              [roboguru, beli, paket]
# 1                            [video, diputar, diunduh]
# 2       [eror, video, nyesel, gue, makai, ruang, guru]
# 3    [keluhan, link, web, xdari, notifikasi, ruangg...
# 4                                   [pc, letak, drill]
# ..                                                 ...
# 395  [suka, banget, ketemu, hebat, makasih, ruanggu...
# 396  [membantu, mengajarkan, tugas, memahami, pelaj...
# 397          [bagus, banget, bantu, cucusaya, belajar]
# 398                              [senang, ruang, guru]
# 399                                           [mixsiu]
#
#                                      text_tokens_fdist  \
# 0    {'roboguru': 1, 'harus': 1, 'beli': 1, 'paket'...
# 1    {'video': 1, 'nya': 1, 'ga': 1, 'bisa': 1, 'di...
# 2    {'eror': 1, 'terus': 1, 'video': 1, 'nya': 1, ...
# 3    {'aku': 2, 'punya': 1, 'keluhan': 1, 'terhadap...
# 4    {'halo': 1, 'ka': 1, 'kalo': 1, 'buat': 1, 'pc...
# ..                                                 ...
# 395  {'aku': 2, 'suka': 1, 'banget': 1, 'bisa': 1, ...
# 396  {'sangat': 1, 'membantu': 1, 'saya': 1, 'menga...
# 397  {'ini': 1, 'bagus': 1, 'banget': 1, 'karena': ...
# 398  {'saya': 1, 'sangat': 1, 'senang': 1, 'sekali'...
# 399                                      {'mixsiu': 1}
#
#                                        text_normalized  \
# 0                              [roboguru, beli, paket]
# 1                            [video, diputar, diunduh]
# 2     [eror, video, menyesal, gue, makai, ruang, guru]
# 3    [keluhan, link, web, xdari, notifikasi, ruangg...
# 4                                   [pc, letak, drill]
# ..                                                 ...
# 395  [suka, banget, ketemu, hebat, terima kasih, ru...
# 396  [membantu, mengajarkan, tugas, memahami, pelaj...
# 397          [bagus, banget, bantu, cucusaya, belajar]
# 398                              [senang, ruang, guru]
# 399                                           [mixsiu]
#
#                                    text_tokens_stemmed
# 0                              [roboguru, beli, paket]
# 1                                [video, putar, unduh]
# 2         [eror, video, sesal, gue, maka, ruang, guru]
# 3    [keluh, link, web, xdari, notifikasi, ruanggur...
# 4                                   [pc, letak, drill]
# ..                                                 ...
# 395  [suka, banget, ketemu, hebat, terima kasih, ru...
# 396                  [bantu, ajar, tugas, paham, ajar]
# 397             [bagus, banget, bantu, cucusaya, ajar]
# 398                              [senang, ruang, guru]
# 399                                           [mixsiu]
#
# [380 rows x 8 columns]

# %% [markdown]
# # Menampilkan Kembali Gabungan Data

# %%
def merge_again(text):
    return ' '.join(text)

# %%
df_skripsi['done_text'] = df_skripsi['text_tokens_stemmed'].apply(merge_again)
df_skripsi
# Out:
#         label                                          text_real  \
# 0    Negative                    Roboguru harus beli paket… why?
# 1    Negative  Video nya ga bisa diputar, padahal udah diundu...
# 2    Negative  Eror terus video nya ,nyesel gue Makai ruang guru
# 3    Negative  Aku punya keluhan terhadap link web atau xdari...
# 4    Negative  halo ka, kalo buat PC letak drill soal nya ada...
# ..        ...                                                ...
# 395  Positive  Aku suka banget .aku bisa ketemu orang orang h...
# 396  Positive  Sangat membantu saya mengajarkan tugas dan mem...
# 397  Positive  Ini bagus banget karena bisa bantu cucusaya be...
# 398  Positive       Saya sangat senang sekali bisa di ruang guru
# 399  Positive                                             Mixsiu
#
#                                                   text  \
# 0                        roboguru harus beli paket why
# 1       video nya ga bisa diputar padahal udah diunduh
# 2     eror terus video nya nyesel gue makai ruang guru
# 3    aku punya keluhan terhadap link web atau xdari...
# 4    halo ka kalo buat pc letak drill soal nya ada ...
# ..                                                 ...
# 395  aku suka banget aku bisa ketemu orang orang he...
# 396  sangat membantu saya mengajarkan tugas dan mem...
# 397  ini bagus banget karena bisa bantu cucusaya be...
# 398       saya sangat senang sekali bisa di ruang guru
# 399                                             mixsiu
#
#                                            text_tokens  \
# 0                  [roboguru, harus, beli, paket, why]
# 1    [video, nya, ga, bisa, diputar, padahal, udah,...
# 2    [eror, terus, video, nya, nyesel, gue, makai, ...
# 3    [aku, punya, keluhan, terhadap, link, web, ata...
# 4    [halo, ka, kalo, buat, pc, letak, drill, soal,...
# ..                                                 ...
# 395  [aku, suka, banget, aku, bisa, ketemu, orang, ...
# 396  [sangat, membantu, saya, mengajarkan, tugas, d...
# 397  [ini, bagus, banget, karena, bisa, bantu, cucu...
# 398  [saya, sangat, senang, sekali, bisa, di, ruang...
# 399                                           [mixsiu]
#
#                                              Stopwords  \
# 0                              [roboguru, beli, paket]
# 1                            [video, diputar, diunduh]
# 2       [eror, video, nyesel, gue, makai, ruang, guru]
# 3    [keluhan, link, web, xdari, notifikasi, ruangg...
# 4                                   [pc, letak, drill]
# ..                                                 ...
# 395  [suka, banget, ketemu, hebat, makasih, ruanggu...
# 396  [membantu, mengajarkan, tugas, memahami, pelaj...
# 397          [bagus, banget, bantu, cucusaya, belajar]
# 398                              [senang, ruang, guru]
# 399                                           [mixsiu]
#
#                                      text_tokens_fdist  \
# 0    {'roboguru': 1, 'harus': 1, 'beli': 1, 'paket'...
# 1    {'video': 1, 'nya': 1, 'ga': 1, 'bisa': 1, 'di...
# 2    {'eror': 1, 'terus': 1, 'video': 1, 'nya': 1, ...
# 3    {'aku': 2, 'punya': 1, 'keluhan': 1, 'terhadap...
# 4    {'halo': 1, 'ka': 1, 'kalo': 1, 'buat': 1, 'pc...
# ..                                                 ...
# 395  {'aku': 2, 'suka': 1, 'banget': 1, 'bisa': 1, ...
# 396  {'sangat': 1, 'membantu': 1, 'saya': 1, 'menga...
# 397  {'ini': 1, 'bagus': 1, 'banget': 1, 'karena': ...
# 398  {'saya': 1, 'sangat': 1, 'senang': 1, 'sekali'...
# 399                                      {'mixsiu': 1}
#
#                                        text_normalized  \
# 0                              [roboguru, beli, paket]
# 1                            [video, diputar, diunduh]
# 2     [eror, video, menyesal, gue, makai, ruang, guru]
# 3    [keluhan, link, web, xdari, notifikasi, ruangg...
# 4                                   [pc, letak, drill]
# ..                                                 ...
# 395  [suka, banget, ketemu, hebat, terima kasih, ru...
# 396  [membantu, mengajarkan, tugas, memahami, pelaj...
# 397          [bagus, banget, bantu, cucusaya, belajar]
# 398                              [senang, ruang, guru]
# 399                                           [mixsiu]
#
#                                    text_tokens_stemmed  \
# 0                              [roboguru, beli, paket]
# 1                                [video, putar, unduh]
# 2         [eror, video, sesal, gue, maka, ruang, guru]
# 3    [keluh, link, web, xdari, notifikasi, ruanggur...
# 4                                   [pc, letak, drill]
# ..                                                 ...
# 395  [suka, banget, ketemu, hebat, terima kasih, ru...
# 396                  [bantu, ajar, tugas, paham, ajar]
# 397             [bagus, banget, bantu, cucusaya, ajar]
# 398                              [senang, ruang, guru]
# 399                                           [mixsiu]
#
#                                              done_text
# 0                                  roboguru beli paket
# 1                                    video putar unduh
# 2                 eror video sesal gue maka ruang guru
# 3    keluh link web xdari notifikasi ruangguru buka...
# 4                                       pc letak drill
# ..                                                 ...
# 395  suka banget ketemu hebat terima kasih ruanggur...
# 396                        bantu ajar tugas paham ajar
# 397                   bagus banget bantu cucusaya ajar
# 398                                  senang ruang guru
# 399                                             mixsiu
#
# [380 rows x 9 columns]

# %%
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# %%
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer

# %%
tfid = TfidfVectorizer(
    min_df = 3,
    max_df = 0.10,
    ngram_range = (1,2)
)

# %%
count_vect = CountVectorizer(
    min_df = 3,
    max_df = 0.10,
    ngram_range = (1,2)
)

# %%
tfid_result = tfid.fit_transform(df_skripsi["done_text"]).toarray()
tfid_df = pd.DataFrame(tfid_result, columns = tfid.get_feature_names())
tfid_df.columns = ["word_" + str(x) for x in tfid_df.columns]
tfid_df.index = df_skripsi.index
# new_data = pd.concat([, tfid_df], axis=1)

# %%
tfid_df.columns
# Out:
# Index(['word_10', 'word_adapto', 'word_ajar ajar', 'word_ajar bagus',
#        'word_ajar ganggu', 'word_ajar mudah', 'word_ajar ruang',
#        'word_ajar susah', 'word_akses', 'word_alami',
#        ...
#        'word_ulang', 'word_utbk', 'word_video ajar', 'word_video loading',
#        'word_video putar', 'word_vidio', 'word_web', 'word_whatsapp',
#        'word_wifi', 'word_youtube'],
#       dtype='object', length=226)

# %%
tfid_df.columns
# Out:
# Index(['word_10', 'word_adapto', 'word_ajar ajar', 'word_ajar bagus',
#        'word_ajar ganggu', 'word_ajar mudah', 'word_ajar ruang',
#        'word_ajar susah', 'word_akses', 'word_alami',
#        ...
#        'word_ulang', 'word_utbk', 'word_video ajar', 'word_video loading',
#        'word_video putar', 'word_vidio', 'word_web', 'word_whatsapp',
#        'word_wifi', 'word_youtube'],
#       dtype='object', length=226)

# %%
cvzr_result = count_vect.fit_transform(df_skripsi["done_text"]).toarray()
cvzr_df = pd.DataFrame(cvzr_result, columns = count_vect.get_feature_names())
cvzr_df.columns = ["word_" + str(x) for x in cvzr_df.columns]
cvzr_df.index = df_skripsi.index
# new_data = pd.concat([, tfid_df], axis=1)

# %% [markdown]
# # Menampilkan Label Kolom

# %%
kolomcv = cvzr_df.columns
kolomcv
# Out:
# Index(['word_10', 'word_adapto', 'word_ajar ajar', 'word_ajar bagus',
#        'word_ajar ganggu', 'word_ajar mudah', 'word_ajar ruang',
#        'word_ajar susah', 'word_akses', 'word_alami',
#        ...
#        'word_ulang', 'word_utbk', 'word_video ajar', 'word_video loading',
#        'word_video putar', 'word_vidio', 'word_web', 'word_whatsapp',
#        'word_wifi', 'word_youtube'],
#       dtype='object', length=226)

# %% [markdown]
# # Menampilkan Hasil Classification

# %%
y = df_skripsi.label

# %%
X = cvzr_df.to_numpy()
y = df_skripsi.label
y_pred = cross_val_predict(clf, X, y, cv=5)
conf_mat = confusion_matrix(y_pred, y)

# %%
print(conf_mat)
print(classification_report(y, y_pred, digits = 4))
# Out:
# [[135  20]
#  [ 65 160]]
#               precision    recall  f1-score   support
#
#     Negative     0.8710    0.6750    0.7606       200
#     Positive     0.7111    0.8889    0.7901       180
#
#     accuracy                         0.7763       380
#    macro avg     0.7910    0.7819    0.7753       380
# weighted avg     0.7952    0.7763    0.7746       380

# %%
print('Naive Bayes')
X = cvzr_df.to_numpy()
y = df_skripsi.label
y_pred = cross_val_predict(nb, X, y, cv=10)
conf_mat = confusion_matrix(y_pred, y)
print(conf_mat)
print(classification_report(y, y_pred, digits = 4))
# Out:
# Naive Bayes
# [[151  24]
#  [ 49 156]]
#               precision    recall  f1-score   support
#
#     Negative     0.8629    0.7550    0.8053       200
#     Positive     0.7610    0.8667    0.8104       180
#
#     accuracy                         0.8079       380
#    macro avg     0.8119    0.8108    0.8079       380
# weighted avg     0.8146    0.8079    0.8077       380

# %%
print('Naive Bayes')
X = tfid_df.to_numpy()
y = df_skripsi.label
y_pred = cross_val_predict(nb, X, y, cv=10)
conf_mat = confusion_matrix(y_pred, y)
print(conf_mat)
print(classification_report(y, y_pred, digits = 4))
# Out:
# Naive Bayes
# [[152  28]
#  [ 48 152]]
#               precision    recall  f1-score   support
#
#     Negative     0.8444    0.7600    0.8000       200
#     Positive     0.7600    0.8444    0.8000       180
#
#     accuracy                         0.8000       380
#    macro avg     0.8022    0.8022    0.8000       380
# weighted avg     0.8044    0.8000    0.8000       380

# %% [markdown]
# # Menampilkan Hasil K-Nearest Neighbor

# %%
print('KNN')
X = cvzr_df.to_numpy()
y = df_skripsi.label
y_pred = cross_val_predict(knn, X, y, cv=10)
conf_mat = confusion_matrix(y_pred, y)
print(conf_mat)
print(classification_report(y, y_pred, digits = 4))
# Out:
# KNN
# [[ 86  30]
#  [114 150]]
#               precision    recall  f1-score   support
#
#     Negative     0.7414    0.4300    0.5443       200
#     Positive     0.5682    0.8333    0.6757       180
#
#     accuracy                         0.6211       380
#    macro avg     0.6548    0.6317    0.6100       380
# weighted avg     0.6593    0.6211    0.6065       380

# %%
print('KNN')
X = tfid_df.to_numpy()
y = df_skripsi.label
y_pred = cross_val_predict(knn, X, y, cv=10)
conf_mat = confusion_matrix(y_pred, y)
print(conf_mat)
print(classification_report(y, y_pred, digits = 4))
# Out:
# KNN
# [[199 137]
#  [  1  43]]
#               precision    recall  f1-score   support
#
#     Negative     0.5923    0.9950    0.7425       200
#     Positive     0.9773    0.2389    0.3839       180
#
#     accuracy                         0.6368       380
#    macro avg     0.7848    0.6169    0.5632       380
# weighted avg     0.7746    0.6368    0.5727       380

# %% [markdown]
# # Menampilkan Hasil Support Vector Machine

# %%
print('SVM')
X = cvzr_df.to_numpy()
y = df_skripsi.label
y_pred = cross_val_predict(svm, X, y, cv=10)
conf_mat = confusion_matrix(y_pred, y)
print(conf_mat)
print(classification_report(y, y_pred, digits = 4))
# Out:
# SVM
# [[124  28]
#  [ 76 152]]
#               precision    recall  f1-score   support
#
#     Negative     0.8158    0.6200    0.7045       200
#     Positive     0.6667    0.8444    0.7451       180
#
#     accuracy                         0.7263       380
#    macro avg     0.7412    0.7322    0.7248       380
# weighted avg     0.7452    0.7263    0.7238       380

# %%
print('SVM')
X = cvzr_df.to_numpy()
y = df_skripsi.label
y_pred = cross_val_predict(svm, X, y, cv=10)
conf_mat = confusion_matrix(y_pred, y)
print(conf_mat)
print(classification_report(y, y_pred, digits = 4))
# Out:
# SVM
# [[124  28]
#  [ 76 152]]
#               precision    recall  f1-score   support
#
#     Negative     0.8158    0.6200    0.7045       200
#     Positive     0.6667    0.8444    0.7451       180
#
#     accuracy                         0.7263       380
#    macro avg     0.7412    0.7322    0.7248       380
# weighted avg     0.7452    0.7263    0.7238       380

# %% [markdown]
# # Menampilkan Hasil Random Forest

# %%
print('Random Forest')
X = cvzr_df.to_numpy()
y = df_skripsi.label
y_pred = cross_val_predict(clf, X, y, cv=10)
conf_mat = confusion_matrix(y_pred, y)
print(conf_mat)
print(classification_report(y, y_pred, digits = 4))
# Out:
# Random Forest
# [[140  19]
#  [ 60 161]]
#               precision    recall  f1-score   support
#
#     Negative     0.8805    0.7000    0.7799       200
#     Positive     0.7285    0.8944    0.8030       180
#
#     accuracy                         0.7921       380
#    macro avg     0.8045    0.7972    0.7915       380
# weighted avg     0.8085    0.7921    0.7909       380

# %%
print('Random Forest')
X = tfid_df.to_numpy()
y = df_skripsi.label
y_pred = cross_val_predict(clf, X, y, cv=10)
conf_mat = confusion_matrix(y_pred, y)
print(conf_mat)
print(classification_report(y, y_pred, digits = 4))
# Out:
# Random Forest
# [[137  20]
#  [ 63 160]]
#               precision    recall  f1-score   support
#
#     Negative     0.8726    0.6850    0.7675       200
#     Positive     0.7175    0.8889    0.7940       180
#
#     accuracy                         0.7816       380
#    macro avg     0.7951    0.7869    0.7808       380
# weighted avg     0.7991    0.7816    0.7801       380

# %% [markdown]
# # Membuat Word Cloud

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

# %%
SemuaText = "".join(df_skripsi['done_text'])

def create_wordcloud(text, filename): 
    stopwords = set(STOPWORDS)

    wc = WordCloud(background_color="white",
                   max_words=200,
                   stopwords=stopwords)

    wc.generate(text)
    wc.to_file(filename+".png")
    plt.figure()
    plt.imshow(wc, interpolation="bilinear")
    plt.axis("off")
    plt.show()

# %%
SemuaText
# Out:
# 'roboguru beli paketvideo putar unduheror video sesal gue maka ruang gurukeluh link web xdari notifikasi ruangguru buka semuakesel banget coba pindah lokasi siyalnya full loading errorpleaselah tolong banget jaga nyaman aplikasi jugasebenernya tinggal jaring ngebut nyaman pakai ruanggurupc letak drillmaksa langganjawab salahkasih ar salah ulang 92 buruksudah bagus kadang quiznya error benar dapat xpaplikasi bagus banget ajar kasih bintang 4 seru banget video dafa lulu seru bangetaplikasi ruang guru senang kecewa jawabanpenjelasan komputerleptop websitecrome diaksesdan langgan langgan dibukaitu saran kesan sayasaya harap depan guna ruang guru website buka bagus terimakasihlumayan tuli tolong upgrade subtitle indonesia tuli terima kasihbangetsumpah keluh kesah doang ruang guru suport android suruh pindah web hh selesai benar ruang guru sekian terimakasihtolong video tulisanya gagal muat video coba 3 nyobs coba buka video mode online offline tulis kayak ajar susahtolong hasil screenshot mtk wajib minat pisah mudah terimakasihoverall bagus eemm tanya tutor koin mahal 1 15 krg pas tutorvideo putus2 jaring lancar langganmaaf tolong kondisi konsultan 1 hubung chat telfon risih minat langgan konfirmasi salah konsultanbeli paket marketplace terima kasihhapus karena ajar english tagihburiksokbahas banayaknetralaplikasi bagus fitur fiturnya lengkap sayang materi ajar lengkap error aksesgbnginstal smkwakwakwakjelek banget aplikasi bayar 2 komplen berminggu2 selesai anggap beli paket ajar bukti sertadownload video banget jaring bagusaplikasi bagus langgan video dibukaerror sihkalau tolong benahsuruh muat ulang trussvidio putar knpaa padhal sudah langganjelek langgan tonton download sesalruang baca suka lolalobby tetap pas tekan avatar ubah persis teman lobby avayar lan ubah bari level 82 rgburiekjujur banguss banget ganggu spam messageganti paket langgan salah beli kemarin coba ganti web salah sistem terus pakai wifi tiket ganti paket 2 telah tiket paket ganti takut 7 ganti butuh ajar moga ganti paket cepat terimakasihmaaf bintang suka langgan duit bayarkenapa enggak mapel bhsa daerah pertanianseni budaya pakarya informatika mapel sekolahkemarin tutor lupa kasih nilai guru ingat kasih nilai guru pas selesai asih bintang pas ku pencet kirim muncul tulis begini invalid response was received upstream server tolong kasih solusiapk pas download video offline tulis tunggu antri download 1 pakai wifi jaring aman pakai download apk kisar 50 atas video cepat download video 10 tolong baiktipu fitur roboguru plus guru nama dinna sesuai foto tolong tindaklanjutisemenjak lihat bayar gaenakfitur hp sudah bagusdi laptop jelek banget sistem download video tonton offline laptop banget simpan laptop banding hpmateri ajar bagus lengkap lengkap bayarnomer kirim tawar kayak teror pinjolawalawal langgan fitur nama roboguru plus pakai koin harga beli lumayan beli sesi 1 koin nanyain terus fitur roboguru plus sesi 1 sesi ngabisin koin harga lumayan kecewa atur ubah begini harga koin turunaneh pas langgan roboguru pakai terus google pas langgan batesnya google gilir roboguru rg pakai batesruangguru bagus anak langgan lounching maaf panjang serasa koyak oyakpdhl langgan 1 2 semester smstr 2 tolong langgan perhati yakin cocok tetap panjangmateri mudah paham tingkat fitur adapto kuis video tibatiba buram bergarisgarislanggan video niat ajar bayar uangsuka tampilantingkatknkenapa gratisaplikasi bagus kadang bug musik pas ganggu bangetapkkoneksi suka error suka force close heran hp poco 3 pro chipsetnya snapdragon 800ruang gurumalas langgan mahal banget 1lumayan ajar baik putar video ajar loading hewan ajar sakitbalikin fitur nyicil pengin beli tapi lagi hemat uang dkembaiin pasti langganaffah iya jelekbututminimal difix apk rilis poling lantai masih ngawurthis application very live suka lagenggak usah langgan sesal parahsuka ruangguru sulit bandingreting suruh paksaburikakses video ajar susah loading jaring bagus ruang simpan luaslanggan fitur fungsi loading tolong ba ...

# %%
create_wordcloud(SemuaText,"Semua Sentimen")

# %%
komenpositif= df_skripsi[df_skripsi['label'] == "Positive"]

# %%
Positive = "".join(komenpositif['done_text'])

def create_wordcloud(text, filename): 
    stopwords = set(STOPWORDS)

    wc = WordCloud(background_color="white",
                   max_words=200,
                   stopwords=stopwords)

    wc.generate(text)
    wc.to_file(filename+".png")
    plt.figure()
    plt.imshow(wc, interpolation="bilinear")
    plt.axis("off")
    plt.show()

# %%
create_wordcloud(Positive,"Semua Positive")

# %%
komennegatif= df_skripsi[df_skripsi['label'] == "Negative"]

# %%
Negative = "".join(komennegatif['done_text'])

def create_wordcloud(text, filename): 
    stopwords = set(STOPWORDS)

    wc = WordCloud(background_color="white",
                   max_words=200,
                   stopwords=stopwords)

    wc.generate(text)
    wc.to_file(filename+".png")
    plt.figure()
    plt.imshow(wc, interpolation="bilinear")
    plt.axis("off")
    plt.show()

# %%
create_wordcloud(Negative,"Semua Negative")
