# %%
import pandas as pd 
import numpy as np
import string 
import re 
from nltk.tokenize import word_tokenize 
from nltk.probability import FreqDist
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

# %%
df = pd.read_excel('data_skripsi.xlsx')

# %%
df
# Out:
#      Sentiment                                            content  score  \
# 0     Positive  Aplikasinya bagus banget, dong banget waktu di...      5
# 1     Positive  Nice ini aplikasinya sangat mantap, saya suka ...      5
# 2     Positive  Membantuu banget pliss yang materi gratisnyaa,...      5
# 3     Positive                    Dalam pembelajaran sangat bagus      5
# 4     Positive                                              Bagus      5
# ...        ...                                                ...    ...
# 1676  Positive  Sangat kreatif bagus sekali ini applikasi ruan...      5
# 1677  Positive      Keren ada roboguru dafa lulu bisa pilih hewan      5
# 1678  Positive                                         Keren abis      5
# 1679  Positive                               Ruang guru nya bagus      5
# 1680  Negative                                           Ah jelek      1
#
#      reviewCreatedVersion
# 0                   6.9.0
# 1                   6.9.0
# 2                   6.9.0
# 3                   6.9.0
# 4                   6.9.0
# ...                   ...
# 1676                6.6.1
# 1677                6.6.1
# 1678                6.6.1
# 1679                6.6.1
# 1680                6.6.1
#
# [1681 rows x 4 columns]

# %%
df_skripsi = df.drop(['score','reviewCreatedVersion'],axis = 1)

# %%
df_skripsi
# Out:
#      Sentiment                                            content
# 0     Positive  Aplikasinya bagus banget, dong banget waktu di...
# 1     Positive  Nice ini aplikasinya sangat mantap, saya suka ...
# 2     Positive  Membantuu banget pliss yang materi gratisnyaa,...
# 3     Positive                    Dalam pembelajaran sangat bagus
# 4     Positive                                              Bagus
# ...        ...                                                ...
# 1676  Positive  Sangat kreatif bagus sekali ini applikasi ruan...
# 1677  Positive      Keren ada roboguru dafa lulu bisa pilih hewan
# 1678  Positive                                         Keren abis
# 1679  Positive                               Ruang guru nya bagus
# 1680  Negative                                           Ah jelek
#
# [1681 rows x 2 columns]

# %%
komennegatif= df_skripsi[df_skripsi['Sentiment'] == "Negative"]
komenpositif= df_skripsi[df_skripsi['Sentiment'] == "Positive"]

# %%
komennegatif100 = komennegatif.head(100)
komenpositif100 = komenpositif.head(100)

# %%
df_komen100 = komennegatif100.merge(komenpositif100 , how='outer')
df_komen100
# Out:
#     Sentiment                                            content
# 0    Negative  Ini bagus. Tapi ini kenapa pas udh enggak donw...
# 1    Negative  Aku boleh saran ngga? Tambahin juga fitur scre...
# 2    Negative  Suka spam telpon... Lebih bagus sekalian belaj...
# 3    Negative  So, when i was tried to open the app, then imm...
# 4    Negative  Sangat bagus,tapi saya mohon kepada devloper b...
# ..        ...                                                ...
# 195  Positive            Sangat bagus bisa belajar sambil nonton
# 196  Positive  Udah bagus tapi ada beberapa hal yang harus di...
# 197  Positive                                        Bagus bgttt
# 198  Positive  Keren banget dan sangat membantuðŸ‘ðŸ‘ðŸ‘ðŸ...
# 199  Positive                                             Okelah
#
# [200 rows x 2 columns]

# %%
df_komen100.Sentiment.value_counts()
# Out:
# Negative    100
# Positive    100
# Name: Sentiment, dtype: int64

# %%
df_skripsi = df_komen100

# %%
df_skripsi.columns = ['label','text_real']

# %%
df_skripsi['text'] = df_skripsi.text_real

# %%
df_skripsi
# Out:
#         label                                          text_real  \
# 0    Negative  Ini bagus. Tapi ini kenapa pas udh enggak donw...
# 1    Negative  Aku boleh saran ngga? Tambahin juga fitur scre...
# 2    Negative  Suka spam telpon... Lebih bagus sekalian belaj...
# 3    Negative  So, when i was tried to open the app, then imm...
# 4    Negative  Sangat bagus,tapi saya mohon kepada devloper b...
# ..        ...                                                ...
# 195  Positive            Sangat bagus bisa belajar sambil nonton
# 196  Positive  Udah bagus tapi ada beberapa hal yang harus di...
# 197  Positive                                        Bagus bgttt
# 198  Positive  Keren banget dan sangat membantuðŸ‘ðŸ‘ðŸ‘ðŸ...
# 199  Positive                                             Okelah
#
#                                                   text
# 0    Ini bagus. Tapi ini kenapa pas udh enggak donw...
# 1    Aku boleh saran ngga? Tambahin juga fitur scre...
# 2    Suka spam telpon... Lebih bagus sekalian belaj...
# 3    So, when i was tried to open the app, then imm...
# 4    Sangat bagus,tapi saya mohon kepada devloper b...
# ..                                                 ...
# 195            Sangat bagus bisa belajar sambil nonton
# 196  Udah bagus tapi ada beberapa hal yang harus di...
# 197                                        Bagus bgttt
# 198  Keren banget dan sangat membantuðŸ‘ðŸ‘ðŸ‘ðŸ...
# 199                                             Okelah
#
# [200 rows x 3 columns]

# %%
df_skripsi['text'] = df_skripsi['text'].str.lower()
print('Case Folding Result : \n')
print(df_skripsi['text'].head(5))
print('\n\n\n')
# Out:
# Case Folding Result :
#
# 0    ini bagus. tapi ini kenapa pas udh enggak donw...
# 1    aku boleh saran ngga? tambahin juga fitur scre...
# 2    suka spam telpon... lebih bagus sekalian belaj...
# 3    so, when i was tried to open the app, then imm...
# 4    sangat bagus,tapi saya mohon kepada devloper b...
# Name: text, dtype: object

# %%
df_skripsi
# Out:
#         label                                          text_real  \
# 0    Negative  Ini bagus. Tapi ini kenapa pas udh enggak donw...
# 1    Negative  Aku boleh saran ngga? Tambahin juga fitur scre...
# 2    Negative  Suka spam telpon... Lebih bagus sekalian belaj...
# 3    Negative  So, when i was tried to open the app, then imm...
# 4    Negative  Sangat bagus,tapi saya mohon kepada devloper b...
# ..        ...                                                ...
# 195  Positive            Sangat bagus bisa belajar sambil nonton
# 196  Positive  Udah bagus tapi ada beberapa hal yang harus di...
# 197  Positive                                        Bagus bgttt
# 198  Positive  Keren banget dan sangat membantuðŸ‘ðŸ‘ðŸ‘ðŸ...
# 199  Positive                                             Okelah
#
#                                                   text
# 0    ini bagus. tapi ini kenapa pas udh enggak donw...
# 1    aku boleh saran ngga? tambahin juga fitur scre...
# 2    suka spam telpon... lebih bagus sekalian belaj...
# 3    so, when i was tried to open the app, then imm...
# 4    sangat bagus,tapi saya mohon kepada devloper b...
# ..                                                 ...
# 195            sangat bagus bisa belajar sambil nonton
# 196  udah bagus tapi ada beberapa hal yang harus di...
# 197                                        bagus bgttt
# 198  keren banget dan sangat membantuðÿ‘ðÿ‘ðÿ‘ðÿ...
# 199                                             okelah
#
# [200 rows x 3 columns]

# %%
def remove_text_special(text):
    # hapus tab, new line, ans back slice
    text = text.replace('\\t'," ").replace('\\n'," ").replace('\\u'," ").replace('\\',"")
    # hapus non ASCII (emot, bahasa china dll)
    text = text.encode('ascii', 'replace').decode('ascii')
    # hapus mention, link, hashtag
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)"," ", text).split())
    # remove URL 
    return text.replace("http://", " ").replace("https://", " ")
df_skripsi['text'] = df_skripsi.text.astype('str')                
df_skripsi['text'] = df_skripsi['text'].apply(remove_text_special)

# %%
df_skripsi
# Out:
#         label                                          text_real  \
# 0    Negative  Ini bagus. Tapi ini kenapa pas udh enggak donw...
# 1    Negative  Aku boleh saran ngga? Tambahin juga fitur scre...
# 2    Negative  Suka spam telpon... Lebih bagus sekalian belaj...
# 3    Negative  So, when i was tried to open the app, then imm...
# 4    Negative  Sangat bagus,tapi saya mohon kepada devloper b...
# ..        ...                                                ...
# 195  Positive            Sangat bagus bisa belajar sambil nonton
# 196  Positive  Udah bagus tapi ada beberapa hal yang harus di...
# 197  Positive                                        Bagus bgttt
# 198  Positive  Keren banget dan sangat membantuðŸ‘ðŸ‘ðŸ‘ðŸ...
# 199  Positive                                             Okelah
#
#                                                   text
# 0    ini bagus. tapi ini kenapa pas udh enggak donw...
# 1    aku boleh saran ngga? tambahin juga fitur scre...
# 2    suka spam telpon... lebih bagus sekalian belaj...
# 3    so, when i was tried to open the app, then imm...
# 4    sangat bagus,tapi saya mohon kepada devloper b...
# ..                                                 ...
# 195            sangat bagus bisa belajar sambil nonton
# 196  udah bagus tapi ada beberapa hal yang harus di...
# 197                                        bagus bgttt
# 198  keren banget dan sangat membantu??????????????...
# 199                                             okelah
#
# [200 rows x 3 columns]

# %%
#remove kata yang sengaja dipanjangkan
# seperti bisaaaaaaa -> bisa
def spell(word):
    if re.search(r'([a-zA-Z])\1{2,}', word):
        rword = re.sub(r'([a-zA-Z])\1{2,}','\\1', word)
        return rword
    else:
        return word
df_skripsi['text'] = df_skripsi['text'].apply(spell)

# %%
df_skripsi
# Out:
#         label                                          text_real  \
# 0    Negative  Ini bagus. Tapi ini kenapa pas udh enggak donw...
# 1    Negative  Aku boleh saran ngga? Tambahin juga fitur scre...
# 2    Negative  Suka spam telpon... Lebih bagus sekalian belaj...
# 3    Negative  So, when i was tried to open the app, then imm...
# 4    Negative  Sangat bagus,tapi saya mohon kepada devloper b...
# ..        ...                                                ...
# 195  Positive            Sangat bagus bisa belajar sambil nonton
# 196  Positive  Udah bagus tapi ada beberapa hal yang harus di...
# 197  Positive                                        Bagus bgttt
# 198  Positive  Keren banget dan sangat membantuðŸ‘ðŸ‘ðŸ‘ðŸ...
# 199  Positive                                             Okelah
#
#                                                   text
# 0    ini bagus. tapi ini kenapa pas udh enggak donw...
# 1    aku boleh saran ngga? tambahin juga fitur scre...
# 2    suka spam telpon... lebih bagus sekalian belaj...
# 3    so, when i was tried to open the app, then imm...
# 4    sangat bagus,tapi saya mohon kepada devloper b...
# ..                                                 ...
# 195            sangat bagus bisa belajar sambil nonton
# 196  udah bagus tapi ada beberapa hal yang harus di...
# 197                                          bagus bgt
# 198  keren banget dan sangat membantu??????????????...
# 199                                             okelah
#
# [200 rows x 3 columns]

# %%
def remove_punctuation(text):
    return text.translate(str.maketrans("","",string.punctuation))

df_skripsi['text'] = df_skripsi['text'].apply(remove_punctuation)

df_skripsi
# Out:
#         label                                          text_real  \
# 0    Negative  Ini bagus. Tapi ini kenapa pas udh enggak donw...
# 1    Negative  Aku boleh saran ngga? Tambahin juga fitur scre...
# 2    Negative  Suka spam telpon... Lebih bagus sekalian belaj...
# 3    Negative  So, when i was tried to open the app, then imm...
# 4    Negative  Sangat bagus,tapi saya mohon kepada devloper b...
# ..        ...                                                ...
# 195  Positive            Sangat bagus bisa belajar sambil nonton
# 196  Positive  Udah bagus tapi ada beberapa hal yang harus di...
# 197  Positive                                        Bagus bgttt
# 198  Positive  Keren banget dan sangat membantuðŸ‘ðŸ‘ðŸ‘ðŸ...
# 199  Positive                                             Okelah
#
#                                                   text
# 0    ini bagus tapi ini kenapa pas udh enggak donwl...
# 1    aku boleh saran ngga tambahin juga fitur scree...
# 2    suka spam telpon lebih bagus sekalian belajar ...
# 3    so when i was tried to open the app then immed...
# 4    sangat bagustapi saya mohon kepada devloper bi...
# ..                                                 ...
# 195            sangat bagus bisa belajar sambil nonton
# 196  udah bagus tapi ada beberapa hal yang harus di...
# 197                                          bagus bgt
# 198                   keren banget dan sangat membantu
# 199                                             okelah
#
# [200 rows x 3 columns]

# %%
#remove whitespace leading & trailing
def remove_whitespace_LT(text):
    return text.strip()

df_skripsi['text'] = df_skripsi['text'].apply(remove_whitespace_LT)

df_skripsi
# Out:
#         label                                          text_real  \
# 0    Negative  Ini bagus. Tapi ini kenapa pas udh enggak donw...
# 1    Negative  Aku boleh saran ngga? Tambahin juga fitur scre...
# 2    Negative  Suka spam telpon... Lebih bagus sekalian belaj...
# 3    Negative  So, when i was tried to open the app, then imm...
# 4    Negative  Sangat bagus,tapi saya mohon kepada devloper b...
# ..        ...                                                ...
# 195  Positive            Sangat bagus bisa belajar sambil nonton
# 196  Positive  Udah bagus tapi ada beberapa hal yang harus di...
# 197  Positive                                        Bagus bgttt
# 198  Positive  Keren banget dan sangat membantuðŸ‘ðŸ‘ðŸ‘ðŸ...
# 199  Positive                                             Okelah
#
#                                                   text
# 0    ini bagus tapi ini kenapa pas udh enggak donwl...
# 1    aku boleh saran ngga tambahin juga fitur scree...
# 2    suka spam telpon lebih bagus sekalian belajar ...
# 3    so when i was tried to open the app then immed...
# 4    sangat bagustapi saya mohon kepada devloper bi...
# ..                                                 ...
# 195            sangat bagus bisa belajar sambil nonton
# 196  udah bagus tapi ada beberapa hal yang harus di...
# 197                                          bagus bgt
# 198                   keren banget dan sangat membantu
# 199                                             okelah
#
# [200 rows x 3 columns]

# %%
def remove_whitespace_multiple(text):
    return re.sub('\s+',' ',text)

df_skripsi['text'] = df_skripsi['text'].apply(remove_whitespace_multiple)

# %%
def remove_singl_char(text):
    return re.sub(r"\b[a-zA-Z]\b", "", text)

df_skripsi['text'] = df_skripsi['text'].apply(remove_singl_char)

df_skripsi
# Out:
#         label                                          text_real  \
# 0    Negative  Ini bagus. Tapi ini kenapa pas udh enggak donw...
# 1    Negative  Aku boleh saran ngga? Tambahin juga fitur scre...
# 2    Negative  Suka spam telpon... Lebih bagus sekalian belaj...
# 3    Negative  So, when i was tried to open the app, then imm...
# 4    Negative  Sangat bagus,tapi saya mohon kepada devloper b...
# ..        ...                                                ...
# 195  Positive            Sangat bagus bisa belajar sambil nonton
# 196  Positive  Udah bagus tapi ada beberapa hal yang harus di...
# 197  Positive                                        Bagus bgttt
# 198  Positive  Keren banget dan sangat membantuðŸ‘ðŸ‘ðŸ‘ðŸ...
# 199  Positive                                             Okelah
#
#                                                   text
# 0    ini bagus tapi ini kenapa pas udh enggak donwl...
# 1    aku boleh saran ngga tambahin juga fitur scree...
# 2    suka spam telpon lebih bagus sekalian belajar ...
# 3    so when  was tried to open the app then immedi...
# 4    sangat bagustapi saya mohon kepada devloper bi...
# ..                                                 ...
# 195            sangat bagus bisa belajar sambil nonton
# 196  udah bagus tapi ada beberapa hal yang harus di...
# 197                                          bagus bgt
# 198                   keren banget dan sangat membantu
# 199                                             okelah
#
# [200 rows x 3 columns]

# %%
df_skripsi = df_skripsi.drop(['label'],axis = 1)

# %%
df_skripsi
# Out:
#                                              text_real  \
# 0    Ini bagus. Tapi ini kenapa pas udh enggak donw...
# 1    Aku boleh saran ngga? Tambahin juga fitur scre...
# 2    Suka spam telpon... Lebih bagus sekalian belaj...
# 3    So, when i was tried to open the app, then imm...
# 4    Sangat bagus,tapi saya mohon kepada devloper b...
# ..                                                 ...
# 195            Sangat bagus bisa belajar sambil nonton
# 196  Udah bagus tapi ada beberapa hal yang harus di...
# 197                                        Bagus bgttt
# 198  Keren banget dan sangat membantuðŸ‘ðŸ‘ðŸ‘ðŸ...
# 199                                             Okelah
#
#                                                   text
# 0    ini bagus tapi ini kenapa pas udh enggak donwl...
# 1    aku boleh saran ngga tambahin juga fitur scree...
# 2    suka spam telpon lebih bagus sekalian belajar ...
# 3    so when  was tried to open the app then immedi...
# 4    sangat bagustapi saya mohon kepada devloper bi...
# ..                                                 ...
# 195            sangat bagus bisa belajar sambil nonton
# 196  udah bagus tapi ada beberapa hal yang harus di...
# 197                                          bagus bgt
# 198                   keren banget dan sangat membantu
# 199                                             okelah
#
# [200 rows x 2 columns]

# %%
def word_tokenize_wrapper(text):
    return word_tokenize(text)

df_skripsi['text_tokens'] = df_skripsi['text'].apply(word_tokenize_wrapper)

# %%
df_skripsi
# Out:
#                                              text_real  \
# 0    Ini bagus. Tapi ini kenapa pas udh enggak donw...
# 1    Aku boleh saran ngga? Tambahin juga fitur scre...
# 2    Suka spam telpon... Lebih bagus sekalian belaj...
# 3    So, when i was tried to open the app, then imm...
# 4    Sangat bagus,tapi saya mohon kepada devloper b...
# ..                                                 ...
# 195            Sangat bagus bisa belajar sambil nonton
# 196  Udah bagus tapi ada beberapa hal yang harus di...
# 197                                        Bagus bgttt
# 198  Keren banget dan sangat membantuðŸ‘ðŸ‘ðŸ‘ðŸ...
# 199                                             Okelah
#
#                                                   text  \
# 0    ini bagus tapi ini kenapa pas udh enggak donwl...
# 1    aku boleh saran ngga tambahin juga fitur scree...
# 2    suka spam telpon lebih bagus sekalian belajar ...
# 3    so when  was tried to open the app then immedi...
# 4    sangat bagustapi saya mohon kepada devloper bi...
# ..                                                 ...
# 195            sangat bagus bisa belajar sambil nonton
# 196  udah bagus tapi ada beberapa hal yang harus di...
# 197                                          bagus bgt
# 198                   keren banget dan sangat membantu
# 199                                             okelah
#
#                                            text_tokens
# 0    [ini, bagus, tapi, ini, kenapa, pas, udh, engg...
# 1    [aku, boleh, saran, ngga, tambahin, juga, fitu...
# 2    [suka, spam, telpon, lebih, bagus, sekalian, b...
# 3    [so, when, was, tried, to, open, the, app, the...
# 4    [sangat, bagustapi, saya, mohon, kepada, devlo...
# ..                                                 ...
# 195     [sangat, bagus, bisa, belajar, sambil, nonton]
# 196  [udah, bagus, tapi, ada, beberapa, hal, yang, ...
# 197                                       [bagus, bgt]
# 198             [keren, banget, dan, sangat, membantu]
# 199                                           [okelah]
#
# [200 rows x 3 columns]

# %%
df_skripsi = df_skripsi.drop(['text_real'],axis = 1)

# %%
df_skripsi
# Out:
#                                                   text  \
# 0    ini bagus tapi ini kenapa pas udh enggak donwl...
# 1    aku boleh saran ngga tambahin juga fitur scree...
# 2    suka spam telpon lebih bagus sekalian belajar ...
# 3    so when  was tried to open the app then immedi...
# 4    sangat bagustapi saya mohon kepada devloper bi...
# ..                                                 ...
# 195            sangat bagus bisa belajar sambil nonton
# 196  udah bagus tapi ada beberapa hal yang harus di...
# 197                                          bagus bgt
# 198                   keren banget dan sangat membantu
# 199                                             okelah
#
#                                            text_tokens
# 0    [ini, bagus, tapi, ini, kenapa, pas, udh, engg...
# 1    [aku, boleh, saran, ngga, tambahin, juga, fitu...
# 2    [suka, spam, telpon, lebih, bagus, sekalian, b...
# 3    [so, when, was, tried, to, open, the, app, the...
# 4    [sangat, bagustapi, saya, mohon, kepada, devlo...
# ..                                                 ...
# 195     [sangat, bagus, bisa, belajar, sambil, nonton]
# 196  [udah, bagus, tapi, ada, beberapa, hal, yang, ...
# 197                                       [bagus, bgt]
# 198             [keren, banget, dan, sangat, membantu]
# 199                                           [okelah]
#
# [200 rows x 2 columns]

# %%
df_skripsi.columns = ['setelah_caseFolidng','setelah_Tokenisasi']

# %%
df_skripsi
# Out:
#                                    setelah_caseFolidng  \
# 0    ini bagus tapi ini kenapa pas udh enggak donwl...
# 1    aku boleh saran ngga tambahin juga fitur scree...
# 2    suka spam telpon lebih bagus sekalian belajar ...
# 3    so when  was tried to open the app then immedi...
# 4    sangat bagustapi saya mohon kepada devloper bi...
# ..                                                 ...
# 195            sangat bagus bisa belajar sambil nonton
# 196  udah bagus tapi ada beberapa hal yang harus di...
# 197                                          bagus bgt
# 198                   keren banget dan sangat membantu
# 199                                             okelah
#
#                                     setelah_Tokenisasi
# 0    [ini, bagus, tapi, ini, kenapa, pas, udh, engg...
# 1    [aku, boleh, saran, ngga, tambahin, juga, fitu...
# 2    [suka, spam, telpon, lebih, bagus, sekalian, b...
# 3    [so, when, was, tried, to, open, the, app, the...
# 4    [sangat, bagustapi, saya, mohon, kepada, devlo...
# ..                                                 ...
# 195     [sangat, bagus, bisa, belajar, sambil, nonton]
# 196  [udah, bagus, tapi, ada, beberapa, hal, yang, ...
# 197                                       [bagus, bgt]
# 198             [keren, banget, dan, sangat, membantu]
# 199                                           [okelah]
#
# [200 rows x 2 columns]

# %%
list_stopwords = stopwords.words('indonesian')
list_stopwords.extend(["yg", "dg", "rt", "dgn", "ny", "d", 'klo', 
                       'kalo', 'amp', 'biar', 'bikin', 'bilang', 
                       'gak', 'ga', 'krn', 'nya', 'nih', 'sih', 
                       'si', 'tau', 'tdk', 'tuh', 'utk', 'ya', 
                       'jd', 'jgn', 'sdh', 'aja', 'n', 't', 
                       'nyg', 'hehe', 'pen', 'u', 'nan', 'loh', 'rt',
                       '&amp', 'yah'])

txt_stopword = pd.read_csv("stopwords.txt", names= ["stopwords"], header = None)
list_stopwords.extend(txt_stopword["stopwords"][0].split(' '))
list_stopwords = set(list_stopwords)
def stopwords_removal(words):
    return [word for word in words if word not in list_stopwords]
df_skripsi['Stopword'] = df_skripsi['setelah_Tokenisasi'].apply(stopwords_removal)

# %%
df_skripsi
# Out:
#                                    setelah_caseFolidng  \
# 0    ini bagus tapi ini kenapa pas udh enggak donwl...
# 1    aku boleh saran ngga tambahin juga fitur scree...
# 2    suka spam telpon lebih bagus sekalian belajar ...
# 3    so when  was tried to open the app then immedi...
# 4    sangat bagustapi saya mohon kepada devloper bi...
# ..                                                 ...
# 195            sangat bagus bisa belajar sambil nonton
# 196  udah bagus tapi ada beberapa hal yang harus di...
# 197                                          bagus bgt
# 198                   keren banget dan sangat membantu
# 199                                             okelah
#
#                                     setelah_Tokenisasi  \
# 0    [ini, bagus, tapi, ini, kenapa, pas, udh, engg...
# 1    [aku, boleh, saran, ngga, tambahin, juga, fitu...
# 2    [suka, spam, telpon, lebih, bagus, sekalian, b...
# 3    [so, when, was, tried, to, open, the, app, the...
# 4    [sangat, bagustapi, saya, mohon, kepada, devlo...
# ..                                                 ...
# 195     [sangat, bagus, bisa, belajar, sambil, nonton]
# 196  [udah, bagus, tapi, ada, beberapa, hal, yang, ...
# 197                                       [bagus, bgt]
# 198             [keren, banget, dan, sangat, membantu]
# 199                                           [okelah]
#
#                                               Stopword
# 0                    [bagus, pas, udh, donwload, chat]
# 1    [saran, ngga, tambahin, fitur, screenshot, vid...
# 2         [suka, spam, telpon, bagus, belajar, colern]
# 3    [when, was, tried, open, app, then, immediatel...
# 4    [bagustapi, devloper, aplikasi, ruangguru, pak...
# ..                                                 ...
# 195                           [bagus, belajar, nonton]
# 196                              [bagus, ditingkatkan]
# 197                                            [bagus]
# 198                          [keren, banget, membantu]
# 199                                           [okelah]
#
# [200 rows x 3 columns]

# %%
df_skripsi = df_skripsi.drop(['setelah_caseFolidng'],axis = 1)
df_skripsi
# Out:
#                                     setelah_Tokenisasi  \
# 0    [ini, bagus, tapi, ini, kenapa, pas, udh, engg...
# 1    [aku, boleh, saran, ngga, tambahin, juga, fitu...
# 2    [suka, spam, telpon, lebih, bagus, sekalian, b...
# 3    [so, when, was, tried, to, open, the, app, the...
# 4    [sangat, bagustapi, saya, mohon, kepada, devlo...
# ..                                                 ...
# 195     [sangat, bagus, bisa, belajar, sambil, nonton]
# 196  [udah, bagus, tapi, ada, beberapa, hal, yang, ...
# 197                                       [bagus, bgt]
# 198             [keren, banget, dan, sangat, membantu]
# 199                                           [okelah]
#
#                                               Stopword
# 0                    [bagus, pas, udh, donwload, chat]
# 1    [saran, ngga, tambahin, fitur, screenshot, vid...
# 2         [suka, spam, telpon, bagus, belajar, colern]
# 3    [when, was, tried, open, app, then, immediatel...
# 4    [bagustapi, devloper, aplikasi, ruangguru, pak...
# ..                                                 ...
# 195                           [bagus, belajar, nonton]
# 196                              [bagus, ditingkatkan]
# 197                                            [bagus]
# 198                          [keren, banget, membantu]
# 199                                           [okelah]
#
# [200 rows x 2 columns]

# %%
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

normalizad_word = pd.read_csv("colloquial-indonesian-lexicon.csv")

normalizad_word_dict = {}

for index, row in normalizad_word.iterrows():
    if row[0] not in normalizad_word_dict:
        normalizad_word_dict[row[0]] = row[1] 

def normalized_term(document):
    return [normalizad_word_dict[term] if term in normalizad_word_dict else term for term in document]

# df_skripsi['text_normalized'] = df_skripsi['text_tokens_WSW'].apply(normalized_term)


# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in df_skripsi['Stopword']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")


# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]

df_skripsi['normalized & Stemming'] = df_skripsi['Stopword'].swifter.apply(get_stemmed_term)
# Out:
# 711
# ------------------------
# bagus : bagus
# pas : pas
# udh : udh
# donwload : donwload
# chat : chat
# saran : saran
# ngga : ngga
# tambahin : tambahin
# fitur : fitur
# screenshot : screenshot
# video : video
# adaptif : adaptif
# pendalaman : dalam
# materi : materi
# kadang : kadang
# sempet : sempet
# nyatet : nyatet
# adventure : adventure
# makasih : makasih
# banget : banget
# ngebantu : ngebantu
# naikin : naikin
# mood : mood
# belajarku : ajar
# sekian : sekian
# hatur : hatur
# nuhun : nuhun
# kakakkakak : kakakkakak
# ruangguru : ruangguru
# suka : suka
# spam : spam
# telpon : telpon
# belajar : ajar
# colern : colern
# when : when
# was : was
# tried : tried
# open : open
# app : app
# then : then
# immediately : immediately
# log : log
# out : out
# automatically : automatically
# resize : resize
# screen : screen
# big : big
# picture : picture
# wobbly : wobbly
# hope : hope
# got : got
# fixed : fixed
# bagustapi : bagustapi
# devloper : devloper
# aplikasi : aplikasi
# paket : paket
# premium : premium
# kepintaran : pintar
# siswa : siswa
# indonesia : indonesia
# bicarakan : bicara
# terima : terima
# kasih : kasih
# pahamify : pahamify
# tukang : tukang
# teror : teror
# nomor : nomor
# ganti : ganti
# elekk : elekk
# burik : burik
# jelek : jelek
# roboguru : roboguru
# chrome : chrome
# website : website
# install : install
# keberatan : berat
# menginstall : menginstall
# mengurangi : kurang
# membutuhkan : butuh
# simple : simple
# ribet : ribet
# tinggal : tinggal
# dowoad : dowoad
# maaf : maaf
# kota : kota
# kualitas : kualitas
# jaringan : jaring
# terbaik : baik
# didesa : desa
# memprihatinkan : prihatin
# ko : ko
# vidionya : vidionya
# bsa : bsa
# putar : putar
# gmnaa : gmnaa
# macan : macan
# nggak : nggak
# sembuhsembuh : sembuhsembuh
# jam : jam
# sembuh : sembuh
# 24jam : 24jam
# download : download
# galeri : galeri
# urut : urut
# aplikasinya : aplikasi
# eror : eror
# membantu : bantu
# pelajar : ajar
# 1 : 1
# hewan : hewan
# peliharaan : pelihara
# teman : teman
# terganggu : ganggu
# aktivitasnya : aktivitas
# khawatir : khawatir
# produktif : produktif
# belajarnya : ajar
# kea : kea
# terpaksa : paksa
# sehatin : sehatin
# peliharaannya : pelihara
# pahamin : pahamin
# apk : apk
# lapet : lapet
# ruanggurunya : ruanggurunya
# ngesthag : ngesthag
# masak : masak
# habis : habis
# lock : lock
# mencari : cari
# ilmu : ilmu
# drill : drill
# macet : macet
# mwehehehehe : mwehehehehe
# downlod : downlod
# bantuannya : bantu
# nama : nama
# jamiah : jamiah
# pet : pet
# menghitung : hitung
# pembelajaran : ajar
# imbasnya : imbas
# berfungsi : fungsi
# tolong : tolong
# memperbaiki : baik
# maap : maap
# layar : layar
# utama : utama
# perbaiki : baik
# bugnya : bugnya
# lanjutkan : lanjut
# senang : senang
# adapto : adapto
# pengisi : isi
# suara : suara
# cepatsusah : cepatsusah
# dengarya : dengarya
# kecepatan : cepat
# videodan : videodan
# subtitle : subtitle
# jelasmata : jelasmata
# pelajaran : ajar
# ipatapi : ipatapi
# pakai : pakai
# ruang : ruang
# guru : guru
# pliss : pliss
# bug : bug
# benerin : benerin
# semangat : semangat
# suvenir : suvenir
# tirmidzi : tirmidzi
# dishahihkan : dishahihkan
# bersalah : salah
# kerana : rana
# allah : allah
# swt : swt
# nunggu : nunggu
# kehilangan : hilang
# kau : kau
# minat : minat
# silahkan : silah
# merapat : rapat
# menberikan : menberikan
# dukungan : dukung
# relawan : rawan
# ahy : ahy
# familia : familia
# scarabaeidae : scarabaeidae
# ngerjain : ngerjain
# kuis : kuis
# nonton : nonton
# perjelasan : jelas
# tibatiba : tibatiba
# ngelag : ngelag
# ngulang : ngulang
# ulang : ulang
# sampe : sampe
# apkperbaiki : apkperbaiki
# hp : hp
# selesai : selesai
# 0 : 0
# tonton : tonton
# data : data
# loading : loading
# vidio : vidio
# lemot : lot
# penanganan : tangan
# komplen : komplen
# buruk : buruk
# beli : beli
# tematik : tematik
# kelas : kelas
# 3 : 3
# kurikulum : kurikulum
# sesuai : sesuai
# blum : blum
# diperbaiki : baik
# mengajukan : aju
# profesional : profesional
# bgtsering : bgtsering
# neror : neror
# njir : njir
# game : game
# android : android
# sedunia : dunia
# minimal : minimal
# trial : trial
# pengajaran : ajar
# mengakses : akses
# ruangbelajar : ruangbelajar
# sll : sll
# gagal : gagal
# memuat : muat
# pdhl : pdhl
# penjelasan : jelas
# angka : angka
# mapel : mapel
# mtk : mtk
# fisika : fisika
# zenius : zenius
# bagiku : bagi
# salesnya : salesnya
# ajar : ajar
# promosinya : promosi
# ngancam : ngancam
# nyebarin : nyebarin
# pribadi : pribadi
# curiga : curiga
# tindakan : tindak
# ilegal : ilegal
# melanggar : langgar
# privasi : privasi
# penggunanya : guna
# caracara : caracara
# cerdas : cerdas
# sopan : sopan
# beretika : etika
# menjual : jual
# produkproduknya : produkproduknya
# mengecualikan : kecuali
# jasa : jasa
# bidang : bidang
# berhubungan : hubung
# pendidikan : didik
# caracaranya : caracaranya
# latar : latar
# pendidikannya : didik
# nipu : nipu
# dijanjiin : dijanjiin
# konsultanyabaca : konsultanyabaca
# sales : sales
# cashback : cashback
# 200k : 200k
# dikirimnya : kirim
# 50k : 50k
# komplain : komplain
# alasanya : alasanya
# dapet : dapet
# perpanjang : panjang
# konsultanya : konsultanya
# jelasjelas : jelasjelas
# janjiin : janjiin
# nyebutin : nyebutin
# ujungujungnya : ujungujungnya
# lepas : lepas
# tangan : tangan
# sebenernya : sebenernya
# pingin : pingin
# deal : deal
# korbannya : korban
# promo : promo
# akal : akal
# komisi : komisi
# hilang : hilang
# terbantu : bantu
# tolonglah : tolong
# abis : abis
# nonoton : nonoton
# lamalama : lamalama
# tengok : tengok
# videonya : video
# ditonton : tonton
# keluhan : keluh
# developernya : developer
# hahay : hahay
# uhuy : uhuy
# makasi : makas
# karna : karna
# gua : gua
# sibuk : sibuk
# promosi : promosi
# sekolah : sekolah
# ternganggu : ternganggu
# percaya : percaya
# klinik : klinik
# akses : akses
# goblog : goblog
# google : google
# sesad : sad
# smua : smua
# gda : gda
# bnr : bnr
# nilai : nilai
# tuntas : tuntas
# ak : ak
# ksih : ksih
# bntg : bntg
# admin : admin
# kk : kk
# ngechat : ngechat
# trs : trs
# blok : blok
# risih : risih
# berlangganan : langgan
# mempromosikan : promosi
# program : program
# tua : tua
# terusmenerus : terusmenerus
# sembarang : sembarang
# menganggu : menganggu
# xpnya : xpnya
# nambah : nambah
# salah : salah
# 2 : 2
# males : males
# ujian : uji
# suruh : suruh
# pake : pake
# hape : hape
# emangnya : emang
# kuota : kuota
# telfon : telfon
# mengganggu : ganggu
# takut : takut
# nomer : nomer
# kenal : kenal
# penjahat : jahat
# nelfon : nelfon
# hapus : hapus
# apknya : apknya
# suda : suda
# ndak : ndak
# smk : smk
# beranda : beranda
# lag : lag
# sulit : sulit
# scroll : scroll
# error : error
# internet : internet
# lancar : lancar
# xp : xp
# mencapai : capai
# ratusan : ratus
# terkecoh : kecoh
# menipu : tipu
# gratis : gratis
# bayar : bayar
# 700k : 700k
# 1juta : 1juta
# pa : pa
# kepencet : pencet
# super : super
# lainya : lai
# daftar : daftar
# kuliah : kuliah
# tawaran : tawar
# perpanjangan : panjang
# plis : plis
# 10 : 10
# 15 : 15
# berbayar : bayar
# 1mmebingungkan : 1mmebingungkan
# sayang : sayang
# liat : liat
# rangkuman : rangkum
# bolak : bolak
# acak : acak
# acakan : acak
# kesel : kesel
# juara : juara
# 5 : 5
# enam : enam
# kurangin : rangin
# bintangnya : bintang
# ruanguru : ruanguru
# dikasih : kasih
# 1bab : 1bab
# level : level
# 37 : 37
# turun : turun
# 8 : 8
# kenpa : kenpa
# robo : robo
# anjng : anjng
# nggk : nggk
# meresahkan : resah
# tulisannya : tulis
# terhubung : hubung
# padhal : padhal
# youtube : youtube
# instagram : instagram
# tpi : tpi
# koneksinya : koneksi
# sinyal : sinyal
# full : full
# knp : knp
# dibuka : buka
# life : life
# emg : emg
# mantap : mantap
# pembahasan : bahas
# mengerti : erti
# kadang2 : kadang2
# ngerti : ngerti
# intinya : inti
# puyeng : puyeng
# sekolahtapi : sekolahtapi
# bljr : bljr
# bngt : bngt
# kyk : kyk
# paham : paham
# doang : doang
# pusing2 : pusing2
# trimakasih : trimakasih
# pengajar : ajar
# ilmunya : ilmu
# hebat : hebat
# langganannya : langgan
# susah : susah
# diterima : terima
# 4 : 4
# bintang : bintang
# seru : seru
# dpat : dpat
# memahami : paham
# disekolah : seko
# cepat : cepat
# gajelas : gajelas
# mati : mati
# hidup : hidup
# mending : mending
# dipake : dipake
# dina : dina
# santa : santa
# maria : maria
# tanggal : tanggal
# 23 : 23
# september : september
# 2022 : 2022
# kepala : kepala
# sakit : sakit
# atur : atur
# iklannya : iklan
# lumayan : lumayan
# hujat : hujat
# ramah : ramah
# pjok : pjok
# minggu : minggu
# belajarutbk : belajarutbk
# gabisa : gabisa
# dipakek : dipakek
# ditanyain : ditanyain
# kaka : kaka
# consultant : consultant
# direspon : direspon
# sumpah : sumpah
# kecewa : kecewa
# diganggu : ganggu
# consultan : consultan
# nawarin : nawarin
# kedepannya : depan
# maksain : maksain
# iklan : iklan
# ditelpon : telpon
# mknya : mknya
# sya : sya
# jalan : jalan
# angkat : angkat
# kecelakaan : celaka
# dichat : dichat
# tim : tim
# didalam : dalam
# puas : puas
# sistem : sistem
# pengiklanan : iklan
# melewat : lewat
# email : email
# menurutku : turut
# dinamai : nama
# 2020 : 2020
# pesan : pesan
# dijumlahkan : jumlah
# 50 : 50
# mengirim : kirim
# memaksa : paksa
# semoga : moga
# ditindak : tindak
# lanjuti : lanjut
# pengiriman : kirim
# fakta : fakta
# pakem : pakem
# belian : belian
# mulu : mulu
# mambuat : mambuat
# asalnya : asal
# segi : segi
# uinya : uinya
# besarin : besarin
# gambar : gambar
# gambarnya : gambar
# gerak : gerak
# gila : gila
# keren : keren
# olahraga : olahraga
# inii : ini
# buka : buka
# layarnya : layar
# berubah : ubah
# item : item
# pencet : pencet
# subbab : subbab
# belajaarr : belajaarr
# didownload : didownload
# tetep : tetep
# connect : connect
# ngeplay : ngeplay
# habistu : habistu
# downloadnya : downloadnya
# 100 : 100
# jaringannya : jaring
# cepet : cepet
# penyimpanan : simpan
# apl : apl
# stabil : stabil
# wahh : wahh
# bermanfaat : manfaat
# leg : leg
# berterima : terima
# staffnya : staffnya
# stop : stop
# sembarangan : sembarang
# ngasih : ngasih
# pengumuman : umum
# appnya : appnya
# puluhan : puluh
# akun : akun
# ngegangu : ngegangu
# nelpon : nelpon
# aktivitas : aktivitas
# seharihari : seharihari
# bisabisa : bisabisa
# tertarik : tarik
# pekerjanya : kerja
# hi : hi
# mutar : mutar
# alasannya : alas
# wifi : wifi
# dirumah : rumah
# rugi : rugi
# bnget : bnget
# offline : offline
# kujuruannyya : kujuruannyya
# mna : mna
# dasar : dasar
# apa2 : apa2
# rugikan : rugi
# sayangnya : sayang
# bitrate : bitrate
# besarkanterkadang : besarkanterkadang
# blur : blur
# loadingnya : loadingnya
# ganggu : ganggu
# proses : proses
# pulang : pulang
# ruanggurur : ruanggurur
# bab : bab
# merdeka : merdeka
# xxldcudd : xxldcudd
# 2dxm : 2dxm
# xmx : xmx
# zx : zx
# cw : cw
# dijelasin : dijelasin
# nice : nice
# membantuu : membantuu
# gratisnyaa : gratisnyaa
# sangatt : sangatt
# mudah : mudah
# pahami : paham
# superb : superb
# bangus : bangus
# ditingkatkan : tingkat
# gurunya : guru
# anak : anak
# pintar : pintar
# mengajar : ajar
# gokil : gokil
# pelajarannya : ajar
# simpel : simpel
# baguz : baguz
# penjelasannya : jelas
# detail : detail
# animasi : animasi
# bersemangat : semangat
# huru : huru
# bguss : bguss
# memudahkan : mudah
# okeh : okeh
# dipahami : paham
# rinci : rinci
# menarik : tarik
# kemudahan : mudah
# penyampaian : sampai
# bimbingan : bimbing
# sukaa : sukaa
# sgat : sgat
# metode : metode
# bagusd : bagusd
# beanfaat : beanfaat
# beranimasi : animasi
# poll : poll
# pokoke : pokoke
# maju : maju
# mantep : mantep
# belajarjadi : belajarjadi
# berkat : berkat
# uts : uts
# pls : pls
# bener : bener
# lgi : lgi
# lengkap : lengkap
# memuaskan : muas
# camaba : camaba
# okelah : oke
# ranking : ranking
# berturutturut : berturutturut
# bareng : bareng
# iq : iq
# apikasi : apikasi
# kemrenn : kemrenn
# bang : bang
# pinter : pinter
# lope : lope
# berguna : guna
# gils : gils
# debest : debest
# bentuk : bentuk
# bagusan : bagus
# bank : bank
# melatih : latih
# nyuruh : nyuruh
# terimakasih : terimakasih
# faham : faham
# master : master
# teacher : teacher
# terangkan : terang
# ketinggalan : tinggal
# pelajarn : pelajarn
# kemarin : kemarin
# peringkat : peringkat
# gara : gara
# pokonya : poko
# diruangguru : diruangguru
# sukses : sukses
# many : many
# animation : animation
# kurangnya : kurang
# prakarya : prakarya
# seni : seni
# budaya : budaya
# baguss : baguss
# love : love
# perkalin : perkalin
# kerenn : kerenn
# syukak : syukak
# coba : coba
# application : application
# rajin : rajin
# gini : gin
# bikinnya : bikin
# lupa : lupa
# smas : smas
# sungguh : sungguh
# nyajadi : nyajadi
# lagidan : lagidan
# sambir : sambir
# bermain : main
# merekomendasikan : rekomendasi
# fasilitas : fasilitas
# membatu : batu
# {'bagus': 'bagus', 'pas': 'pas', 'udh': 'udh', 'donwload': 'donwload', 'chat': 'chat', 'saran': 'saran', 'ngga': 'ngga', 'tambahin': 'tambahin', 'fitur': 'fitur', 'screenshot': 'screenshot', 'video': 'video', 'adaptif': 'adaptif', 'pendalaman': 'dalam', 'materi': 'materi', 'kadang': 'kadang', 'sempet': 'sempet', 'nyatet': 'nyatet', 'adventure': 'adventure', 'makasih': 'makasih', 'banget': 'banget', 'ngebantu': 'ngebantu', 'naikin': 'naikin', 'mood': 'mood', 'belajarku': 'ajar', 'sekian': 'sekian', 'hatur': 'hatur', 'nuhun': 'nuhun', 'kakakkakak': 'kakakkakak', 'ruangguru': 'ruangguru', 'suka': 'suka', 'spam': 'spam', 'telpon': 'telpon', 'belajar': 'ajar', 'colern': 'colern', 'when': 'when', 'was': 'was', 'tried': 'tried', 'open': 'open', 'app': 'app', 'then': 'then', 'immediately': 'immediately', 'log': 'log', 'out': 'out', 'automatically': 'automatically', 'resize': 'resize', 'screen': 'screen', 'big': 'big', 'picture': 'picture', 'wobbly': 'wobbly', 'hope': 'hope', 'got': 'got', 'fixed': 'fixed', 'bagustapi': 'bagustapi', 'devloper': 'devloper', 'aplikasi': 'aplikasi', 'paket': 'paket', 'premium': 'premium', 'kepintaran': 'pintar', 'siswa': 'siswa', 'indonesia': 'indonesia', 'bicarakan': 'bicara', 'terima': 'terima', 'kasih': 'kasih', 'pahamify': 'pahamify', 'tukang': 'tukang', 'teror': 'teror', 'nomor': 'nomor', 'ganti': 'ganti', 'elekk': 'elekk', 'burik': 'burik', 'jelek': 'jelek', 'roboguru': 'roboguru', 'chrome': 'chrome', 'website': 'website', 'install': 'install', 'keberatan': 'berat', 'menginstall': 'menginstall', 'mengurangi': 'kurang', 'membutuhkan': 'butuh', 'simple': 'simple', 'ribet': 'ribet', 'tinggal': 'tinggal', 'dowoad': 'dowoad', 'maaf': 'maaf', 'kota': 'kota', 'kualitas': 'kualitas', 'jaringan': 'jaring', 'terbaik': 'baik', 'didesa': 'desa', 'memprihatinkan': 'prihatin', 'ko': 'ko', 'vidionya': 'vidionya', 'bsa': 'bsa', 'putar': 'putar', 'gmnaa': 'gmnaa', 'macan': 'macan', 'nggak': 'nggak', 'sembuhsembuh': 'sembuhsembuh', 'jam': 'jam', 'sembuh': 'sembuh', '24jam': '24jam', 'download': 'download', 'galeri': 'galeri', 'urut': 'urut', 'aplikasinya': 'aplikasi', 'eror': 'eror', 'membantu': 'bantu', 'pelajar': 'ajar', '1': '1', 'hewan': 'hewan', 'peliharaan': 'pelihara', 'teman': 'teman', 'terganggu': 'ganggu', 'aktivitasnya': 'aktivitas', 'khawatir': 'khawatir', 'produktif': 'produktif', 'belajarnya': 'ajar', 'kea': 'kea', 'terpaksa': 'paksa', 'sehatin': 'sehatin', 'peliharaannya': 'pelihara', 'pahamin': 'pahamin', 'apk': 'apk', 'lapet': 'lapet', 'ruanggurunya': 'ruanggurunya', 'ngesthag': 'ngesthag', 'masak': 'masak', 'habis': 'habis', 'lock': 'lock', 'mencari': 'cari', 'ilmu': 'ilmu', 'drill': 'drill', 'macet': 'macet', 'mwehehehehe': 'mwehehehehe', 'downlod': 'downlod', 'bantuannya': 'bantu', 'nama': 'nama', 'jamiah': 'jamiah', 'pet': 'pet', 'menghitung': 'hitung', 'pembelajaran': 'ajar', 'imbasnya': 'imbas', 'berfungsi': 'fungsi', 'tolong': 'tolong', 'memperbaiki': 'baik', 'maap': 'maap', 'layar': 'layar', 'utama': 'utama', 'perbaiki': 'baik', 'bugnya': 'bugnya', 'lanjutkan': 'lanjut', 'senang': 'senang', 'adapto': 'adapto', 'pengisi': 'isi', 'suara': 'suara', 'cepatsusah': 'cepatsusah', 'dengarya': 'dengarya', 'kecepatan': 'cepat', 'videodan': 'videodan', 'subtitle': 'subtitle', 'jelasmata': 'jelasmata', 'pelajaran': 'ajar', 'ipatapi': 'ipatapi', 'pakai': 'pakai', 'ruang': 'ruang', 'guru': 'guru', 'pliss': 'pliss', 'bug': 'bug', 'benerin': 'benerin', 'semangat': 'semangat', 'suvenir': 'suvenir', 'tirmidzi': 'tirmidzi', 'dishahihkan': 'dishahihkan', 'bersalah': 'salah', 'kerana': 'rana', 'allah': 'allah', 'swt': 'swt', 'nunggu': 'nunggu', 'kehilangan': 'hilang', 'kau': 'kau', 'minat': 'minat', 'silahkan': 'silah', 'merapat': 'rapat', 'menberikan': 'menberikan', 'dukungan': 'dukung', 'relawan': 'rawan', 'ahy': 'ahy', 'familia': 'familia', 'scarabaeidae': 'scarabaeidae', 'ngerjain': 'ngerjain', 'kuis': 'kuis', 'nonton': 'nonton', 'perjelasan': 'jelas', 'tibatiba': 'tibatiba', 'ngelag': 'ngelag', 'ngulang': 'n ...
# ------------------------
# Pandas Apply:   0%|          | 0/200 [00:00<?, ?it/s]

# %%
df_skripsi
# Out:
#                                     setelah_Tokenisasi  \
# 0    [ini, bagus, tapi, ini, kenapa, pas, udh, engg...
# 1    [aku, boleh, saran, ngga, tambahin, juga, fitu...
# 2    [suka, spam, telpon, lebih, bagus, sekalian, b...
# 3    [so, when, was, tried, to, open, the, app, the...
# 4    [sangat, bagustapi, saya, mohon, kepada, devlo...
# ..                                                 ...
# 195     [sangat, bagus, bisa, belajar, sambil, nonton]
# 196  [udah, bagus, tapi, ada, beberapa, hal, yang, ...
# 197                                       [bagus, bgt]
# 198             [keren, banget, dan, sangat, membantu]
# 199                                           [okelah]
#
#                                               Stopword  \
# 0                    [bagus, pas, udh, donwload, chat]
# 1    [saran, ngga, tambahin, fitur, screenshot, vid...
# 2         [suka, spam, telpon, bagus, belajar, colern]
# 3    [when, was, tried, open, app, then, immediatel...
# 4    [bagustapi, devloper, aplikasi, ruangguru, pak...
# ..                                                 ...
# 195                           [bagus, belajar, nonton]
# 196                              [bagus, ditingkatkan]
# 197                                            [bagus]
# 198                          [keren, banget, membantu]
# 199                                           [okelah]
#
#                                  normalized & Stemming
# 0                    [bagus, pas, udh, donwload, chat]
# 1    [saran, ngga, tambahin, fitur, screenshot, vid...
# 2            [suka, spam, telpon, bagus, ajar, colern]
# 3    [when, was, tried, open, app, then, immediatel...
# 4    [bagustapi, devloper, aplikasi, ruangguru, pak...
# ..                                                 ...
# 195                              [bagus, ajar, nonton]
# 196                                   [bagus, tingkat]
# 197                                            [bagus]
# 198                             [keren, banget, bantu]
# 199                                              [oke]
#
# [200 rows x 3 columns]

# %%
df_skripsi.columns = ['text_real','text']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [86], line 1
# ----> 1 df_skripsi.columns = ['text_real','text']
#
# File c:\users\my asus\appdata\local\programs\python\python39\lib\site-packages\pandas\core\generic.py:5920, in NDFrame.__setattr__(self, name, value)
#    5918 try:
#    5919     object.__getattribute__(self, name)
# -> 5920     return object.__setattr__(self, name, value)
#    5921 except AttributeError:
#    5922     pass
#
# File c:\users\my asus\appdata\local\programs\python\python39\lib\site-packages\pandas\_libs\properties.pyx:69, in pandas._libs.properties.AxisProperty.__set__()
#
# File c:\users\my asus\appdata\local\programs\python\python39\lib\site-packages\pandas\core\generic.py:822, in NDFrame._set_axis(self, axis, labels)
#     820 def _set_axis(self, axis: int, labels: AnyArrayLike | list) -> None:
#     821     labels = ensure_index(labels)
# --> 822     self._mgr.set_axis(axis, labels)
#     823     self._clear_item_cache()
#
# File c:\users\my asus\appdata\local\programs\python\python39\lib\site-packages\pandas\core\internals\managers.py:228, in BaseBlockManager.set_axis(self, axis, new_labels)
#     226 def set_axis(self, axis: int, new_labels: Index) -> None:
#     227     # Caller is responsible for ensuring we have an Index object.
# --> 228     self._validate_set_axis(axis, new_labels)
#     229     self.axes[axis] = new_labels
#
# File c:\users\my asus\appdata\local\programs\python\python39\lib\site-packages\pandas\core\internals\base.py:70, in DataManager._validate_set_axis(self, axis, new_labels)
#      67     pass
#      69 elif new_len != old_len:
# ---> 70     raise ValueError(
#      71         f"Length mismatch: Expected axis has {old_len} elements, new "
#      72         f"values have {new_len} elements"
#      73     )
#
# ValueError: Length mismatch: Expected axis has 3 elements, new values have 2 elements

# %%
df_skripsi.columns = ['label','text_real']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [36], line 1
# ----> 1 df_skripsi.columns = ['label','text_real']
#
# File c:\users\my asus\appdata\local\programs\python\python39\lib\site-packages\pandas\core\generic.py:5920, in NDFrame.__setattr__(self, name, value)
#    5918 try:
#    5919     object.__getattribute__(self, name)
# -> 5920     return object.__setattr__(self, name, value)
#    5921 except AttributeError:
#    5922     pass
#
# File c:\users\my asus\appdata\local\programs\python\python39\lib\site-packages\pandas\_libs\properties.pyx:69, in pandas._libs.properties.AxisProperty.__set__()
#
# File c:\users\my asus\appdata\local\programs\python\python39\lib\site-packages\pandas\core\generic.py:822, in NDFrame._set_axis(self, axis, labels)
#     820 def _set_axis(self, axis: int, labels: AnyArrayLike | list) -> None:
#     821     labels = ensure_index(labels)
# --> 822     self._mgr.set_axis(axis, labels)
#     823     self._clear_item_cache()
#
# File c:\users\my asus\appdata\local\programs\python\python39\lib\site-packages\pandas\core\internals\managers.py:228, in BaseBlockManager.set_axis(self, axis, new_labels)
#     226 def set_axis(self, axis: int, new_labels: Index) -> None:
#     227     # Caller is responsible for ensuring we have an Index object.
# --> 228     self._validate_set_axis(axis, new_labels)
#     229     self.axes[axis] = new_labels
#
# File c:\users\my asus\appdata\local\programs\python\python39\lib\site-packages\pandas\core\internals\base.py:70, in DataManager._validate_set_axis(self, axis, new_labels)
#      67     pass
#      69 elif new_len != old_len:
# ---> 70     raise ValueError(
#      71         f"Length mismatch: Expected axis has {old_len} elements, new "
#      72         f"values have {new_len} elements"
#      73     )
#
# ValueError: Length mismatch: Expected axis has 4 elements, new values have 2 elements

# %%
df_skripsi
# Out:
#         label                                          text_real  \
# 0    Negative  Ini bagus. Tapi ini kenapa pas udh enggak donw...
# 1    Negative  Aku boleh saran ngga? Tambahin juga fitur scre...
# 2    Negative  Suka spam telpon... Lebih bagus sekalian belaj...
# 3    Negative  So, when i was tried to open the app, then imm...
# 4    Negative  Sangat bagus,tapi saya mohon kepada devloper b...
# ..        ...                                                ...
# 195  Positive            Sangat bagus bisa belajar sambil nonton
# 196  Positive  Udah bagus tapi ada beberapa hal yang harus di...
# 197  Positive                                        Bagus bgttt
# 198  Positive  Keren banget dan sangat membantuðŸ‘ðŸ‘ðŸ‘ðŸ...
# 199  Positive                                             Okelah
#
#                                                   text  \
# 0    ini bagus. tapi ini kenapa pas udh enggak donw...
# 1    aku boleh saran ngga? tambahin juga fitur scre...
# 2    suka spam telpon... lebih bagus sekalian belaj...
# 3    so, when i was tried to open the app, then imm...
# 4    sangat bagus,tapi saya mohon kepada devloper b...
# ..                                                 ...
# 195            sangat bagus bisa belajar sambil nonton
# 196  udah bagus tapi ada beberapa hal yang harus di...
# 197                                        bagus bgttt
# 198  keren banget dan sangat membantuðÿ‘ðÿ‘ðÿ‘ðÿ...
# 199                                             okelah
#
#                                    Setelah_caseFolding
# 0    Ini bagus. Tapi ini kenapa pas udh enggak donw...
# 1    Aku boleh saran ngga? Tambahin juga fitur scre...
# 2    Suka spam telpon... Lebih bagus sekalian belaj...
# 3    So, when i was tried to open the app, then imm...
# 4    Sangat bagus,tapi saya mohon kepada devloper b...
# ..                                                 ...
# 195            Sangat bagus bisa belajar sambil nonton
# 196  Udah bagus tapi ada beberapa hal yang harus di...
# 197                                        Bagus bgttt
# 198  Keren banget dan sangat membantuðŸ‘ðŸ‘ðŸ‘ðŸ...
# 199                                             Okelah
#
# [200 rows x 4 columns]

# %%
def remove_text_special(text):
    # hapus tab, new line, ans back slice
    text = text.replace('\\t'," ").replace('\\n'," ").replace('\\u'," ").replace('\\',"")
    # hapus non ASCII (emot, bahasa china dll)
    text = text.encode('ascii', 'replace').decode('ascii')
    # hapus mention, link, hashtag
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)"," ", text).split())
    # remove URL 
    return text.replace("http://", " ").replace("https://", " ")
df_skripsi['text'] = df_skripsi.text.astype('str')                
df_skripsi['text'] = df_skripsi['text'].apply(remove_text_special)

# %%
df_skripsi
# Out:
#         label                                               text  \
# 0    Negative  ini bagus. tapi ini kenapa pas udh enggak donw...
# 1    Negative  aku boleh saran ngga? tambahin juga fitur scre...
# 2    Negative  suka spam telpon... lebih bagus sekalian belaj...
# 3    Negative  so, when i was tried to open the app, then imm...
# 4    Negative  sangat bagus,tapi saya mohon kepada devloper b...
# ..        ...                                                ...
# 195  Positive            sangat bagus bisa belajar sambil nonton
# 196  Positive  udah bagus tapi ada beberapa hal yang harus di...
# 197  Positive                                        bagus bgttt
# 198  Positive  keren banget dan sangat membantu??????????????...
# 199  Positive                                             okelah
#
#                                              text_real
# 0    Ini bagus. Tapi ini kenapa pas udh enggak donw...
# 1    Aku boleh saran ngga? Tambahin juga fitur scre...
# 2    Suka spam telpon... Lebih bagus sekalian belaj...
# 3    So, when i was tried to open the app, then imm...
# 4    Sangat bagus,tapi saya mohon kepada devloper b...
# ..                                                 ...
# 195            Sangat bagus bisa belajar sambil nonton
# 196  Udah bagus tapi ada beberapa hal yang harus di...
# 197                                        Bagus bgttt
# 198  Keren banget dan sangat membantuðŸ‘ðŸ‘ðŸ‘ðŸ...
# 199                                             Okelah
#
# [200 rows x 3 columns]

# %%
#remove kata yang sengaja dipanjangkan
# seperti bisaaaaaaa -> bisa
def spell(word):
    if re.search(r'([a-zA-Z])\1{2,}', word):
        rword = re.sub(r'([a-zA-Z])\1{2,}','\\1', word)
        return rword
    else:
        return word
df_skripsi['text'] = df_skripsi['text'].apply(spell)

# %%
df_skripsi
# Out:
#         label                                               text  \
# 0    Negative  ini bagus. tapi ini kenapa pas udh enggak donw...
# 1    Negative  aku boleh saran ngga? tambahin juga fitur scre...
# 2    Negative  suka spam telpon... lebih bagus sekalian belaj...
# 3    Negative  so, when i was tried to open the app, then imm...
# 4    Negative  sangat bagus,tapi saya mohon kepada devloper b...
# ..        ...                                                ...
# 195  Positive            sangat bagus bisa belajar sambil nonton
# 196  Positive  udah bagus tapi ada beberapa hal yang harus di...
# 197  Positive                                          bagus bgt
# 198  Positive  keren banget dan sangat membantu??????????????...
# 199  Positive                                             okelah
#
#                                              text_real
# 0    Ini bagus. Tapi ini kenapa pas udh enggak donw...
# 1    Aku boleh saran ngga? Tambahin juga fitur scre...
# 2    Suka spam telpon... Lebih bagus sekalian belaj...
# 3    So, when i was tried to open the app, then imm...
# 4    Sangat bagus,tapi saya mohon kepada devloper b...
# ..                                                 ...
# 195            Sangat bagus bisa belajar sambil nonton
# 196  Udah bagus tapi ada beberapa hal yang harus di...
# 197                                        Bagus bgttt
# 198  Keren banget dan sangat membantuðŸ‘ðŸ‘ðŸ‘ðŸ...
# 199                                             Okelah
#
# [200 rows x 3 columns]

# %%
def remove_punctuation(text):
    return text.translate(str.maketrans("","",string.punctuation))

df_skripsi['text'] = df_skripsi['text'].apply(remove_punctuation)

# %%
df_skripsi
# Out:
#         label                                               text  \
# 0    Negative  ini bagus tapi ini kenapa pas udh enggak donwl...
# 1    Negative  aku boleh saran ngga tambahin juga fitur scree...
# 2    Negative  suka spam telpon lebih bagus sekalian belajar ...
# 3    Negative  so when i was tried to open the app then immed...
# 4    Negative  sangat bagustapi saya mohon kepada devloper bi...
# ..        ...                                                ...
# 195  Positive            sangat bagus bisa belajar sambil nonton
# 196  Positive  udah bagus tapi ada beberapa hal yang harus di...
# 197  Positive                                          bagus bgt
# 198  Positive                   keren banget dan sangat membantu
# 199  Positive                                             okelah
#
#                                              text_real
# 0    Ini bagus. Tapi ini kenapa pas udh enggak donw...
# 1    Aku boleh saran ngga? Tambahin juga fitur scre...
# 2    Suka spam telpon... Lebih bagus sekalian belaj...
# 3    So, when i was tried to open the app, then imm...
# 4    Sangat bagus,tapi saya mohon kepada devloper b...
# ..                                                 ...
# 195            Sangat bagus bisa belajar sambil nonton
# 196  Udah bagus tapi ada beberapa hal yang harus di...
# 197                                        Bagus bgttt
# 198  Keren banget dan sangat membantuðŸ‘ðŸ‘ðŸ‘ðŸ...
# 199                                             Okelah
#
# [200 rows x 3 columns]

# %%
#remove whitespace leading & trailing
def remove_whitespace_LT(text):
    return text.strip()

df_skripsi['text'] = df_skripsi['text'].apply(remove_whitespace_LT)

# %%
df_skripsi
# Out:
#         label                                               text  \
# 0    Negative  ini bagus tapi ini kenapa pas udh enggak donwl...
# 1    Negative  aku boleh saran ngga tambahin juga fitur scree...
# 2    Negative  suka spam telpon lebih bagus sekalian belajar ...
# 3    Negative  so when i was tried to open the app then immed...
# 4    Negative  sangat bagustapi saya mohon kepada devloper bi...
# ..        ...                                                ...
# 195  Positive            sangat bagus bisa belajar sambil nonton
# 196  Positive  udah bagus tapi ada beberapa hal yang harus di...
# 197  Positive                                          bagus bgt
# 198  Positive                   keren banget dan sangat membantu
# 199  Positive                                             okelah
#
#                                              text_real
# 0    Ini bagus. Tapi ini kenapa pas udh enggak donw...
# 1    Aku boleh saran ngga? Tambahin juga fitur scre...
# 2    Suka spam telpon... Lebih bagus sekalian belaj...
# 3    So, when i was tried to open the app, then imm...
# 4    Sangat bagus,tapi saya mohon kepada devloper b...
# ..                                                 ...
# 195            Sangat bagus bisa belajar sambil nonton
# 196  Udah bagus tapi ada beberapa hal yang harus di...
# 197                                        Bagus bgttt
# 198  Keren banget dan sangat membantuðŸ‘ðŸ‘ðŸ‘ðŸ...
# 199                                             Okelah
#
# [200 rows x 3 columns]

# %%
def remove_whitespace_multiple(text):
    return re.sub('\s+',' ',text)

df_skripsi['text'] = df_skripsi['text'].apply(remove_whitespace_multiple)

# %%
def remove_singl_char(text):
    return re.sub(r"\b[a-zA-Z]\b", "", text)

df_skripsi['text'] = df_skripsi['text'].apply(remove_singl_char)

# %%
df_skripsi
# Out:
#         label                                               text  \
# 0    Negative  ini bagus tapi ini kenapa pas udh enggak donwl...
# 1    Negative  aku boleh saran ngga tambahin juga fitur scree...
# 2    Negative  suka spam telpon lebih bagus sekalian belajar ...
# 3    Negative  so when  was tried to open the app then immedi...
# 4    Negative  sangat bagustapi saya mohon kepada devloper bi...
# ..        ...                                                ...
# 195  Positive            sangat bagus bisa belajar sambil nonton
# 196  Positive  udah bagus tapi ada beberapa hal yang harus di...
# 197  Positive                                          bagus bgt
# 198  Positive                   keren banget dan sangat membantu
# 199  Positive                                             okelah
#
#                                              text_real
# 0    Ini bagus. Tapi ini kenapa pas udh enggak donw...
# 1    Aku boleh saran ngga? Tambahin juga fitur scre...
# 2    Suka spam telpon... Lebih bagus sekalian belaj...
# 3    So, when i was tried to open the app, then imm...
# 4    Sangat bagus,tapi saya mohon kepada devloper b...
# ..                                                 ...
# 195            Sangat bagus bisa belajar sambil nonton
# 196  Udah bagus tapi ada beberapa hal yang harus di...
# 197                                        Bagus bgttt
# 198  Keren banget dan sangat membantuðŸ‘ðŸ‘ðŸ‘ðŸ...
# 199                                             Okelah
#
# [200 rows x 3 columns]

# %%
df_skripsi = df_skripsi.drop_duplicates()
df_skripsi = df_skripsi[['text_real','text','label']]
df_skripsi['text'] = df_skripsi['text'].str.lower()

def word_tokenize_wrapper(text):
    return word_tokenize(text)

df_skripsi['text_tokens'] = df_skripsi['text'].apply(word_tokenize_wrapper)

# %%
df_skripsi
# Out:
#                                              text_real  \
# 0    Ini bagus. Tapi ini kenapa pas udh enggak donw...
# 1    Aku boleh saran ngga? Tambahin juga fitur scre...
# 2    Suka spam telpon... Lebih bagus sekalian belaj...
# 3    So, when i was tried to open the app, then imm...
# 4    Sangat bagus,tapi saya mohon kepada devloper b...
# ..                                                 ...
# 195            Sangat bagus bisa belajar sambil nonton
# 196  Udah bagus tapi ada beberapa hal yang harus di...
# 197                                        Bagus bgttt
# 198  Keren banget dan sangat membantuðŸ‘ðŸ‘ðŸ‘ðŸ...
# 199                                             Okelah
#
#                                                   text     label  \
# 0    ini bagus tapi ini kenapa pas udh enggak donwl...  Negative
# 1    aku boleh saran ngga tambahin juga fitur scree...  Negative
# 2    suka spam telpon lebih bagus sekalian belajar ...  Negative
# 3    so when  was tried to open the app then immedi...  Negative
# 4    sangat bagustapi saya mohon kepada devloper bi...  Negative
# ..                                                 ...       ...
# 195            sangat bagus bisa belajar sambil nonton  Positive
# 196  udah bagus tapi ada beberapa hal yang harus di...  Positive
# 197                                          bagus bgt  Positive
# 198                   keren banget dan sangat membantu  Positive
# 199                                             okelah  Positive
#
#                                            text_tokens
# 0    [ini, bagus, tapi, ini, kenapa, pas, udh, engg...
# 1    [aku, boleh, saran, ngga, tambahin, juga, fitu...
# 2    [suka, spam, telpon, lebih, bagus, sekalian, b...
# 3    [so, when, was, tried, to, open, the, app, the...
# 4    [sangat, bagustapi, saya, mohon, kepada, devlo...
# ..                                                 ...
# 195     [sangat, bagus, bisa, belajar, sambil, nonton]
# 196  [udah, bagus, tapi, ada, beberapa, hal, yang, ...
# 197                                       [bagus, bgt]
# 198             [keren, banget, dan, sangat, membantu]
# 199                                           [okelah]
#
# [194 rows x 4 columns]

# %%
list_stopwords = stopwords.words('indonesian')
list_stopwords.extend(["yg", "dg", "rt", "dgn", "ny", "d", 'klo', 
                       'kalo', 'amp', 'biar', 'bikin', 'bilang', 
                       'gak', 'ga', 'krn', 'nya', 'nih', 'sih', 
                       'si', 'tau', 'tdk', 'tuh', 'utk', 'ya', 
                       'jd', 'jgn', 'sdh', 'aja', 'n', 't', 
                       'nyg', 'hehe', 'pen', 'u', 'nan', 'loh', 'rt',
                       '&amp', 'yah'])

txt_stopword = pd.read_csv("stopwords.txt", names= ["stopwords"], header = None)
list_stopwords.extend(txt_stopword["stopwords"][0].split(' '))
list_stopwords = set(list_stopwords)
def stopwords_removal(words):
    return [word for word in words if word not in list_stopwords]
df_skripsi['text_tokens_WSW'] = df_skripsi['text_tokens'].apply(stopwords_removal)

# %%
list_stopwords
# Out:
# {'',
#  'mam',
#  'tar',
#  'dikatakan',
#  'aaaakkkhhhhhh',
#  'uhuii',
#  'wi',
#  'liyat',
#  'jika',
#  'nyaaa',
#  'diberikannya',
#  'tandasnya',
#  'spt',
#  'lc',
#  'tersebutlah',
#  'yokk',
#  'pin',
#  'astagfirullah',
#  'twit',
#  'sich',
#  'aku',
#  'suggest',
#  'sa',
#  'begitu',
#  'eih',
#  'ampe',
#  'and',
#  'berlalu',
#  'oalah',
#  'mula',
#  'ot',
#  'assuuu',
#  'berakhir',
#  'terdahulu',
#  'asalkan',
#  'gar',
#  'diperbuat',
#  'ny',
#  'katakan',
#  'e',
#  'sal',
#  'semampu',
#  'bolehlah',
#  'selain',
#  'wooyy',
#  'sosi',
#  'ibaratnya',
#  'klop',
#  'meng',
#  'flood',
#  'begi',
#  'diingat',
#  'jangankan',
#  'woy',
#  'mpod',
#  'ehe',
#  'of',
#  'can',
#  'diucapkannya',
#  'buat',
#  'diibaratkan',
#  'seorang',
#  'terkira',
#  'cuy',
#  'memberikan',
#  'apasih',
#  'jee',
#  'bain',
#  'gw',
#  'may',
#  'benar',
#  'more',
#  'semisal',
#  'woi',
#  'hilihhh',
#  'padanya',
#  'sebagai',
#  'kam',
#  'mengibaratkan',
#  'dimulai',
#  'semacam',
#  'syi',
#  'dilihat',
#  'kak',
#  'gig',
#  'hehehe',
#  'seolah-olah',
#  'sebaliknya',
#  'diibaratkannya',
#  'tentulah',
#  'mengenai',
#  'yee',
#  'menginginkan',
#  'adoh',
#  'tanya',
#  'lainnya',
#  'mengatakan',
#  'terjadilah',
#  'y',
#  'ataupun',
#  'dng',
#  'mr',
#  'keunn',
#  'sayalah',
#  'woooyyyyy',
#  'melalui',
#  'dimulailah',
#  'itu',
#  'tampak',
#  'diperlukan',
#  '&amp',
#  'huh',
#  'ato',
#  'apkah',
#  'adalah',
#  'dy',
#  'hadeehhh',
#  'hanyalah',
#  'sampai',
#  'kkk',
#  'gsk',
#  'wuiih',
#  'akan',
#  'khususnya',
#  'look',
#  'rupa',
#  'aajh',
#  'wonderfull',
#  'ter',
#  'berlainan',
#  'punya',
#  'apalagi',
#  'mahl',
#  'so',
#  'xi',
#  'gin',
#  'lewat',
#  'masa',
#  'waahh',
#  'gt',
#  'sebaiknya',
#  'diketahui',
#  'bila',
#  'bawah',
#  'melihatnya',
#  'ntar',
#  'duhh',
#  'dah',
#  'hayo',
#  'yah',
#  'asa',
#  'merekalah',
#  'tidakkah',
#  'ja',
#  'c',
#  'alhamdulillah',
#  'andalah',
#  'kini',
#  'kelihatan',
#  'tdak',
#  'baru',
#  'joss',
#  'astagaaaahhh',
#  'secara',
#  'suatu',
#  'cam',
#  'kok',
#  'owalah',
#  'tgjwb',
#  'bahwasannya',
#  'kal',
#  'yv',
#  'pea',
#  'tampaknya',
#  'setiba',
#  'sj',
#  'mempunyai',
#  'fyi',
#  'yaelah',
#  'ooo',
#  'dong',
#  'kala',
#  'lbh',
#  'hanya',
#  'biup',
#  'ajasi',
#  'dimulainya',
#  'kemudian',
#  'ts',
#  'asiiik',
#  'pun',
#  'sebenarnya',
#  'secukupnya',
#  'begini',
#  'aseeekkk',
#  'kelamaan',
#  'smuwa',
#  'kn',
#  'bara',
#  'ke',
#  'sinilah',
#  'tuu',
#  'ti',
#  'entah',
#  'malahan',
#  'ai',
#  'meski',
#  'going',
#  'tang',
#  'apa',
#  'ahhahshahahsha',
#  'tuturnya',
#  'kasus',
#  'gunakan',
#  'sempat',
#  'vi',
#  'memang',
#  'bertanya',
#  'woyyy',
#  'aiiihhh',
#  'seringnya',
#  'saat',
#  'lg',
#  'sendirinya',
#  'siip',
#  'dech',
#  'sangatlah',
#  'bahahak',
#  'don',
#  'hadeeeeeh',
#  'tetapi',
#  'piye',
#  's',
#  'betulkah',
#  'sebagian',
#  'blom',
#  'hih',
#  'dp',
#  'tan',
#  'hsil',
#  'ibu',
#  'bar',
#  'ing',
#  'benarlah',
#  'dimaksud',
#  'share',
#  'tuit',
#  'beginian',
#  'o',
#  'krn',
#  'aaah',
#  'ajaah',
#  'ab',
#  'akse',
#  'dibuat',
#  'walaupun',
#  'meyakini',
#  'baaeerrree',
#  'agree',
#  'seseorang',
#  'mata',
#  'bukanlah',
#  'good',
#  'klw',
#  'bwa',
#  'katanya',
#  'manalagi',
#  'diakhirinya',
#  'tertentu',
#  'kerna',
#  'they',
#  'tepat',
#  'oiya',
#  'terbanyak',
#  'berapakah',
#  'ms',
#  'cik',
#  'bakalan',
#  'sendiri',
#  'toh',
#  'apaaaannnn',
#  'apalgi',
#  'bk',
#  'kedua',
#  'keadaan',
#  'supaya',
#  'go',
#  'penc',
#  'terutama',
#  'wh',
#  'ssst',
#  'segala',
#  'bagai',
#  'persoalan',
#  'agaknya',
#  'no',
#  'dipergunakan',
#  'hny',
#  'awwww',
#  'beberapa',
#  'sepantasnya',
#  'gn',
#  'kl',
#  'terl',
#  'yukk',
#  'dn',
#  'uittt',
#  'klo',
#  'in',
#  'sehingga',
#  'astagpirullohalazmin',
#  'termasuk',
#  'huhuhu',
#  'dari',
#  'mengucapkan',
#  'berakhirnya',
#  'did',
#  'nah',
#  'dini',
#  'laku',
#  'ehhhh',
#  'karenanya',
#  'biar',
#  'hadeeuh',
#  'as',
#  'mengingat',
#  'ibaratkan',
#  'bisakah',
#  'soalnya',
#  'pertama',
#  'nyang',
#  'ketika',
#  'diperkirakan',
#  'apabila',
#  'eye',
#  'mengibaratkannya',
#  'mksh',
#  'er',
#  'aaa',
#  'sar',
#  'besar',
#  'jat',
#  'mengetahui',
#  'tegas',
#  'ucapnya',
#  'di',
#  'sejauh',
#  'digunakan',
#  'jomp',
#  'ikut',
#  'tuh',
#  'kamu',
#  'kembali',
#  'lima',
#  'tanpa',
#  'mwnyedihkan',
#  'ne',
#  'didatangkan',
#  'diar',
#  'saatnya',
#  'mp',
#  'lha',
#  'aj',
#  'seperti',
#  'ealah',
#  'ncuup',
#  'tegasnya',
#  'ckakak',
#  'semua',
#  'm',
#  'sana',
#  'menunjukkan',
#  'jawaban',
#  'update',
#  'if',
#  'keri',
#  'hmmm',
#  'dahh',
#  'march',
#  'sepertinya',
#  'menyer',
#  'tiga',
#  'akutuh',
#  'menyatakan',
#  'mulai',
#  'maupun',
#  'selanjutnya',
#  'kayak',
#  'ehh',
#  'diperlukannya',
#  'melainkan',
#  'akh',
#  'memperbuat',
#  'rb',
#  'untuk',
#  'menanyakan',
#  'ki',
#  'silakan',
#  'akhirx',
#  'diingatkan',
#  'wahhh',
#  'mengakhiri',
#  'mempergunakan',
#  'bikin',
#  'saling',
#  'acan',
#  'cok',
#  'lohhhh',
#  'aahhh',
#  'guna',
#  'blo',
#  'sin',
#  'apakh',
#  'udahan',
#  'from',
#  'at',
#  'bagi',
#  'hendaklah',
#  'menunjuki',
#  'olehnya',
#  'astaghfrullah',
#  'namun',
#  'adapun',
#  'mengatakannya',
#  'mendapat',
#  'dimaksudnya',
#  'bkal',
#  'smple',
#  'kapanpun',
#  'ahahahah',
#  'seketika',
#  'my',
#  'wihhhhh',
#  'anca',
#  'ww',
#  'perlu',
#  'ihh',
#  'mengingatkan',
#  'is',
#  'hendak',
#  'keterlaluan',
#  'lah',
#  'ahhay',
#  'berkeinginan',
#  'bolehkah',
#  'mirip',
#  'siiiiiiiih',
#  'seolah',
#  'ujar',
#  'juaraaa',
#  'heeeeellloooo',
#  'jl',
#  'dikatakannya',
#  'berturut-turut',
#  'again',
#  'terjadinya',
#  'dituturkan',
#  'mungkin',
#  'following',
#  'tidaklah',
#  'u',
#  'berikan',
#  'bant',
#  'demikianlah',
#  'bagemana',
#  'd',
#  'we',
#  'yaa',
#  'ajjaaa',
#  'penting',
#  'terhadapnya',
#  'didapat',
#  'kalaulah',
#  'memisalkan',
#  'memba',
#  'diketahuinya',
#  'woyyyyyy',
#  'semakin',
#  'wih',
#  'bahahaha',
#  'menantikan',
#  'selamanya',
#  'pohonnnn',
#  'ci',
#  'ia',
#  'dimaksudkan',
#  'mul',
#  'ting',
#  'aka',
#  'yakni',
#  'tapi',
#  'nyatanya',
#  'mer',
#  'ckckck',
#  'bukan',
#  'mrk',
#  'awalnya',
#  'mendatang',
#  'berkehendak',
#  'bers',
#  'kemungkinan',
#  'r',
#  'be',
#  'th',
#  'kecil',
#  'meskipun',
#  'l',
#  'woyyyyy',
#  'gate',
#  'h',
#  'bertutur',
#  'fir',
#  'pada',
#  'bakal',
#  'bo',
#  'sudahlah',
#  'ahhhhh',
#  'hadeuh',
#  'kiranya',
#  'anta',
#  'usah',
#  'siep',
#  'menjelaskan',
#  'tir',
#  'bat',
#  'world',
#  'sewaktu',
#  'sblm',
#  'ingin',
#  'met',
#  'disebut',
#  'mendapatkan',
#  'tur',
#  'imb',
#  'al',
#  'tinggi',
#  'diucapkan',
#  'ooohhh',
#  'menyebutkan',
#  'tu',
#  'bnyk',
#  'tuip',
#  'why',
#  'alangkah',
#  'berapa',
#  'bg',
#  'eiy',
#  'banyak',
#  'ditanyakan',
#  'rata',
#  'sebisanya',
#  'mohon',
#  'om',
#  'nguyu',
#  'kelihatannya',
#  'justru',
#  'laelah',
#  'ken',
#  're',
#  'wahaye',
#  'yupsss',
#  'b',
#  'antara',
#  'zzz',
#  'akhirnya',
#  'perlunya',
#  'ntap',
#  'lanjut',
#  'datang',
#  'rt',
#  'hmmmmmm',
#  'woyy',
#  'zzzzzz',
#  'bol',
#  'do',
#  'eng',
#  'kr',
#  'setiap',
#  'setidaknya',
#  'ditunjuki',
#  'astaghfirullah',
#  'hai',
#  'meyakinkan',
#  'f',
#  'serupa',
#  'kata',
#  'sekaranglah',
#  'sudah',
#  'bgt',
#  'kebetulan',
#  'bagaimanapun',
#  'bagiamana',
#  'bermacam',
#  'loh',
#  'donk',
#  'menunjuknya',
#  'mana',
#  'berjumlah',
#  'sek',
#  'ahh',
#  'toeeettt',
#  'ih',
#  'drpd',
#  'uhuyyy',
#  'tsbt',
#  'atuh',
#  'ba',
#  'sebaik-baiknya',
#  'theatre',
#  'inginkah',
#  'kepa',
#  'kor',
#  'dab',
#  'menanya',
#  'dr',
#  'sang',
#  'bagaimanakah',
#  'beginikah',
#  'msh',
#  'tanyakan',
#  'nie',
#  'menggunakan',
#  'bilang',
#  'you',
#  'diantara',
#  'p',
#  'dikira',
#  'diperbuatnya',
#  'setelah',
#  'ngo',
#  'menjadi',
#  'halo',
#  'hadeeeeehhh',
#  'diperlihatkan',
#  'boleh',
#  'gmn',
#  'broo',
#  'lur',
#  'hari',
#  'asee',
#  'pihak',
#  'peeeeetttt',
#  'pukul',
#  'dipersoalkan',
#  'jikalau',
#  'menyeluruh',
#  'mm',
#  'ngk',
#  'wkwkwk',
#  'yth',
#  'asal',
#  'dpt',
#  'ntup',
#  'yng',
#  'semuanya',
#  'rrrrrr',
#  'tour',
#  'k',
#  'na',
#  'ade',
#  'hey',
#  'bukankah',
#  'jagan',
#  'kelima',
#  'ayyy',
#  'kepada',
#  'i',
#  'jumlah',
#  'ntr',
#  'dijelaskannya',
#  'ca',
#  'dipastikan',
#  'lat',
#  'stand',
#  'dst',
#  'merupakan',
#  'jadinya',
#  'gitulah',
#  'lai',
#  'memperkirakan',
#  'ttg',
#  'pertanyakan',
#  'kom',
#  'nuh',
#  'lum',
#  'naik',
#  'sudahkah',
#  'sekalipun',
#  'bapak',
#  'g',
#  'kagak',
#  'biasa',
#  'hendaknya',
#  'memulai',
#  'btw',
#  'ksp',
#  'tp',
#  'lahh',
#  'begitukah',
#  'saja',
#  'ajib',
#  'sedangkan',
#  'sec',
#  'memerlukan',
#  'wuuuu',
#  'wkwkw',
#  'yaah',
#  'ditunjukkan',
#  'rasanya',
#  'pek',
#  'deee',
#  'tdk',
#  'po',
#  'bun',
#  'apaansi',
#  'pasi',
#  'masih',
#  'se',
#  'uppppsss',
#  'mg',
#  'pen',
#  'iya',
#  'ela',
#  'da',
#  'peesai',
#  'pasti',
#  'jhiee',
#  'hhh',
#  'sebetulnya',
#  'xs',
#  'mbh',
#  'kesampaian',
#  'sekiranya',
#  'menuturkan',
#  'omg',
#  'djangan',
#  'sbuah',
#  'salam',
#  'rupanya',
#  'rit',
#  'disebutkan',
#  'asu',
#  'abc',
#  'gimana',
#  'ah',
#  'dimungkinkan',
#  'on',
#  'enak',
#  'aga',
#  'jelas',
#  'koe',
#  'practice',
#  'semata-mata',
#  'bukanya',
#  'keinginan',
#  'w',
#  'kami',
#  'byk',
#  'beh',
#  'cc',
#  'mks',
#  'haduh',
#  'de',
#  'ditunjukkannya',
#  'ju',
#  'berkali-kali',
#  'josss',
#  'aduch',
#  'su',
#  'atr',
#  'here',
#  'dikarenakan',
#  'what',
#  'ta',
#  'rj',
#  'dlu',
#  'diberikan',
#  'masing-masing',
#  'keluar',
#  'berawal',
#  'reply',
#  'ahhhh',
#  'beg',
#  'aplagi',
#  'jleb',
#  'bro',
#  'dehh',
#  'tadinya',
#  'tragedy',
#  'bermaksud',
#  'inikah',
#  'akubingin',
#  'min',
#  'kalaupun',
#  'menunjuk',
#  'mi',
#  'teh',
#  'var',
#  'wal',
#  'bukannya',
#  'para',
#  'dlm',
#  'kua',
#  'apabedanya',
#  'ser',
#  'lain',
#  'macam',
#  'like',
#  'seusai',
#  'demikian',
#  'nyaris',
#  'pihaknya',
#  'where',
#  'merasa',
#  'for',
#  'daripada',
#  'ben',
#  'ntu',
#  'will',
#  'woooy',
#  'nih',
#  'sekurang-kurangnya',
#  'km',
#  'dil',
#  'akulah',
#  'db',
#  'bersama-sama',
#  'mbok',
#  'ind',
#  'that',
#  'ggu',
#  'coy',
#  'tau',
#  'iyaa',
#  'laah',
#  'care',
#  'cuihhhh',
#  'nang',
#  'toet',
#  'seberapa',
#  'dalam',
#  'hallo',
#  'berapapun',
#  'sada',
#  'agar',
#  'bgini',
#  'benarkah',
#  'kemungkinannya',
#  'dirinya',
#  'mpe',
#  'hiikksss',
#  'ilah',
#  'langsung',
#  'artinya',
#  'khan',
#  'ok',
#  'sud',
#  'samlekum',
#  'enggaknya',
#  'keduanya',
#  'noh',
#  'aernye',
#  'ahhh',
#  'berlebihan',
#  'ani',
#  'sih',
#  'haaa',
#  'dia',
#  'jadilah',
#  'mampu',
#  'dengan',
#  'kinilah',
#  'mulailah',
#  'hadech',
#  'setengah',
#  'mas',
#  'vs',
#  'ojo',
#  'lihat',
#  'neeh',
#  'moh',
#  'ii',
#  'seluruh',
#  'haruslah',
#  'pl',
#  'mes',
#  'seenaknya',
#  'udahlah',
#  'bersiap',
#  'wuiiih',
#  'me',
#  'bur',
#  'jiah',
#  'jengn',
#  'tadi',
#  'mb',
#  'ehhh',
#  'are',
#  'kira-kira',
#  'selaku',
#  'sebelumnya',
#  'ini',
#  'kurang',
#  'keseluruhan',
#  'peel',
#  'kalau',
#  'waduh',
#  'selama',
#  'kwkwk',
#  'sangat',
#  'aig',
#  'his',
#  'lagi',
#  'boys',
#  'pol',
#  'bai',
#  'cara',
#  'death',
#  'du',
#  'yg',
#  'ialah',
#  'amat',
#  'mendatangi',
#  'sekarang',
#  'masuk',
#  'mantaaapp',
#  'gi',
#  'ber',
#  'he',
#  'malah',
#  'laahh',
#  'kalian',
#  'semampunya',
#  'ten',
#  'baiklah',
#  'tho',
#  'thread',
#  'berbagai',
#  'mendatangkan',
#  'bung',
#  'jo',
#  'bahkan',
#  'seng',
#  'tl',
#  'yo',
#  'aa',
#  'keleus',
#  'begitupun',
#  'an',
#  'horeee',
#  'begitulah',
#  'karepmu',
#  'masihkah',
#  'seterusnya',
#  'alu',
#  'ol',
#  'jangn',
#  'lohh',
#  'ma',
#  'un',
#  'akankh',
#  'saya',
#  'mere',
#  'pula',
#  'please',
#  'kudu',
#  'wow',
#  'bwt',
#  'tahu',
#  'disinilah',
#  'jab',
#  'gaesss',
#  'menyangkut',
#  'emng',
#  'tsb',
#  'ng',
#  'fl',
#  'ndy',
#  'free',
#  'jelasnya',
#  'saa',
#  'mai',
#  'dibuatnya',
#  'dipertanyakan',
#  'dg',
#  'padahal',
#  'dialah',
#  'sibuj',
#  'ss',
#  'sajalah',
#  'jngn',
#  'slrh',
#  'sesuatu',
#  'lanjutnya',
#  'menanyai',
#  'diakhiri',
#  'biarpun',
#  'sib',
#  'demi',
#  'always',
#  ...}

# %%
df_skripsi
# Out:
#                                              text_real  \
# 0    Ini bagus. Tapi ini kenapa pas udh enggak donw...
# 1    Aku boleh saran ngga? Tambahin juga fitur scre...
# 2    Suka spam telpon... Lebih bagus sekalian belaj...
# 3    So, when i was tried to open the app, then imm...
# 4    Sangat bagus,tapi saya mohon kepada devloper b...
# ..                                                 ...
# 195            Sangat bagus bisa belajar sambil nonton
# 196  Udah bagus tapi ada beberapa hal yang harus di...
# 197                                        Bagus bgttt
# 198  Keren banget dan sangat membantuðŸ‘ðŸ‘ðŸ‘ðŸ...
# 199                                             Okelah
#
#                                                   text     label  \
# 0    ini bagus tapi ini kenapa pas udh enggak donwl...  Negative
# 1    aku boleh saran ngga tambahin juga fitur scree...  Negative
# 2    suka spam telpon lebih bagus sekalian belajar ...  Negative
# 3    so when  was tried to open the app then immedi...  Negative
# 4    sangat bagustapi saya mohon kepada devloper bi...  Negative
# ..                                                 ...       ...
# 195            sangat bagus bisa belajar sambil nonton  Positive
# 196  udah bagus tapi ada beberapa hal yang harus di...  Positive
# 197                                          bagus bgt  Positive
# 198                   keren banget dan sangat membantu  Positive
# 199                                             okelah  Positive
#
#                                            text_tokens  \
# 0    [ini, bagus, tapi, ini, kenapa, pas, udh, engg...
# 1    [aku, boleh, saran, ngga, tambahin, juga, fitu...
# 2    [suka, spam, telpon, lebih, bagus, sekalian, b...
# 3    [so, when, was, tried, to, open, the, app, the...
# 4    [sangat, bagustapi, saya, mohon, kepada, devlo...
# ..                                                 ...
# 195     [sangat, bagus, bisa, belajar, sambil, nonton]
# 196  [udah, bagus, tapi, ada, beberapa, hal, yang, ...
# 197                                       [bagus, bgt]
# 198             [keren, banget, dan, sangat, membantu]
# 199                                           [okelah]
#
#                                        text_tokens_WSW
# 0                    [bagus, pas, udh, donwload, chat]
# 1    [saran, ngga, tambahin, fitur, screenshot, vid...
# 2         [suka, spam, telpon, bagus, belajar, colern]
# 3    [when, was, tried, open, app, then, immediatel...
# 4    [bagustapi, devloper, aplikasi, ruangguru, pak...
# ..                                                 ...
# 195                           [bagus, belajar, nonton]
# 196                              [bagus, ditingkatkan]
# 197                                            [bagus]
# 198                          [keren, banget, membantu]
# 199                                           [okelah]
#
# [194 rows x 5 columns]

# %%
def freqDist_wrapper(text):
    return FreqDist(text)

df_skripsi['text_tokens_fdist'] = df_skripsi['text_tokens'].apply(freqDist_wrapper)

print('Frequency Tokens : \n') 
print(df_skripsi['text_tokens_fdist'].head().apply(lambda x : x.most_common()))
# Out:
# Frequency Tokens :
#
# 0    [(ini, 2), (bagus, 1), (tapi, 1), (kenapa, 1),...
# 1    [(ngga, 2), (fitur, 2), (aku, 1), (boleh, 1), ...
# 2    [(suka, 1), (spam, 1), (telpon, 1), (lebih, 1)...
# 3    [(the, 3), (so, 2), (when, 2), (is, 2), (was, ...
# 4    [(saya, 2), (tidak, 2), (indonesia, 2), (sanga...
# Name: text_tokens_fdist, dtype: object

# %%
df_skripsi['text_tokens_fdist'] = df_skripsi['text'].apply(freqDist_wrapper)

# %%
df_skripsi
# Out:
#                                              text_real  \
# 0    Ini bagus. Tapi ini kenapa pas udh enggak donw...
# 1    Aku boleh saran ngga? Tambahin juga fitur scre...
# 2    Suka spam telpon... Lebih bagus sekalian belaj...
# 3    So, when i was tried to open the app, then imm...
# 4    Sangat bagus,tapi saya mohon kepada devloper b...
# ..                                                 ...
# 195            Sangat bagus bisa belajar sambil nonton
# 196  Udah bagus tapi ada beberapa hal yang harus di...
# 197                                        Bagus bgttt
# 198  Keren banget dan sangat membantuðŸ‘ðŸ‘ðŸ‘ðŸ...
# 199                                             Okelah
#
#                                                   text     label  \
# 0    ini bagus tapi ini kenapa pas udh enggak donwl...  Negative
# 1    aku boleh saran ngga tambahin juga fitur scree...  Negative
# 2    suka spam telpon lebih bagus sekalian belajar ...  Negative
# 3    so when  was tried to open the app then immedi...  Negative
# 4    sangat bagustapi saya mohon kepada devloper bi...  Negative
# ..                                                 ...       ...
# 195            sangat bagus bisa belajar sambil nonton  Positive
# 196  udah bagus tapi ada beberapa hal yang harus di...  Positive
# 197                                          bagus bgt  Positive
# 198                   keren banget dan sangat membantu  Positive
# 199                                             okelah  Positive
#
#                                            text_tokens  \
# 0    [ini, bagus, tapi, ini, kenapa, pas, udh, engg...
# 1    [aku, boleh, saran, ngga, tambahin, juga, fitu...
# 2    [suka, spam, telpon, lebih, bagus, sekalian, b...
# 3    [so, when, was, tried, to, open, the, app, the...
# 4    [sangat, bagustapi, saya, mohon, kepada, devlo...
# ..                                                 ...
# 195     [sangat, bagus, bisa, belajar, sambil, nonton]
# 196  [udah, bagus, tapi, ada, beberapa, hal, yang, ...
# 197                                       [bagus, bgt]
# 198             [keren, banget, dan, sangat, membantu]
# 199                                           [okelah]
#
#                                        text_tokens_WSW  \
# 0                    [bagus, pas, udh, donwload, chat]
# 1    [saran, ngga, tambahin, fitur, screenshot, vid...
# 2         [suka, spam, telpon, bagus, belajar, colern]
# 3    [when, was, tried, open, app, then, immediatel...
# 4    [bagustapi, devloper, aplikasi, ruangguru, pak...
# ..                                                 ...
# 195                           [bagus, belajar, nonton]
# 196                              [bagus, ditingkatkan]
# 197                                            [bagus]
# 198                          [keren, banget, membantu]
# 199                                           [okelah]
#
#                                      text_tokens_fdist
# 0    {'i': 6, 'n': 5, ' ': 12, 'b': 1, 'a': 10, 'g'...
# 1    {'a': 39, 'k': 13, 'u': 18, ' ': 39, 'b': 6, '...
# 2    {'s': 4, 'u': 2, 'k': 2, 'a': 7, ' ': 8, 'p': ...
# 3    {'s': 7, 'o': 10, ' ': 33, 'w': 4, 'h': 8, 'e'...
# 4    {'s': 13, 'a': 41, 'n': 20, 'g': 7, 't': 8, ' ...
# ..                                                 ...
# 195  {'s': 4, 'a': 7, 'n': 4, 'g': 2, 't': 2, ' ': ...
# 196  {'u': 3, 'd': 3, 'a': 13, 'h': 3, ' ': 9, 'b':...
# 197  {'b': 2, 'a': 1, 'g': 2, 'u': 1, 's': 1, ' ': ...
# 198  {'k': 1, 'e': 4, 'r': 1, 'n': 5, ' ': 4, 'b': ...
# 199   {'o': 1, 'k': 1, 'e': 1, 'l': 1, 'a': 1, 'h': 1}
#
# [194 rows x 6 columns]

# %%
from nltk.corpus import stopwords

# %%
list_stopwords = stopwords.words('indonesian')

# %%
list_stopwords
# Out:
# ['ada',
#  'adalah',
#  'adanya',
#  'adapun',
#  'agak',
#  'agaknya',
#  'agar',
#  'akan',
#  'akankah',
#  'akhir',
#  'akhiri',
#  'akhirnya',
#  'aku',
#  'akulah',
#  'amat',
#  'amatlah',
#  'anda',
#  'andalah',
#  'antar',
#  'antara',
#  'antaranya',
#  'apa',
#  'apaan',
#  'apabila',
#  'apakah',
#  'apalagi',
#  'apatah',
#  'artinya',
#  'asal',
#  'asalkan',
#  'atas',
#  'atau',
#  'ataukah',
#  'ataupun',
#  'awal',
#  'awalnya',
#  'bagai',
#  'bagaikan',
#  'bagaimana',
#  'bagaimanakah',
#  'bagaimanapun',
#  'bagi',
#  'bagian',
#  'bahkan',
#  'bahwa',
#  'bahwasanya',
#  'baik',
#  'bakal',
#  'bakalan',
#  'balik',
#  'banyak',
#  'bapak',
#  'baru',
#  'bawah',
#  'beberapa',
#  'begini',
#  'beginian',
#  'beginikah',
#  'beginilah',
#  'begitu',
#  'begitukah',
#  'begitulah',
#  'begitupun',
#  'bekerja',
#  'belakang',
#  'belakangan',
#  'belum',
#  'belumlah',
#  'benar',
#  'benarkah',
#  'benarlah',
#  'berada',
#  'berakhir',
#  'berakhirlah',
#  'berakhirnya',
#  'berapa',
#  'berapakah',
#  'berapalah',
#  'berapapun',
#  'berarti',
#  'berawal',
#  'berbagai',
#  'berdatangan',
#  'beri',
#  'berikan',
#  'berikut',
#  'berikutnya',
#  'berjumlah',
#  'berkali-kali',
#  'berkata',
#  'berkehendak',
#  'berkeinginan',
#  'berkenaan',
#  'berlainan',
#  'berlalu',
#  'berlangsung',
#  'berlebihan',
#  'bermacam',
#  'bermacam-macam',
#  'bermaksud',
#  'bermula',
#  'bersama',
#  'bersama-sama',
#  'bersiap',
#  'bersiap-siap',
#  'bertanya',
#  'bertanya-tanya',
#  'berturut',
#  'berturut-turut',
#  'bertutur',
#  'berujar',
#  'berupa',
#  'besar',
#  'betul',
#  'betulkah',
#  'biasa',
#  'biasanya',
#  'bila',
#  'bilakah',
#  'bisa',
#  'bisakah',
#  'boleh',
#  'bolehkah',
#  'bolehlah',
#  'buat',
#  'bukan',
#  'bukankah',
#  'bukanlah',
#  'bukannya',
#  'bulan',
#  'bung',
#  'cara',
#  'caranya',
#  'cukup',
#  'cukupkah',
#  'cukuplah',
#  'cuma',
#  'dahulu',
#  'dalam',
#  'dan',
#  'dapat',
#  'dari',
#  'daripada',
#  'datang',
#  'dekat',
#  'demi',
#  'demikian',
#  'demikianlah',
#  'dengan',
#  'depan',
#  'di',
#  'dia',
#  'diakhiri',
#  'diakhirinya',
#  'dialah',
#  'diantara',
#  'diantaranya',
#  'diberi',
#  'diberikan',
#  'diberikannya',
#  'dibuat',
#  'dibuatnya',
#  'didapat',
#  'didatangkan',
#  'digunakan',
#  'diibaratkan',
#  'diibaratkannya',
#  'diingat',
#  'diingatkan',
#  'diinginkan',
#  'dijawab',
#  'dijelaskan',
#  'dijelaskannya',
#  'dikarenakan',
#  'dikatakan',
#  'dikatakannya',
#  'dikerjakan',
#  'diketahui',
#  'diketahuinya',
#  'dikira',
#  'dilakukan',
#  'dilalui',
#  'dilihat',
#  'dimaksud',
#  'dimaksudkan',
#  'dimaksudkannya',
#  'dimaksudnya',
#  'diminta',
#  'dimintai',
#  'dimisalkan',
#  'dimulai',
#  'dimulailah',
#  'dimulainya',
#  'dimungkinkan',
#  'dini',
#  'dipastikan',
#  'diperbuat',
#  'diperbuatnya',
#  'dipergunakan',
#  'diperkirakan',
#  'diperlihatkan',
#  'diperlukan',
#  'diperlukannya',
#  'dipersoalkan',
#  'dipertanyakan',
#  'dipunyai',
#  'diri',
#  'dirinya',
#  'disampaikan',
#  'disebut',
#  'disebutkan',
#  'disebutkannya',
#  'disini',
#  'disinilah',
#  'ditambahkan',
#  'ditandaskan',
#  'ditanya',
#  'ditanyai',
#  'ditanyakan',
#  'ditegaskan',
#  'ditujukan',
#  'ditunjuk',
#  'ditunjuki',
#  'ditunjukkan',
#  'ditunjukkannya',
#  'ditunjuknya',
#  'dituturkan',
#  'dituturkannya',
#  'diucapkan',
#  'diucapkannya',
#  'diungkapkan',
#  'dong',
#  'dua',
#  'dulu',
#  'empat',
#  'enggak',
#  'enggaknya',
#  'entah',
#  'entahlah',
#  'guna',
#  'gunakan',
#  'hal',
#  'hampir',
#  'hanya',
#  'hanyalah',
#  'hari',
#  'harus',
#  'haruslah',
#  'harusnya',
#  'hendak',
#  'hendaklah',
#  'hendaknya',
#  'hingga',
#  'ia',
#  'ialah',
#  'ibarat',
#  'ibaratkan',
#  'ibaratnya',
#  'ibu',
#  'ikut',
#  'ingat',
#  'ingat-ingat',
#  'ingin',
#  'inginkah',
#  'inginkan',
#  'ini',
#  'inikah',
#  'inilah',
#  'itu',
#  'itukah',
#  'itulah',
#  'jadi',
#  'jadilah',
#  'jadinya',
#  'jangan',
#  'jangankan',
#  'janganlah',
#  'jauh',
#  'jawab',
#  'jawaban',
#  'jawabnya',
#  'jelas',
#  'jelaskan',
#  'jelaslah',
#  'jelasnya',
#  'jika',
#  'jikalau',
#  'juga',
#  'jumlah',
#  'jumlahnya',
#  'justru',
#  'kala',
#  'kalau',
#  'kalaulah',
#  'kalaupun',
#  'kalian',
#  'kami',
#  'kamilah',
#  'kamu',
#  'kamulah',
#  'kan',
#  'kapan',
#  'kapankah',
#  'kapanpun',
#  'karena',
#  'karenanya',
#  'kasus',
#  'kata',
#  'katakan',
#  'katakanlah',
#  'katanya',
#  'ke',
#  'keadaan',
#  'kebetulan',
#  'kecil',
#  'kedua',
#  'keduanya',
#  'keinginan',
#  'kelamaan',
#  'kelihatan',
#  'kelihatannya',
#  'kelima',
#  'keluar',
#  'kembali',
#  'kemudian',
#  'kemungkinan',
#  'kemungkinannya',
#  'kenapa',
#  'kepada',
#  'kepadanya',
#  'kesampaian',
#  'keseluruhan',
#  'keseluruhannya',
#  'keterlaluan',
#  'ketika',
#  'khususnya',
#  'kini',
#  'kinilah',
#  'kira',
#  'kira-kira',
#  'kiranya',
#  'kita',
#  'kitalah',
#  'kok',
#  'kurang',
#  'lagi',
#  'lagian',
#  'lah',
#  'lain',
#  'lainnya',
#  'lalu',
#  'lama',
#  'lamanya',
#  'lanjut',
#  'lanjutnya',
#  'lebih',
#  'lewat',
#  'lima',
#  'luar',
#  'macam',
#  'maka',
#  'makanya',
#  'makin',
#  'malah',
#  'malahan',
#  'mampu',
#  'mampukah',
#  'mana',
#  'manakala',
#  'manalagi',
#  'masa',
#  'masalah',
#  'masalahnya',
#  'masih',
#  'masihkah',
#  'masing',
#  'masing-masing',
#  'mau',
#  'maupun',
#  'melainkan',
#  'melakukan',
#  'melalui',
#  'melihat',
#  'melihatnya',
#  'memang',
#  'memastikan',
#  'memberi',
#  'memberikan',
#  'membuat',
#  'memerlukan',
#  'memihak',
#  'meminta',
#  'memintakan',
#  'memisalkan',
#  'memperbuat',
#  'mempergunakan',
#  'memperkirakan',
#  'memperlihatkan',
#  'mempersiapkan',
#  'mempersoalkan',
#  'mempertanyakan',
#  'mempunyai',
#  'memulai',
#  'memungkinkan',
#  'menaiki',
#  'menambahkan',
#  'menandaskan',
#  'menanti',
#  'menanti-nanti',
#  'menantikan',
#  'menanya',
#  'menanyai',
#  'menanyakan',
#  'mendapat',
#  'mendapatkan',
#  'mendatang',
#  'mendatangi',
#  'mendatangkan',
#  'menegaskan',
#  'mengakhiri',
#  'mengapa',
#  'mengatakan',
#  'mengatakannya',
#  'mengenai',
#  'mengerjakan',
#  'mengetahui',
#  'menggunakan',
#  'menghendaki',
#  'mengibaratkan',
#  'mengibaratkannya',
#  'mengingat',
#  'mengingatkan',
#  'menginginkan',
#  'mengira',
#  'mengucapkan',
#  'mengucapkannya',
#  'mengungkapkan',
#  'menjadi',
#  'menjawab',
#  'menjelaskan',
#  'menuju',
#  'menunjuk',
#  'menunjuki',
#  'menunjukkan',
#  'menunjuknya',
#  'menurut',
#  'menuturkan',
#  'menyampaikan',
#  'menyangkut',
#  'menyatakan',
#  'menyebutkan',
#  'menyeluruh',
#  'menyiapkan',
#  'merasa',
#  'mereka',
#  'merekalah',
#  'merupakan',
#  'meski',
#  'meskipun',
#  'meyakini',
#  'meyakinkan',
#  'minta',
#  'mirip',
#  'misal',
#  'misalkan',
#  'misalnya',
#  'mula',
#  'mulai',
#  'mulailah',
#  'mulanya',
#  'mungkin',
#  'mungkinkah',
#  'nah',
#  'naik',
#  'namun',
#  'nanti',
#  'nantinya',
#  'nyaris',
#  'nyatanya',
#  'oleh',
#  'olehnya',
#  'pada',
#  'padahal',
#  'padanya',
#  'pak',
#  'paling',
#  'panjang',
#  'pantas',
#  'para',
#  'pasti',
#  'pastilah',
#  'penting',
#  'pentingnya',
#  'per',
#  'percuma',
#  'perlu',
#  'perlukah',
#  'perlunya',
#  'pernah',
#  'persoalan',
#  'pertama',
#  'pertama-tama',
#  'pertanyaan',
#  'pertanyakan',
#  'pihak',
#  'pihaknya',
#  'pukul',
#  'pula',
#  'pun',
#  'punya',
#  'rasa',
#  'rasanya',
#  'rata',
#  'rupanya',
#  'saat',
#  'saatnya',
#  'saja',
#  'sajalah',
#  'saling',
#  'sama',
#  'sama-sama',
#  'sambil',
#  'sampai',
#  'sampai-sampai',
#  'sampaikan',
#  'sana',
#  'sangat',
#  'sangatlah',
#  'satu',
#  'saya',
#  'sayalah',
#  'se',
#  'sebab',
#  'sebabnya',
#  'sebagai',
#  'sebagaimana',
#  'sebagainya',
#  'sebagian',
#  'sebaik',
#  'sebaik-baiknya',
#  'sebaiknya',
#  'sebaliknya',
#  'sebanyak',
#  'sebegini',
#  'sebegitu',
#  'sebelum',
#  'sebelumnya',
#  'sebenarnya',
#  'seberapa',
#  'sebesar',
#  'sebetulnya',
#  'sebisanya',
#  'sebuah',
#  'sebut',
#  'sebutlah',
#  'sebutnya',
#  'secara',
#  'secukupnya',
#  'sedang',
#  'sedangkan',
#  'sedemikian',
#  'sedikit',
#  'sedikitnya',
#  'seenaknya',
#  'segala',
#  'segalanya',
#  'segera',
#  'seharusnya',
#  'sehingga',
#  'seingat',
#  'sejak',
#  'sejauh',
#  'sejenak',
#  'sejumlah',
#  'sekadar',
#  'sekadarnya',
#  'sekali',
#  'sekali-kali',
#  'sekalian',
#  'sekaligus',
#  'sekalipun',
#  'sekarang',
#  'sekarang',
#  'sekecil',
#  'seketika',
#  'sekiranya',
#  'sekitar',
#  'sekitarnya',
#  'sekurang-kurangnya',
#  'sekurangnya',
#  'sela',
#  'selain',
#  'selaku',
#  'selalu',
#  'selama',
#  'selama-lamanya',
#  'selamanya',
#  'selanjutnya',
#  'seluruh',
#  'seluruhnya',
#  'semacam',
#  'semakin',
#  'semampu',
#  'semampunya',
#  'semasa',
#  'semasih',
#  'semata',
#  'semata-mata',
#  'semaunya',
#  'sementara',
#  'semisal',
#  'semisalnya',
#  'sempat',
#  'semua',
#  'semuanya',
#  'semula',
#  'sendiri',
#  'sendirian',
#  'sendirinya',
#  'seolah',
#  'seolah-olah',
#  'seorang',
#  'sepanjang',
#  'sepantasnya',
#  'sepantasnyalah',
#  'seperlunya',
#  'seperti',
#  'sepertinya',
#  'sepihak',
#  'sering',
#  'seringnya',
#  'serta',
#  'serupa',
#  'sesaat',
#  'sesama',
#  'sesampai',
#  'sesegera',
#  'sesekali',
#  'seseorang',
#  'sesuatu',
#  'sesuatunya',
#  'sesudah',
#  'sesudahnya',
#  'setelah',
#  'setempat',
#  'setengah',
#  'seterusnya',
#  'setiap',
#  'setiba',
#  'setibanya',
#  'setidak-tidaknya',
#  'setidaknya',
#  'setinggi',
#  'seusai',
#  'sewaktu',
#  'siap',
#  'siapa',
#  'siapakah',
#  'siapapun',
#  'sini',
#  'sinilah',
#  'soal',
#  'soalnya',
#  'suatu',
#  'sudah',
#  'sudahkah',
#  'sudahlah',
#  'supaya',
#  'tadi',
#  'tadinya',
#  'tahu',
#  'tahun',
#  'tak',
#  'tambah',
#  'tambahnya',
#  'tampak',
#  'tampaknya',
#  'tandas',
#  'tandasnya',
#  'tanpa',
#  'tanya',
#  'tanyakan',
#  'tanyanya',
#  'tapi',
#  'tegas',
#  'tegasnya',
#  'telah',
#  'tempat',
#  'tengah',
#  'tentang',
#  'tentu',
#  'tentulah',
#  'tentunya',
#  'tepat',
#  'terakhir',
#  'terasa',
#  'terbanyak',
#  'terdahulu',
#  'terdapat',
#  'terdiri',
#  'terhadap',
#  'terhadapnya',
#  'teringat',
#  'teringat-ingat',
#  'terjadi',
#  'terjadilah',
#  'terjadinya',
#  'terkira',
#  'terlalu',
#  'terlebih',
#  'terlihat',
#  'termasuk',
#  'ternyata',
#  'tersampaikan',
#  'tersebut',
#  'tersebutlah',
#  'tertentu',
#  'tertuju',
#  'terus',
#  'terutama',
#  'tetap',
#  'tetapi',
#  'tiap',
#  'tiba',
#  'tiba-tiba',
#  'tidak',
#  'tidakkah',
#  'tidaklah',
#  'tiga',
#  'tinggi',
#  'toh',
#  'tunjuk',
#  'turut',
#  'tutur',
#  'tuturnya',
#  'ucap',
#  'ucapnya',
#  'ujar',
#  'ujarnya',
#  'umum',
#  'umumnya',
#  'ungkap',
#  'ungkapnya',
#  'untuk',
#  'usah',
#  'usai',
#  'waduh',
#  'wah',
#  'wahai',
#  'waktu',
#  'waktunya',
#  'walau',
#  'walaupun',
#  'wong',
#  'yaitu',
#  'yakin',
#  'yakni',
#  'yang']

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier

clf =  RandomForestClassifier(random_state=0, max_features ='sqrt',max_depth = 100)
knn = KNeighborsClassifier(n_neighbors=7)
nb = GaussianNB()
dt = DecisionTreeClassifier(max_features ='sqrt',max_depth = 100)
svm = SVC(degree=3)
# clf.fit(X, y)

# %%
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

normalizad_word = pd.read_csv("colloquial-indonesian-lexicon.csv")

normalizad_word_dict = {}

for index, row in normalizad_word.iterrows():
    if row[0] not in normalizad_word_dict:
        normalizad_word_dict[row[0]] = row[1] 

def normalized_term(document):
    return [normalizad_word_dict[term] if term in normalizad_word_dict else term for term in document]

df_skripsi['text_normalized'] = df_skripsi['text_tokens_WSW'].apply(normalized_term)


# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in df_skripsi['text_normalized']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")


# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]

df_skripsi['text_tokens_stemmed'] = df_skripsi['text_normalized'].swifter.apply(get_stemmed_term)
# Out:
# 687
# ------------------------
# bagus : bagus
# pas : pas
# sudah : sudah
# donwload : donwload
# chat : chat
# saran : saran
# enggak : enggak
# tambahkan : tambah
# fitur : fitur
# screenshot : screenshot
# video : video
# adaptif : adaptif
# pendalaman : dalam
# materi : materi
# kadang : kadang
# sempat : sempat
# nyatet : nyatet
# adventure : adventure
# terima kasih : terima kasih
# banget : banget
# membantu : bantu
# naikin : naikin
# mood : mood
# belajarku : ajar
# sekian : sekian
# hatur : hatur
# nuhun : nuhun
# kakakkakak : kakakkakak
# ruangguru : ruangguru
# suka : suka
# spam : spam
# telpon : telpon
# belajar : ajar
# colern : colern
# when : when
# was : was
# tried : tried
# open : open
# app : app
# then : then
# immediately : immediately
# log : log
# out : out
# automatically : automatically
# resize : resize
# screen : screen
# big : big
# picture : picture
# wobbly : wobbly
# hope : hope
# got : got
# fixed : fixed
# bagustapi : bagustapi
# devloper : devloper
# aplikasi : aplikasi
# paket : paket
# premium : premium
# kepintaran : pintar
# siswa : siswa
# indonesia : indonesia
# bicarakan : bicara
# terima : terima
# kasih : kasih
# pahamify : pahamify
# tukang : tukang
# teror : teror
# nomor : nomor
# ganti : ganti
# elekk : elekk
# burik : burik
# jelek : jelek
# roboguru : roboguru
# chrome : chrome
# website : website
# install : install
# keberatan : berat
# menginstall : menginstall
# mengurangi : kurang
# membutuhkan : butuh
# simple : simple
# ribet : ribet
# tinggal : tinggal
# dowoad : dowoad
# maaf : maaf
# kota : kota
# kualitas : kualitas
# jaringan : jaring
# terbaik : baik
# didesa : desa
# memprihatinkan : prihatin
# kok : kok
# vidionya : vidionya
# bisa : bisa
# putar : putar
# gmnaa : gmnaa
# macan : macan
# sembuhsembuh : sembuhsembuh
# jam : jam
# sembuh : sembuh
# 24jam : 24jam
# download : download
# galeri : galeri
# urut : urut
# aplikasinya : aplikasi
# eror : eror
# pelajar : ajar
# 1 : 1
# hewan : hewan
# peliharaan : pelihara
# teman : teman
# terganggu : ganggu
# aktivitasnya : aktivitas
# khawatir : khawatir
# produktif : produktif
# belajarnya : ajar
# kea : kea
# terpaksa : paksa
# sehatin : sehatin
# peliharaannya : pelihara
# pahami : paham
# apk : apk
# lapet : lapet
# ruanggurunya : ruanggurunya
# ngesthag : ngesthag
# masak : masak
# habis : habis
# lock : lock
# mencari : cari
# ilmu : ilmu
# drill : drill
# macet : macet
# mwehehehehe : mwehehehehe
# downlod : downlod
# bantuannya : bantu
# nama : nama
# jamiah : jamiah
# pet : pet
# menghitung : hitung
# pembelajaran : ajar
# imbasnya : imbas
# berfungsi : fungsi
# tolong : tolong
# memperbaiki : baik
# layar : layar
# utama : utama
# perbaiki : baik
# bugnya : bugnya
# lanjutkan : lanjut
# senang : senang
# adapto : adapto
# pengisi : isi
# suara : suara
# cepatsusah : cepatsusah
# dengarya : dengarya
# kecepatan : cepat
# videodan : videodan
# subtitle : subtitle
# jelasmata : jelasmata
# pelajaran : ajar
# ipatapi : ipatapi
# pakai : pakai
# ruang : ruang
# guru : guru
# pliss : pliss
# bug : bug
# benerin : benerin
# semangat : semangat
# suvenir : suvenir
# tirmidzi : tirmidzi
# dishahihkan : dishahihkan
# bersalah : salah
# kerana : rana
# allah : allah
# swt : swt
# menunggu : tunggu
# kehilangan : hilang
# kau : kau
# minat : minat
# silakan : sila
# merapat : rapat
# menberikan : menberikan
# dukungan : dukung
# relawan : rawan
# ahy : ahy
# familia : familia
# scarabaeidae : scarabaeidae
# ngerjain : ngerjain
# kuis : kuis
# menonton : tonton
# perjelasan : jelas
# tibatiba : tibatiba
# ngelag : ngelag
# ngulang : ngulang
# ulang : ulang
# sampai : sampai
# apkperbaiki : apkperbaiki
# hp : hp
# selesai : selesai
# 0 : 0
# tonton : tonton
# data : data
# loading : loading
# vidio : vidio
# lemot : lot
# penanganan : tangan
# komplen : komplen
# buruk : buruk
# beli : beli
# tematik : tematik
# kelas : kelas
# 3 : 3
# kurikulum : kurikulum
# sesuai : sesuai
# belum : belum
# diperbaiki : baik
# mengajukan : aju
# profesional : profesional
# bgtsering : bgtsering
# neror : neror
# anjir : anjir
# game : game
# android : android
# sedunia : dunia
# minimal : minimal
# trial : trial
# pengajaran : ajar
# mengakses : akses
# ruangbelajar : ruangbelajar
# selalu : selalu
# gagal : gagal
# memuat : muat
# padahal : padahal
# penjelasan : jelas
# angka : angka
# mapel : mapel
# mtk : mtk
# fisika : fisika
# zenius : zenius
# bagiku : bagi
# salesnya : salesnya
# ajar : ajar
# promosinya : promosi
# ngancam : ngancam
# nyebarin : nyebarin
# pribadi : pribadi
# curiga : curiga
# tindakan : tindak
# ilegal : ilegal
# melanggar : langgar
# privasi : privasi
# penggunanya : guna
# caracara : caracara
# cerdas : cerdas
# sopan : sopan
# beretika : etika
# menjual : jual
# produkproduknya : produkproduknya
# mengecualikan : kecuali
# jasa : jasa
# bidang : bidang
# berhubungan : hubung
# pendidikan : didik
# caracaranya : caracaranya
# latar : latar
# pendidikannya : didik
# nipu : nipu
# dijanjiin : dijanjiin
# konsultanyabaca : konsultanyabaca
# sales : sales
# cashback : cashback
# 200k : 200k
# dikirimnya : kirim
# 50k : 50k
# komplain : komplain
# alasanya : alasanya
# dapat : dapat
# perpanjang : panjang
# konsultanya : konsultanya
# jelasjelas : jelasjelas
# janjiin : janjiin
# menyebutkan : sebut
# ujungujungnya : ujungujungnya
# lepas : lepas
# tangan : tangan
# sebenarnya : benar
# pengin : pengin
# deal : deal
# korbannya : korban
# promo : promo
# akal : akal
# komisi : komisi
# hilang : hilang
# terbantu : bantu
# tolonglah : tolong
# nonoton : nonoton
# lamalama : lamalama
# tengok : tengok
# videonya : video
# ditonton : tonton
# keluhan : keluh
# developernya : developer
# hahay : hahay
# uhuy : uhuy
# karena : karena
# gua : gua
# sibuk : sibuk
# promosi : promosi
# sekolah : sekolah
# ternganggu : ternganggu
# percaya : percaya
# klinik : klinik
# akses : akses
# goblog : goblog
# google : google
# sesad : sad
# semua : semua
# enggak ada : enggak ada
# benar : benar
# nilai : nilai
# tuntas : tuntas
# aku : aku
# bntg : bntg
# admin : admin
# kakak : kakak
# ngechat : ngechat
# terus : terus
# blok : blok
# risih : risih
# berlangganan : langgan
# mempromosikan : promosi
# program : program
# tua : tua
# terusmenerus : terusmenerus
# sembarang : sembarang
# menganggu : menganggu
# xpnya : xpnya
# bertambah : tambah
# salah : salah
# 2 : 2
# malas : malas
# ujian : uji
# suruh : suruh
# hape : hape
# memangnya : memang
# kuota : kuota
# telfon : telfon
# mengganggu : ganggu
# takut : takut
# nomer : nomer
# kenal : kenal
# penjahat : jahat
# nelfon : nelfon
# hapus : hapus
# apknya : apknya
# indak : indak
# smk : smk
# beranda : beranda
# lag : lag
# sulit : sulit
# scroll : scroll
# error : error
# internet : internet
# lancar : lancar
# xp : xp
# mencapai : capai
# ratusan : ratus
# terkecoh : kecoh
# menipu : tipu
# gratis : gratis
# bayar : bayar
# 700k : 700k
# 1juta : 1juta
# apa : apa
# kepencet : pencet
# super : super
# lainya : lai
# daftar : daftar
# kuliah : kuliah
# tawaran : tawar
# perpanjangan : panjang
# plis : plis
# 10 : 10
# 15 : 15
# berbayar : bayar
# 1mmebingungkan : 1mmebingungkan
# sayang : sayang
# lihat : lihat
# rangkuman : rangkum
# bolak : bolak
# acak : acak
# acakan : acak
# kesel : kesel
# juara : juara
# 5 : 5
# enam : enam
# kurangi : kurang
# bintangnya : bintang
# ruanguru : ruanguru
# dikasih : kasih
# 1bab : 1bab
# level : level
# 37 : 37
# turun : turun
# 8 : 8
# kenpa : kenpa
# robo : robo
# anjng : anjng
# meresahkan : resah
# tulisannya : tulis
# terhubung : hubung
# padhal : padhal
# youtube : youtube
# instagram : instagram
# tapi : tapi
# koneksinya : koneksi
# sinyal : sinyal
# full : full
# kenapa : kenapa
# dibuka : buka
# life : life
# memang : memang
# mantap : mantap
# pembahasan : bahas
# mengerti : erti
# kadang2 : kadang2
# intinya : inti
# puyeng : puyeng
# sekolahtapi : sekolahtapi
# kayak : kayak
# paham : paham
# doang : doang
# pusing2 : pusing2
# trimakasih : trimakasih
# pengajar : ajar
# ilmunya : ilmu
# hebat : hebat
# langganannya : langgan
# susah : susah
# diterima : terima
# 4 : 4
# bintang : bintang
# seru : seru
# dpat : dpat
# memahami : paham
# disekolah : seko
# cepat : cepat
# enggak jelas : enggak jelas
# mati : mati
# hidup : hidup
# mending : mending
# dipakai : pakai
# dina : dina
# santa : santa
# maria : maria
# tanggal : tanggal
# 23 : 23
# september : september
# 2022 : 2022
# kepala : kepala
# sakit : sakit
# atur : atur
# iklannya : iklan
# lumayan : lumayan
# hujat : hujat
# ramah : ramah
# pjok : pjok
# minggu : minggu
# belajarutbk : belajarutbk
# enggak bisa : enggak bisa
# dipakek : dipakek
# ditanyain : ditanyain
# consultant : consultant
# direspon : direspon
# sumpah : sumpah
# kecewa : kecewa
# diganggu : ganggu
# consultan : consultan
# menawari : tawar
# kedepannya : depan
# memaksakan : paksa
# iklan : iklan
# ditelpon : telpon
# makanya : makanya
# saya : saya
# jalan : jalan
# angkat : angkat
# kecelakaan : celaka
# dichat : dichat
# tim : tim
# didalam : dalam
# puas : puas
# sistem : sistem
# pengiklanan : iklan
# melewat : lewat
# email : email
# menurutku : turut
# dinamai : nama
# 2020 : 2020
# pesan : pesan
# dijumlahkan : jumlah
# 50 : 50
# mengirim : kirim
# memaksa : paksa
# semoga : moga
# ditindak : tindak
# lanjuti : lanjut
# pengiriman : kirim
# fakta : fakta
# pakem : pakem
# belian : belian
# mulu : mulu
# mambuat : mambuat
# asalnya : asal
# segi : segi
# uinya : uinya
# membesarkan : besar
# gambar : gambar
# gambarnya : gambar
# gerak : gerak
# gila : gila
# keren : keren
# olahraga : olahraga
# ini : ini
# buka : buka
# layarnya : layar
# berubah : ubah
# item : item
# pencet : pencet
# subbab : subbab
# belajaarr : belajaarr
# didownload : didownload
# tetap : tetap
# connect : connect
# ngeplay : ngeplay
# habistu : habistu
# downloadnya : downloadnya
# 100 : 100
# jaringannya : jaring
# penyimpanan : simpan
# apl : apl
# stabil : stabil
# wah : wah
# bermanfaat : manfaat
# leg : leg
# berterima : terima
# staffnya : staffnya
# stop : stop
# sembarangan : sembarang
# mengasih : asih
# pengumuman : umum
# appnya : appnya
# puluhan : puluh
# akun : akun
# ngegangu : ngegangu
# nelpon : nelpon
# aktivitas : aktivitas
# seharihari : seharihari
# bisabisa : bisabisa
# tertarik : tarik
# pekerjanya : kerja
# hi : hi
# mutar : mutar
# alasannya : alas
# wifi : wifi
# dirumah : rumah
# rugi : rugi
# offline : offline
# kujuruannyya : kujuruannyya
# mana : mana
# dasar : dasar
# apa-apa : apa
# rugikan : rugi
# sayangnya : sayang
# bitrate : bitrate
# besarkanterkadang : besarkanterkadang
# blur : blur
# loadingnya : loadingnya
# ganggu : ganggu
# proses : proses
# pulang : pulang
# ruanggurur : ruanggurur
# bab : bab
# merdeka : merdeka
# xxldcudd : xxldcudd
# 2dxm : 2dxm
# xmx : xmx
# zx : zx
# cewek : cewek
# dijelasin : dijelasin
# nice : nice
# membantuu : membantuu
# gratisnyaa : gratisnyaa
# sangatt : sangatt
# mudah : mudah
# superb : superb
# bangus : bangus
# ditingkatkan : tingkat
# gurunya : guru
# anak : anak
# pintar : pintar
# mengajar : ajar
# pelajarannya : ajar
# simpel : simpel
# baguz : baguz
# penjelasannya : jelas
# detail : detail
# animasi : animasi
# bersemangat : semangat
# huru : huru
# bguss : bguss
# memudahkan : mudah
# okeh : okeh
# dipahami : paham
# rinci : rinci
# menarik : tarik
# kemudahan : mudah
# penyampaian : sampai
# bimbingan : bimbing
# sgat : sgat
# metode : metode
# bagusd : bagusd
# beanfaat : beanfaat
# beranimasi : animasi
# poll : poll
# pokoke : pokoke
# maju : maju
# belajarjadi : belajarjadi
# berkat : berkat
# uts : uts
# pls : pls
# lagi : lagi
# lengkap : lengkap
# memuaskan : muas
# camaba : camaba
# okelah : oke
# ranking : ranking
# berturutturut : berturutturut
# bareng : bareng
# iq : iq
# apikasi : apikasi
# kemrenn : kemrenn
# bang : bang
# lope : lope
# berguna : guna
# debest : debest
# bentuk : bentuk
# bagusan : bagus
# bank : bank
# melatih : latih
# nyuruh : nyuruh
# terimakasih : terimakasih
# faham : faham
# master : master
# teacher : teacher
# terangkan : terang
# ketinggalan : tinggal
# pelajarn : pelajarn
# kemarin : kemarin
# peringkat : peringkat
# gara : gara
# pokoknya : pokok
# diruangguru : diruangguru
# sukses : sukses
# many : many
# animation : animation
# kurangnya : kurang
# prakarya : prakarya
# seni : seni
# budaya : budaya
# love : love
# perkalin : perkalin
# syukak : syukak
# coba : coba
# application : application
# rajin : rajin
# begini : begini
# bikinnya : bikin
# lupa : lupa
# smas : smas
# sungguh : sungguh
# nyajadi : nyajadi
# lagidan : lagidan
# sambir : sambir
# bermain : main
# merekomendasikan : rekomendasi
# fasilitas : fasilitas
# membatu : batu
# {'bagus': 'bagus', 'pas': 'pas', 'sudah': 'sudah', 'donwload': 'donwload', 'chat': 'chat', 'saran': 'saran', 'enggak': 'enggak', 'tambahkan': 'tambah', 'fitur': 'fitur', 'screenshot': 'screenshot', 'video': 'video', 'adaptif': 'adaptif', 'pendalaman': 'dalam', 'materi': 'materi', 'kadang': 'kadang', 'sempat': 'sempat', 'nyatet': 'nyatet', 'adventure': 'adventure', 'terima kasih': 'terima kasih', 'banget': 'banget', 'membantu': 'bantu', 'naikin': 'naikin', 'mood': 'mood', 'belajarku': 'ajar', 'sekian': 'sekian', 'hatur': 'hatur', 'nuhun': 'nuhun', 'kakakkakak': 'kakakkakak', 'ruangguru': 'ruangguru', 'suka': 'suka', 'spam': 'spam', 'telpon': 'telpon', 'belajar': 'ajar', 'colern': 'colern', 'when': 'when', 'was': 'was', 'tried': 'tried', 'open': 'open', 'app': 'app', 'then': 'then', 'immediately': 'immediately', 'log': 'log', 'out': 'out', 'automatically': 'automatically', 'resize': 'resize', 'screen': 'screen', 'big': 'big', 'picture': 'picture', 'wobbly': 'wobbly', 'hope': 'hope', 'got': 'got', 'fixed': 'fixed', 'bagustapi': 'bagustapi', 'devloper': 'devloper', 'aplikasi': 'aplikasi', 'paket': 'paket', 'premium': 'premium', 'kepintaran': 'pintar', 'siswa': 'siswa', 'indonesia': 'indonesia', 'bicarakan': 'bicara', 'terima': 'terima', 'kasih': 'kasih', 'pahamify': 'pahamify', 'tukang': 'tukang', 'teror': 'teror', 'nomor': 'nomor', 'ganti': 'ganti', 'elekk': 'elekk', 'burik': 'burik', 'jelek': 'jelek', 'roboguru': 'roboguru', 'chrome': 'chrome', 'website': 'website', 'install': 'install', 'keberatan': 'berat', 'menginstall': 'menginstall', 'mengurangi': 'kurang', 'membutuhkan': 'butuh', 'simple': 'simple', 'ribet': 'ribet', 'tinggal': 'tinggal', 'dowoad': 'dowoad', 'maaf': 'maaf', 'kota': 'kota', 'kualitas': 'kualitas', 'jaringan': 'jaring', 'terbaik': 'baik', 'didesa': 'desa', 'memprihatinkan': 'prihatin', 'kok': 'kok', 'vidionya': 'vidionya', 'bisa': 'bisa', 'putar': 'putar', 'gmnaa': 'gmnaa', 'macan': 'macan', 'sembuhsembuh': 'sembuhsembuh', 'jam': 'jam', 'sembuh': 'sembuh', '24jam': '24jam', 'download': 'download', 'galeri': 'galeri', 'urut': 'urut', 'aplikasinya': 'aplikasi', 'eror': 'eror', 'pelajar': 'ajar', '1': '1', 'hewan': 'hewan', 'peliharaan': 'pelihara', 'teman': 'teman', 'terganggu': 'ganggu', 'aktivitasnya': 'aktivitas', 'khawatir': 'khawatir', 'produktif': 'produktif', 'belajarnya': 'ajar', 'kea': 'kea', 'terpaksa': 'paksa', 'sehatin': 'sehatin', 'peliharaannya': 'pelihara', 'pahami': 'paham', 'apk': 'apk', 'lapet': 'lapet', 'ruanggurunya': 'ruanggurunya', 'ngesthag': 'ngesthag', 'masak': 'masak', 'habis': 'habis', 'lock': 'lock', 'mencari': 'cari', 'ilmu': 'ilmu', 'drill': 'drill', 'macet': 'macet', 'mwehehehehe': 'mwehehehehe', 'downlod': 'downlod', 'bantuannya': 'bantu', 'nama': 'nama', 'jamiah': 'jamiah', 'pet': 'pet', 'menghitung': 'hitung', 'pembelajaran': 'ajar', 'imbasnya': 'imbas', 'berfungsi': 'fungsi', 'tolong': 'tolong', 'memperbaiki': 'baik', 'layar': 'layar', 'utama': 'utama', 'perbaiki': 'baik', 'bugnya': 'bugnya', 'lanjutkan': 'lanjut', 'senang': 'senang', 'adapto': 'adapto', 'pengisi': 'isi', 'suara': 'suara', 'cepatsusah': 'cepatsusah', 'dengarya': 'dengarya', 'kecepatan': 'cepat', 'videodan': 'videodan', 'subtitle': 'subtitle', 'jelasmata': 'jelasmata', 'pelajaran': 'ajar', 'ipatapi': 'ipatapi', 'pakai': 'pakai', 'ruang': 'ruang', 'guru': 'guru', 'pliss': 'pliss', 'bug': 'bug', 'benerin': 'benerin', 'semangat': 'semangat', 'suvenir': 'suvenir', 'tirmidzi': 'tirmidzi', 'dishahihkan': 'dishahihkan', 'bersalah': 'salah', 'kerana': 'rana', 'allah': 'allah', 'swt': 'swt', 'menunggu': 'tunggu', 'kehilangan': 'hilang', 'kau': 'kau', 'minat': 'minat', 'silakan': 'sila', 'merapat': 'rapat', 'menberikan': 'menberikan', 'dukungan': 'dukung', 'relawan': 'rawan', 'ahy': 'ahy', 'familia': 'familia', 'scarabaeidae': 'scarabaeidae', 'ngerjain': 'ngerjain', 'kuis': 'kuis', 'menonton': 'tonton', 'perjelasan': 'jelas', 'tibatiba': 'tibatiba', 'ngelag': 'ngelag', 'ngulang': 'ngulang', 'ulang': 'ulang', 'sampai': ' ...
# ------------------------
# Pandas Apply:   0%|          | 0/194 [00:00<?, ?it/s]

# %%
df_skripsi
# Out:
#                                              text_real  \
# 0    Ini bagus. Tapi ini kenapa pas udh enggak donw...
# 1    Aku boleh saran ngga? Tambahin juga fitur scre...
# 2    Suka spam telpon... Lebih bagus sekalian belaj...
# 3    So, when i was tried to open the app, then imm...
# 4    Sangat bagus,tapi saya mohon kepada devloper b...
# ..                                                 ...
# 195            Sangat bagus bisa belajar sambil nonton
# 196  Udah bagus tapi ada beberapa hal yang harus di...
# 197                                        Bagus bgttt
# 198  Keren banget dan sangat membantuðŸ‘ðŸ‘ðŸ‘ðŸ...
# 199                                             Okelah
#
#                                                   text     label  \
# 0    ini bagus tapi ini kenapa pas udh enggak donwl...  Negative
# 1    aku boleh saran ngga tambahin juga fitur scree...  Negative
# 2    suka spam telpon lebih bagus sekalian belajar ...  Negative
# 3    so when  was tried to open the app then immedi...  Negative
# 4    sangat bagustapi saya mohon kepada devloper bi...  Negative
# ..                                                 ...       ...
# 195            sangat bagus bisa belajar sambil nonton  Positive
# 196  udah bagus tapi ada beberapa hal yang harus di...  Positive
# 197                                          bagus bgt  Positive
# 198                   keren banget dan sangat membantu  Positive
# 199                                             okelah  Positive
#
#                                            text_tokens  \
# 0    [ini, bagus, tapi, ini, kenapa, pas, udh, engg...
# 1    [aku, boleh, saran, ngga, tambahin, juga, fitu...
# 2    [suka, spam, telpon, lebih, bagus, sekalian, b...
# 3    [so, when, was, tried, to, open, the, app, the...
# 4    [sangat, bagustapi, saya, mohon, kepada, devlo...
# ..                                                 ...
# 195     [sangat, bagus, bisa, belajar, sambil, nonton]
# 196  [udah, bagus, tapi, ada, beberapa, hal, yang, ...
# 197                                       [bagus, bgt]
# 198             [keren, banget, dan, sangat, membantu]
# 199                                           [okelah]
#
#                                        text_tokens_WSW  \
# 0                    [bagus, pas, udh, donwload, chat]
# 1    [saran, ngga, tambahin, fitur, screenshot, vid...
# 2         [suka, spam, telpon, bagus, belajar, colern]
# 3    [when, was, tried, open, app, then, immediatel...
# 4    [bagustapi, devloper, aplikasi, ruangguru, pak...
# ..                                                 ...
# 195                           [bagus, belajar, nonton]
# 196                              [bagus, ditingkatkan]
# 197                                            [bagus]
# 198                          [keren, banget, membantu]
# 199                                           [okelah]
#
#                                      text_tokens_fdist  \
# 0    {'i': 6, 'n': 5, ' ': 12, 'b': 1, 'a': 10, 'g'...
# 1    {'a': 39, 'k': 13, 'u': 18, ' ': 39, 'b': 6, '...
# 2    {'s': 4, 'u': 2, 'k': 2, 'a': 7, ' ': 8, 'p': ...
# 3    {'s': 7, 'o': 10, ' ': 33, 'w': 4, 'h': 8, 'e'...
# 4    {'s': 13, 'a': 41, 'n': 20, 'g': 7, 't': 8, ' ...
# ..                                                 ...
# 195  {'s': 4, 'a': 7, 'n': 4, 'g': 2, 't': 2, ' ': ...
# 196  {'u': 3, 'd': 3, 'a': 13, 'h': 3, ' ': 9, 'b':...
# 197  {'b': 2, 'a': 1, 'g': 2, 'u': 1, 's': 1, ' ': ...
# 198  {'k': 1, 'e': 4, 'r': 1, 'n': 5, ' ': 4, 'b': ...
# 199   {'o': 1, 'k': 1, 'e': 1, 'l': 1, 'a': 1, 'h': 1}
#
#                                        text_normalized  \
# 0                  [bagus, pas, sudah, donwload, chat]
# 1    [saran, enggak, tambahkan, fitur, screenshot, ...
# 2         [suka, spam, telpon, bagus, belajar, colern]
# 3    [when, was, tried, open, app, then, immediatel...
# 4    [bagustapi, devloper, aplikasi, ruangguru, pak...
# ..                                                 ...
# 195                         [bagus, belajar, menonton]
# 196                              [bagus, ditingkatkan]
# 197                                            [bagus]
# 198                          [keren, banget, membantu]
# 199                                           [okelah]
#
#                                    text_tokens_stemmed
# 0                  [bagus, pas, sudah, donwload, chat]
# 1    [saran, enggak, tambah, fitur, screenshot, vid...
# 2            [suka, spam, telpon, bagus, ajar, colern]
# 3    [when, was, tried, open, app, then, immediatel...
# 4    [bagustapi, devloper, aplikasi, ruangguru, pak...
# ..                                                 ...
# 195                              [bagus, ajar, tonton]
# 196                                   [bagus, tingkat]
# 197                                            [bagus]
# 198                             [keren, banget, bantu]
# 199                                              [oke]
#
# [194 rows x 8 columns]

# %%
def merge_again(text):
    return ' '.join(text)

# %%
df_skripsi['done_text'] = df_skripsi['text_tokens_stemmed'].apply(merge_again)
df_skripsi
# Out:
#                                              text_real  \
# 0    Ini bagus. Tapi ini kenapa pas udh enggak donw...
# 1    Aku boleh saran ngga? Tambahin juga fitur scre...
# 2    Suka spam telpon... Lebih bagus sekalian belaj...
# 3    So, when i was tried to open the app, then imm...
# 4    Sangat bagus,tapi saya mohon kepada devloper b...
# ..                                                 ...
# 195            Sangat bagus bisa belajar sambil nonton
# 196  Udah bagus tapi ada beberapa hal yang harus di...
# 197                                        Bagus bgttt
# 198  Keren banget dan sangat membantuðŸ‘ðŸ‘ðŸ‘ðŸ...
# 199                                             Okelah
#
#                                                   text     label  \
# 0    ini bagus tapi ini kenapa pas udh enggak donwl...  Negative
# 1    aku boleh saran ngga tambahin juga fitur scree...  Negative
# 2    suka spam telpon lebih bagus sekalian belajar ...  Negative
# 3    so when  was tried to open the app then immedi...  Negative
# 4    sangat bagustapi saya mohon kepada devloper bi...  Negative
# ..                                                 ...       ...
# 195            sangat bagus bisa belajar sambil nonton  Positive
# 196  udah bagus tapi ada beberapa hal yang harus di...  Positive
# 197                                          bagus bgt  Positive
# 198                   keren banget dan sangat membantu  Positive
# 199                                             okelah  Positive
#
#                                            text_tokens  \
# 0    [ini, bagus, tapi, ini, kenapa, pas, udh, engg...
# 1    [aku, boleh, saran, ngga, tambahin, juga, fitu...
# 2    [suka, spam, telpon, lebih, bagus, sekalian, b...
# 3    [so, when, was, tried, to, open, the, app, the...
# 4    [sangat, bagustapi, saya, mohon, kepada, devlo...
# ..                                                 ...
# 195     [sangat, bagus, bisa, belajar, sambil, nonton]
# 196  [udah, bagus, tapi, ada, beberapa, hal, yang, ...
# 197                                       [bagus, bgt]
# 198             [keren, banget, dan, sangat, membantu]
# 199                                           [okelah]
#
#                                        text_tokens_WSW  \
# 0                    [bagus, pas, udh, donwload, chat]
# 1    [saran, ngga, tambahin, fitur, screenshot, vid...
# 2         [suka, spam, telpon, bagus, belajar, colern]
# 3    [when, was, tried, open, app, then, immediatel...
# 4    [bagustapi, devloper, aplikasi, ruangguru, pak...
# ..                                                 ...
# 195                           [bagus, belajar, nonton]
# 196                              [bagus, ditingkatkan]
# 197                                            [bagus]
# 198                          [keren, banget, membantu]
# 199                                           [okelah]
#
#                                      text_tokens_fdist  \
# 0    {'i': 6, 'n': 5, ' ': 12, 'b': 1, 'a': 10, 'g'...
# 1    {'a': 39, 'k': 13, 'u': 18, ' ': 39, 'b': 6, '...
# 2    {'s': 4, 'u': 2, 'k': 2, 'a': 7, ' ': 8, 'p': ...
# 3    {'s': 7, 'o': 10, ' ': 33, 'w': 4, 'h': 8, 'e'...
# 4    {'s': 13, 'a': 41, 'n': 20, 'g': 7, 't': 8, ' ...
# ..                                                 ...
# 195  {'s': 4, 'a': 7, 'n': 4, 'g': 2, 't': 2, ' ': ...
# 196  {'u': 3, 'd': 3, 'a': 13, 'h': 3, ' ': 9, 'b':...
# 197  {'b': 2, 'a': 1, 'g': 2, 'u': 1, 's': 1, ' ': ...
# 198  {'k': 1, 'e': 4, 'r': 1, 'n': 5, ' ': 4, 'b': ...
# 199   {'o': 1, 'k': 1, 'e': 1, 'l': 1, 'a': 1, 'h': 1}
#
#                                        text_normalized  \
# 0                  [bagus, pas, sudah, donwload, chat]
# 1    [saran, enggak, tambahkan, fitur, screenshot, ...
# 2         [suka, spam, telpon, bagus, belajar, colern]
# 3    [when, was, tried, open, app, then, immediatel...
# 4    [bagustapi, devloper, aplikasi, ruangguru, pak...
# ..                                                 ...
# 195                         [bagus, belajar, menonton]
# 196                              [bagus, ditingkatkan]
# 197                                            [bagus]
# 198                          [keren, banget, membantu]
# 199                                           [okelah]
#
#                                    text_tokens_stemmed  \
# 0                  [bagus, pas, sudah, donwload, chat]
# 1    [saran, enggak, tambah, fitur, screenshot, vid...
# 2            [suka, spam, telpon, bagus, ajar, colern]
# 3    [when, was, tried, open, app, then, immediatel...
# 4    [bagustapi, devloper, aplikasi, ruangguru, pak...
# ..                                                 ...
# 195                              [bagus, ajar, tonton]
# 196                                   [bagus, tingkat]
# 197                                            [bagus]
# 198                             [keren, banget, bantu]
# 199                                              [oke]
#
#                                              done_text
# 0                        bagus pas sudah donwload chat
# 1    saran enggak tambah fitur screenshot video ada...
# 2                   suka spam telpon bagus ajar colern
# 3    when was tried open app then immediately log o...
# 4    bagustapi devloper aplikasi ruangguru paket pr...
# ..                                                 ...
# 195                                  bagus ajar tonton
# 196                                      bagus tingkat
# 197                                              bagus
# 198                                 keren banget bantu
# 199                                                oke
#
# [194 rows x 9 columns]

# %%
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# %%
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer

# %%
tfid = TfidfVectorizer(
    min_df = 3,
    max_df = 0.10,
    ngram_range = (1,2)
)

# %%
count_vect = CountVectorizer(
    min_df = 3,
    max_df = 0.10,
    ngram_range = (1,2)
)

# %%
tfid_result = tfid.fit_transform(df_skripsi["done_text"]).toarray()
tfid_df = pd.DataFrame(tfid_result, columns = tfid.get_feature_names())
tfid_df.columns = ["word_" + str(x) for x in tfid_df.columns]
tfid_df.index = df_skripsi.index
# new_data = pd.concat([, tfid_df], axis=1)

# %%
tfid_df.columns
# Out:
# Index(['word_ajar bagus', 'word_ajar ruang', 'word_ajar ruangguru',
#        'word_anak', 'word_apk', 'word_aplikasi bagus', 'word_bagus ajar',
#        'word_bagus banget', 'word_bagus bantu', 'word_baik',
#        'word_banget ajar', 'word_bantu ajar', 'word_bayar', 'word_beli',
#        'word_benar', 'word_bintang', 'word_bisa', 'word_bug', 'word_buka',
#        'word_cepat', 'word_chat', 'word_dalam', 'word_download', 'word_enggak',
#        'word_enggak bisa', 'word_erti', 'word_fitur', 'word_fitur ajar',
#        'word_ganggu', 'word_gila', 'word_guru bagus', 'word_habis', 'word_hp',
#        'word_hubung', 'word_iklan', 'word_ilmu', 'word_internet',
#        'word_jaring', 'word_jelas', 'word_kakak', 'word_karena', 'word_kasih',
#        'word_kasih ruang', 'word_kasih ruangguru', 'word_kelas', 'word_keren',
#        'word_keren banget', 'word_kuis', 'word_kurang', 'word_lancar',
#        'word_langgan', 'word_loading', 'word_lot', 'word_maaf', 'word_mantap',
#        'word_materi', 'word_moga', 'word_mudah', 'word_mudah paham',
#        'word_ngelag', 'word_nomor', 'word_paham', 'word_paham ajar',
#        'word_paham materi', 'word_pakai', 'word_paket', 'word_paksa',
#        'word_pas', 'word_pintar', 'word_promosi', 'word_saran', 'word_sekian',
#        'word_sekolah', 'word_semangat', 'word_senang', 'word_seru',
#        'word_spam', 'word_sudah', 'word_suka', 'word_susah', 'word_telpon',
#        'word_terima', 'word_terima kasih', 'word_tolong', 'word_tolong baik',
#        'word_tonton', 'word_video', 'word_vidio'],
#       dtype='object')

# %%
cvzr_result = count_vect.fit_transform(df_skripsi["done_text"]).toarray()
cvzr_df = pd.DataFrame(cvzr_result, columns = count_vect.get_feature_names())
cvzr_df.columns = ["word_" + str(x) for x in cvzr_df.columns]
cvzr_df.index = df_skripsi.index
# new_data = pd.concat([, tfid_df], axis=1)

# %%
kolomcv = cvzr_df.columns
kolomcv
# Out:
# Index(['word_ajar bagus', 'word_ajar ruang', 'word_ajar ruangguru',
#        'word_anak', 'word_apk', 'word_aplikasi bagus', 'word_bagus ajar',
#        'word_bagus banget', 'word_bagus bantu', 'word_baik',
#        'word_banget ajar', 'word_bantu ajar', 'word_bayar', 'word_beli',
#        'word_benar', 'word_bintang', 'word_bisa', 'word_bug', 'word_buka',
#        'word_cepat', 'word_chat', 'word_dalam', 'word_download', 'word_enggak',
#        'word_enggak bisa', 'word_erti', 'word_fitur', 'word_fitur ajar',
#        'word_ganggu', 'word_gila', 'word_guru bagus', 'word_habis', 'word_hp',
#        'word_hubung', 'word_iklan', 'word_ilmu', 'word_internet',
#        'word_jaring', 'word_jelas', 'word_kakak', 'word_karena', 'word_kasih',
#        'word_kasih ruang', 'word_kasih ruangguru', 'word_kelas', 'word_keren',
#        'word_keren banget', 'word_kuis', 'word_kurang', 'word_lancar',
#        'word_langgan', 'word_loading', 'word_lot', 'word_maaf', 'word_mantap',
#        'word_materi', 'word_moga', 'word_mudah', 'word_mudah paham',
#        'word_ngelag', 'word_nomor', 'word_paham', 'word_paham ajar',
#        'word_paham materi', 'word_pakai', 'word_paket', 'word_paksa',
#        'word_pas', 'word_pintar', 'word_promosi', 'word_saran', 'word_sekian',
#        'word_sekolah', 'word_semangat', 'word_senang', 'word_seru',
#        'word_spam', 'word_sudah', 'word_suka', 'word_susah', 'word_telpon',
#        'word_terima', 'word_terima kasih', 'word_tolong', 'word_tolong baik',
#        'word_tonton', 'word_video', 'word_vidio'],
#       dtype='object')

# %%
y = df_skripsi.label

# %%
X = cvzr_df.to_numpy()
y = df_skripsi.label
y_pred = cross_val_predict(clf, X, y, cv=5)
conf_mat = confusion_matrix(y_pred, y)

# %%
print(conf_mat)
print(classification_report(y, y_pred, digits = 4))
# Out:
# [[59  6]
#  [40 89]]
#               precision    recall  f1-score   support
#
#     Negative     0.9077    0.5960    0.7195        99
#     Positive     0.6899    0.9368    0.7946        95
#
#     accuracy                         0.7629       194
#    macro avg     0.7988    0.7664    0.7571       194
# weighted avg     0.8011    0.7629    0.7563       194

# %%
print('Naive Bayes')
X = cvzr_df.to_numpy()
y = df_skripsi.label
y_pred = cross_val_predict(nb, X, y, cv=10)
conf_mat = confusion_matrix(y_pred, y)
print(conf_mat)
print(classification_report(y, y_pred, digits = 4))
# Out:
# Naive Bayes
# [[53  8]
#  [46 87]]
#               precision    recall  f1-score   support
#
#     Negative     0.8689    0.5354    0.6625        99
#     Positive     0.6541    0.9158    0.7632        95
#
#     accuracy                         0.7216       194
#    macro avg     0.7615    0.7256    0.7128       194
# weighted avg     0.7637    0.7216    0.7118       194

# %%
print('Naive Bayes')
X = tfid_df.to_numpy()
y = df_skripsi.label
y_pred = cross_val_predict(nb, X, y, cv=10)
conf_mat = confusion_matrix(y_pred, y)
print(conf_mat)
print(classification_report(y, y_pred, digits = 4))
# Out:
# Naive Bayes
# [[55  9]
#  [44 86]]
#               precision    recall  f1-score   support
#
#     Negative     0.8594    0.5556    0.6748        99
#     Positive     0.6615    0.9053    0.7644        95
#
#     accuracy                         0.7268       194
#    macro avg     0.7605    0.7304    0.7196       194
# weighted avg     0.7625    0.7268    0.7187       194

# %%
print('KNN')
X = cvzr_df.to_numpy()
y = df_skripsi.label
y_pred = cross_val_predict(knn, X, y, cv=10)
conf_mat = confusion_matrix(y_pred, y)
print(conf_mat)
print(classification_report(y, y_pred, digits = 4))
# Out:
# KNN
# [[16  0]
#  [83 95]]
#               precision    recall  f1-score   support
#
#     Negative     1.0000    0.1616    0.2783        99
#     Positive     0.5337    1.0000    0.6960        95
#
#     accuracy                         0.5722       194
#    macro avg     0.7669    0.5808    0.4871       194
# weighted avg     0.7717    0.5722    0.4828       194

# %%
print('KNN')
X = tfid_df.to_numpy()
y = df_skripsi.label
y_pred = cross_val_predict(knn, X, y, cv=10)
conf_mat = confusion_matrix(y_pred, y)
print(conf_mat)
print(classification_report(y, y_pred, digits = 4))
# Out:
# KNN
# [[96 76]
#  [ 3 19]]
#               precision    recall  f1-score   support
#
#     Negative     0.5581    0.9697    0.7085        99
#     Positive     0.8636    0.2000    0.3248        95
#
#     accuracy                         0.5928       194
#    macro avg     0.7109    0.5848    0.5166       194
# weighted avg     0.7077    0.5928    0.5206       194

# %%
print('SVM')
X = cvzr_df.to_numpy()
y = df_skripsi.label
y_pred = cross_val_predict(svm, X, y, cv=10)
conf_mat = confusion_matrix(y_pred, y)
print(conf_mat)
print(classification_report(y, y_pred, digits = 4))
# Out:
# SVM
# [[53 11]
#  [46 84]]
#               precision    recall  f1-score   support
#
#     Negative     0.8281    0.5354    0.6503        99
#     Positive     0.6462    0.8842    0.7467        95
#
#     accuracy                         0.7062       194
#    macro avg     0.7371    0.7098    0.6985       194
# weighted avg     0.7390    0.7062    0.6975       194

# %%
print('SVM')
X = tfid_df.to_numpy()
y = df_skripsi.label
y_pred = cross_val_predict(svm, X, y, cv=10)
conf_mat = confusion_matrix(y_pred, y)
print(conf_mat)
print(classification_report(y, y_pred, digits = 4))
# Out:
# SVM
# [[68 11]
#  [31 84]]
#               precision    recall  f1-score   support
#
#     Negative     0.8608    0.6869    0.7640        99
#     Positive     0.7304    0.8842    0.8000        95
#
#     accuracy                         0.7835       194
#    macro avg     0.7956    0.7855    0.7820       194
# weighted avg     0.7969    0.7835    0.7817       194

# %%
print('Random Forest')
X = cvzr_df.to_numpy()
y = df_skripsi.label
y_pred = cross_val_predict(clf, X, y, cv=10)
conf_mat = confusion_matrix(y_pred, y)
print(conf_mat)
print(classification_report(y, y_pred, digits = 4))
# Out:
# Random Forest
# [[56  6]
#  [43 89]]
#               precision    recall  f1-score   support
#
#     Negative     0.9032    0.5657    0.6957        99
#     Positive     0.6742    0.9368    0.7841        95
#
#     accuracy                         0.7474       194
#    macro avg     0.7887    0.7512    0.7399       194
# weighted avg     0.7911    0.7474    0.7390       194

# %%
print('Random Forest')
X = tfid_df.to_numpy()
y = df_skripsi.label
y_pred = cross_val_predict(clf, X, y, cv=10)
conf_mat = confusion_matrix(y_pred, y)
print(conf_mat)
print(classification_report(y, y_pred, digits = 4))
# Out:
# Random Forest
# [[58  9]
#  [41 86]]
#               precision    recall  f1-score   support
#
#     Negative     0.8657    0.5859    0.6988        99
#     Positive     0.6772    0.9053    0.7748        95
#
#     accuracy                         0.7423       194
#    macro avg     0.7714    0.7456    0.7368       194
# weighted avg     0.7734    0.7423    0.7360       194

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

# %%
SemuaText = "".join(df_skripsi['done_text'])

def create_wordcloud(text, filename): 
    stopwords = set(STOPWORDS)

    wc = WordCloud(background_color="white",
                   max_words=200,
                   stopwords=stopwords)

    wc.generate(text)
    wc.to_file(filename+".png")
    plt.figure()
    plt.imshow(wc, interpolation="bilinear")
    plt.axis("off")
    plt.show()

# %%
SemuaText
# Out:
# 'bagus pas sudah donwload chatsaran enggak tambah fitur screenshot video adaptif dalam materi kadang enggak sempat nyatet pas fitur adventure terima kasih banget bantu naikin mood ajar sekian hatur nuhun kakakkakak ruanggurusuka spam telpon bagus ajar colernwhen was tried open app then immediately log out automatically when resize screen big picture wobbly hope got fixedbagustapi devloper aplikasi ruangguru paket premium pintar siswa indonesia indonesia sekian bicara terima kasihpahamifyruangguru tukang teror nomor gantielekkburikjelekroboguru ruangguru chrome website install aplikasi berat menginstall aplikasi kurang butuh simple ribet tinggal dowoad maaf tinggal kota kualitas jaring baik tinggal desa kualitas jaring prihatin sekian terima kasihkok vidionya bisa putar gmnaamacan enggak sembuhsembuh jam ajar sembuh 24jamdownload materi galeri urutaplikasi erorbagus bantu ajar indonesia 1 hewan pelihara teman ajar fitur ajar ganggu aktivitas khawatir ajar produktif ajar kea paksa sehatin hewan pelihara paham materiapk lapetbagus banget ruanggurunya ngesthag masak habislockbagus bantu cari ilmu drill suka macet mwehehehehedownlod bantunama jamiahfitur pet hitung ajar imbas fitur pet fungsi tolong baik fiturmaaf download ruangguru layar utama tolong baik bugnyabagus lanjut senang adapto saran isi suara video cepatsusah dengarya fitur cepat videodan subtitle subtitle kadang jelasmata ajar ipatapi tolong tolong baik pakai ruang gurupliss bug benerin semangat ajarsuvenir tirmidzi dishahihkan salah rana allah swt tunggu hilang kau minat sila rapat menberikan dukung rawan ahy familia scarabaeidaebanget ngerjain kuis tonton jelas tibatiba ngelag ngulang ulang sampai apkperbaiki mood ajarhp aplikasi bug selesai materi ruangguru 0 tonton paket data jaring loading tonton vidio lottangan komplen buruk beli paket tematik kelas 3 kurikulum sesuai belum baik aju komplen profesionalbgtsering neror anjirgame android baik duniaminimal kasih trial 1fitur ajar bagus banget akses fitur ruangbelajar selalu loading selalu gagal muat padahal jaring bagusbagus jelas angka mapel mtk fisika bagus zenius bagi ruanggurusalesnya ajar promosi ngancam ngancam nyebarin data pribadi curiga tindak ilegal langgar privasi guna caracara cerdas sopan etika jual produkproduknya ruang guru kecuali ruang guru jual jasa bidang hubung didik caracaranya latar didikaplikasi didik nipu dijanjiin konsultanyabaca sales cashback 200k kirim 50k pas komplain alasanya dapat cashback panjang 3 konsultanya jelasjelas janjiin dapat 200k sebut dapat 200k panjang 3 ujungujungnya lepas tangan benar pengin deal korban promo akal dapat komisi hilangbantu ajar ruang guru tolong baik bug pas habis nonoton video lamalama pas tengok video tonton keluh developerhahay uhuyterima kasih karena gua sibukpromosi sekolah promosi materi ternganggupercayangelagklinik akses benerin goblogroboguru google sad semua enggak ada benar nilai tuntasmaaf aku kasih bntg 1 admin kakak ngechat aku terus sudah blok chat maaf aku risihlanggan telpon promosi program ajar telpon tua telpon terusmenerus sembarang telpon mengangguxpnya tambah 0 salah 2jaringruang guru sekolah guru malas uji suruh pakai hape memang kuota belibagus telpon sibuk maaf baik telfon ganggu sibuk takut nomer kenal jahat maaf enggak baik nelfon apk pas hapus ruang guru telfon apknya sudah hapusindak smkberanda lag sulit scroll drill error internet lancar masak xp capai ratus 0 baikkecoh aplikasi tipu gratis bayar 700k 1jutaspam tolong gangguapa ruang guru pencet super ajar ajar laidaftar spam chat kuliah chat tawar panjang langgan plis spam chat 1 10 15 chat tawar ruangguru nomorbayar ajar kelas 1mmebingungkanruang guru bagus sayang ngelag lihat rangkum banget bolak materi acak acaksuka kesel pas tonton video loading jaring bagusbagus juara kelas kelas 2 ruang guru juara 1 kelas kelas 5 kelas 1 pakai aplikasi juara 5 enam siswa maaf kurang bintang bayar ruang guru 1juta bayar habis bayar ruanguru kasih 1bab level 37 turun level 0 level 8 tolon ...

# %%
create_wordcloud(SemuaText,"Semua Sentimen")

# %%
komenpositif= df_skripsi[df_skripsi['label'] == "Positive"]

# %%
Positive = "".join(komenpositif['done_text'])

def create_wordcloud(text, filename): 
    stopwords = set(STOPWORDS)

    wc = WordCloud(background_color="white",
                   max_words=200,
                   stopwords=stopwords)

    wc.generate(text)
    wc.to_file(filename+".png")
    plt.figure()
    plt.imshow(wc, interpolation="bilinear")
    plt.axis("off")
    plt.show()

# %%
create_wordcloud(Positive,"Semua Positive")

# %%
komennegatif= df_skripsi[df_skripsi['label'] == "Negative"]

# %%
Negative = "".join(komennegatif['done_text'])

def create_wordcloud(text, filename): 
    stopwords = set(STOPWORDS)

    wc = WordCloud(background_color="white",
                   max_words=200,
                   stopwords=stopwords)

    wc.generate(text)
    wc.to_file(filename+".png")
    plt.figure()
    plt.imshow(wc, interpolation="bilinear")
    plt.axis("off")
    plt.show()

# %%
create_wordcloud(Negative,"Semua Negative")
