# %%
import pandas as pd 
import numpy as np
import string 
import re 
from nltk.tokenize import word_tokenize 
from nltk.probability import FreqDist
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

# %%
df = pd.read_excel('data_skripsiku.xlsx')

# %%
df
# Out:
#                     Time Sentiment  \
# 0    2023-02-11 15:32:42  Negative
# 1    2023-02-11 13:55:16  Positive
# 2    2023-02-11 06:55:16  Negative
# 3    2022-10-16 12:57:02  Negative
# 4    2023-02-11 06:39:53  Positive
# ...                  ...       ...
# 1582 2022-10-17 06:24:26  Positive
# 1583 2022-10-17 05:59:16  Positive
# 1584 2022-10-17 03:28:27  Negative
# 1585 2022-10-17 02:48:35  Positive
# 1586 2022-10-16 12:17:51  Positive
#
#                                                 Content  score  \
# 0                       Roboguru harus beli paket… why?      3
# 1                 Sangat membantu jaya terus ruang guru      5
# 2     Video nya ga bisa diputar, padahal udah diundu...      4
# 3     Eror terus video nya ,nyesel gue Makai ruang guru      1
# 4                             Keren banget deh pokoknya      5
# ...                                                 ...    ...
# 1582  Bagus banget aplikasinya, bisa membantu saya d...      5
# 1583  Aplikasi nya bagus banget apa lagi belajar nya...      5
# 1584            Buruk sekali tidak ada mapel ushul fiqh      1
# 1585                   Bagussssssssssssss S s s s sss S      5
# 1586  Puasss bangatt bisa langsung paham, semoga rua...      5
#
#      reviewCreatedVersion
# 0                  6.39.0
# 1                  6.52.0
# 2                  6.52.0
# 3                     NaN
# 4                  6.52.0
# ...                   ...
# 1582                  NaN
# 1583               6.45.1
# 1584               6.45.0
# 1585               6.45.0
# 1586               6.45.0
#
# [1587 rows x 5 columns]

# %%
df_skripsi = df.drop(['score','reviewCreatedVersion','Time'],axis = 1)

# %%
komennegatif= df_skripsi[df_skripsi['Sentiment'] == "Negative"]
komenpositif= df_skripsi[df_skripsi['Sentiment'] == "Positive"]

# %%
komennegatif100 = komennegatif.head(499)
komenpositif100 = komenpositif.head(499)

# %%
df_komen100 = komennegatif100.merge(komenpositif100 , how='outer')
df_komen100
# Out:
#     Sentiment                                            Content
# 0    Negative                    Roboguru harus beli paket… why?
# 1    Negative  Video nya ga bisa diputar, padahal udah diundu...
# 2    Negative  Eror terus video nya ,nyesel gue Makai ruang guru
# 3    Negative  Aku punya keluhan terhadap link web atau xdari...
# 4    Negative  halo ka, kalo buat PC letak drill soal nya ada...
# ..        ...                                                ...
# 993  Positive                      iya bagus banget aplikasi nya
# 994  Positive  Dari ruangguru ini cukup oke tapi tolong tamba...
# 995  Positive             Ruang guru dapat memahami pelajarannya
# 996  Positive  gila gila gila ! 3 kata tp gils bgt sih! Gatau...
# 997  Positive  Wah ruang guru ini cocoa until anak anak ya an...
#
# [998 rows x 2 columns]

# %% [markdown]
# # Mendeteksi Positive & Negative

# %%
df_komen100.Sentiment.value_counts()
# Out:
# Negative    499
# Positive    499
# Name: Sentiment, dtype: int64

# %%
df_skripsi = df_komen100

# %% [markdown]
# # Menampilkan Bagian Kolom pada Data

# %%
df_skripsi.columns = ['label','text_real']

# %%
df_skripsi['text'] = df_skripsi.text_real

# %% [markdown]
# # Menampilkan DataFrame

# %%
df_skripsi
# Out:
#         label                                          text_real  \
# 0    Negative                    Roboguru harus beli paket… why?
# 1    Negative  Video nya ga bisa diputar, padahal udah diundu...
# 2    Negative  Eror terus video nya ,nyesel gue Makai ruang guru
# 3    Negative  Aku punya keluhan terhadap link web atau xdari...
# 4    Negative  halo ka, kalo buat PC letak drill soal nya ada...
# ..        ...                                                ...
# 993  Positive                      iya bagus banget aplikasi nya
# 994  Positive  Dari ruangguru ini cukup oke tapi tolong tamba...
# 995  Positive             Ruang guru dapat memahami pelajarannya
# 996  Positive  gila gila gila ! 3 kata tp gils bgt sih! Gatau...
# 997  Positive  Wah ruang guru ini cocoa until anak anak ya an...
#
#                                                   text
# 0                      Roboguru harus beli paket… why?
# 1    Video nya ga bisa diputar, padahal udah diundu...
# 2    Eror terus video nya ,nyesel gue Makai ruang guru
# 3    Aku punya keluhan terhadap link web atau xdari...
# 4    halo ka, kalo buat PC letak drill soal nya ada...
# ..                                                 ...
# 993                      iya bagus banget aplikasi nya
# 994  Dari ruangguru ini cukup oke tapi tolong tamba...
# 995             Ruang guru dapat memahami pelajarannya
# 996  gila gila gila ! 3 kata tp gils bgt sih! Gatau...
# 997  Wah ruang guru ini cocoa until anak anak ya an...
#
# [998 rows x 3 columns]

# %% [markdown]
# # Mengubah Huruf menjadi Kecil

# %%
df_skripsi['text'] = df_skripsi['text'].str.lower()
print('Case Folding Result : \n')
print(df_skripsi['text'].head(5))
print('\n\n\n')
# Out:
# Case Folding Result :
#
# 0                      roboguru harus beli paket… why?
# 1    video nya ga bisa diputar, padahal udah diundu...
# 2    eror terus video nya ,nyesel gue makai ruang guru
# 3    aku punya keluhan terhadap link web atau xdari...
# 4    halo ka, kalo buat pc letak drill soal nya ada...
# Name: text, dtype: object

# %% [markdown]
# # Menghapus Special Karakter dan Url

# %%
def remove_text_special(text):
    # hapus tab, new line, ans back slice
    text = text.replace('\\t'," ").replace('\\n'," ").replace('\\u'," ").replace('\\',"")
    # hapus non ASCII (emot, bahasa china dll)
    text = text.encode('ascii', 'replace').decode('ascii')
    # hapus mention, link, hashtag
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)"," ", text).split())
    # remove URL 
    return text.replace("http://", " ").replace("https://", " ")
df_skripsi['text'] = df_skripsi.text.astype('str')                
df_skripsi['text'] = df_skripsi['text'].apply(remove_text_special)

# %% [markdown]
# # Menghapus Elongasi

# %%
#remove kata yang sengaja dipanjangkan
# seperti bisaaaaaaa -> bisa
def spell(word):
    if re.search(r'([a-zA-Z])\1{2,}', word):
        rword = re.sub(r'([a-zA-Z])\1{2,}','\\1', word)
        return rword
    else:
        return word
df_skripsi['text'] = df_skripsi['text'].apply(spell)

# %% [markdown]
# # Menghapus Tanda Baca

# %%
def remove_punctuation(text):
    return text.translate(str.maketrans("","",string.punctuation))

df_skripsi['text'] = df_skripsi['text'].apply(remove_punctuation)

df_skripsi
# Out:
#         label                                          text_real  \
# 0    Negative                    Roboguru harus beli paket… why?
# 1    Negative  Video nya ga bisa diputar, padahal udah diundu...
# 2    Negative  Eror terus video nya ,nyesel gue Makai ruang guru
# 3    Negative  Aku punya keluhan terhadap link web atau xdari...
# 4    Negative  halo ka, kalo buat PC letak drill soal nya ada...
# ..        ...                                                ...
# 993  Positive                      iya bagus banget aplikasi nya
# 994  Positive  Dari ruangguru ini cukup oke tapi tolong tamba...
# 995  Positive             Ruang guru dapat memahami pelajarannya
# 996  Positive  gila gila gila ! 3 kata tp gils bgt sih! Gatau...
# 997  Positive  Wah ruang guru ini cocoa until anak anak ya an...
#
#                                                   text
# 0                        roboguru harus beli paket why
# 1      video nya ga bisa diputar padahal udah diunduh
# 2     eror terus video nya nyesel gue makai ruang guru
# 3    aku punya keluhan terhadap link web atau xdari...
# 4    halo ka kalo buat pc letak drill soal nya ada ...
# ..                                                 ...
# 993                      iya bagus banget aplikasi nya
# 994  dari ruangguru ini cukup oke tapi tolong tamba...
# 995             ruang guru dapat memahami pelajarannya
# 996  gila gila gila  3 kata tp gils bgt sih gatau m...
# 997  wah ruang guru ini cocoa until anak anak ya an...
#
# [998 rows x 3 columns]

# %% [markdown]
# # Menghapus Enter Tab

# %%
#remove whitespace leading & trailing
def remove_whitespace_LT(text):
    return text.strip()

df_skripsi['text'] = df_skripsi['text'].apply(remove_whitespace_LT)

df_skripsi
# Out:
#         label                                          text_real  \
# 0    Negative                    Roboguru harus beli paket… why?
# 1    Negative  Video nya ga bisa diputar, padahal udah diundu...
# 2    Negative  Eror terus video nya ,nyesel gue Makai ruang guru
# 3    Negative  Aku punya keluhan terhadap link web atau xdari...
# 4    Negative  halo ka, kalo buat PC letak drill soal nya ada...
# ..        ...                                                ...
# 993  Positive                      iya bagus banget aplikasi nya
# 994  Positive  Dari ruangguru ini cukup oke tapi tolong tamba...
# 995  Positive             Ruang guru dapat memahami pelajarannya
# 996  Positive  gila gila gila ! 3 kata tp gils bgt sih! Gatau...
# 997  Positive  Wah ruang guru ini cocoa until anak anak ya an...
#
#                                                   text
# 0                        roboguru harus beli paket why
# 1       video nya ga bisa diputar padahal udah diunduh
# 2     eror terus video nya nyesel gue makai ruang guru
# 3    aku punya keluhan terhadap link web atau xdari...
# 4    halo ka kalo buat pc letak drill soal nya ada ...
# ..                                                 ...
# 993                      iya bagus banget aplikasi nya
# 994  dari ruangguru ini cukup oke tapi tolong tamba...
# 995             ruang guru dapat memahami pelajarannya
# 996  gila gila gila  3 kata tp gils bgt sih gatau m...
# 997  wah ruang guru ini cocoa until anak anak ya an...
#
# [998 rows x 3 columns]

# %% [markdown]
# # Menghapus Spasi yang Terlalu Banyak

# %%
def remove_whitespace_multiple(text):
    return re.sub('\s+',' ',text)

df_skripsi['text'] = df_skripsi['text'].apply(remove_whitespace_multiple)

def remove_singl_char(text):
    return re.sub(r"\b[a-zA-Z]\b", "", text)

df_skripsi['text'] = df_skripsi['text'].apply(remove_singl_char)

df_skripsi
# Out:
#         label                                          text_real  \
# 0    Negative                    Roboguru harus beli paket… why?
# 1    Negative  Video nya ga bisa diputar, padahal udah diundu...
# 2    Negative  Eror terus video nya ,nyesel gue Makai ruang guru
# 3    Negative  Aku punya keluhan terhadap link web atau xdari...
# 4    Negative  halo ka, kalo buat PC letak drill soal nya ada...
# ..        ...                                                ...
# 993  Positive                      iya bagus banget aplikasi nya
# 994  Positive  Dari ruangguru ini cukup oke tapi tolong tamba...
# 995  Positive             Ruang guru dapat memahami pelajarannya
# 996  Positive  gila gila gila ! 3 kata tp gils bgt sih! Gatau...
# 997  Positive  Wah ruang guru ini cocoa until anak anak ya an...
#
#                                                   text
# 0                        roboguru harus beli paket why
# 1       video nya ga bisa diputar padahal udah diunduh
# 2     eror terus video nya nyesel gue makai ruang guru
# 3    aku punya keluhan terhadap link web atau xdari...
# 4    halo ka kalo buat pc letak drill soal nya ada ...
# ..                                                 ...
# 993                      iya bagus banget aplikasi nya
# 994  dari ruangguru ini cukup oke tapi tolong tamba...
# 995             ruang guru dapat memahami pelajarannya
# 996  gila gila gila 3 kata tp gils bgt sih gatau mo...
# 997  wah ruang guru ini cocoa until anak anak ya an...
#
# [998 rows x 3 columns]

# %% [markdown]
# # Membuat Kolom text_token berisi Kumpulan Kata-kata yang dipisah dengan Koma

# %%
df_skripsi = df_skripsi.drop_duplicates()
df_skripsi = df_skripsi[['label','text_real','text']]
df_skripsi['text'] = df_skripsi['text'].str.lower()

def word_tokenize_wrapper(text):
    return word_tokenize(text)

df_skripsi['text_tokens'] = df_skripsi['text'].apply(word_tokenize_wrapper)

# %%
df_skripsi
# Out:
#         label                                          text_real  \
# 0    Negative                    Roboguru harus beli paket… why?
# 1    Negative  Video nya ga bisa diputar, padahal udah diundu...
# 2    Negative  Eror terus video nya ,nyesel gue Makai ruang guru
# 3    Negative  Aku punya keluhan terhadap link web atau xdari...
# 4    Negative  halo ka, kalo buat PC letak drill soal nya ada...
# ..        ...                                                ...
# 993  Positive                      iya bagus banget aplikasi nya
# 994  Positive  Dari ruangguru ini cukup oke tapi tolong tamba...
# 995  Positive             Ruang guru dapat memahami pelajarannya
# 996  Positive  gila gila gila ! 3 kata tp gils bgt sih! Gatau...
# 997  Positive  Wah ruang guru ini cocoa until anak anak ya an...
#
#                                                   text  \
# 0                        roboguru harus beli paket why
# 1       video nya ga bisa diputar padahal udah diunduh
# 2     eror terus video nya nyesel gue makai ruang guru
# 3    aku punya keluhan terhadap link web atau xdari...
# 4    halo ka kalo buat pc letak drill soal nya ada ...
# ..                                                 ...
# 993                      iya bagus banget aplikasi nya
# 994  dari ruangguru ini cukup oke tapi tolong tamba...
# 995             ruang guru dapat memahami pelajarannya
# 996  gila gila gila 3 kata tp gils bgt sih gatau mo...
# 997  wah ruang guru ini cocoa until anak anak ya an...
#
#                                            text_tokens
# 0                  [roboguru, harus, beli, paket, why]
# 1    [video, nya, ga, bisa, diputar, padahal, udah,...
# 2    [eror, terus, video, nya, nyesel, gue, makai, ...
# 3    [aku, punya, keluhan, terhadap, link, web, ata...
# 4    [halo, ka, kalo, buat, pc, letak, drill, soal,...
# ..                                                 ...
# 993                [iya, bagus, banget, aplikasi, nya]
# 994  [dari, ruangguru, ini, cukup, oke, tapi, tolon...
# 995       [ruang, guru, dapat, memahami, pelajarannya]
# 996  [gila, gila, gila, 3, kata, tp, gils, bgt, sih...
# 997  [wah, ruang, guru, ini, cocoa, until, anak, an...
#
# [936 rows x 4 columns]

# %% [markdown]
# # Menghapus Stopwords

# %%
list_stopwords = stopwords.words('indonesian')
list_stopwords.extend(["yg", "dg", "rt", "dgn", "ny", "d", 'klo', 
                       'kalo', 'amp', 'biar', 'bikin', 'bilang', 
                       'gak', 'ga', 'krn', 'nya', 'nih', 'sih', 
                       'si', 'tau', 'tdk', 'tuh', 'utk', 'ya', 
                       'jd', 'jgn', 'sdh', 'aja', 'n', 't', 
                       'nyg', 'hehe', 'pen', 'u', 'nan', 'loh', 'rt',
                       '&amp', 'yah'])

txt_stopword = pd.read_csv("stopwords.txt", names= ["stopwords"], header = None)
list_stopwords.extend(txt_stopword["stopwords"][0].split(' '))
list_stopwords = set(list_stopwords)
def stopwords_removal(words):
    return [word for word in words if word not in list_stopwords]
df_skripsi['Stopwords'] = df_skripsi['text_tokens'].apply(stopwords_removal)

# %%
list_stopwords
# Out:
# {'',
#  'preesss',
#  'bkal',
#  'menambahkan',
#  'dimisalkan',
#  'teringat-ingat',
#  'as',
#  'tragedy',
#  'belumlah',
#  'ooohhh',
#  'by',
#  'r',
#  'bena',
#  'p',
#  'oei',
#  'membuat',
#  'menanti',
#  'dapat',
#  'ajaaah',
#  'menyatakan',
#  'seketika',
#  'sewaktu',
#  'aahhh',
#  'lah',
#  'sementara',
#  'mr',
#  'sesudahnya',
#  'sempat',
#  'sejenak',
#  'peeeeetttt',
#  'follow',
#  'kagak',
#  'sekarang',
#  'hhh',
#  'pi',
#  'eng',
#  'ajaah',
#  'udahlah',
#  'dilakukan',
#  'apabl',
#  'alhamdulillah',
#  'na',
#  'diakhirinya',
#  'terlalu',
#  'more',
#  'theatre',
#  'heleh',
#  'sec',
#  'aseekk',
#  'sekitar',
#  'semampu',
#  'gass',
#  'sig',
#  'sayrap',
#  'menjawab',
#  'itulah',
#  'mahl',
#  'bilang',
#  'usah',
#  'is',
#  'anca',
#  'uea',
#  'menunjukkan',
#  'men',
#  'krn',
#  'ayyy',
#  'bat',
#  'dikarenakan',
#  'kwk',
#  'lanjut',
#  'ab',
#  'udahan',
#  'diinginkan',
#  'masihkah',
#  'bs',
#  'joosss',
#  'mp',
#  'syyo',
#  'tdk',
#  'will',
#  'beer',
#  'diperkirakan',
#  'bwa',
#  'seorang',
#  'kedua',
#  'wk',
#  'kepa',
#  'tsb',
#  'siep',
#  'ahh',
#  'klu',
#  'what',
#  'gaesss',
#  'woyy',
#  'bgini',
#  'mengibaratkan',
#  'fl',
#  'hendaknya',
#  'mirip',
#  'baik',
#  'sana',
#  'nyang',
#  'sejumlah',
#  'aahh',
#  'aww',
#  'sesampai',
#  'apaa',
#  'thd',
#  'bahwa',
#  'bisakah',
#  'mah',
#  'c',
#  'dikira',
#  'sini',
#  'menyampaikan',
#  'sebetulnya',
#  'gi',
#  'acan',
#  'mendatangkan',
#  'atau',
#  'terl',
#  'mendatangi',
#  'bur',
#  'gak',
#  'ngak',
#  'jengn',
#  'dirinya',
#  'aeeee',
#  'lak',
#  'ato',
#  'mengungkapkan',
#  'ama',
#  'fyi',
#  'world',
#  'ssst',
#  'dijelaskannya',
#  'wkwkwk',
#  'mon',
#  'hadeeuh',
#  'jab',
#  'misalnya',
#  'selamanya',
#  'atr',
#  'tong',
#  'road',
#  'jah',
#  'seh',
#  'bgaimana',
#  'kamu',
#  'bolehkah',
#  'dg',
#  'ne',
#  'memba',
#  'wa',
#  'nguyu',
#  'satu',
#  'silakan',
#  'tentunya',
#  'terhadapnya',
#  'dtg',
#  'menanti-nanti',
#  'jan',
#  'aa',
#  'cour',
#  'ditunjukkan',
#  'siapa',
#  'bara',
#  'sampai-sampai',
#  'wahaye',
#  'he',
#  'kemungkinannya',
#  'kurang',
#  'gunakan',
#  'nk',
#  'akankh',
#  'aud',
#  'menyer',
#  'segalanya',
#  'yaaa',
#  'yg',
#  'padahal',
#  'dekat',
#  'keunn',
#  'tik',
#  'rasa',
#  'umumnya',
#  'sesudah',
#  'sama-sama',
#  'ni',
#  'kr',
#  'sebabnya',
#  'h',
#  'dimintai',
#  'enggak',
#  'akh',
#  'mampu',
#  'pernah',
#  'ndroo',
#  'ntu',
#  'kepadanya',
#  'ja',
#  'astagpirullohalazmin',
#  'dink',
#  'asiiikkk',
#  'diperlihatkan',
#  'cuk',
#  'dikerjakan',
#  'hk',
#  'ng',
#  'diminta',
#  'menuju',
#  'memperba',
#  'for',
#  'kami',
#  'kem',
#  'bo',
#  'berikan',
#  'elah',
#  'mere',
#  'berawal',
#  'mempunyai',
#  'hadeh',
#  'tinggi',
#  'mul',
#  'pula',
#  'keleus',
#  'enak',
#  'blom',
#  'dipergunakan',
#  'oo',
#  'nan',
#  'noh',
#  'ahool',
#  'prop',
#  'pasti',
#  'tela',
#  'disini',
#  'ha',
#  'deee',
#  'cu',
#  'soal',
#  'piye',
#  'selalu',
#  'bakal',
#  'dipastikan',
#  'yukk',
#  'seseorang',
#  'asyik',
#  'aka',
#  'sering',
#  'ca',
#  'ih',
#  'x',
#  'hayo',
#  'drpd',
#  'march',
#  'tgjwb',
#  'ucap',
#  'angg',
#  'peke',
#  'sekitarnya',
#  'tuu',
#  'diperbuatnya',
#  'bagaimanakah',
#  'memastikan',
#  'akhiri',
#  'terkira',
#  'tek',
#  'yv',
#  'z',
#  'eeeh',
#  'spt',
#  'suatu',
#  'tir',
#  'wih',
#  'meski',
#  'asiiik',
#  'maka',
#  'no',
#  'asyiapp',
#  'juga',
#  'terlebih',
#  'sbg',
#  'penc',
#  'aih',
#  'mendatang',
#  'biup',
#  'hny',
#  'berlangsung',
#  'sayalah',
#  'bagainamakah',
#  'wkwaww',
#  'bermaksud',
#  'alah',
#  'deh',
#  'jelasnya',
#  'pertama',
#  'asyiiiiik',
#  'seingat',
#  'pentingnya',
#  'dituturkan',
#  'ndy',
#  'gom',
#  'dlm',
#  'go',
#  'ser',
#  'menunjuki',
#  'ditunjuknya',
#  'asal',
#  'apkah',
#  'mwnyedihkan',
#  'sebagainya',
#  'per',
#  'berjumlah',
#  'hehe',
#  'sambil',
#  'jagan',
#  'bkn',
#  'ihh',
#  'begitu',
#  'sang',
#  'ingin',
#  'semampunya',
#  'akse',
#  'tegas',
#  'ketika',
#  'atuh',
#  'adoh',
#  'nis',
#  'memang',
#  'ada',
#  'gpp',
#  'menanyai',
#  'tiga',
#  'bk',
#  'eye',
#  'masalah',
#  'diungkapkan',
#  'neg',
#  'percuma',
#  'su',
#  'bahkan',
#  'sebagaimana',
#  'jadi',
#  'josss',
#  'mb',
#  'yakin',
#  'memperlihatkan',
#  'tahun',
#  'gih',
#  'setelah',
#  'neeh',
#  'di',
#  'spy',
#  'sebagian',
#  'koit',
#  'sem',
#  'berlalu',
#  'begitupun',
#  'ntup',
#  'agar',
#  'jawaban',
#  'menurut',
#  'ngoahahahahahaaa',
#  'jikalau',
#  'tok',
#  'moga',
#  'pertama-tama',
#  'diingatkan',
#  'laku',
#  'mengakhiri',
#  'stand',
#  'nya',
#  'maupun',
#  'spya',
#  'bahahak',
#  'tahu',
#  'waduuuhhhh',
#  'malahan',
#  'sesama',
#  'tang',
#  'memihak',
#  'diketahuinya',
#  'apakh',
#  'hai',
#  'sam',
#  'siapapun',
#  'selaku',
#  'lha',
#  'sebegitu',
#  'mend',
#  'yng',
#  'luar',
#  'menyeluruh',
#  'ww',
#  'lu',
#  'ehh',
#  'dipunyai',
#  'woyyy',
#  'ajaa',
#  'hey',
#  'gedhe',
#  'ntuh',
#  'aplg',
#  'asuuu',
#  'dalam',
#  'mempertanyakan',
#  'kelamaan',
#  'pin',
#  'bnyk',
#  'kelima',
#  'tur',
#  'aaa',
#  'bant',
#  'daripada',
#  'sejak',
#  'sekadarnya',
#  'yaa',
#  'man',
#  'sook',
#  'don',
#  'mantaaapp',
#  'wala',
#  'wuiih',
#  'lagi',
#  'skrg',
#  'md',
#  'diingat',
#  'euy',
#  'astaghf',
#  'nah',
#  'wkwkw',
#  'huaaahaaaaa',
#  'iya',
#  'sin',
#  'ingat-ingat',
#  'bikin',
#  'demi',
#  'ok',
#  'kali',
#  'bi',
#  'langsung',
#  'diibaratkan',
#  'hampir',
#  'hmmmmmm',
#  'bagaimana',
#  'seharusnya',
#  'blenggg',
#  'helo',
#  'are',
#  'bun',
#  'piyu',
#  'tersebutlah',
#  'dimulai',
#  'saling',
#  'tidaklah',
#  'rt',
#  'pak',
#  'wow',
#  'rasanya',
#  'kwak',
#  'they',
#  'dar',
#  'yakali',
#  'biarpun',
#  'dia',
#  'bawah',
#  'para',
#  'sek',
#  'bain',
#  'sebagai',
#  'aig',
#  'terasa',
#  'didatangkan',
#  'ups',
#  'lho',
#  'ci',
#  'menandaskan',
#  'sebegini',
#  'ntap',
#  'ypk',
#  'sebesar',
#  'pasi',
#  'masa',
#  'kua',
#  'pertanyakan',
#  'mendapat',
#  'dahulu',
#  'ny',
#  'ting',
#  'sebenarnya',
#  'nahh',
#  'ter',
#  'ge',
#  'ping',
#  'aga',
#  'klw',
#  'tertuju',
#  'meyakini',
#  'keluar',
#  'ealah',
#  'yah',
#  'share',
#  'tar',
#  'tepat',
#  'apasih',
#  'toeeettt',
#  'misalkan',
#  'sebanyak',
#  'yess',
#  'jat',
#  'memberi',
#  'kita',
#  'lamanya',
#  'jleb',
#  'ky',
#  'woyyyyy',
#  'lohh',
#  'gsk',
#  'semakin',
#  'it',
#  'k',
#  'segala',
#  'wkwk',
#  'sekadar',
#  'piyek',
#  'aernye',
#  'xs',
#  'menggunakan',
#  'penting',
#  'disebutkannya',
#  'bahwasannya',
#  'pret',
#  'jg',
#  'terdapat',
#  'sekaranglah',
#  'apalagi',
#  'bagi',
#  'merekalah',
#  'tho',
#  'melihat',
#  'dmn',
#  'ba',
#  'karepmu',
#  'memulai',
#  'lama',
#  'wuiiih',
#  'nie',
#  'sbuah',
#  'diketahui',
#  'ikut',
#  'berlainan',
#  'akhir',
#  'co',
#  'ker',
#  'aing',
#  'eaaaa',
#  'aph',
#  'hmmm',
#  'sih',
#  'tak',
#  'cuy',
#  'sar',
#  'tanpa',
#  'dikatakan',
#  'dibuat',
#  'bar',
#  't',
#  'pek',
#  'halah',
#  'baaeerrree',
#  'begitukah',
#  'care',
#  'sudah',
#  'mam',
#  'agree',
#  'berkata',
#  'selain',
#  'pem',
#  'bahahaha',
#  'dijelaskan',
#  'manalagi',
#  'bapak',
#  'hanya',
#  'apas',
#  'agak',
#  'la',
#  'berkehendak',
#  'rj',
#  'itu',
#  'mempersiapkan',
#  'terjadi',
#  'ndase',
#  'pol',
#  'menginginkan',
#  'dp',
#  'smuwa',
#  'sepihak',
#  'akan',
#  'kantri',
#  'teh',
#  'setiba',
#  'bgt',
#  'naik',
#  'gaes',
#  'tanyakan',
#  'kor',
#  'd',
#  'kalau',
#  'pada',
#  'macam',
#  'wal',
#  'artinya',
#  'mengenai',
#  'sekiranya',
#  'jin',
#  'gug',
#  'hari',
#  'udah',
#  'cuma',
#  'si',
#  'selanjutnya',
#  'pea',
#  'setengah',
#  'common',
#  'diperbuat',
#  'sedikitnya',
#  'but',
#  'neh',
#  'kira-kira',
#  'lat',
#  'sal',
#  'sekecil',
#  'beri',
#  'lain',
#  'seolah-olah',
#  'semua',
#  'serupa',
#  'wahai',
#  'hadeeeeehhh',
#  'lum',
#  'nyok',
#  'eihh',
#  'setinggi',
#  'ben',
#  'wadoooohhh',
#  'sebutnya',
#  'kemungkinan',
#  'ajjaaa',
#  'dahh',
#  'sebaiknya',
#  'yaitu',
#  'pt',
#  'kam',
#  'seterusnya',
#  'klop',
#  'ieu',
#  'lohhhh',
#  'jee',
#  'selama-lamanya',
#  'keinginan',
#  'terutama',
#  'ela',
#  'you',
#  'my',
#  'manakala',
#  'terdiri',
#  'asalkan',
#  'bg',
#  'aaah',
#  'amat',
#  'kira',
#  'berapa',
#  'perlunya',
#  'bag',
#  'say',
#  'dn',
#  'maww',
#  'ckakak',
#  'inilah',
#  'berakhirlah',
#  'dech',
#  'gn',
#  'ta',
#  'persoalan',
#  'rrrrrr',
#  'mlm',
#  'jiaah',
#  'atas',
#  'depan',
#  'oleh',
#  'ngk',
#  'bukanlah',
#  'wen',
#  'setiap',
#  'gangs',
#  'berturut-turut',
#  'sekali-kali',
#  'sekali',
#  'digunakan',
#  'umum',
#  'hadeuh',
#  'ampe',
#  'pp',
#  'kalo',
#  'aja',
#  'ksp',
#  'dikatakannya',
#  'blm',
#  'aduhh',
#  'hiikksss',
#  'jangankan',
#  'terlihat',
#  'bukanya',
#  'dianya',
#  'twit',
#  'kembali',
#  'yoiii',
#  'baru',
#  'bersiap',
#  'ti',
#  'ibu',
#  'tersebut',
#  'olehnya',
#  'nang',
#  'tidak',
#  'dipersoalkan',
#  'mpod',
#  'huhuhu',
#  'mohon',
#  'cik',
#  'asee',
#  'waduhhh',
#  'hadeeehhh',
#  'memperbuat',
#  'hendak',
#  'me',
#  'secara',
#  'mengatakan',
#  'hmm',
#  'ataupun',
#  'walaupun',
#  'dan',
#  'nyaris',
#  'memintakan',
#  'bagian',
#  'ee',
#  'semaunya',
#  'siip',
#  'tambahnya',
#  'yupsss',
#  'katakanlah',
#  'huh',
#  'xi',
#  'nih',
#  'walau',
#  'demikianlah',
#  'keadaan',
#  'here',
#  'mendapatkan',
#  'waaahh',
#  'haruslah',
#  'sebutlah',
#  'keseluruhan',
#  'gun',
#  'sesegera',
#  'did',
#  'ggu',
#  'tunjuk',
#  'jawabnya',
#  'hmmmmm',
#  'dah',
#  'hend',
#  'i',
#  'yar',
#  'ay',
#  'mas',
#  'bukannya',
#  'ini',
#  'dng',
#  'dil',
#  'iki',
#  'dr',
#  'or',
#  'wouy',
#  'mempersoalkan',
#  'sik',
#  'asn',
#  'nek',
#  'practice',
#  'asik',
#  'aku',
#  'v',
#  'tentulah',
#  'con',
#  'mistakes',
#  'ayoo',
#  'lg',
#  'mba',
#  'kalian',
#  'ind',
#  'masih',
#  'where',
#  'baiklah',
#  'ber',
#  'pd',
#  'kapan',
#  'mbok',
#  'boys',
#  'coy',
#  'pic',
#  'coz',
#  'gmn',
#  'jawab',
#  'bageb',
#  'gig',
#  'awalnya',
#  'nge',
#  'diberikannya',
#  'gw',
#  'wooiiii',
#  'kes',
#  'hsil',
#  'sekalian',
#  'wonderfull',
#  'mengucapkannya',
#  'tr',
#  'km',
#  'tu',
#  'ms',
#  'ciiee',
#  'hingga',
#  'tapi',
#  'dila',
#  'ahhahshahahsha',
#  'harusnya',
#  'memerlukan',
#  'alla',
#  'dgn',
#  'za',
#  'asa',
#  'khususnya',
#  'dahhh',
#  'setidaknya',
#  'mau',
#  'menunjuknya',
#  'aseeekkk',
#  'jadinya',
#  'mi',
#  'we',
#  'kah',
#  'broo',
#  'sudahkah',
#  'anda',
#  'berakhirnya',
#  'antara',
#  'ucapnya',
#  'may',
#  'kinilah',
#  'toh',
#  'lainnya',
#  'lai',
#  'guys',
#  'his',
#  'mulailah',
#  'diucapkan',
#  'dua',
#  'gimana',
#  'panjang',
#  'karenanya',
#  'jelas',
#  'sedang',
#  'from',
#  'ke',
#  'diri',
#  'pihaknya',
#  'bai',
#  'kata',
#  'menyebutkan',
#  'mks',
#  'tanya',
#  'ditegaskan',
#  'yaelah',
#  'apatah',
#  'laahh',
#  'yups',
#  'menegaskan',
#  'bersiap-siap',
#  'pen',
#  'lahh',
#  'menunjuk',
#  'mata',
#  'apabilah',
#  'empat',
#  'mel',
#  'waktunya',
#  'oalah',
#  'bung',
#  'mksh',
#  'sekaligus',
#  'be',
#  'ungkapnya',
#  'sela',
#  'kom',
#  'tutur',
#  'sejauh',
#  'kelihatannya',
#  'usai',
#  'utk',
#  'gt',
#  'jumlah',
#  'menanyakan',
#  'abc',
#  'hr',
#  'pl',
#  'seberapa',
#  'berarti',
#  'mai',
#  'third',
#  'apabila',
#  're',
#  'bah',
#  'bilakah',
#  'omg',
#  'ditanya',
#  'mengapa',
#  'ahhhhh',
#  'ternyata',
#  'ahaaaaa',
#  'memberikan',
#  'y',
#  'bersama',
#  'var',
#  'kemudian',
#  'sehingga',
#  'saya',
#  'm',
#  'tuk',
#  'punya',
#  'seenaknya',
#  'fya',
#  'dulu',
#  'diantaranya',
#  'jadilah',
#  'free',
#  'apalg',
#  'padanya',
#  'sesekali',
#  'kenapa',
#  'yakni',
#  'n',
#  'akubingin',
#  'apabedanya',
#  'woi',
#  'pr',
#  'bertanya-tanya',
#  'blo',
#  'koe',
#  'eo',
#  'adanya',
#  'cm',
#  's',
#  'fir',
#  'tambah',
#  'sihhh',
#  'dialah',
#  'secukupnya',
#  'mrk',
#  'jugaa',
#  'namun',
#  'update',
#  'ht',
#  'tadinya',
#  'ga',
#  'dust',
#  'akhirnya',
#  'tan',
#  'disinilah',
#  'semacam',
#  'mengibaratkannya',
#  'mungkinkah',
#  'caranya',
#  'kepada',
#  'nyata',
#  'doing',
#  'begi',
#  'apaka',
#  'woii',
#  'berkenaan',
#  'mm',
#  'loe',
#  'lbh',
#  'look',
#  'mulai',
#  'sendiri',
#  'ashes',
#  'cok',
#  'hadeeeeeh',
#  'woyyyyyy',
#  'sak',
#  ...}

# %%
df_skripsi
# Out:
#         label                                          text_real  \
# 0    Negative                    Roboguru harus beli paket… why?
# 1    Negative  Video nya ga bisa diputar, padahal udah diundu...
# 2    Negative  Eror terus video nya ,nyesel gue Makai ruang guru
# 3    Negative  Aku punya keluhan terhadap link web atau xdari...
# 4    Negative  halo ka, kalo buat PC letak drill soal nya ada...
# ..        ...                                                ...
# 993  Positive                      iya bagus banget aplikasi nya
# 994  Positive  Dari ruangguru ini cukup oke tapi tolong tamba...
# 995  Positive             Ruang guru dapat memahami pelajarannya
# 996  Positive  gila gila gila ! 3 kata tp gils bgt sih! Gatau...
# 997  Positive  Wah ruang guru ini cocoa until anak anak ya an...
#
#                                                   text  \
# 0                        roboguru harus beli paket why
# 1       video nya ga bisa diputar padahal udah diunduh
# 2     eror terus video nya nyesel gue makai ruang guru
# 3    aku punya keluhan terhadap link web atau xdari...
# 4    halo ka kalo buat pc letak drill soal nya ada ...
# ..                                                 ...
# 993                      iya bagus banget aplikasi nya
# 994  dari ruangguru ini cukup oke tapi tolong tamba...
# 995             ruang guru dapat memahami pelajarannya
# 996  gila gila gila 3 kata tp gils bgt sih gatau mo...
# 997  wah ruang guru ini cocoa until anak anak ya an...
#
#                                            text_tokens  \
# 0                  [roboguru, harus, beli, paket, why]
# 1    [video, nya, ga, bisa, diputar, padahal, udah,...
# 2    [eror, terus, video, nya, nyesel, gue, makai, ...
# 3    [aku, punya, keluhan, terhadap, link, web, ata...
# 4    [halo, ka, kalo, buat, pc, letak, drill, soal,...
# ..                                                 ...
# 993                [iya, bagus, banget, aplikasi, nya]
# 994  [dari, ruangguru, ini, cukup, oke, tapi, tolon...
# 995       [ruang, guru, dapat, memahami, pelajarannya]
# 996  [gila, gila, gila, 3, kata, tp, gils, bgt, sih...
# 997  [wah, ruang, guru, ini, cocoa, until, anak, an...
#
#                                              Stopwords
# 0                              [roboguru, beli, paket]
# 1                            [video, diputar, diunduh]
# 2       [eror, video, nyesel, gue, makai, ruang, guru]
# 3    [keluhan, link, web, xdari, notifikasi, ruangg...
# 4                                   [pc, letak, drill]
# ..                                                 ...
# 993                          [bagus, banget, aplikasi]
# 994  [ruangguru, oke, tolong, fitur, nomer, 10, ana...
# 995              [ruang, guru, memahami, pelajarannya]
# 996  [gila, gila, gila, 3, gils, gatau, ngetik, apa...
# 997  [ruang, guru, cocoa, until, anak, anak, anak, ...
#
# [936 rows x 5 columns]

# %% [markdown]
# # Distribusi Frekuensi NLTK

# %%
def freqDist_wrapper(text):
    return FreqDist(text)

df_skripsi['text_tokens_fdist'] = df_skripsi['text_tokens'].apply(freqDist_wrapper)

print('Frequency Tokens : \n') 
print(df_skripsi['text_tokens_fdist'].head().apply(lambda x : x.most_common()))
# Out:
# Frequency Tokens :
#
# 0    [(roboguru, 1), (harus, 1), (beli, 1), (paket,...
# 1    [(video, 1), (nya, 1), (ga, 1), (bisa, 1), (di...
# 2    [(eror, 1), (terus, 1), (video, 1), (nya, 1), ...
# 3    [(di, 4), (yang, 3), (aku, 2), (ruangguru, 2),...
# 4    [(halo, 1), (ka, 1), (kalo, 1), (buat, 1), (pc...
# Name: text_tokens_fdist, dtype: object

# %% [markdown]
# # Filtering (Penghapusan Stopwords) / Normalisasi

# %%
from nltk.corpus import stopwords

# %%
list_stopwords = stopwords.words('indonesian')

# %%
list_stopwords
# Out:
# ['ada',
#  'adalah',
#  'adanya',
#  'adapun',
#  'agak',
#  'agaknya',
#  'agar',
#  'akan',
#  'akankah',
#  'akhir',
#  'akhiri',
#  'akhirnya',
#  'aku',
#  'akulah',
#  'amat',
#  'amatlah',
#  'anda',
#  'andalah',
#  'antar',
#  'antara',
#  'antaranya',
#  'apa',
#  'apaan',
#  'apabila',
#  'apakah',
#  'apalagi',
#  'apatah',
#  'artinya',
#  'asal',
#  'asalkan',
#  'atas',
#  'atau',
#  'ataukah',
#  'ataupun',
#  'awal',
#  'awalnya',
#  'bagai',
#  'bagaikan',
#  'bagaimana',
#  'bagaimanakah',
#  'bagaimanapun',
#  'bagi',
#  'bagian',
#  'bahkan',
#  'bahwa',
#  'bahwasanya',
#  'baik',
#  'bakal',
#  'bakalan',
#  'balik',
#  'banyak',
#  'bapak',
#  'baru',
#  'bawah',
#  'beberapa',
#  'begini',
#  'beginian',
#  'beginikah',
#  'beginilah',
#  'begitu',
#  'begitukah',
#  'begitulah',
#  'begitupun',
#  'bekerja',
#  'belakang',
#  'belakangan',
#  'belum',
#  'belumlah',
#  'benar',
#  'benarkah',
#  'benarlah',
#  'berada',
#  'berakhir',
#  'berakhirlah',
#  'berakhirnya',
#  'berapa',
#  'berapakah',
#  'berapalah',
#  'berapapun',
#  'berarti',
#  'berawal',
#  'berbagai',
#  'berdatangan',
#  'beri',
#  'berikan',
#  'berikut',
#  'berikutnya',
#  'berjumlah',
#  'berkali-kali',
#  'berkata',
#  'berkehendak',
#  'berkeinginan',
#  'berkenaan',
#  'berlainan',
#  'berlalu',
#  'berlangsung',
#  'berlebihan',
#  'bermacam',
#  'bermacam-macam',
#  'bermaksud',
#  'bermula',
#  'bersama',
#  'bersama-sama',
#  'bersiap',
#  'bersiap-siap',
#  'bertanya',
#  'bertanya-tanya',
#  'berturut',
#  'berturut-turut',
#  'bertutur',
#  'berujar',
#  'berupa',
#  'besar',
#  'betul',
#  'betulkah',
#  'biasa',
#  'biasanya',
#  'bila',
#  'bilakah',
#  'bisa',
#  'bisakah',
#  'boleh',
#  'bolehkah',
#  'bolehlah',
#  'buat',
#  'bukan',
#  'bukankah',
#  'bukanlah',
#  'bukannya',
#  'bulan',
#  'bung',
#  'cara',
#  'caranya',
#  'cukup',
#  'cukupkah',
#  'cukuplah',
#  'cuma',
#  'dahulu',
#  'dalam',
#  'dan',
#  'dapat',
#  'dari',
#  'daripada',
#  'datang',
#  'dekat',
#  'demi',
#  'demikian',
#  'demikianlah',
#  'dengan',
#  'depan',
#  'di',
#  'dia',
#  'diakhiri',
#  'diakhirinya',
#  'dialah',
#  'diantara',
#  'diantaranya',
#  'diberi',
#  'diberikan',
#  'diberikannya',
#  'dibuat',
#  'dibuatnya',
#  'didapat',
#  'didatangkan',
#  'digunakan',
#  'diibaratkan',
#  'diibaratkannya',
#  'diingat',
#  'diingatkan',
#  'diinginkan',
#  'dijawab',
#  'dijelaskan',
#  'dijelaskannya',
#  'dikarenakan',
#  'dikatakan',
#  'dikatakannya',
#  'dikerjakan',
#  'diketahui',
#  'diketahuinya',
#  'dikira',
#  'dilakukan',
#  'dilalui',
#  'dilihat',
#  'dimaksud',
#  'dimaksudkan',
#  'dimaksudkannya',
#  'dimaksudnya',
#  'diminta',
#  'dimintai',
#  'dimisalkan',
#  'dimulai',
#  'dimulailah',
#  'dimulainya',
#  'dimungkinkan',
#  'dini',
#  'dipastikan',
#  'diperbuat',
#  'diperbuatnya',
#  'dipergunakan',
#  'diperkirakan',
#  'diperlihatkan',
#  'diperlukan',
#  'diperlukannya',
#  'dipersoalkan',
#  'dipertanyakan',
#  'dipunyai',
#  'diri',
#  'dirinya',
#  'disampaikan',
#  'disebut',
#  'disebutkan',
#  'disebutkannya',
#  'disini',
#  'disinilah',
#  'ditambahkan',
#  'ditandaskan',
#  'ditanya',
#  'ditanyai',
#  'ditanyakan',
#  'ditegaskan',
#  'ditujukan',
#  'ditunjuk',
#  'ditunjuki',
#  'ditunjukkan',
#  'ditunjukkannya',
#  'ditunjuknya',
#  'dituturkan',
#  'dituturkannya',
#  'diucapkan',
#  'diucapkannya',
#  'diungkapkan',
#  'dong',
#  'dua',
#  'dulu',
#  'empat',
#  'enggak',
#  'enggaknya',
#  'entah',
#  'entahlah',
#  'guna',
#  'gunakan',
#  'hal',
#  'hampir',
#  'hanya',
#  'hanyalah',
#  'hari',
#  'harus',
#  'haruslah',
#  'harusnya',
#  'hendak',
#  'hendaklah',
#  'hendaknya',
#  'hingga',
#  'ia',
#  'ialah',
#  'ibarat',
#  'ibaratkan',
#  'ibaratnya',
#  'ibu',
#  'ikut',
#  'ingat',
#  'ingat-ingat',
#  'ingin',
#  'inginkah',
#  'inginkan',
#  'ini',
#  'inikah',
#  'inilah',
#  'itu',
#  'itukah',
#  'itulah',
#  'jadi',
#  'jadilah',
#  'jadinya',
#  'jangan',
#  'jangankan',
#  'janganlah',
#  'jauh',
#  'jawab',
#  'jawaban',
#  'jawabnya',
#  'jelas',
#  'jelaskan',
#  'jelaslah',
#  'jelasnya',
#  'jika',
#  'jikalau',
#  'juga',
#  'jumlah',
#  'jumlahnya',
#  'justru',
#  'kala',
#  'kalau',
#  'kalaulah',
#  'kalaupun',
#  'kalian',
#  'kami',
#  'kamilah',
#  'kamu',
#  'kamulah',
#  'kan',
#  'kapan',
#  'kapankah',
#  'kapanpun',
#  'karena',
#  'karenanya',
#  'kasus',
#  'kata',
#  'katakan',
#  'katakanlah',
#  'katanya',
#  'ke',
#  'keadaan',
#  'kebetulan',
#  'kecil',
#  'kedua',
#  'keduanya',
#  'keinginan',
#  'kelamaan',
#  'kelihatan',
#  'kelihatannya',
#  'kelima',
#  'keluar',
#  'kembali',
#  'kemudian',
#  'kemungkinan',
#  'kemungkinannya',
#  'kenapa',
#  'kepada',
#  'kepadanya',
#  'kesampaian',
#  'keseluruhan',
#  'keseluruhannya',
#  'keterlaluan',
#  'ketika',
#  'khususnya',
#  'kini',
#  'kinilah',
#  'kira',
#  'kira-kira',
#  'kiranya',
#  'kita',
#  'kitalah',
#  'kok',
#  'kurang',
#  'lagi',
#  'lagian',
#  'lah',
#  'lain',
#  'lainnya',
#  'lalu',
#  'lama',
#  'lamanya',
#  'lanjut',
#  'lanjutnya',
#  'lebih',
#  'lewat',
#  'lima',
#  'luar',
#  'macam',
#  'maka',
#  'makanya',
#  'makin',
#  'malah',
#  'malahan',
#  'mampu',
#  'mampukah',
#  'mana',
#  'manakala',
#  'manalagi',
#  'masa',
#  'masalah',
#  'masalahnya',
#  'masih',
#  'masihkah',
#  'masing',
#  'masing-masing',
#  'mau',
#  'maupun',
#  'melainkan',
#  'melakukan',
#  'melalui',
#  'melihat',
#  'melihatnya',
#  'memang',
#  'memastikan',
#  'memberi',
#  'memberikan',
#  'membuat',
#  'memerlukan',
#  'memihak',
#  'meminta',
#  'memintakan',
#  'memisalkan',
#  'memperbuat',
#  'mempergunakan',
#  'memperkirakan',
#  'memperlihatkan',
#  'mempersiapkan',
#  'mempersoalkan',
#  'mempertanyakan',
#  'mempunyai',
#  'memulai',
#  'memungkinkan',
#  'menaiki',
#  'menambahkan',
#  'menandaskan',
#  'menanti',
#  'menanti-nanti',
#  'menantikan',
#  'menanya',
#  'menanyai',
#  'menanyakan',
#  'mendapat',
#  'mendapatkan',
#  'mendatang',
#  'mendatangi',
#  'mendatangkan',
#  'menegaskan',
#  'mengakhiri',
#  'mengapa',
#  'mengatakan',
#  'mengatakannya',
#  'mengenai',
#  'mengerjakan',
#  'mengetahui',
#  'menggunakan',
#  'menghendaki',
#  'mengibaratkan',
#  'mengibaratkannya',
#  'mengingat',
#  'mengingatkan',
#  'menginginkan',
#  'mengira',
#  'mengucapkan',
#  'mengucapkannya',
#  'mengungkapkan',
#  'menjadi',
#  'menjawab',
#  'menjelaskan',
#  'menuju',
#  'menunjuk',
#  'menunjuki',
#  'menunjukkan',
#  'menunjuknya',
#  'menurut',
#  'menuturkan',
#  'menyampaikan',
#  'menyangkut',
#  'menyatakan',
#  'menyebutkan',
#  'menyeluruh',
#  'menyiapkan',
#  'merasa',
#  'mereka',
#  'merekalah',
#  'merupakan',
#  'meski',
#  'meskipun',
#  'meyakini',
#  'meyakinkan',
#  'minta',
#  'mirip',
#  'misal',
#  'misalkan',
#  'misalnya',
#  'mula',
#  'mulai',
#  'mulailah',
#  'mulanya',
#  'mungkin',
#  'mungkinkah',
#  'nah',
#  'naik',
#  'namun',
#  'nanti',
#  'nantinya',
#  'nyaris',
#  'nyatanya',
#  'oleh',
#  'olehnya',
#  'pada',
#  'padahal',
#  'padanya',
#  'pak',
#  'paling',
#  'panjang',
#  'pantas',
#  'para',
#  'pasti',
#  'pastilah',
#  'penting',
#  'pentingnya',
#  'per',
#  'percuma',
#  'perlu',
#  'perlukah',
#  'perlunya',
#  'pernah',
#  'persoalan',
#  'pertama',
#  'pertama-tama',
#  'pertanyaan',
#  'pertanyakan',
#  'pihak',
#  'pihaknya',
#  'pukul',
#  'pula',
#  'pun',
#  'punya',
#  'rasa',
#  'rasanya',
#  'rata',
#  'rupanya',
#  'saat',
#  'saatnya',
#  'saja',
#  'sajalah',
#  'saling',
#  'sama',
#  'sama-sama',
#  'sambil',
#  'sampai',
#  'sampai-sampai',
#  'sampaikan',
#  'sana',
#  'sangat',
#  'sangatlah',
#  'satu',
#  'saya',
#  'sayalah',
#  'se',
#  'sebab',
#  'sebabnya',
#  'sebagai',
#  'sebagaimana',
#  'sebagainya',
#  'sebagian',
#  'sebaik',
#  'sebaik-baiknya',
#  'sebaiknya',
#  'sebaliknya',
#  'sebanyak',
#  'sebegini',
#  'sebegitu',
#  'sebelum',
#  'sebelumnya',
#  'sebenarnya',
#  'seberapa',
#  'sebesar',
#  'sebetulnya',
#  'sebisanya',
#  'sebuah',
#  'sebut',
#  'sebutlah',
#  'sebutnya',
#  'secara',
#  'secukupnya',
#  'sedang',
#  'sedangkan',
#  'sedemikian',
#  'sedikit',
#  'sedikitnya',
#  'seenaknya',
#  'segala',
#  'segalanya',
#  'segera',
#  'seharusnya',
#  'sehingga',
#  'seingat',
#  'sejak',
#  'sejauh',
#  'sejenak',
#  'sejumlah',
#  'sekadar',
#  'sekadarnya',
#  'sekali',
#  'sekali-kali',
#  'sekalian',
#  'sekaligus',
#  'sekalipun',
#  'sekarang',
#  'sekarang',
#  'sekecil',
#  'seketika',
#  'sekiranya',
#  'sekitar',
#  'sekitarnya',
#  'sekurang-kurangnya',
#  'sekurangnya',
#  'sela',
#  'selain',
#  'selaku',
#  'selalu',
#  'selama',
#  'selama-lamanya',
#  'selamanya',
#  'selanjutnya',
#  'seluruh',
#  'seluruhnya',
#  'semacam',
#  'semakin',
#  'semampu',
#  'semampunya',
#  'semasa',
#  'semasih',
#  'semata',
#  'semata-mata',
#  'semaunya',
#  'sementara',
#  'semisal',
#  'semisalnya',
#  'sempat',
#  'semua',
#  'semuanya',
#  'semula',
#  'sendiri',
#  'sendirian',
#  'sendirinya',
#  'seolah',
#  'seolah-olah',
#  'seorang',
#  'sepanjang',
#  'sepantasnya',
#  'sepantasnyalah',
#  'seperlunya',
#  'seperti',
#  'sepertinya',
#  'sepihak',
#  'sering',
#  'seringnya',
#  'serta',
#  'serupa',
#  'sesaat',
#  'sesama',
#  'sesampai',
#  'sesegera',
#  'sesekali',
#  'seseorang',
#  'sesuatu',
#  'sesuatunya',
#  'sesudah',
#  'sesudahnya',
#  'setelah',
#  'setempat',
#  'setengah',
#  'seterusnya',
#  'setiap',
#  'setiba',
#  'setibanya',
#  'setidak-tidaknya',
#  'setidaknya',
#  'setinggi',
#  'seusai',
#  'sewaktu',
#  'siap',
#  'siapa',
#  'siapakah',
#  'siapapun',
#  'sini',
#  'sinilah',
#  'soal',
#  'soalnya',
#  'suatu',
#  'sudah',
#  'sudahkah',
#  'sudahlah',
#  'supaya',
#  'tadi',
#  'tadinya',
#  'tahu',
#  'tahun',
#  'tak',
#  'tambah',
#  'tambahnya',
#  'tampak',
#  'tampaknya',
#  'tandas',
#  'tandasnya',
#  'tanpa',
#  'tanya',
#  'tanyakan',
#  'tanyanya',
#  'tapi',
#  'tegas',
#  'tegasnya',
#  'telah',
#  'tempat',
#  'tengah',
#  'tentang',
#  'tentu',
#  'tentulah',
#  'tentunya',
#  'tepat',
#  'terakhir',
#  'terasa',
#  'terbanyak',
#  'terdahulu',
#  'terdapat',
#  'terdiri',
#  'terhadap',
#  'terhadapnya',
#  'teringat',
#  'teringat-ingat',
#  'terjadi',
#  'terjadilah',
#  'terjadinya',
#  'terkira',
#  'terlalu',
#  'terlebih',
#  'terlihat',
#  'termasuk',
#  'ternyata',
#  'tersampaikan',
#  'tersebut',
#  'tersebutlah',
#  'tertentu',
#  'tertuju',
#  'terus',
#  'terutama',
#  'tetap',
#  'tetapi',
#  'tiap',
#  'tiba',
#  'tiba-tiba',
#  'tidak',
#  'tidakkah',
#  'tidaklah',
#  'tiga',
#  'tinggi',
#  'toh',
#  'tunjuk',
#  'turut',
#  'tutur',
#  'tuturnya',
#  'ucap',
#  'ucapnya',
#  'ujar',
#  'ujarnya',
#  'umum',
#  'umumnya',
#  'ungkap',
#  'ungkapnya',
#  'untuk',
#  'usah',
#  'usai',
#  'waduh',
#  'wah',
#  'wahai',
#  'waktu',
#  'waktunya',
#  'walau',
#  'walaupun',
#  'wong',
#  'yaitu',
#  'yakin',
#  'yakni',
#  'yang']

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier

clf =  RandomForestClassifier(random_state=0, max_features ='sqrt',max_depth = 100)
knn = KNeighborsClassifier(n_neighbors=7)
nb = GaussianNB()
dt = DecisionTreeClassifier(max_features ='sqrt',max_depth = 100)
svm = SVC(degree=3)
# clf.fit(X, y)

# %%
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

normalizad_word = pd.read_csv("colloquial-indonesian-lexicon.csv")

normalizad_word_dict = {}

for index, row in normalizad_word.iterrows():
    if row[0] not in normalizad_word_dict:
        normalizad_word_dict[row[0]] = row[1] 

def normalized_term(document):
    return [normalizad_word_dict[term] if term in normalizad_word_dict else term for term in document]

df_skripsi['text_normalized'] = df_skripsi['Stopwords'].apply(normalized_term)


# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in df_skripsi['text_normalized']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")


# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]

df_skripsi['text_tokens_stemmed'] = df_skripsi['text_normalized'].swifter.apply(get_stemmed_term)
# Out:
# 2074
# ------------------------
# roboguru : roboguru
# beli : beli
# paket : paket
# video : video
# diputar : putar
# diunduh : unduh
# eror : eror
# menyesal : sesal
# gue : gue
# makai : maka
# ruang : ruang
# guru : guru
# keluhan : keluh
# link : link
# web : web
# xdari : xdari
# notifikasi : notifikasi
# ruangguru : ruangguru
# buka : buka
# semuakesel : semuakesel
# banget : banget
# mencoba : coba
# pindah : pindah
# lokasi : lokasi
# siyalnya : siyalnya
# full : full
# loading : loading
# errorpleaselah : errorpleaselah
# tolong : tolong
# jaga : jaga
# kenyamanan : nyaman
# aplikasi : aplikasi
# jugasebenernya : jugasebenernya
# tinggal : tinggal
# jaringannya : jaring
# ngebut : ngebut
# nyaman : nyaman
# pakai : pakai
# pc : pc
# letak : letak
# drill : drill
# maksa : maksa
# langganan : langgan
# jawabannya : jawab
# salah : salah
# kasih : kasih
# ar : ar
# ulangan : ulang
# 92 : 92
# buruk : buruk
# sudah : sudah
# bagus : bagus
# kadang : kadang
# quiznya : quiznya
# error : error
# benar : benar
# dapat : dapat
# xp : xp
# pelajaran : ajar
# bintang : bintang
# 4 : 4
# seru : seru
# dafa : dafa
# lulu : lulu
# menyenangkan : senang
# kecewa : kecewa
# jawabanpenjelasan : jawabanpenjelasan
# komputerleptop : komputerleptop
# websitecrome : websitecrome
# diaksesdan : diaksesdan
# berlangganan : langgan
# dibukaitu : dibukaitu
# saran : saran
# kesan : kesan
# sayasaya : sayasaya
# harap : harap
# kedepannya : depan
# penggunaan : guna
# website : website
# terbuka : buka
# terimakasih : terimakasih
# lumayan : lumayan
# tuli : tuli
# upgrade : upgrade
# subtitle : subtitle
# indonesia : indonesia
# terima kasih : terima kasih
# sumpah : sumpah
# keluh : keluh
# kesah : kesah
# doang : doang
# suport : suport
# android : android
# suruh : suruh
# hh : hh
# selesai : selesai
# sekian : sekian
# videonya : video
# tulisanya : tulisanya
# gagal : gagal
# memuat : muat
# coba : coba
# 3 : 3
# nyobs : nyobs
# mode : mode
# online : online
# offline : offline
# tulisannya : tulis
# kayak : kayak
# belajar : ajar
# susah : susah
# hasil : hasil
# screenshot : screenshot
# mtk : mtk
# wajib : wajib
# minat : minat
# dipisahkan : pisah
# mudah : mudah
# overall : overall
# eemm : eemm
# tanya : tanya
# tutor : tutor
# koinnya : koin
# mahal : mahal
# 1 : 1
# 15 : 15
# krg : krg
# pas : pas
# putus2 : putus2
# jaringan : jaring
# lancar : lancar
# maaf : maaf
# kondisikan : kondisi
# konsultannya : konsultan
# menghubungi : hubung
# chat : chat
# telfon : telfon
# risih : risih
# berminat : minat
# konfirmasi : konfirmasi
# konsultanbeli : konsultanbeli
# marketplace : marketplace
# terima : terima
# hapus : hapus
# karena : karena
# english : english
# tagihan : tagih
# burik : burik
# sok : sok
# pembahasan : bahas
# banayak : banayak
# netral : netral
# aplikasinya : aplikasi
# fitur : fitur
# fiturnya : fiturnya
# lengkap : lengkap
# sayangnya : sayang
# materi : materi
# diakses : akses
# gbng : gbng
# instal : instal
# smkwakwakwak : smkwakwakwak
# jelek : jelek
# bayar : bayar
# 2 : 2
# komplen : komplen
# berminggu2 : berminggu2
# penyelesaian : selesai
# dianggap : anggap
# bukti : bukti
# disertakan : serta
# download : download
# dibukaerror : dibukaerror
# sihkalau : sihkalau
# dibenahi : benah
# muat : muat
# ulang : ulang
# trussvidio : trussvidio
# putar : putar
# knpaa : knpaa
# padhal : padhal
# menonton : tonton
# baca : baca
# suka : suka
# lola : lola
# lobby : lobby
# tetap : tetap
# menekan : tekan
# avatar : avatar
# berubah : ubah
# persis : persis
# teman : teman
# avayar : avayar
# lan : lan
# diubah : ubah
# bari : bari
# level : level
# 82 : 82
# rg : rg
# buriek : buriek
# jujur : jujur
# banguss : banguss
# keganggu : ganggu
# spam : spam
# message : message
# ganti : ganti
# membeli : beli
# kemarin : kemarin
# kesalahan : salah
# sistem : sistem
# terus : terus
# wifi : wifi
# tiket : tiket
# setelah : telah
# takutnya : takut
# 7 : 7
# butuh : butuh
# semoga : moga
# secepatnya : cepat
# duit : duit
# kenapa : kenapa
# enggak : enggak
# mapel : mapel
# bhsa : bhsa
# daerah : daerah
# pertanianseni : pertanianseni
# budaya : budaya
# pakarya : pakarya
# informatika : informatika
# sekolah : sekolah
# lupa : lupa
# nilai : nilai
# gurunya : guru
# ingat : ingat
# mengasih : asih
# ku : ku
# pencet : pencet
# kirim : kirim
# muncul : muncul
# tulisan : tulis
# begini : begini
# invalid : invalid
# response : response
# was : was
# received : received
# upstream : upstream
# server : server
# solusi : solusi
# apk : apk
# menunggu : tunggu
# antrian : antri
# aman : aman
# berkisar : kisar
# 50 : 50
# keatas : atas
# cepat : cepat
# 10 : 10
# diperbaiki : baik
# tertipu : tipu
# plus : plus
# bernama : nama
# dinna : dinna
# sesuai : sesuai
# difoto : foto
# tindaklanjuti : tindaklanjuti
# semenjak : semenjak
# lihat : lihat
# gaenak : gaenak
# hp : hp
# bagusdi : bagusdi
# laptop : laptop
# ditonton : tonton
# penyimpanan : simpan
# dibandingkan : banding
# mengajarnya : ajar
# selengkapnya : lengkap
# nomer : nomer
# penawaran : tawar
# teror : teror
# pinjol : pinjol
# awalawal : awalawal
# namanya : nama
# koin : koin
# harga : harga
# belinya : beli
# sesi : sesi
# nanyain : nanyain
# sesinya : sesi
# ngabisin : ngabisin
# harganya : harga
# peraturannya : atur
# turun : turun
# aneh : aneh
# dipakai : pakai
# terusan : terus
# google : google
# batesnya : batesnya
# giliran : gilir
# bates : bates
# anak : anak
# lounching : lounching
# perpanjangan : panjang
# serasa : serasa
# dikoyak : koyak
# oyakpdhl : oyakpdhl
# semester : semester
# smstr : smstr
# pelanggan : langgan
# diperhatikan : perhati
# yakinlah : yakin
# cocok : cocok
# dipahami : paham
# peningkatan : tingkat
# adapto : adapto
# kuis : kuis
# tibatiba : tibatiba
# buram : buram
# bergarisgaris : bergarisgaris
# niat : niat
# uang : uang
# tampilantingkatkn : tampilantingkatkn
# gratis : gratis
# bug : bug
# musik : musik
# ganggu : ganggu
# koneksi : koneksi
# force : force
# close : close
# heran : heran
# poco : poco
# pro : pro
# chipsetnya : chipsetnya
# snapdragon : snapdragon
# 800 : 800
# malas : malas
# perbaiki : baik
# pembelajaran : ajar
# hewan : hewan
# sakit : sakit
# balikin : balikin
# nyicil : nyicil
# pengin : pengin
# tapi : tapi
# lagi : lagi
# hemat : hemat
# dkembaiin : dkembaiin
# pasti : pasti
# affah : affah
# iya : iya
# butut : butut
# minimal : minimal
# difix : difix
# rilis : rilis
# poling : poling
# lantai : lantai
# masih : masih
# ngawur : ngawur
# this : this
# application : application
# very : very
# live : live
# lag : lag
# enggak usah : enggak usah
# parah : parah
# sulit : sulit
# reting : reting
# paksa : paksa
# akses : akses
# luas : luas
# berfungsi : fungsi
# mengecewakan : kecewa
# pengguna : guna
# ruanggru : ruanggru
# dihilangkan : hilang
# pelekspiperlekspi : pelekspiperlekspi
# pepiku : pepiku
# awaskslsutidak : awaskslsutidak
# lengakappetoperepiku : lengakappetoperepiku
# sayang : sayang
# juara : juara
# kelas : kelas
# berusaha : usaha
# semaksimal : maksimal
# dering : dering
# menyebut : sebut
# nama : nama
# pemangil : pemangil
# vidionya : vidionya
# mulu : mulu
# daily : daily
# challenge : challenge
# indak : indak
# dibuka : buka
# customer : customer
# servicenya : servicenya
# tutup : tutup
# install : install
# sms : sms
# kode : kode
# otp : otp
# ngelag : ngelag
# scroll : scroll
# diam : diam
# sinyal : sinyal
# konten : konten
# promosi : promosi
# dipikirkan : pikir
# dichat : dichat
# orang tua : orang tua
# pemaksaan : paksa
# liga : liga
# quality : quality
# terganggu : ganggu
# cuman : cuman
# ngelagnya : ngelagnya
# anjing : anjing
# login : login
# ngerjain : ngerjain
# donlot : donlot
# 80 : 80
# apli : apli
# penjelasannya : jelas
# pahami : paham
# lemot : lot
# padahal : padahal
# stabil : stabil
# mood : mood
# pembelajarannyaa : pembelajarannyaa
# polling : polling
# teaching : teaching
# disalahkan : salah
# latsolnya : latsolnya
# hasilnya : hasil
# berulang : ulang
# mempelajari : ajar
# bahasa : bahasa
# asing : asing
# semudah : mudah
# ucapkanmemerlukan : ucapkanmemerlukan
# ketekunan : tekun
# rajin : rajin
# mempraktikan : praktik
# pemakaian : pakai
# pelajari : ajar
# takut : takut
# salahsalah : salahsalah
# kok : kok
# kagak : kagak
# ml : ml
# memakai : pakai
# vale : vale
# brain : brain
# academy : academy
# ekspektasi : ekspektasi
# menjamin : jamin
# kualitas : kualitas
# emosi : emosi
# sukacuman : sukacuman
# membantu : bantu
# meningkat : tingkat
# paham : paham
# telepon : telepon
# kendala : kendala
# memutar : putar
# adaptonya : adaptonya
# berjalan : jalan
# sampai : sampai
# stuck : stuck
# situ : situ
# tolonglah : tolong
# jengkel : jengkel
# pelajarannya : ajar
# dikit : dikit
# hilang : hilang
# mati : mati
# hidup : hidup
# game : game
# diteror : teror
# whatsapp : whatsapp
# telpon : telpon
# berkali : kali
# minggu : minggu
# ajaran : ajar
# mengesalkan : kesal
# load : load
# belum : belum
# akun : akun
# log : log
# out : out
# history : history
# tontonan : tonton
# otomatis : otomatis
# hilangtolong : hilangtolong
# habis : habis
# ngedown : ngedown
# sihapaa : sihapaa
# siyal : siyal
# gua : gua
# kencengtolong : kencengtolong
# teamnya : teamnya
# kofirmasikannggangu : kofirmasikannggangu
# diganggutolong : diganggutolong
# belajarnya : ajar
# alasannya : alas
# tunggu : tunggu
# ulangi : ulang
# pencarian : cari
# klik : klik
# berkalikali : berkalikali
# batal : batal
# tutornya : tutor
# tugas : tugas
# buangbuang : buangbuang
# kesal : kesal
# buffering : buffering
# notif : notif
# kondisi : kondisi
# komentar : komentar
# mengalami : alami
# menghambat : hambat
# nelponganggu : nelponganggu
# sopan : sopan
# stop : stop
# putus : putus
# enjoy : enjoy
# belajarnyaaku : belajarnyaaku
# main : main
# youtube : youtube
# 5 : 5
# menit : menit
# putusputustolonglahya : putusputustolonglahya
# gampang : gampang
# aplkasi : aplkasi
# pertannyan : pertannyan
# kalkulator : kalkulator
# iklan : iklan
# dimengerti : erti
# mengarti : arti
# manyoritas : manyoritas
# kapitalis : kapitalis
# puas : puas
# kesini : kesini
# terbatas : batas
# berbayar : bayar
# mengganggu : ganggu
# penurunan : turun
# performa : performa
# satunya : satu
# sharing : sharing
# yangmana : yangmana
# diupload : diupload
# terkropterzoom : terkropterzoom
# menyebabkan : sebab
# informasi : informasi
# terbaca : baca
# terkrop : terkrop
# turunkan : turun
# rating : rating
# ada : ada
# mulok : mulok
# sistemnya : sistem
# kasihan : kasihan
# kepakai : pakai
# pembelajarannya : ajar
# interaktif : interaktif
# detik : detik
# orang : orang
# bilangnya : bilang
# alhasil : alhasil
# poin : poin
# sedih : sedih
# termotivasi : motivasi
# payah : payah
# perpanjang : panjang
# kakak2 : kakak2
# tidakk : tidakk
# jelaas : jelaas
# kebimbel : kebimbel
# hubungi : hubung
# karyawan : karyawan
# menggangu : menggangu
# mendownload : mendownload
# terkendala : kendala
# streamingnya : streamingnya
# masukan : masuk
# email : email
# mengapus : mengapus
# gurusinyal : gurusinyal
# oke : oke
# terpaksa : paksa
# enggak jelas : enggak jelas
# kesel : kesel
# konyol : konyol
# meninggalkan : tinggal
# sebentar : sebentar
# open : open
# rangkuman : rangkum
# saja : saja
# lagih : lagih
# les : les
# dikunci : kunci
# babi : babi
# tua : tua
# plis : plis
# vidio : vidio
# servernya : servernya
# growtopia : growtopia
# play : play
# kuota : kuota
# try : try
# premiumnya : premium
# 0 : 0
# seminggu : minggu
# normal : normal
# diperbaik : baik
# sinyalnya : sinyal
# materinya : materi
# banayakin : banayakin
# vid : vid
# kurikulum : kurikulum
# merdeka : merdeka
# tersedia : sedia
# lengkapi : lengkap
# perfect : perfect
# sempurna : sempurna
# premium : premium
# menyebarkan : sebar
# nomor : nomor
# auto : auto
# lock : lock
# scren : scren
# terkadang : terkadang
# layar : layar
# rasionalisasi : rasionalisasi
# rapot : rapot
# refresh : refresh
# capek : capek
# memasukkan : masuk
# bagustetapi : bagustetapi
# sebenarnya : benar
# detail : detail
# memang : memang
# bermasalah : masalah
# berpuluh : puluh
# puluh : puluh
# menolak : tolak
# paketnya : paket
# diturunin : diturunin
# ditambahin : ditambahin
# miskin : miskin
# berlanggan : langgan
# memaksa : paksa
# kebutuhan : butuh
# ngechat : ngechat
# upload : upload
# file : file
# rapor : rapor
# x1 : x1
# gmnaa : gmnaa
# tolol : tolol
# smk : smk
# t0d : t0d
# disayang : sayang
# internet : internet
# amanaman : amanaman
# memaksakan : paksa
# kehendak : hendak
# merating : merating
# menerus : terus
# scrolling : scrolling
# temui : temu
# typo : typo
# penulisan : tulis
# note : note
# signal : signal
# enggak bisa : enggak bisa
# dekat : dekat
# utbk : utbk
# dikasih : kasih
# penjelasan : jelas
# bagusstetapi : bagusstetapi
# bab : bab
# pkn : pkn
# 8 : 8
# tambahkan : tambah
# daftar : daftar
# tranfer : tranfer
# 600rb : 600rb
# 24jam : 24jam
# adminnya : adminnya
# dulu : dulu
# menepati : tepat
# janji : janji
# bertambah : tambah
# bintangnya : bintang
# sebel : sebel
# ditungguin : ditungguin
# jam : jam
# kuisnya : kuis
# munculmuncul : munculmuncul
# pikir : pikir
# protes : protes
# tanggapan : tanggap
# menyakn : menyakn
# forum : forum
# ketemu : ketemu
# robo : robo
# bad : bad
# request : request
# ambil : ambil
# rendah : rendah
# lancar2 : lancar2
# keputar : putar
# nyangkut2 : nyangkut2
# pelitt : pelitt
# gratisin : gratisin
# proses : proses
# penjawabnya : jawab
# diupdate : diupdate
# loadingnya : loadingnya
# bagusbagus : bagusbagus
# memperbaiki : baik
# owner : owner
# palagi : palagi
# semangat : semangat
# ribet : ribet
# tersembunyi : sembunyi
# diskon : diskon
# murah : murah
# dispam : dispam
# nomornya : nomor
# mengirim : kirim
# promo : promo
# beik : beik
# sajatapi : sajatapi
# baguslahdll : baguslahdll
# 5oh : 5oh
# data : data
# bicara : bicara
# ngejelasin : ngejelasin
# dengar : dengar
# ngelek : ngelek
# geser : geser
# kekana : kana
# kekiri : kir
# bermasalahtolong : bermasalahtolong
# dicoba : coba
# berbeda : beda
# beda : beda
# menangis : menang
# huhu : huhu
# benerin : benerin
# apknya : apknya
# opsi : opsi
# seringkali : seringkali
# peluang : peluang
# snbp : snbp
# terblokir : blokir
# ngulang : ngulang
# bolak : bolak
# super : super
# duper : duper
# gurusales : gurusales
# admin : admin
# jelasin : jelasin
# lemah : lemah
# oaksa : oaksa
# kegunaannya : guna
# soak : soak
# menyimpang : simpang
# sesuaisoal : sesuaisoal
# berbobot : bobot
# service : service
# memuaskan : muas
# membosankan : bosan
# pelayananan : pelayananan
# valas : valas
# merepotkan : repot
# belajae : belajae
# disuruh : suruh
# apl : apl
# bayak : bayak
# layarnya : layar
# udak : udak
# jenjang : jenjang
# jurusan : jurus
# farmasisemoga : farmasisemoga
# menyediakan : sedia
# farmasi : farmasi
# latihan : latih
# mission : mission
# scheduling : scheduling
# errornya : errornya
# masmba : masmba
# respon : respon
# diread : diread
# sekarangjauh : sekarangjauh
# onlineyang : onlineyang
# 30mnt : 30mnt
# batasan : batas
# soalyang : soalyang
# 1soal : 1soal
# koinkaya : koinkaya
# minsemoga : minsemoga
# lagiagar : lagiagar
# senang : senang
# contohnya : contoh
# format : format
# memori : memori
# sd : sd
# card : card
# gagaltidak : gagaltidak
# ranking : ranking
# terhubung : hubung
# internetpadahal : internetpadahal
# wifidatanya : wifidatanya
# dehsekarang : dehsekarang
# lancarr : lancarr
# muter : muter
# videone : videone
# padshal : padshal
# enak2 : enak2
# gamood : gamood
# bagusberjalan : bagusberjalan
# dikiranya : kira
# dibikin : bikin
# slesai : slesai
# skornya : skor
# kosong : kosong
# makan : makan
# ruangbelajar : ruangbelajar
# bao : bao
# kebuka : buka
# perbaikan : baik
# selesaidiakhir : selesaidiakhir
# rangkumannya : rangkum
# nggat : nggat
# jawabanya : jawabanya
# tiada : tiada
# memahami : paham
# terbantu : bantu
# disayangkan : sayang
# dikenal : kenal
# menelpon : telpon
# menawarkan : tawar
# elite : elite
# disitu : situ
# reguler : reguler
# sejujurnya : jujur
# seakan : akan
# menyepelekan : sepele
# privasi : privasi
# kebijakan : bijak
# lang : lang
# ganan : ganan
# biat : biat
# ringkasan : ringkas
# ringkasanya : ringkasanya
# bugstuck : bugstuck
# kecepatan : cepat
# mbps : mbps
# pengertiannya : erti
# masnya : mas
# ramah : ramah
# bercanda : canda
# kesemua : semua
# sekolahlu : sekolahlu
# membuka : buka
# videony : videony
# berlanggananykok : berlanggananykok
# pls : pls
# responnya : responnya
# hangus : hangus
# 800k : 800k
# utbkuntuk : utbkuntuk
# responyakarena : responyakarena
# mending : mending
# ngebosenin : ngebosenin
# rindu : rindu
# berhasil : hasil
# registrasi : registrasi
# tryout : tryout
# nyagimana : nyagimana
# dimana : mana
# pilihan : pilih
# tekan : tekan
# bu : bu
# sumber : sumber
# tawarin : tawarin
# hi : hi
# lulus : lulus
# kuliah : kuliah
# menghapus : hapus
# namai : nama
# palsusamaran : palsusamaran
# sigw : sigw
# kakak : kakak
# inikrna : inikrna
# menempel : tempel
# trskaka : trskaka
# berlanggananudh : berlanggananudh
# loginin : loginin
# jugatapi : jugatapi
# terustrs : terustrs
# hati : hati
# gara : gara
# abangga : abangga
# bersungguh : sungguh
# sungguh : sungguh
# anjga : anjga
# mengerti : erti
# sama : sama
# gwdan : gwdan
# sometimes : sometimes
# think : think
# born : born
# telpon2 : telpon2
# ngeganggu : ngeganggu
# trkoordinir : trkoordinir
# mnjengkelkan : mnjengkelkan
# teros : ros
# staf-stafnya : staf
# jawabinmbok : jawabinmbok
# mnghubungi : mnghubungi
# dicek : cek
# blomsudah : blomsudah
# tanggal : tanggal
# 25februari2022 : 25februari2022
# 28maret2022 : 28maret2022
# sebulan : bulan
# benaran : benar
# diiklankan : iklan
# tidakyg : tidakyg
# telanjur : telanjur
# setahun : tahun
# selese : selese
# dimatiin : dimatiin
# dibagian : bagi
# snbt : snbt
# episode : episode
# 14 : 14
# cek : cek
# terkerjakan : kerja
# awokawok : awokawok
# mampua : mampua
# bangkrut : bangkrut
# tugasnya : tugas
# muter2 : muter2
# kencang : kencang
# lemott : lemott
# rugi : rugi
# mengeejakan : eja
# trimakasih : trimakasih
# syangnya : syangnya
# cari : cari
# tiba-tiba : tiba
# sendiri : sendiri
# enng : enng
# berguna : guna
# daffa : daffa
# lulunya : lulunya
# tv : tv
# invasi : invasi
# lakukan : laku
# brainly : brainly
# awoakwoakwk : awoakwoakwk
# asli : asli
# konsultasi : konsultasi
# lelet : lelet
# app : app
# jlk : jlk
# film : film
# mendukung : dukung
# pengajaran : ajar
# kurikulumnya : kurikulum
# suaranya : suara
# lirih : lirih
# quizznya : quizznya
# kendalalangganan : kendalalangganan
# 9blnbaru : 9blnbaru
# 1bln : 1bln
# nydan : nydan
# sandinya : sandi
# solusinyamohon : solusinyamohon
# bantuannya : bantu
# bebe : bebe
# rapa : rapa
# plajaran : plajaran
# pjokdanbahasa : pjokdanbahasa
# baiki : baik
# kls : kls
# leg : leg
# buatyang : buatyang
# berlangganannya : langgan
# metode : metode
# efektif : efektif
# mls : mls
# pakaisering : pakaisering
# screen : screen
# shot : shot
# aduh : aduh
# deh : deh
# ikutan : ikut
# apanya : apa
# kreativitas : kreativitas
# menentu : tentu
# playlist : playlist
# direfresh : direfresh
# anjh : anjh
# developermengenai : developermengenai
# pengerjaan : kerja
# tryouttolong : tryouttolong
# batas : batas
# diulang : ulang
# pengerjaannyadengan : pengerjaannyadengan
# siswa : siswa
# terbiasa : biasa
# tersebutterimakasih : tersebutterimakasih
# dipaksa : paksa
# au : au
# screnshot : screnshot
# menyebalkan : sebal
# anjir : anjir
# rese : rese
# wu : wu
# sampaah : sampaah
# kebanyak : banyak
# macetpadahal : macetpadahal
# laintapi : laintapi
# pay : pay
# version : version
# hahaha : hahaha
# perintahkan : perintah
# bearti : bearti
# biaya : biaya
# tambahan : tambah
# bangettcuma : bangettcuma
# harganyaapadahal : harganyaapadahal
# buatku : buat
# menemukan : temu
# ppkn : ppkn
# pts : pts
# pelayanannya : layan
# ajukan : aju
# costumer : costumer
# mengabaikan : abai
# pesan : pesan
# persiapan : siap
# pernyataan : nyata
# ruanggur : ruanggur
# akhir2 : akhir2
# sangat : sangat
# jarang : jarang
# membutuhkan : butuh
# diroboguru : diroboguru
# dsb : dsb
# membayar : bayar
# 12 : 12
# robogurunya : robogurunya
# versi : versi
# dekstop : dekstop
# bugnya : bugnya
# hitam : hitam
# bantu : bantu
# mahal2 : mahal2
# tombol : tombol
# lompat : lompat
# pcdesktop : pcdesktop
# tekantekan : tekantekan
# sport : sport
# bidang : bidang
# sosiologi : sosiologi
# tindakan : tindak
# sosial : sosial
# lakilaki : lakilaki
# ngajarnya : ngajarnya
# menghilangkan : hilang
# tlong : tlong
# nih : nih
# masak : masak
# kerusakan : rusa
# kalau : kalau
# rate : rate
# 5lagi : 5lagi
# disaat : saat
# pliss : pliss
# kekurangan : kurang
# 1suaranya : 1suaranya
# patah : patah
# lima5 : lima5
# jepang : jepang
# mandarin : mandarin
# ibb : ibb
# rangkumansering : rangkumansering
# bawahscroll : bawahscroll
# turunmohon : turunmohon
# diperbaikiterimakasih : diperbaikiterimakasih
# pendapatku : dapat
# animasinya : animasi
# diruang : ruang
# disekolah : seko
# konsentrasinya : konsentrasi
# otak : otak
# pemula : mula
# lamaa : lamaa
# ditingkatkan : tingkat
# bioguru : bioguru
# foto : foto
# perbaki : baki
# pembayarannya : bayar
# gpay : gpay
# bermanfaat : manfaat
# apaansih : apaansih
# ipad : ipad
# kayaknya : kayak
# ngelanjutin : ngelanjutin
# aksesnya : akses
# enggak ada : enggak ada
# gaji : gaji
# rafli : rafli
# malije : malije
# sdn : sdn
# bukit : bukit
# durian : durian
# diruangguru : diruangguru
# sebagus : bagus
# itutp : itutp
# kendalasaya : kendalasaya
# berhenti : henti
# ruanggurulebih : ruanggurulebih
# ubah : ubah
# diajarkan : ajar
# smooth : smooth
# fleksibel : fleksibel
# rada : rada
# kaku : kaku
# mutar : mutar
# fidio : fidio
# tiduran : tidur
# lanskap : lanskap
# penjelasanya : jasa
# soalkalau : soalkalau
# nextsering : nextsering
# home : home
# nyaangeselin : nyaangeselin
# bagusan : bagus
# sebelemun : bun
# berisik : berisik
# hdehh : hdehh
# jwbn : jwbn
# bnrny : bnrny
# gjls : gjls
# otoh : otoh
# mu : mu
# 6 : 6
# jahat : jahat
# baguscuma : baguscuma
# yasaya : yasaya
# gitukayak : gitukayak
# dukungan : dukung
# asww : asww
# minini : min
# 89 : 89
# stan : stan
# ketahuan : tahu
# bngke : bngke
# murahin : murahin
# langgananya : langgananya
# pollingnya : pollingnya
# menyambung : sambung
# pengennya : ken
# sampah : sampah
# bertele : tele
# tele : tele
# over : over
# all : all
# anjg : anjg
# kacau : kacau
# enggak tau : enggak tau
# bego : bego
# ngegame : ngegame
# developernya : developer
# cache : cache
# bersih : bersih
# ratusan : ratus
# ribu : ribu
# uangnya : uang
# mencapai : capai
# cita : cita
# citaku : cita
# 700 : 700
# kebanyakan : banyak
# gaya : gaya
# ngebug : ngebug
# stylenya : stylenya
# dibanding : banding
# apalah : apa
# aktif : aktif
# 2x : 2x
# cs : cs
# via : via
# tim : tim
# nelfon : nelfon
# mulupadahal : mulupadahal
# iseng : iseng
# ditelfonin : ditelfonin
# call : call
# ngembaliinnya : ngembaliinnya
# bimbel : bimbel
# ruangbelajarruangbelajar : ruangbelajarruangbelajar
# kritik : kritik
# dipertahankan : tahan
# penyebab : sebab
# pelajar : ajar
# pergi : pergi
# bertelelele : tele
# bosan : bosan
# kesempatan : sempat
# menurutku : turut
# baiknya : baik
# kembangkan : kembang
# provaider : provaider
# kecewe : kecewe
# indongmert : indongmert
# pesanan : pesan
# tolak : tolak
# alasan : alas
# kendalanya : kendala
# perbaik : baik
# kinerja : kerja
# tingkatkan : tingkat
# membanyaki : banyak
# ngapai : ngapai
# kepo : kepo
# yauda : yauda
# begitu : begitu
# gadijawab : gadijawab
# malah : malah
# bpk : bpk
# verifikasi : verifikasi
# menyusahkan : susah
# juga : juga
# puter : puter
# kira-kira : kira
# ngerjakan : ngerjakan
# overal : overal
# ngestuck : ngestuck
# papa : papa
# karyawannya : karyawannya
# phk : phk
# kegedean : gede
# ngiklan : ngiklan
# daridulu : daridulu
# terdaftar : daftar
# tube : tube
# koneksinya : koneksi
# pet : pet
# levelnya : level
# evolusi : evolusi
# ruangguruku : ruangguruku
# internetnya : internetnya
# ruanggurunya : ruanggurunya
# bermaanfaat : bermaanfaat
# meledakrip : meledakrip
# 33 : 33
# stm : stm
# mts : mts
# janjian : janji
# logout : logout
# buang : buang
# dikasi : kasi
# kesulitan : sulit
# sembarangan : sembarang
# siapamungkin : siapamungkin
# uh : uh
# kimia : kimia
# 100 : 100
# kukira : kira
# 64 : 64
# 500 : 500
# angus : angus
# garagara : garagara
# wooi : wooi
# nerror : nerror
# setaon : setaon
# agen : agen
# kalian : kalian
# balas : balas
# kak : kak
# suer : suer
# baik : baik
# dibalas : balas
# blok : blok
# kejar : kejar
# rentenir : rentenir
# biarkan : biar
# tenang : tenang
# efisien : efisien
# karmilah : karmilah
# balita : balita
# mdhnya : mdhnya
# ktkn : ktkn
# lama-lama : lama
# ladang : ladang
# bisnis : bisnis
# berujung : ujung
# marketing : marketing
# telpwa : telpwa
# sewajarnya : wajar
# bisnisnya : bisnis
# pendidikannya : didik
# matematikanya : matematika
# 11 : 11
# brmsalah : brmsalah
# ternyata : nyata
# sananya : sana
# uninstall : uninstall
# berbelit : belit
# belit : belit
# pusing : pusing
# assalamualaikum : assalamualaikum
# bayargak : bayargak
# buku : buku
# gamegaada : gamegaada
# ditanyain : ditanyain
# ditelpon : telpon
# nelp : nelp
# kegiatan : giat
# apa : apa
# smart : smart
# schedule : schedule
# menampilkan : tampil
# misi : misi
# mingguan : minggu
# ruaanguru : ruaanguru
# menyesatkan : sesat
# pelajaranku : ajar
# dapatnya : dapat
# didownload : didownload
# mencari : cari
# bingung : bingung
# ph : ph
# media : media
# cuan : cuan
# serba : serba
# loginnya : loginnya
# bodoh : bodoh
# rangking : rangking
# dahulutpi : dahulutpi
# peliharaanyabelajar : peliharaanyabelajar
# ngescroll : ngescroll
# mitra : mitra
# gede : gede
# skalinya : skalinya
# seharian : hari
# cobattp : cobattp
# bisasaya : bisasaya
# lapor : lapor
# yamohon : yamohon
# gadapet : gadapet
# gambar : gambar
# maunya : mau
# singkat : singkat
# padat : padat
# akunnya : akun
# jangka : jangka
# masukkan : masuk
# dijamin : jamin
# ptn : ptn
# sesat : sesat
# presentase : presentase
# serius : serius
# jatuhnya : jatuh
# downloadnya : downloadnya
# naikin : naikin
# ratingnya : ratingnya
# downlot : downlot
# buset : buset
# allah : allah
# kepala : kepala
# bubarkan : bubar
# macet : macet
# tersinkronisasi : sinkronisasi
# menunjukan : tunjuk
# windows : windows
# selalu : selalu
# isi : isi
# akhirakhir : akhirakhir
# terkunci : kunci
# lama : lama
# nelponpdhl : nelponpdhl
# instalnya : instalnya
# student : student
# advisor : advisor
# gbisa : gbisa
# sikap : sikap
# putri : putri
# harian : hari
# dimarahi : marah
# mengcewakan : mengcewakan
# pelayanan : layan
# membalas : balas
# gambarnya : gambar
# terbaru : baru
# official : official
# malam2 : malam2
# sibuk : sibuk
# dek : dek
# chatnya : chatnya
# 2220 : 2220
# wth : wth
# research : research
# anakanak : anakanak
# segitu : segitu
# larut : larut
# beware : beware
# persubbab : subbab
# rung : rung
# ngisi : ngisi
# pwiss : pwiss
# memenuhi : penuh
# ilmu : ilmu
# biasnya : bias
# kucing : kucing
# menambah : tambah
# energi : energi
# haloruangguru : haloruangguru
# keperawatan : awat
# kefarmasiandan : kefarmasiandan
# teknik : teknik
# laboratorium : laboratorium
# medikjadi : medikjadi
# jurusannya : jurus
# yamasa : yamasa
# kesehatan : sehat
# sihmohon : sihmohon
# dikembangkan : kembang
# kecawa : kecawa
# segini : gin
# melulu : melulu
# menyelesaikan : selesai
# untukpihak : untukpihak
# kenqoa : kenqoa
# jawab : jawab
# terakhirnya : akhir
# usah : usah
# perlukan : perlu
# paketan : paket
# freeze : freeze
# pkt : pkt
# orangtua : orangtua
# mengeluarkan : keluar
# 600000 : 600000
# konrol : konrol
# woe : woe
# kelewat : lewat
# asw : asw
# amamaj : amamaj
# direspon : direspon
# dibandingin : dibandingin
# qr : qr
# disana : sana
# anaknya : anak
# rumus : rumus
# cepatnya : cepat
# ketimbang : ketimbang
# zonk : zonk
# contoh : contoh
# berhatihati : berhatihati
# memilih : pilih
# digunain : digunain
# sih : sih
# beserta : serta
# quiz : quiz
# menikmatinya : nikmat
# kakakabang : kakakabang
# enggak punya : enggak punya
# modal : modal
# kakbang : kakbang
# butuhkan : butuh
# mengakses : akses
# terjedah : terjedah
# langgana : langgana
# jeda : jeda
# keren : keren
# segi : segi
# ekonomi : ekonomi
# klamaan : klamaan
# inggrisnya : inggris
# banyakan : banyak
# mind : mind
# map : map
# keburuntunggan : keburuntunggan
# besok : besok
# aku : aku
# ditagih : tagih
# rp : rp
# 100000 : 100000
# ganiat : ganiat
# ajg : ajg
# zenius : zenius
# get : get
# contact : contact
# taunya : tau
# dibilang : bilang
# malamnya : malam
# misscall : misscall
# saya : saya
# lgii : lgii
# nglaig : nglaig
# chatny : chatny
# blokir : blokir
# aktivitas : aktivitas
# skem : skem
# bilang : bilang
# berkerja : kerja
# marahin : marahin
# pilih : pilih
# sukanya : suka
# lahlagi : lahlagi
# jwbnnya : jwbnnya
# dari : dari
# huft : huft
# disesuaikan : sesuai
# thanks : thanks
# yasama : yasama
# 3x : 3x
# transaksi : transaksi
# ditindaklanjuti : ditindaklanjuti
# ywojalh : ywojalh
# cantik : cantik
# nalah : nalah
# fokus : fokus
# maksud : maksud
# bagusnya : bagus
# operator : operator
# ditlp : ditlp
# mengaku : aku
# capslock : capslock
# profesional : profesional
# opeator : opeator
# tqs : tqs
# bangetmudah : bangetmudah
# durasi : durasi
# 4050 : 4050
# logo : logo
# perbaikannya : baik
# 0000 : 0000
# bangun : bangun
# akhrinya : akhrinya
# harry : harry
# diamond : diamond
# tiger : tiger
# lesu : lesu
# bangunnya : bangun
# atur : atur
# 1200 : 1200
# bermenitmenit : bermenitmenit
# skip : skip
# epep : epep
# ushul : ushul
# fiqh : fiqh
# jaya : jaya
# pokoknya : pokok
# aplikasihnya : aplikasihnya
# olimpiade : olimpiade
# ambon : ambon
# terimaiasih : terimaiasih
# pembuat : buat
# mantap : mantap
# terbaik : baik
# dunia : dunia
# pickup : pickup
# miliki : milik
# operasi : operasi
# militer : militer
# politik : politik
# menderita : derita
# je : je
# champions : champions
# uefa : uefa
# musim : musim
# panas : panas
# orang-orang : orang
# beriman : iman
# beramal : amal
# soleh : soleh
# solehah : solehah
# mejing : mejing
# gapyear : gapyear
# bantuan : bantu
# hyo : hyo
# best : best
# because : because
# spesifikasinya : spesifikasi
# really : really
# with : with
# understand : understand
# about : about
# each : each
# lesson : lesson
# enthusiastic : enthusiastic
# exploring : exploring
# every : every
# knowledge : knowledge
# day : day
# hope : hope
# support : support
# future : future
# even : even
# better : better
# interesting : interesting
# everyone : everyone
# interested : interested
# thank : thank
# much : much
# developers : developers
# mempermudah : mudah
# pekerjaan : kerja
# modul : modul
# dimasukkan : masuk
# didalam : dalam
# soalsoal : soalsoal
# menunjang : tunjang
# guruguru : guruguru
# anakpun : anak
# dalamnya : dalam
# memgerti : memgerti
# skor : skor
# worksheetnya : worksheetnya
# dibutuhkan : butuh
# mengoreksi : koreksi
# persiapannya : siap
# second : second
# device : device
# pclaptop : pclaptop
# pintar : pintar
# wawasan : wawas
# ruanggurudari : ruanggurudari
# pahamjuga : pahamjuga
# sulitjuga : sulitjuga
# dafadan : dafadan
# luluyang : luluyang
# usia : usia
# prasekolah : prasekolah
# love : love
# ngejar : ngejar
# baguus : baguus
# mudahh : mudahh
# laporkan : lapor
# kakaknyapembelajarannya : kakaknyapembelajarannya
# jiwa : jiwa
# baguuss : baguuss
# lengkapbelajar : lengkapbelajar
# top : top
# tampah : tampah
# 54 : 54
# gut : gut
# matematika : matematika
# matemetikakalo : matemetikakalo
# dijelasin : dijelasin
# permisi : permisi
# menarik : tarik
# plajari : plajari
# masbro : masbro
# membaca : baca
# bolehh : bolehh
# sehari : hari
# kah : kah
# rekomendasi : rekomendasi
# bermanfaatdan : bermanfaatdan
# sekolahan : sekolah
# anak-anak : anak
# ranting5 : ranting5
# dqri : dqri
# giat : giat
# menghitung : hitung
# menggukur : menggukur
# sudut : sudut
# phytagoras : phytagoras
# untung : untung
# pemahaman : paham
# baangget : baangget
# aplikadi : aplikadi
# tabisa : tabisa
# qjsudoeojoffikroeorrirutjyyri : qjsudoeojoffikroeorrirutjyyri
# fruuttugutir : fruuttugutir
# trik : trik
# ir : ir
# tiri : tiri
# taman : taman
# routoytyui : routoytyui
# yirritkhohohjonou : yirritkhohohjonou
# hridurugituuouih : hridurugituuouih
# today : today
# trigonometri : trigonometri
# huigititiriirurut : huigititiriirurut
# tuturu4u4uru : tuturu4u4uru
# ruhfhhdjujdjduduudfuuftryrehudfuufuufjggjugjgjg : ruhfhhdjujdjduduudfuuftryrehudfuufuufjggjugjgjg
# jgguutuguyru : jgguutuguyru
# gadis : gadis
# gr : gr
# daging : daging
# ayam : ayam
# i6 : i6
# berbagayrghtiihhjyigki : berbagayrghtiihhjyigki
# tempatku : tempat
# itiutktuykktu : itiutktuykktu
# uduu : uduu
# belajarsaya : belajarsaya
# soalsoalnya : soalsoalnya
# pembahasannya : bahas
# rebahan : rebah
# intinya : inti
# xyiqis : xyiqis
# memberika : memberika
# lumayanlah : lumayan
# volum : volum
# kubustabung : kubustabung
# pelajarin : pelajarin
# pemilihan : pilih
# rute : rute
# driver : driver
# seragam : seragam
# memudahkan : mudah
# kakaknya : kakak
# kegunaan : guna
# berkualitas : kualitas
# sembilan : sembilan
# andi : andi
# sekali : sekali
# unik : unik
# terpercaya : percaya
# menengah : tengah
# ujian : uji
# dev : dev
# knt : knt
# god : god
# reward : reward
# mengajar : ajar
# itu : itu
# kita : kita
# nya : nya
# pokok : pokok
# buatt : buatt
# berterimakasih : berterimakasih
# rekomend : rekomend
# semuaa : semuaa
# terkenal : kenal
# naira : naira
# salsabila : salsabila
# pipi : pipi
# vivi : vivi
# dina : dina
# naya : naya
# grbrugeuvskhuve : grbrugeuvskhuve
# jwuhruvlwhvrbhxisvnkechsgrirhrh73vehehehehhsbks : jwuhruvlwhvrbhxisvnkechsgrirhrh73vehehehehhsbks
#  : 
# anakmaterinya : anakmaterinya
# bagusguru : bagusguru
# pembimbing : bimbing
# baiktelitikompeten : baiktelitikompeten
# masingtrimakasih : masingtrimakasih
# maha : maha
# animasi : animasi
# dibawakan : bawa
# siswasiswi : siswasiswi
# rumah : rumah
# terjangkau : jangkau
# diluar : luar
# terpenting : penting
# ilmunya : ilmu
# kelaz : kelaz
# dirasa : rasa
# bahas : bahas
# ika : ika
# memberitahukan : memberitahukan
# dilengkapi : lengkap
# quiz2 : quiz2
# mengasah : asah
# tingkat : tingkat
# kepahaman : paham
# osnksn : osnksn
# bidangnya : bidang
# masingmasing : masingmasing
# beranimasi : animasi
# membahas : bahas
# soal2 : soal2
# osk : osk
# osp : osp
# osn : osn
# diterima : terima
# bimbingan : bimbing
# minn : minn
# keluarga : keluarga
# nice : nice
# saking : saking
# sadar : sadar
# belajarruang : belajarruang
# terbaikterima : terbaikterima
# sngat : sngat
# lawan : lawan
# bimble : bimble
# semakin : makin
# chuy : chuy
# melamar : lamar
# disuatu : suatu
# perusahan : usah
# hebat : hebat
# mengajarkan : ajar
# cucusaya : cucusaya
# mixsiu : mixsiu
# byr : byr
# diharapkan : harap
# dikembalikan : kembali
# membeliberlangganan : membeliberlangganan
# dibolehin : dibolehin
# thx : thx
# gratisnya : gratis
# indstri : indstri
# berpendidikan : didik
# meskii : meski
# didapatkan : dapat
# barbagai : barbagai
# silakan : sila
# temani : teman
# makaisnya : maka
# informatif : informatif
# trimakaciw : trimakaciw
# beast : beast
# l0 : l0
# inggris : inggris
# ipa : ipa
# mantab : mantab
# kudapat : dapat
# lupakanseperti : lupakanseperti
# kehidupan : hidup
# dberikan : dberikan
# seksamadari : seksamadari
# terbit : terbit
# matahari : matahari
# terbenamnya : benam
# ddekat : ddekat
# sayawalaupun : sayawalaupun
# manusia : manusia
# menyempurnakan : sempurna
# apps : apps
# rgtapi : rgtapi
# malam : malam
# jamnya : jam
# kesorean : sore
# nabrak : nabrak
# simpel : simpel
# dptdi : dptdi
# pemanfaatan : manfaat
# bsar : bsar
# ilustrasinya : ilustrasi
# jika : jika
# mengedepankan : depan
# mulaiterima : mulaiterima
# sukses : sukses
# mengasyik : asyik
# dipahi : pah
# guruterimakasih : guruterimakasih
# esmezing : esmezing
# wicis : wicis
# kul : kul
# af : af
# belajarjdi : belajarjdi
# berkat : berkat
# apapun : apa
# selamat : selamat
# worth : worth
# ngantuk : ngantuk
# peliharaan : pelihara
# hewanya : hewanya
# lucu : lucu
# dewasa : dewasa
# ketiga : tiga
# kerajinan : rajin
# pengetahuan : tahu
# 834403 : 834403
# facebook : facebook
# laznxcarlw : laznxcarlw
# apkx : apkx
# anakku : anak
# lovee : lovee
# guruu : guruu
# menghadapi : hadap
# snbtutbk : snbtutbk
# mendidik : didik
# nasional : nasional
# bangga : bangga
# biologi : biologi
# fisika : fisika
# praktikumnya : praktikum
# terbayang : bayang
# amazing : amazing
# ringking : ringking
# gara-gara : gara-gara
# its : its
# learning : learning
# help : help
# understanding : understanding
# school : school
# tes : tes
# awesome : awesome
# bagusmembantu : bagusmembantu
# urutnya : urut
# rank : rank
# 23 : 23
# donwload : donwload
# apalagii : apalagi
# libur : libur
# bisa : bisa
# meluangkan : luang
# bawaannya : bawa
# program : program
# cha : cha
# ching : ching
# progam : progam
# kedepan : depan
# mangkin : mangkin
# ya : ya
# baikdan : baikdan
# bangsa : bangsa
# besardan : besardan
# terussudah : terussudah
# kelass : kelass
# benerkeren : benerkeren
# naikk : naikk
# malasan : malas
# gurukeren : gurukeren
# apiikas : apiikas
# menajubkan : menajubkan
# bantuin : bantuin
# lolos : lolos
# kampus : kampus
# menyerukan : seru
# snmptnsbmptn : snmptnsbmptn
# serap : serap
# bekal : bekal
# non : non
# master : master
# semuah : semuah
# ulasan : ulas
# sakli : sakli
# peringkat : peringkat
# pulsa : pulsa
# rp25000 : rp25000
# institusi : institusi
# pendidikan : didik
# baikterutama : baikterutama
# elegan : elegan
# aplikasinnya : aplikasinnya
# wr : wr
# taala : taala
# wb : wb
# khalifahtul : khalifahtul
# rasyid : rasyid
# generasi : generasi
# prinsip : prinsip
# menjunjung : junjung
# perkembangan : kembang
# membaharui : baharu
# inovasi : inovasi
# setia : setia
# not : not
# have : have
# great : great
# serusekali : serusekali
# jokowi : jokowi
# dirumah : rumah
# dicerna : cerna
# gru : gru
# penuh : penuh
# tahunan : tahun
# aslii : asli
# recomen : recomen
# bismillah : bismillah
# axis : axis
# infertilitas : infertilitas
# adik : adik
# okee : okee
# sekedar : dar
# usulan : usul
# pembagian : bagi
# persemester : semester
# terimakasihh : terimakasihh
# sistematis : sistematis
# membimbing : bimbing
# amin : amin
# ifa : ifa
# dikata : kata
# culun : culun
# bodo : bodo
# mantul : mantul
# komen : komen
# benyak : benyak
# edit : edit
# ketagihan : tagih
# gold : gold
# goldnya : goldnya
# pakaian : pakai
# ranknyajadi : ranknyajadi
# stiker : stiker
# hadiah : hadiah
# 9 : 9
# robotguru : robotguru
# fix : fix
# salahnya : salah
# marahtidak : marahtidak
# becanda : becanda
# enteh : enteh
# menyukai : suka
# sukaak : sukaak
# mengapai : kapai
# mengadakan : ada
# meningkatkan : tingkat
# wah : wah
# boo : boo
# 9084 : 9084
# mematika : mematika
# apiksilnya : apiksilnya
# lembar : lembar
# mencatat : catat
# menggambar : gambar
# snang : snang
# dngn : dngn
# bohong : bohong
# kokk : kokk
# lmao : lmao
# membatu : batu
# pemberian : beri
# andai : andai
# mahasiswa : mahasiswa
# maba : maba
# tahap : tahap
# tpb : tpb
# berpengalaman : alam
# gurupengalaman : gurupengalaman
# most : most
# appropriate : appropriate
# gampanh : gampanh
# tipe : tipe
# visual : visual
# gratismenurut : gratismenurut
# gurusemoga : gurusemoga
# betah : betah
# belajarbikin : belajarbikin
# terstruktur : struktur
# latihannya : latih
# uptodate : uptodate
# syadr : syadr
# menjelaskanya : menjelaskanya
# sangngat : sangngat
# kepikiran : pikir
# stars : stars
# obsasinal : obsasinal
# sangatt : sangatt
# mambantu : mambantu
# terkonsep : konsep
# gila : gila
# mengetik : etik
# apalagitakjub : apalagitakjub
# bgtdi : bgtdi
# pelajarannilai : pelajarannilai
# trsgatau : trsgatau
# lagitp : lagitp
# manfaat : manfaat
# kerasa : rasa
# cocoa : cocoa
# until : until
# testing : testing
# {'roboguru': 'roboguru', 'beli': 'beli', 'paket': 'paket', 'video': 'video', 'diputar': 'putar', 'diunduh': 'unduh', 'eror': 'eror', 'menyesal': 'sesal', 'gue': 'gue', 'makai': 'maka', 'ruang': 'ruang', 'guru': 'guru', 'keluhan': 'keluh', 'link': 'link', 'web': 'web', 'xdari': 'xdari', 'notifikasi': 'notifikasi', 'ruangguru': 'ruangguru', 'buka': 'buka', 'semuakesel': 'semuakesel', 'banget': 'banget', 'mencoba': 'coba', 'pindah': 'pindah', 'lokasi': 'lokasi', 'siyalnya': 'siyalnya', 'full': 'full', 'loading': 'loading', 'errorpleaselah': 'errorpleaselah', 'tolong': 'tolong', 'jaga': 'jaga', 'kenyamanan': 'nyaman', 'aplikasi': 'aplikasi', 'jugasebenernya': 'jugasebenernya', 'tinggal': 'tinggal', 'jaringannya': 'jaring', 'ngebut': 'ngebut', 'nyaman': 'nyaman', 'pakai': 'pakai', 'pc': 'pc', 'letak': 'letak', 'drill': 'drill', 'maksa': 'maksa', 'langganan': 'langgan', 'jawabannya': 'jawab', 'salah': 'salah', 'kasih': 'kasih', 'ar': 'ar', 'ulangan': 'ulang', '92': '92', 'buruk': 'buruk', 'sudah': 'sudah', 'bagus': 'bagus', 'kadang': 'kadang', 'quiznya': 'quiznya', 'error': 'error', 'benar': 'benar', 'dapat': 'dapat', 'xp': 'xp', 'pelajaran': 'ajar', 'bintang': 'bintang', '4': '4', 'seru': 'seru', 'dafa': 'dafa', 'lulu': 'lulu', 'menyenangkan': 'senang', 'kecewa': 'kecewa', 'jawabanpenjelasan': 'jawabanpenjelasan', 'komputerleptop': 'komputerleptop', 'websitecrome': 'websitecrome', 'diaksesdan': 'diaksesdan', 'berlangganan': 'langgan', 'dibukaitu': 'dibukaitu', 'saran': 'saran', 'kesan': 'kesan', 'sayasaya': 'sayasaya', 'harap': 'harap', 'kedepannya': 'depan', 'penggunaan': 'guna', 'website': 'website', 'terbuka': 'buka', 'terimakasih': 'terimakasih', 'lumayan': 'lumayan', 'tuli': 'tuli', 'upgrade': 'upgrade', 'subtitle': 'subtitle', 'indonesia': 'indonesia', 'terima kasih': 'terima kasih', 'sumpah': 'sumpah', 'keluh': 'keluh', 'kesah': 'kesah', 'doang': 'doang', 'suport': 'suport', 'android': 'android', 'suruh': 'suruh', 'hh': 'hh', 'selesai': 'selesai', 'sekian': 'sekian', 'videonya': 'video', 'tulisanya': 'tulisanya', 'gagal': 'gagal', 'memuat': 'muat', 'coba': 'coba', '3': '3', 'nyobs': 'nyobs', 'mode': 'mode', 'online': 'online', 'offline': 'offline', 'tulisannya': 'tulis', 'kayak': 'kayak', 'belajar': 'ajar', 'susah': 'susah', 'hasil': 'hasil', 'screenshot': 'screenshot', 'mtk': 'mtk', 'wajib': 'wajib', 'minat': 'minat', 'dipisahkan': 'pisah', 'mudah': 'mudah', 'overall': 'overall', 'eemm': 'eemm', 'tanya': 'tanya', 'tutor': 'tutor', 'koinnya': 'koin', 'mahal': 'mahal', '1': '1', '15': '15', 'krg': 'krg', 'pas': 'pas', 'putus2': 'putus2', 'jaringan': 'jaring', 'lancar': 'lancar', 'maaf': 'maaf', 'kondisikan': 'kondisi', 'konsultannya': 'konsultan', 'menghubungi': 'hubung', 'chat': 'chat', 'telfon': 'telfon', 'risih': 'risih', 'berminat': 'minat', 'konfirmasi': 'konfirmasi', 'konsultanbeli': 'konsultanbeli', 'marketplace': 'marketplace', 'terima': 'terima', 'hapus': 'hapus', 'karena': 'karena', 'english': 'english', 'tagihan': 'tagih', 'burik': 'burik', 'sok': 'sok', 'pembahasan': 'bahas', 'banayak': 'banayak', 'netral': 'netral', 'aplikasinya': 'aplikasi', 'fitur': 'fitur', 'fiturnya': 'fiturnya', 'lengkap': 'lengkap', 'sayangnya': 'sayang', 'materi': 'materi', 'diakses': 'akses', 'gbng': 'gbng', 'instal': 'instal', 'smkwakwakwak': 'smkwakwakwak', 'jelek': 'jelek', 'bayar': 'bayar', '2': '2', 'komplen': 'komplen', 'berminggu2': 'berminggu2', 'penyelesaian': 'selesai', 'dianggap': 'anggap', 'bukti': 'bukti', 'disertakan': 'serta', 'download': 'download', 'dibukaerror': 'dibukaerror', 'sihkalau': 'sihkalau', 'dibenahi': 'benah', 'muat': 'muat', 'ulang': 'ulang', 'trussvidio': 'trussvidio', 'putar': 'putar', 'knpaa': 'knpaa', 'padhal': 'padhal', 'menonton': 'tonton', 'baca': 'baca', 'suka': 'suka', 'lola': 'lola', 'lobby': 'lobby', 'tetap': 'tetap', 'menekan': 'tekan', 'avatar': 'avatar', 'berubah': 'ubah', 'persis': 'persis', 'teman': 'teman', 'avayar': 'avayar', 'lan': 'lan', 'diubah': 'ubah', 'bari': 'bari', 'level': 'level',  ...
# ------------------------
# Pandas Apply:   0%|          | 0/936 [00:00<?, ?it/s]

# %%
df_skripsi
# Out:
#         label                                          text_real  \
# 0    Negative                    Roboguru harus beli paket… why?
# 1    Negative  Video nya ga bisa diputar, padahal udah diundu...
# 2    Negative  Eror terus video nya ,nyesel gue Makai ruang guru
# 3    Negative  Aku punya keluhan terhadap link web atau xdari...
# 4    Negative  halo ka, kalo buat PC letak drill soal nya ada...
# ..        ...                                                ...
# 993  Positive                      iya bagus banget aplikasi nya
# 994  Positive  Dari ruangguru ini cukup oke tapi tolong tamba...
# 995  Positive             Ruang guru dapat memahami pelajarannya
# 996  Positive  gila gila gila ! 3 kata tp gils bgt sih! Gatau...
# 997  Positive  Wah ruang guru ini cocoa until anak anak ya an...
#
#                                                   text  \
# 0                        roboguru harus beli paket why
# 1       video nya ga bisa diputar padahal udah diunduh
# 2     eror terus video nya nyesel gue makai ruang guru
# 3    aku punya keluhan terhadap link web atau xdari...
# 4    halo ka kalo buat pc letak drill soal nya ada ...
# ..                                                 ...
# 993                      iya bagus banget aplikasi nya
# 994  dari ruangguru ini cukup oke tapi tolong tamba...
# 995             ruang guru dapat memahami pelajarannya
# 996  gila gila gila 3 kata tp gils bgt sih gatau mo...
# 997  wah ruang guru ini cocoa until anak anak ya an...
#
#                                            text_tokens  \
# 0                  [roboguru, harus, beli, paket, why]
# 1    [video, nya, ga, bisa, diputar, padahal, udah,...
# 2    [eror, terus, video, nya, nyesel, gue, makai, ...
# 3    [aku, punya, keluhan, terhadap, link, web, ata...
# 4    [halo, ka, kalo, buat, pc, letak, drill, soal,...
# ..                                                 ...
# 993                [iya, bagus, banget, aplikasi, nya]
# 994  [dari, ruangguru, ini, cukup, oke, tapi, tolon...
# 995       [ruang, guru, dapat, memahami, pelajarannya]
# 996  [gila, gila, gila, 3, kata, tp, gils, bgt, sih...
# 997  [wah, ruang, guru, ini, cocoa, until, anak, an...
#
#                                              Stopwords  \
# 0                              [roboguru, beli, paket]
# 1                            [video, diputar, diunduh]
# 2       [eror, video, nyesel, gue, makai, ruang, guru]
# 3    [keluhan, link, web, xdari, notifikasi, ruangg...
# 4                                   [pc, letak, drill]
# ..                                                 ...
# 993                          [bagus, banget, aplikasi]
# 994  [ruangguru, oke, tolong, fitur, nomer, 10, ana...
# 995              [ruang, guru, memahami, pelajarannya]
# 996  [gila, gila, gila, 3, gils, gatau, ngetik, apa...
# 997  [ruang, guru, cocoa, until, anak, anak, anak, ...
#
#                                      text_tokens_fdist  \
# 0    {'roboguru': 1, 'harus': 1, 'beli': 1, 'paket'...
# 1    {'video': 1, 'nya': 1, 'ga': 1, 'bisa': 1, 'di...
# 2    {'eror': 1, 'terus': 1, 'video': 1, 'nya': 1, ...
# 3    {'aku': 2, 'punya': 1, 'keluhan': 1, 'terhadap...
# 4    {'halo': 1, 'ka': 1, 'kalo': 1, 'buat': 1, 'pc...
# ..                                                 ...
# 993  {'iya': 1, 'bagus': 1, 'banget': 1, 'aplikasi'...
# 994  {'dari': 1, 'ruangguru': 1, 'ini': 1, 'cukup':...
# 995  {'ruang': 1, 'guru': 1, 'dapat': 1, 'memahami'...
# 996  {'gila': 3, '3': 1, 'kata': 1, 'tp': 1, 'gils'...
# 997  {'wah': 1, 'ruang': 1, 'guru': 1, 'ini': 1, 'c...
#
#                                        text_normalized  \
# 0                              [roboguru, beli, paket]
# 1                            [video, diputar, diunduh]
# 2     [eror, video, menyesal, gue, makai, ruang, guru]
# 3    [keluhan, link, web, xdari, notifikasi, ruangg...
# 4                                   [pc, letak, drill]
# ..                                                 ...
# 993                          [bagus, banget, aplikasi]
# 994  [ruangguru, oke, tolong, fitur, nomer, 10, ana...
# 995              [ruang, guru, memahami, pelajarannya]
# 996  [gila, gila, gila, 3, gila, enggak tau, menget...
# 997  [ruang, guru, cocoa, until, anak, anak, anak, ...
#
#                                    text_tokens_stemmed
# 0                              [roboguru, beli, paket]
# 1                                [video, putar, unduh]
# 2         [eror, video, sesal, gue, maka, ruang, guru]
# 3    [keluh, link, web, xdari, notifikasi, ruanggur...
# 4                                   [pc, letak, drill]
# ..                                                 ...
# 993                          [bagus, banget, aplikasi]
# 994  [ruangguru, oke, tolong, fitur, nomer, 10, ana...
# 995                         [ruang, guru, paham, ajar]
# 996  [gila, gila, gila, 3, gila, enggak tau, etik, ...
# 997  [ruang, guru, cocoa, until, anak, anak, anak, ...
#
# [936 rows x 8 columns]

# %% [markdown]
# # Menampilkan Kembali Gabungan Data

# %%
def merge_again(text):
    return ' '.join(text)

# %%
df_skripsi['done_text'] = df_skripsi['text_tokens_stemmed'].apply(merge_again)
df_skripsi
# Out:
#         label                                          text_real  \
# 0    Negative                    Roboguru harus beli paket… why?
# 1    Negative  Video nya ga bisa diputar, padahal udah diundu...
# 2    Negative  Eror terus video nya ,nyesel gue Makai ruang guru
# 3    Negative  Aku punya keluhan terhadap link web atau xdari...
# 4    Negative  halo ka, kalo buat PC letak drill soal nya ada...
# ..        ...                                                ...
# 993  Positive                      iya bagus banget aplikasi nya
# 994  Positive  Dari ruangguru ini cukup oke tapi tolong tamba...
# 995  Positive             Ruang guru dapat memahami pelajarannya
# 996  Positive  gila gila gila ! 3 kata tp gils bgt sih! Gatau...
# 997  Positive  Wah ruang guru ini cocoa until anak anak ya an...
#
#                                                   text  \
# 0                        roboguru harus beli paket why
# 1       video nya ga bisa diputar padahal udah diunduh
# 2     eror terus video nya nyesel gue makai ruang guru
# 3    aku punya keluhan terhadap link web atau xdari...
# 4    halo ka kalo buat pc letak drill soal nya ada ...
# ..                                                 ...
# 993                      iya bagus banget aplikasi nya
# 994  dari ruangguru ini cukup oke tapi tolong tamba...
# 995             ruang guru dapat memahami pelajarannya
# 996  gila gila gila 3 kata tp gils bgt sih gatau mo...
# 997  wah ruang guru ini cocoa until anak anak ya an...
#
#                                            text_tokens  \
# 0                  [roboguru, harus, beli, paket, why]
# 1    [video, nya, ga, bisa, diputar, padahal, udah,...
# 2    [eror, terus, video, nya, nyesel, gue, makai, ...
# 3    [aku, punya, keluhan, terhadap, link, web, ata...
# 4    [halo, ka, kalo, buat, pc, letak, drill, soal,...
# ..                                                 ...
# 993                [iya, bagus, banget, aplikasi, nya]
# 994  [dari, ruangguru, ini, cukup, oke, tapi, tolon...
# 995       [ruang, guru, dapat, memahami, pelajarannya]
# 996  [gila, gila, gila, 3, kata, tp, gils, bgt, sih...
# 997  [wah, ruang, guru, ini, cocoa, until, anak, an...
#
#                                              Stopwords  \
# 0                              [roboguru, beli, paket]
# 1                            [video, diputar, diunduh]
# 2       [eror, video, nyesel, gue, makai, ruang, guru]
# 3    [keluhan, link, web, xdari, notifikasi, ruangg...
# 4                                   [pc, letak, drill]
# ..                                                 ...
# 993                          [bagus, banget, aplikasi]
# 994  [ruangguru, oke, tolong, fitur, nomer, 10, ana...
# 995              [ruang, guru, memahami, pelajarannya]
# 996  [gila, gila, gila, 3, gils, gatau, ngetik, apa...
# 997  [ruang, guru, cocoa, until, anak, anak, anak, ...
#
#                                      text_tokens_fdist  \
# 0    {'roboguru': 1, 'harus': 1, 'beli': 1, 'paket'...
# 1    {'video': 1, 'nya': 1, 'ga': 1, 'bisa': 1, 'di...
# 2    {'eror': 1, 'terus': 1, 'video': 1, 'nya': 1, ...
# 3    {'aku': 2, 'punya': 1, 'keluhan': 1, 'terhadap...
# 4    {'halo': 1, 'ka': 1, 'kalo': 1, 'buat': 1, 'pc...
# ..                                                 ...
# 993  {'iya': 1, 'bagus': 1, 'banget': 1, 'aplikasi'...
# 994  {'dari': 1, 'ruangguru': 1, 'ini': 1, 'cukup':...
# 995  {'ruang': 1, 'guru': 1, 'dapat': 1, 'memahami'...
# 996  {'gila': 3, '3': 1, 'kata': 1, 'tp': 1, 'gils'...
# 997  {'wah': 1, 'ruang': 1, 'guru': 1, 'ini': 1, 'c...
#
#                                        text_normalized  \
# 0                              [roboguru, beli, paket]
# 1                            [video, diputar, diunduh]
# 2     [eror, video, menyesal, gue, makai, ruang, guru]
# 3    [keluhan, link, web, xdari, notifikasi, ruangg...
# 4                                   [pc, letak, drill]
# ..                                                 ...
# 993                          [bagus, banget, aplikasi]
# 994  [ruangguru, oke, tolong, fitur, nomer, 10, ana...
# 995              [ruang, guru, memahami, pelajarannya]
# 996  [gila, gila, gila, 3, gila, enggak tau, menget...
# 997  [ruang, guru, cocoa, until, anak, anak, anak, ...
#
#                                    text_tokens_stemmed  \
# 0                              [roboguru, beli, paket]
# 1                                [video, putar, unduh]
# 2         [eror, video, sesal, gue, maka, ruang, guru]
# 3    [keluh, link, web, xdari, notifikasi, ruanggur...
# 4                                   [pc, letak, drill]
# ..                                                 ...
# 993                          [bagus, banget, aplikasi]
# 994  [ruangguru, oke, tolong, fitur, nomer, 10, ana...
# 995                         [ruang, guru, paham, ajar]
# 996  [gila, gila, gila, 3, gila, enggak tau, etik, ...
# 997  [ruang, guru, cocoa, until, anak, anak, anak, ...
#
#                                              done_text
# 0                                  roboguru beli paket
# 1                                    video putar unduh
# 2                 eror video sesal gue maka ruang guru
# 3    keluh link web xdari notifikasi ruangguru buka...
# 4                                       pc letak drill
# ..                                                 ...
# 993                              bagus banget aplikasi
# 994  ruangguru oke tolong fitur nomer 10 anak ajar ...
# 995                              ruang guru paham ajar
# 996  gila gila gila 3 gila enggak tau etik apalagit...
# 997  ruang guru cocoa until anak anak anak testing ...
#
# [936 rows x 9 columns]

# %%
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# %%
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer

# %%
tfid = TfidfVectorizer(
    min_df = 3,
    max_df = 0.10,
    ngram_range = (1,2)
)

# %%
count_vect = CountVectorizer(
    min_df = 3,
    max_df = 0.10,
    ngram_range = (1,2)
)

# %%
tfid_result = tfid.fit_transform(df_skripsi["done_text"]).toarray()
tfid_df = pd.DataFrame(tfid_result, columns = tfid.get_feature_names())
tfid_df.columns = ["word_" + str(x) for x in tfid_df.columns]
tfid_df.index = df_skripsi.index
# new_data = pd.concat([, tfid_df], axis=1)

# %%
tfid_df.columns
# Out:
# Index(['word_10', 'word_academy', 'word_ada', 'word_adapto', 'word_admin',
#        'word_ajar ajar', 'word_ajar bagus', 'word_ajar bahasa',
#        'word_ajar baik', 'word_ajar bosan',
#        ...
#        'word_video loading', 'word_video putar', 'word_vidio', 'word_vidionya',
#        'word_wajib', 'word_wajib banget', 'word_web', 'word_whatsapp',
#        'word_wifi', 'word_youtube'],
#       dtype='object', length=539)

# %%
cvzr_result = count_vect.fit_transform(df_skripsi["done_text"]).toarray()
cvzr_df = pd.DataFrame(cvzr_result, columns = count_vect.get_feature_names())
cvzr_df.columns = ["word_" + str(x) for x in cvzr_df.columns]
cvzr_df.index = df_skripsi.index
# new_data = pd.concat([, tfid_df], axis=1)

# %% [markdown]
# # Menampilkan Label kolom

# %%
kolomcv = cvzr_df.columns
kolomcv
# Out:
# Index(['word_10', 'word_academy', 'word_ada', 'word_adapto', 'word_admin',
#        'word_ajar ajar', 'word_ajar bagus', 'word_ajar bahasa',
#        'word_ajar baik', 'word_ajar bosan',
#        ...
#        'word_video loading', 'word_video putar', 'word_vidio', 'word_vidionya',
#        'word_wajib', 'word_wajib banget', 'word_web', 'word_whatsapp',
#        'word_wifi', 'word_youtube'],
#       dtype='object', length=539)

# %% [markdown]
# # Menampilkan Hasil classification

# %%
y = df_skripsi.label

# %%
X = cvzr_df.to_numpy()
y = df_skripsi.label
y_pred = cross_val_predict(clf, X, y, cv=5)
conf_mat = confusion_matrix(y_pred, y)

# %%
print(conf_mat)
print(classification_report(y, y_pred, digits = 4))
# Out:
# [[364  46]
#  [134 392]]
#               precision    recall  f1-score   support
#
#     Negative     0.8878    0.7309    0.8018       498
#     Positive     0.7452    0.8950    0.8133       438
#
#     accuracy                         0.8077       936
#    macro avg     0.8165    0.8130    0.8075       936
# weighted avg     0.8211    0.8077    0.8072       936

# %% [markdown]
# # Menampilkan Hasil Naive Bayes

# %%
print('Naive Bayes')
X = cvzr_df.to_numpy()
y = df_skripsi.label
y_pred = cross_val_predict(nb, X, y, cv=10)
conf_mat = confusion_matrix(y_pred, y)
print(conf_mat)
print(classification_report(y, y_pred, digits = 4))
# Out:
# Naive Bayes
# [[363  57]
#  [135 381]]
#               precision    recall  f1-score   support
#
#     Negative     0.8643    0.7289    0.7908       498
#     Positive     0.7384    0.8699    0.7987       438
#
#     accuracy                         0.7949       936
#    macro avg     0.8013    0.7994    0.7948       936
# weighted avg     0.8054    0.7949    0.7945       936

# %%
print('Naive Bayes')
X = tfid_df.to_numpy()
y = df_skripsi.label
y_pred = cross_val_predict(nb, X, y, cv=10)
conf_mat = confusion_matrix(y_pred, y)
print(conf_mat)
print(classification_report(y, y_pred, digits = 4))
# Out:
# Naive Bayes
# [[373  68]
#  [125 370]]
#               precision    recall  f1-score   support
#
#     Negative     0.8458    0.7490    0.7945       498
#     Positive     0.7475    0.8447    0.7931       438
#
#     accuracy                         0.7938       936
#    macro avg     0.7966    0.7969    0.7938       936
# weighted avg     0.7998    0.7938    0.7938       936

# %% [markdown]
# # Menampilkan Hasil K-Nearest Neighbor

# %%
print('KNN')
X = cvzr_df.to_numpy()
y = df_skripsi.label
y_pred = cross_val_predict(knn, X, y, cv=10)
conf_mat = confusion_matrix(y_pred, y)
print(conf_mat)
print(classification_report(y, y_pred, digits = 4))
# Out:
# KNN
# [[161  19]
#  [337 419]]
#               precision    recall  f1-score   support
#
#     Negative     0.8944    0.3233    0.4749       498
#     Positive     0.5542    0.9566    0.7018       438
#
#     accuracy                         0.6197       936
#    macro avg     0.7243    0.6400    0.5884       936
# weighted avg     0.7352    0.6197    0.5811       936

# %%
print('KNN')
X = tfid_df.to_numpy()
y = df_skripsi.label
y_pred = cross_val_predict(knn, X, y, cv=10)
conf_mat = confusion_matrix(y_pred, y)
print(conf_mat)
print(classification_report(y, y_pred, digits = 4))
# Out:
# KNN
# [[489 306]
#  [  9 132]]
#               precision    recall  f1-score   support
#
#     Negative     0.6151    0.9819    0.7564       498
#     Positive     0.9362    0.3014    0.4560       438
#
#     accuracy                         0.6635       936
#    macro avg     0.7756    0.6416    0.6062       936
# weighted avg     0.7653    0.6635    0.6158       936

# %% [markdown]
# # Menampilkan Hasil Support Vector Machine

# %%
print('SVM')
X = cvzr_df.to_numpy()
y = df_skripsi.label
y_pred = cross_val_predict(svm, X, y, cv=10)
conf_mat = confusion_matrix(y_pred, y)
print(conf_mat)
print(classification_report(y, y_pred, digits = 4))
# Out:
# SVM
# [[366  68]
#  [132 370]]
#               precision    recall  f1-score   support
#
#     Negative     0.8433    0.7349    0.7854       498
#     Positive     0.7371    0.8447    0.7872       438
#
#     accuracy                         0.7863       936
#    macro avg     0.7902    0.7898    0.7863       936
# weighted avg     0.7936    0.7863    0.7863       936

# %%
print('SVM')
X = cvzr_df.to_numpy()
y = df_skripsi.label
y_pred = cross_val_predict(svm, X, y, cv=10)
conf_mat = confusion_matrix(y_pred, y)
print(conf_mat)
print(classification_report(y, y_pred, digits = 4))
# Out:
# SVM
# [[366  68]
#  [132 370]]
#               precision    recall  f1-score   support
#
#     Negative     0.8433    0.7349    0.7854       498
#     Positive     0.7371    0.8447    0.7872       438
#
#     accuracy                         0.7863       936
#    macro avg     0.7902    0.7898    0.7863       936
# weighted avg     0.7936    0.7863    0.7863       936

# %% [markdown]
# # Menampilkan Hasil Random Forest

# %%
print('Random Forest')
X = cvzr_df.to_numpy()
y = df_skripsi.label
y_pred = cross_val_predict(clf, X, y, cv=10)
conf_mat = confusion_matrix(y_pred, y)
print(conf_mat)
print(classification_report(y, y_pred, digits = 4))
# Out:
# Random Forest
# [[370  44]
#  [128 394]]
#               precision    recall  f1-score   support
#
#     Negative     0.8937    0.7430    0.8114       498
#     Positive     0.7548    0.8995    0.8208       438
#
#     accuracy                         0.8162       936
#    macro avg     0.8243    0.8213    0.8161       936
# weighted avg     0.8287    0.8162    0.8158       936

# %%
print('Random Forest')
X = tfid_df.to_numpy()
y = df_skripsi.label
y_pred = cross_val_predict(clf, X, y, cv=10)
conf_mat = confusion_matrix(y_pred, y)
print(conf_mat)
print(classification_report(y, y_pred, digits = 4))
# Out:
# Random Forest
# [[374  51]
#  [124 387]]
#               precision    recall  f1-score   support
#
#     Negative     0.8800    0.7510    0.8104       498
#     Positive     0.7573    0.8836    0.8156       438
#
#     accuracy                         0.8130       936
#    macro avg     0.8187    0.8173    0.8130       936
# weighted avg     0.8226    0.8130    0.8128       936

# %% [markdown]
# # Membuat Wordcloud

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

# %%
SemuaText = "".join(df_skripsi['done_text'])

def create_wordcloud(text, filename): 
    stopwords = set(STOPWORDS)

    wc = WordCloud(background_color="white",
                   max_words=200,
                   stopwords=stopwords)

    wc.generate(text)
    wc.to_file(filename+".png")
    plt.figure()
    plt.imshow(wc, interpolation="bilinear")
    plt.axis("off")
    plt.show()

# %%
SemuaText
# Out:
# 'roboguru beli paketvideo putar unduheror video sesal gue maka ruang gurukeluh link web xdari notifikasi ruangguru buka semuakesel banget coba pindah lokasi siyalnya full loading errorpleaselah tolong banget jaga nyaman aplikasi jugasebenernya tinggal jaring ngebut nyaman pakai ruanggurupc letak drillmaksa langganjawab salahkasih ar salah ulang 92 buruksudah bagus kadang quiznya error benar dapat xpaplikasi bagus banget ajar kasih bintang 4 seru banget video dafa lulu seru bangetaplikasi ruang guru senang kecewa jawabanpenjelasan komputerleptop websitecrome diaksesdan langgan langgan dibukaitu saran kesan sayasaya harap depan guna ruang guru website buka bagus terimakasihlumayan tuli tolong upgrade subtitle indonesia tuli terima kasihbangetsumpah keluh kesah doang ruang guru suport android suruh pindah web hh selesai benar ruang guru sekian terimakasihtolong video tulisanya gagal muat video coba 3 nyobs coba buka video mode online offline tulis kayak ajar susahtolong hasil screenshot mtk wajib minat pisah mudah terimakasihoverall bagus eemm tanya tutor koin mahal 1 15 krg pas tutorvideo putus2 jaring lancar langganmaaf tolong kondisi konsultan 1 hubung chat telfon risih minat langgan konfirmasi salah konsultanbeli paket marketplace terima kasihhapus karena ajar english tagihburiksokbahas banayaknetralaplikasi bagus fitur fiturnya lengkap sayang materi ajar lengkap error aksesgbnginstal smkwakwakwakjelek banget aplikasi bayar 2 komplen berminggu2 selesai anggap beli paket ajar bukti sertadownload video banget jaring bagusaplikasi bagus langgan video dibukaerror sihkalau tolong benahsuruh muat ulang trussvidio putar knpaa padhal sudah langganjelek langgan tonton download sesalruang baca suka lolalobby tetap pas tekan avatar ubah persis teman lobby avayar lan ubah bari level 82 rgburiekjujur banguss banget ganggu spam messageganti paket langgan salah beli kemarin coba ganti web salah sistem terus pakai wifi tiket ganti paket 2 telah tiket paket ganti takut 7 ganti butuh ajar moga ganti paket cepat terimakasihmaaf bintang suka langgan duit bayarkenapa enggak mapel bhsa daerah pertanianseni budaya pakarya informatika mapel sekolahkemarin tutor lupa kasih nilai guru ingat kasih nilai guru pas selesai asih bintang pas ku pencet kirim muncul tulis begini invalid response was received upstream server tolong kasih solusiapk pas download video offline tulis tunggu antri download 1 pakai wifi jaring aman pakai download apk kisar 50 atas video cepat download video 10 tolong baiktipu fitur roboguru plus guru nama dinna sesuai foto tolong tindaklanjutisemenjak lihat bayar gaenakfitur hp sudah bagusdi laptop jelek banget sistem download video tonton offline laptop banget simpan laptop banding hpmateri ajar bagus lengkap lengkap bayarnomer kirim tawar kayak teror pinjolawalawal langgan fitur nama roboguru plus pakai koin harga beli lumayan beli sesi 1 koin nanyain terus fitur roboguru plus sesi 1 sesi ngabisin koin harga lumayan kecewa atur ubah begini harga koin turunaneh pas langgan roboguru pakai terus google pas langgan batesnya google gilir roboguru rg pakai batesruangguru bagus anak langgan lounching maaf panjang serasa koyak oyakpdhl langgan 1 2 semester smstr 2 tolong langgan perhati yakin cocok tetap panjangmateri mudah paham tingkat fitur adapto kuis video tibatiba buram bergarisgarislanggan video niat ajar bayar uangsuka tampilantingkatknkenapa gratisaplikasi bagus kadang bug musik pas ganggu bangetapkkoneksi suka error suka force close heran hp poco 3 pro chipsetnya snapdragon 800ruang gurumalas langgan mahal banget 1lumayan ajar baik putar video ajar loading hewan ajar sakitbalikin fitur nyicil pengin beli tapi lagi hemat uang dkembaiin pasti langganaffah iya jelekbututminimal difix apk rilis poling lantai masih ngawurthis application very live suka lagenggak usah langgan sesal parahsuka ruangguru sulit bandingreting suruh paksaburikakses video ajar susah loading jaring bagus ruang simpan luaslanggan fitur fungsi loading tolong ba ...

# %%
create_wordcloud(SemuaText,"Semua Sentimen")

# %%
komenpositif= df_skripsi[df_skripsi['label'] == "Positive"]

# %%
Positive = "".join(komenpositif['done_text'])

def create_wordcloud(text, filename): 
    stopwords = set(STOPWORDS)

    wc = WordCloud(background_color="white",
                   max_words=200,
                   stopwords=stopwords)

    wc.generate(text)
    wc.to_file(filename+".png")
    plt.figure()
    plt.imshow(wc, interpolation="bilinear")
    plt.axis("off")
    plt.show()

# %%
create_wordcloud(Positive,"Semua Positive")

# %%
komennegatif= df_skripsi[df_skripsi['label'] == "Negative"]

# %%
Negative = "".join(komennegatif['done_text'])

def create_wordcloud(text, filename): 
    stopwords = set(STOPWORDS)

    wc = WordCloud(background_color="white",
                   max_words=200,
                   stopwords=stopwords)

    wc.generate(text)
    wc.to_file(filename+".png")
    plt.figure()
    plt.imshow(wc, interpolation="bilinear")
    plt.axis("off")
    plt.show()

# %%
create_wordcloud(Negative,"Semua Negative")
